# %% [markdown]
# # HARDWARE

# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

"""
To change attributes:
1) Change ATTRIBUTE and you're good to go
"""
ATTRIBUTE = 'polarity'
COUNTER = '_baseline2'
PARALLEL = 20
PARALLEL_EXTRACTION = 8
DEV_SIZE = 125

import os
import sys
sys.path.append(os.environ['SNORKELHOME'] + '/tutorials/tables/')
snorkel_postgres = os.environ['SNORKELDB'].startswith('postgres')
print snorkel_postgres
# Out:
# True

# %%
import os
if snorkel_postgres:
    os.environ['SNORKELDBNAME'] = ATTRIBUTE + str(COUNTER)
    print os.system("dropdb " + os.environ['SNORKELDBNAME'])
    print os.system("createdb " + os.environ['SNORKELDBNAME'])
    print "SNORKELDBNAME = %s" % os.environ['SNORKELDBNAME']
else:
    try:
        os.remove('snorkel.db')
    except:
        pass

from snorkel import SnorkelSession
session = SnorkelSession()
# Out:
# 256
# 0
# SNORKELDBNAME = polarity_baseline2

# %% [markdown]
# ## Parsing

# %%
import os
if snorkel_postgres:
    from snorkel.async_parser import parse_corpus, HTMLParser, AsyncOmniParser
    print "Starting async parse..."
    
    # PARSE DEV
    docs_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/dev/html/'
    pdf_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/dev/pdf/'
    doc_parser = HTMLParser()
    context_parser = AsyncOmniParser(blacklist=['style'], flatten=['span','br'], 
                                     tabular=True, lingual=True,
                                     visual=True, pdf_path=pdf_path)
    # %time corpus = parse_corpus(session, 'Hardware Dev', docs_path,\
                                doc_parser, context_parser,\
                                max_docs=DEV_SIZE, parallel=PARALLEL)
    print "%s contains %d documents" % (corpus, len(corpus))
else:
    from snorkel.parser import CorpusParser, HTMLParser, OmniParser
    from snorkel.utils import get_ORM_instance
    from snorkel.queries import split_corpus

    print "Starting sync parse..."
    
    # PARSE DEV
    docs_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/dev/html/'
    pdf_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/dev/pdf/'
    doc_parser = HTMLParser(path=docs_path)
    context_parser = AsyncOmniParser(blacklist=['style'], flatten=['span','br'], 
                                 tabular=True, lingual=True,
                                 visual=True, pdf_path=pdf_path)
    cp = CorpusParser(doc_parser, context_parser, max_docs=125)

    # %time corpus = cp.parse_corpus(name='Hardware Dev', session=session)
    print "%s contains %d documents" % (corpus, len(corpus))
    session.add(corpus)
    session.commit()
# Out:
# Starting async parse...
# [========================================] 100%
# CPU times: user 412 ms, sys: 180 ms, total: 592 ms
# Wall time: 1min 16s
# Corpus (Hardware Dev) contains 122 documents

# %% [markdown]
# ### Save Corpus

# %%
# If necessary
if not snorkel_postgres:
    import os
    os.system('cp snorkel.db snorkel.db\ corpus');

# %% [markdown]
# ## Extraction

# %%
from snorkel.models import candidate_subclass

Part_Attr = candidate_subclass('Part_Attr', ['part','attr'])

# %% [markdown]
# ### Define Matchers

# %%
from hardware_matchers import get_matcher

part_matcher = get_matcher('part_rgx')
attr_matcher = get_matcher(ATTRIBUTE)

# %% [markdown]
# ### Define ContextSpaces

# %%
from hardware_spaces import get_space
from hardware_spaces import OmniNgramsPart
    
part_ngrams = OmniNgramsPart(n_max=3, expand=False)
attr_ngrams = get_space(ATTRIBUTE)

# %% [markdown]
# ### Run CandidateExtractor

# %%
from snorkel.models import Corpus
from snorkel.candidates import CandidateExtractor
from snorkel.utils import get_ORM_instance
from snorkel.async_candidates import parallel_extract

ce = CandidateExtractor(Part_Attr, 
                        [part_ngrams, attr_ngrams], 
                        [part_matcher, attr_matcher], 
                        throttler=None)


for corpus_name in ['Hardware Dev']:
    corpus = get_ORM_instance(Corpus, session, corpus_name)
    print "Extracting Candidates from %s" % corpus
    # %time candidates = parallel_extract(session, ce, corpus, \
                                        corpus_name + ' Candidates', \
                                        parallel=PARALLEL_EXTRACTION)
    session.add(candidates)
    print "%s contains %d Candidates" % (candidates, len(candidates))
session.commit()
# Out:
# Extracting Candidates from Corpus (Hardware Dev)
# [========================================] 100%
# CPU times: user 308 ms, sys: 184 ms, total: 492 ms
# Wall time: 20.3 s
# Candidate Set (Hardware Dev Candidates) contains 32156 Candidates

# %% [markdown]
# ## Apply Rules

# %%
from snorkel.lf_helpers import is_horz_aligned, get_horz_ngrams

def baseline_rules(c):
    if ((not c.part.is_tabular() or is_horz_aligned(c))):
        return True
    else:
        return False

passing_candidates = set()
for c in candidates:
    if baseline_rules(c):
        passing_candidates.add(c)

print "%d/%d candidates accepted" % (len(passing_candidates), len(candidates))
# Out:
# 15300/32156 candidates accepted

# %%
from snorkel.models import Corpus
from hardware_utils import entity_level_f1_from_candidates
import os

gold_file = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/dev/hardware_dev_gold.csv'
corpus = session.query(Corpus).filter(Corpus.name == 'Hardware Dev').one()
(TP, FP, FN) = entity_level_f1_from_candidates(passing_candidates, gold_file, ATTRIBUTE, corpus)
# Out:
# Preparing candidates...
# [========================================] 100%
# ========================================
# Scoring on Entity-Level Gold Data
# ========================================
# Corpus Precision 0.442
# Corpus Recall    0.483
# Corpus F1        0.462
# ----------------------------------------
# TP: 448 | FP: 565 | FN: 479
# ========================================

# %%
from pprint import pprint
pprint(FP)
# Out:
# [(u'AUKCS04635-1', u'2N3904', u'PNP'),
#  (u'BC337', u'BC327', u'NPN'),
#  (u'BC337', u'BC328', u'NPN'),
#  (u'BC337-D', u'BC337-XX', u'NPN'),
#  (u'BC546', u'BC556', u'NPN'),
#  (u'BC546', u'BC557', u'NPN'),
#  (u'BC546', u'BC558', u'NPN'),
#  (u'BC546', u'BC559', u'NPN'),
#  (u'BC546', u'BC560', u'NPN'),
#  (u'BC546-BC548C(TO-92)', u'BC546-BC548C', u'NPN'),
#  (u'BC546_DIOTEC', u'BC546', u'PNP'),
#  (u'BC546_DIOTEC', u'BC546A', u'PNP'),
#  (u'BC546_DIOTEC', u'BC546B', u'PNP'),
#  (u'BC546_DIOTEC', u'BC547', u'PNP'),
#  (u'BC546_DIOTEC', u'BC547A', u'PNP'),
#  (u'BC546_DIOTEC', u'BC547B', u'PNP'),
#  (u'BC546_DIOTEC', u'BC547C', u'PNP'),
#  (u'BC546_DIOTEC', u'BC548', u'PNP'),
#  (u'BC546_DIOTEC', u'BC548A', u'PNP'),
#  (u'BC546_DIOTEC', u'BC548B', u'PNP'),
#  (u'BC546_DIOTEC', u'BC548C', u'PNP'),
#  (u'BC546_DIOTEC', u'BC549', u'PNP'),
#  (u'BC546_DIOTEC', u'BC549B', u'PNP'),
#  (u'BC546_DIOTEC', u'BC549C', u'PNP'),
#  (u'BC546_DIOTEC', u'BC556', u'NPN'),
#  (u'BC546_DIOTEC', u'BC556', u'PNP'),
#  (u'DISES00645-1', u'BC808K', u'PNP'),
#  (u'DISES00645-1', u'BC817K', u'PNP'),
#  (u'DISES00645-1', u'BC817K-16', u'PNP'),
#  (u'DISES00645-1', u'BC817K-25', u'PNP'),
#  (u'DISES00645-1', u'BC817K-40', u'PNP'),
#  (u'DISES00645-1', u'BC818K', u'PNP'),
#  (u'DISES00645-1', u'BC818K-16', u'PNP'),
#  (u'DISES00645-1', u'BC818K-25', u'PNP'),
#  (u'DISES00645-1', u'BC818K-40', u'PNP'),
#  (u'DTC114W', u'DTC114W', u'PNP'),
#  (u'FAIRS19194-1', u'BC846', u'PNP'),
#  (u'FAIRS19194-1', u'BC847', u'PNP'),
#  (u'FAIRS19194-1', u'BC848', u'PNP'),
#  (u'FAIRS19194-1', u'BC849', u'PNP'),
#  (u'FAIRS19194-1', u'BC850', u'PNP'),
#  (u'INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', u'AN077', u'NPN'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'AN077',
#   u'NPN'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'AN077',
#   u'PNP'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC856-BC860',
#   u'NPN'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC856-BC860',
#   u'PNP'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857',
#   u'NPN'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857BL3',
#   u'NPN'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857W',
#   u'NPN'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857W',
#   u'PNP'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857W-BC860W',
#   u'NPN'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857W-BC860W',
#   u'PNP'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC858',
#   u'NPN'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC858W',
#   u'NPN'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC858W',
#   u'PNP'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC859',
#   u'NPN'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC859W',
#   u'NPN'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC859W',
#   u'PNP'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC860',
#   u'NPN'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC860W',
#   u'NPN'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC860W',
#   u'PNP'),
#  (u'INFNS19372-1', u'AN077', u'NPN'),
#  (u'INFNS19372-1', u'MMBT3906', u'NPN'),
#  (u'INFNS19372-1', u'SMBT3906', u'NPN'),
#  (u'KECCS03676-1', u'BC846', u'NPN'),
#  (u'KECCS03676-1', u'BC846', u'PNP'),
#  (u'KECCS03676-1', u'BC847', u'NPN'),
#  (u'KECCS03676-1', u'BC847', u'PNP'),
#  (u'KECCS03676-1', u'BC848', u'NPN'),
#  (u'KECCS03676-1', u'BC848', u'PNP'),
#  (u'KECCS03676-1', u'BC856', u'NPN'),
#  (u'KECCS03676-1', u'BC857', u'NPN'),
#  (u'KECCS03676-1', u'BC858', u'NPN'),
#  (u'KECCS05435-1', u'BC546', u'PNP'),
#  (u'KECCS05435-1', u'BC547', u'PNP'),
#  (u'KECCS05435-1', u'BC548', u'PNP'),
#  (u'KECCS05435-1', u'BC556', u'NPN'),
#  (u'KECCS05435-1', u'BC556', u'PNP'),
#  (u'KECCS05435-1', u'BC557', u'NPN'),
#  (u'KECCS05435-1', u'BC557', u'PNP'),
#  (u'KECCS05435-1', u'BC558', u'NPN'),
#  (u'KECCS05435-1', u'BC558', u'PNP'),
#  (u'LITES00424-1', u'2N3904', u'NPN'),
#  (u'LITES00424-1', u'2N3904', u'PNP'),
#  (u'LITES00424-1', u'2N3906', u'NPN'),
#  (u'LITES00424-1', u'MMBT3906', u'NPN'),
#  (u'LITES00424-1', u'MMBT3906', u'PNP'),
#  (u'LITES00690-1', u'BC546', u'PNP'),
#  (u'LITES00690-1', u'BC547', u'PNP'),
#  (u'LITES00690-1', u'BC548', u'PNP'),
#  (u'LITES00690-1', u'BC556', u'NPN'),
#  (u'LITES00690-1', u'BC556', u'PNP'),
#  (u'LITES00690-1', u'BC557', u'NPN'),
#  (u'LITES00690-1', u'BC557', u'PNP'),
#  (u'LITES00690-1', u'BC558', u'NPN'),
#  (u'LITES00690-1', u'BC558', u'PNP'),
#  (u'LTSCS02910-1', u'BC818-REV', u'NPN'),
#  (u'LTSCS02912-1', u'BC846W-REV', u'NPN'),
#  (u'LTSCS02920-1', u'BC857-REV', u'PNP'),
#  (u'MCCCS09540-1', u'BC846A-BC849C', u'NPN'),
#  (u'MICROCOMMERCIALCO_TIP29ABP', u'TIP29', u'PNP'),
#  (u'MICROCOMMERCIALCO_TIP29ABP', u'TIP
#  (u'PNJIS01593-1', u'BC849', u'PNP'),
#  (u'RECTS01158-1', u'BC807-25', u'NPN'),
#  (u'RECTS01158-1', u'BC807-25LT1', u'NPN'),
#  (u'RECTS01158-1', u'BC807-25LT1', u'PNP'),
#  (u'RECTS01158-1', u'BC817', u'NPN'),
#  (u'RECTS01158-1', u'BC817', u'PNP'),
#  (u'RECTS01214-1', u'DTC114ECA-1', u'NPN'),
#  (u'RECTS01242-1', u'BC857BLT1', u'PNP'),
#  (u'RECTS01325-1', u'DTC114YCA-1', u'NPN'),
#  (u'SANKEN_2SC4886', u'2SA1860', u'NPN'),
#  (u'SANKEN_2SD2643', u'2SB1687', u'NPN'),
#  (u'SANKEN_STD01N', u'STD01', u'NPN'),
#  (u'SANKEN_STD01N', u'STD01', u'PNP'),
#  (u'SANKEN_STD01N', u'STD01N', u'PNP'),
#  (u'SANKEN_STD01N', u'STD01P', u'NPN'),
#  (u'SGSTS13702-1', u'BC547B', u'PNP'),
#  (u'SGSTS13702-1', u'BC547C', u'PNP'),
#  (u'SGSTS13702-1', u'BC557B', u'NPN'),
#  (u'SGSTS13702-1', u'BC557B', u'PNP'),
#  (u'SGSTS13734-1', u'BC327-25', u'NPN'),
#  (u'SGSTS13734-1', u'BC327-25', u'PNP'),
#  (u'SGSTS13734-1', u'BC327-40', u'NPN'),
#  (u'SGSTS13734-1', u'BC327-40', u'PNP'),
#  (u'SGSTS13734-1', u'BC337-25', u'PNP'),
#  (u'SGSTS13734-1', u'BC337-40', u'PNP'),
#  (u'TWSCS04757-1', u'BC807', u'NPN'),
#  (u'TWSCS04757-1', u'BC807', u'PNP'),
#  (u'TWSCS04757-1', u'BC807-16', u'NPN'),
#  (u'TWSCS04757-1', u'BC807-XX', u'NPN'),
#  (u'TWSCS04757-1', u'BC817', u'NPN'),
#  (u'TWSCS04757-1', u'BC817', u'PNP'),
#  (u'UTCLS01324-1', u'MMBT3904-E', u'NPN'),
#  (u'UTCLS01324-1', u'MMBT3906', u'NPN'),
#  (u'UTCLS03593-1', u'DTC114E-I', u'NPN'),
#  (u'VISHS23888-1', u'BC546', u'PNP'),
#  (u'VISHS23888-1', u'BC547', u'PNP'),
#  (u'VISHS23888-1', u'BC548', u'PNP'),
#  (u'VISHS23888-1', u'BC549', u'PNP'),
#  (u'VISHS23888-1', u'BC556', u'NPN'),
#  (u'VISHS23888-1', u'BC556', u'PNP'),
#  (u'VISHS23888-1', u'BC557', u'NPN'),
#  (u'VISHS23888-1', u'BC557', u'PNP'),
#  (u'VISHS23888-1', u'BC558', u'NPN'),
#  (u'VISHS23888-1', u'BC558', u'PNP'),
#  (u'VISHS23888-1', u'BC559', u'NPN'),
#  (u'VISHS23888-1', u'BC559', u'PNP'),
#  (u'VSMIS00373-1', u'BC327', u'NPN'),
#  (u'VSMIS00373-1', u'BC327', u'PNP'),
#  (u'VSMIS00373-1', u'BC328', u'NPN'),
#  (u'VSMIS00373-1', u'BC328', u'PNP'),
#  (u'VSMIS00373-1', u'BC337', u'PNP'),
#  (u'VSMIS00373-1', u'BC338', u'PNP'),
#  (u'VSMIS03793-1', u'BC807', u'NPN'),
#  (u'VSMIS03793-1', u'BC807', u'PNP'),
#  (u'VSMIS03793-1', u'BC808', u'NPN'),
#  (u'VSMIS03793-1', u'BC808', u'PNP'),
#  (u'VSMIS03793-1', u'BC817', u'PNP'),
#  (u'VSMIS03793-1', u'BC817-16', u'PNP'),
#  (u'VSMIS03793-1', u'BC817-25', u'PNP'),
#  (u'VSMIS03793-1', u'BC817-40', u'PNP'),
#  (u'VSMIS03793-1', u'BC818', u'PNP'),
#  (u'VSMIS03793-1', u'BC818-16', u'PNP'),
#  (u'VSMIS03793-1', u'BC818-25', u'PNP'),
#  (u'VSMIS03793-1', u'BC818-40', u'PNP'),
#  (u'WEITS00252-1', u'BC807-1', u'PNP'),
#  (u'WEITS00252-1', u'BC807-17', u'PNP'),
#  (u'ZETXS01948-1', u'BC860C', u'PNP')]

# %%
from pprint import pprint
pprint(FN)
# Out:
# [('112823', 'BC546BG', 'NPN'),
#  ('112823', 'BC546BRL1', 'NPN'),
#  ('112823', 'BC546BZL1G', 'NPN'),
#  ('112823', 'BC547ARL', 'NPN'),
#  ('112823', 'BC547ARLG', 'NPN'),
#  ('112823', 'BC547AZL1G', 'NPN'),
#  ('112823', 'BC547BG', 'NPN'),
#  ('112823', 'BC547BRL1G', 'NPN'),
#  ('112823', 'BC547BZL1G', 'NPN'),
#  ('112823', 'BC547C', 'NPN'),
#  ('112823', 'BC547CG', 'NPN'),
#  ('112823', 'BC547CZL1G', 'NPN'),
#  ('112823', 'BC548BG', 'NPN'),
#  ('112823', 'BC548BRL1G', 'NPN'),
#  ('112823', 'BC548BZL1G', 'NPN'),
#  ('112823', 'BC548CG', 'NPN'),
#  ('112823', 'BC548CZL1G', 'NPN'),
#  ('2N3906', '2N3906BU', 'PNP'),
#  ('2N3906', '2N3906TA', 'PNP'),
#  ('2N3906', '2N3906TAR', 'PNP'),
#  ('2N3906', '2N3906TF', 'PNP'),
#  ('2N3906', '2N3906TFR', 'PNP'),
#  ('2N3906-D', '2N3906G', 'PNP'),
#  ('2N3906-D', '2N3906RLRA', 'PNP'),
#  ('2N3906-D', '2N3906RLRAG', 'PNP'),
#  ('2N3906-D', '2N3906RLRM', 'PNP'),
#  ('2N3906-D', '2N3906RLRMG', 'PNP'),
#  ('2N3906-D', '2N3906RLRP', 'PNP'),
#  ('2N3906-D', '2N3906RLRPG', 'PNP'),
#  ('2N4123-D', '2N4123RLRM', 'NPN'),
#  ('2N4123-D', '2N4124G', 'NPN'),
#  ('2N6426-D', '2N6426G', 'NPN'),
#  ('2N6426-D', '2N6426RLRAG', 'NPN'),
#  ('2N6426-D', '2N6427G', 'NPN'),
#  ('2N6426-D', '2N6427RLRAG', 'NPN'),
#  ('BC182-D', 'BC182BG', 'NPN'),
#  ('BC182-D', 'BC182BRL1G', 'NPN'),
#  ('BC182-D', 'BC182G', 'NPN'),
#  ('BC337', 'BC337-16', 'NPN'),
#  ('BC337', 'BC337-25', 'NPN'),
#  ('BC337', 'BC337-40', 'NPN'),
#  ('BC337', 'BC33716BU', 'NPN'),
#  ('BC337', 'BC33716TA', 'NPN'),
#  ('BC337', 'BC33716TFR', 'NPN'),
#  ('BC337', 'BC33725BU', 'NPN'),
#  ('BC337', 'BC33725TA', 'NPN'),
#  ('BC337', 'BC33725TAR', 'NPN'),
#  ('BC337', 'BC33725TF', 'NPN'),
#  ('BC337', 'BC33725TFR', 'NPN'),
#  ('BC337', 'BC33740TA', 'NPN'),
#  ('BC337', 'BC338-25', 'NPN'),
#  ('BC337', 'BC33825TA', 'NPN'),
#  ('BC337-D', 'BC337-025G', 'NPN'),
#  ('BC337-D', 'BC337-040G', 'NPN'),
#  ('BC337-D', 'BC337-25ZL1G', 'NPN'),
#  ('BC337-D', 'BC337-40RL1G', 'NPN'),
#  ('BC337-D', 'BC337-40ZL1G', 'NPN'),
#  ('BC337-D', 'BC337G', 'NPN'),
#  ('BC337-D', 'BC337RL1G', 'NPN'),
#  ('BC546', 'BC547BBU', 'NPN'),
#  ('BC546', 'BC547BTA', 'NPN'),
#  ('BC546', 'BC547BTF', 'NPN'),
#  ('BC546', 'BC547C', 'NPN'),
#  ('BC546', 'BC547CBU', 'NPN'),
#  ('BC546', 'BC547CTA', 'NPN'),
#  ('BC546', 'BC547CTFR', 'NPN'),
#  ('BC546', 'BC548B', 'NPN'),
#  ('BC546', 'BC548BTA', 'NPN'),
#  ('BC546', 'BC548BU', 'NPN'),
#  ('BC546', 'BC548C', 'NPN'),
#  ('BC546', 'BC548CTA', 'NPN'),
#  ('BC546', 'BC549B', 'NPN'),
#  ('BC546', 'BC549BTA', 'NPN'),
#  ('BC546', 'BC549BTF', 'NPN'),
#  ('BC546', 'BC549C', 'NPN'),
#  ('BC546', 'BC549CTA', 'NPN'),
#  ('BC546', 'BC550C', 'NPN'),
#  ('BC546', 'BC550CBU', 'NPN'),
#  ('BC546', 'BC550CTA', 'NPN'),
#  ('BC546-D', 'BC546BG', 'NPN'),
#  ('BC546-D', 'BC546BRL1', 'NPN'),
#  ('BC546-D', 'BC546BZL1G', 'NPN'),
#  ('BC546-D', 'BC547ARL', 'NPN'),
#  ('BC546-D', 'BC547ARLG', 'NPN'),
#  ('BC546-D', 'BC547AZL1G', 'NPN'),
#  ('BC546-D', 'BC547BG', 'NPN'),
#  ('BC546-D', 'BC547BRL1G', 'NPN'),
#  ('BC546-D', 'BC547BZL1G', 'NPN'),
#  ('BC546-D', 'BC547C', 'NPN'),
#  ('BC546-D', 'BC547CG', 'NPN'),
#  ('BC546-D', 'BC547CZL1G', 'NPN'),
#  ('BC546-D', 'BC548BG', 'NPN'),
#  ('BC546-D', 'BC548BRL1G', 'NPN'),
#  ('BC546-D', 'BC548BZL1G', 'NPN'),
#  ('BC546-D', 'BC548CG', 'NPN'),
#  ('BC546-D', 'BC548CZL1G', 'NPN'),
#  ('BC546A_SERIES_B14-521026', 'BC546', 'NPN'),
#  ('BC546A_SERIES_B14-521026', 'BC547', 'NPN'),
#  ('BC546A_SERIES_B14-521026', 'BC548', 'NPN'),
#  ('BC546A_SERIES_B14-521026', 'BC549', 'NPN'),
#  ('BC546A_SERIES_B14-521026', 'BC550', 'NPN'),
#  ('BC547', 'BC547BBU', 'NPN'),
#  ('BC547', 'BC547BTA', 'NPN'),
#  ('BC547', 'BC547BTF', 'NPN'),
#  ('BC547', 'BC547C', 'NPN'),
#  ('BC547', 'BC547CBU', 'NPN'),
#  ('BC547', 'BC547CTA', 'NPN'),
#  ('BC547', 'BC547CTFR', 'NPN'),
#  ('BC547', 'BC548B', 'NPN'),
#  ('BC547', 'BC548BTA', 'NPN'),
#  ('BC547', 'BC548C', 'NPN'),
#  ('BC547', 'BC548CTA', 'NPN'),
#  ('BC547', 'BC549B', 'NPN'),
#  ('BC547', 'BC549BTA', 'NPN'),
#  ('BC547', 'BC549BTF', 'NPN'),
#  ('BC547', 'BC549C', 'NPN'),
#  ('BC547', 'BC549CTA', 'NPN'),
#  ('BC547', 'BC550C', 'NPN'),
#  ('BC547', 'BC550CBU', 'NPN'),
#  ('BC547', 'BC550CTA', 'NPN'),
#  ('BC550', 'BC546A', 'NPN'),
#  ('BC550', 'BC546B', 'NPN'),
#  ('BC550', 'BC546C', 'NPN'),
#  ('BC550', 'BC547A', 'NPN'),
#  ('BC550', 'BC547B', 'NPN'),
#  ('BC550', 'BC547C', 'NPN'),
#  ('BC550', 'BC548A', 'NPN'),
#  ('BC550', 'BC548B', 'NPN'),
#  ('BC550', 'BC548C', 'NPN'),
#  ('BC550', 'BC549A', 'NPN'),
#  ('BC550', 'BC549B', 'NPN'),
#  ('BC550', 'BC549C', 'NPN'),
#  ('BC550', 'BC550A', 'NPN'),
#  ('BC550', 'BC550B', 'NPN'),
#  ('BC550', 'BC550C', 'NPN'),
#  ('BC818', 'BC817-16', 'NPN'),
#  ('BC818', 'BC817-25', 'NPN'),
#  ('BC818', 'BC817-40', 'NPN'),
#  ('BC818', 'BC81716MTF', 'NPN'),
#  ('BC818', 'BC81740MTF', 'NPN'),
#  ('BC818', 'BC818-16', 'NPN'),
#  ('BC818', 'BC818-25', 'NPN'),
#  ('BC818', 'BC818-40', 'NPN'),
#  ('BC818', 'BC81816MTF', 'NPN'),
#  ('BC818', 'BC81825MTF', 'NPN'),
#  ('BC818', 'BC81840MTF', 'NPN'),
#  ('BC818-40LT1-D', 'BC818-40LT1G', 'NPN'),
#  ('BC818-40LT1-D', 'NSVBC818-40LT1G', 'NPN'),
#  ('BOURNSINC_BD246BS', 'BD246', 'PNP'),
#  ('BOURNSINC_BD246BS', 'BD246A', 'PNP'),
#  ('BOURNSINC_BD246BS', 'BD246B', 'PNP'),
#  ('BOURNSINC_BD246BS', 'BD246C', 'PNP'),
#  ('BOURNSINC_TIP152S', 'TIP150', 'NPN'),
#  ('BOURNSINC_TIP152S', 'TIP151', 'NPN'),
#  ('BOURNSINC_TIP152S', 'TIP152', 'NPN'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N3576', 'PNP'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N3672', 'PNP'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N3798A', 'PNP'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N3946', 'NPN'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N3963', 'PNP'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N3964', 'PNP'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N3965', 'PNP'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N4014', 'NPN'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N4029', 'PNP'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N4207', 'PNP'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N4359', 'PNP'),
#  ('CENTRALSEMICONDUCTORCORP_CENU45', 'CEN-U45', 'NPN'),
#  ('CENTRALSEMICONDUCTORCORP_CMPT5401ETR', 'CMPT5401E', 'PNP'),
#  ('CENTRALSEMICONDUCTORCORP_CXT4033TR', 'CXT4033', 'PNP'),
#  ('CSEMS02742-1', 'BC846A', 'NPN'),
#  ('CSEMS02742-1', 'BC846B', 'NPN'),
#  ('CSEMS02742-1', 'BC847A', 'NPN'),
#  ('CSEMS02742-1', 'BC847B', 'NPN'),
#  ('CSEMS02742-1', 'BC847C', 'NPN'),
#  ('CSEMS02742-1', 'BC848A', 'NPN'),
#  ('CSEMS02742-1', 'BC848B', 'NPN'),
#  ('CSEMS02742-1', 'BC848C', 'NPN'),
#  ('CSEMS05382-1', 'BC546A', 'NPN'),
#  ('CSEMS05382-1', 'BC546B', 'NPN'),
#  ('CSEMS05382-1', 'BC547A', 'NPN'),
#  ('CSEMS05382-1', 'BC547B', 'NPN'),
#  ('CSEMS05382-1', 'BC547C', 'NPN'),
#  ('CSEMS05382-1', 'BC548A', 'NPN'),
#  ('CSEMS05382-1', 'BC548B', 'NPN'),
#  ('CSEMS05382-1', 'BC548C', 'NPN'),
#  ('CSEMS05383-1', 'BC817-16', 'NPN'),
#  ('CSEMS05383-1', 'BC817-25', 'NPN'),
#  ('CSEMS05383-1', 'BC817-40', 'NPN'),
#  ('CSEMS05383-1', 'BC818-16', 'NPN'),
#  ('CSEMS05383-1', 'BC818-25', 'NPN'),
#  ('CSEMS05383-1', 'BC818-40', 'NPN'),
#  ('DIODESINCORPORATED_2DD26527', '2DD2652', 'NPN'),
#  ('DIODESINCORPORATED_2DD26527', '2DD2652-7', 'NPN'),
#  ('DIODESINCORPORATED_FCX491ATA', 'FCX491A', 'NPN'),
#  ('DIODESINCORPORATED_FZT651TC', 'FZT651TA', 'NPN'),
#  ('DIODESINCORPORATED_FZT651TC', 'FZT651TC', 'NPN'),
#  ('DIODESINCORPORATED_ZXT690BKTC', 'ZXT690BKQTC', 'NPN'),
#  ('DIODESINCORPORATED_ZXT690BKTC', 'ZXT690BKTC', 'NPN'),
#  ('DTC114W', 'DTC114WE', 'NPN'),
#  ('DTC114W', 'DTC114WKA', 'NPN'),
#  ('DTC114W', 'DTC114WUA', 'NPN'),
#  ('FAIRCHILDSEMICONDUCTOR_KSC2310YTA', 'KSC2310', 'NPN'),
#  ('FAIRCHILDSEMICONDUCTOR_KSC2310YTA', 'KSC2310O', 'NPN'),
#  ('FAIRCHILDSEMICONDUCTOR_KSC2310YTA', 'KSC2310R', 'NPN'),
#  ('FAIRCHILDSEMICONDUCTOR_KSC2310YTA', 'KSC2310Y', 'NPN'),
#  ('FAIRS19194-1', 'BC856A', 'PNP'),
#  ('FAIRS19194-1', 'BC856B', 'PNP'),
#  ('FAIRS19194-1', 'BC856C', 'PNP'),
#  ('FAIRS19194-1', 'BC857A', 'PNP'),
#  ('FAIRS19194-1', 'BC857B', 'PNP'),
#  ('FAIRS19194-1', 'BC857C', 'PNP'),
#  ('FAIRS19194-1', 'BC858A', 'PNP'),
#  ('FAIRS19194-1', 'BC858B', 'PNP'),
#  ('FAIRS19194-1', 'BC858C', 'PNP'),
#  ('FAIRS19194-1', 'BC859A', 'PNP'),
#  ('FAIRS19194-1', 'BC859B', 'PNP'),
#  ('FAIRS19194-1', 'BC859C', 'PNP'),
#  ('FAIRS19194-1', 'BC860A', 'PNP'),
#  ('FAIRS19194-1', 'BC860B', 'PNP'),
#  ('FAIRS19194-1', 'BC860C', 'PNP'),
#  ('FAIRS25065-1', 'BC237A', 'NPN'),
#  ('FAIRS25065-1', 'BC237B', 'NPN'),
#  ('FAIRS25065-1', 'BC237C', 'NPN'),
#  ('FAIRS25065-1', 'BC238A', 'NPN'),
#  ('FAIRS25065-1', 'BC238B', 'NPN'),
#  ('FAIRS25065-1', 'BC238C', 'NPN'),
#  ('FAIRS25065-1', 'BC239A', 'NPN'),
#  ('FAIRS25065-1', 'BC239B', 'NPN'),
#  ('FAIRS25065-1', 'BC239C', 'NPN'),
#  ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-16', 'NPN'),
#  ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-16W', 'NPN'),
#  ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-25', 'NPN'),
#  ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-25W', 'NPN'),
#  ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-40', 'NPN'),
#  ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-40W', 'NPN'),
#  ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC818K-16W', 'NPN'),
#  ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC818K-40', 'NPN'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC857A',
#   'PNP'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC857B',
#   'PNP'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC857BW',
#   'PNP'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC857C',
#   'PNP'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC857CW',
#   'PNP'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC858A',
#   'PNP'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC858B',
#   'PNP'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC858BW',
#   'PNP'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC858C',
#   'PNP'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC858CW',
#   'PNP'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC859C',
#   'PNP'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC860B',
#   'PNP'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC860BW',
#   'PNP'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC860CW',
#   'PNP'),
#  ('KECCS03676-1', 'BC856A', 'PNP'),
#  ('KECCS03676-1', 'BC856B', 'PNP'),
#  ('KECCS03676-1', 'BC857A', 'PNP'),
#  ('KECCS03676-1', 'BC857B', 'PNP'),
#  ('KECCS03676-1', 'BC857C', 'PNP'),
#  ('KECCS03676-1', 'BC858A', 'PNP'),
#  ('KECCS03676-1', 'BC858B', 'PNP'),
#  ('KECCS03676-1', 'BC858C', 'PNP'),
#  ('KECCS05435-1', 'BC546A', 'NPN'),
#  ('KECCS05435-1', 'BC546B', 'NPN'),
#  ('KECCS05435-1', 'BC547A', 'NPN'),
#  ('KECCS05435-1', 'BC547B', 'NPN'),
#  ('KECCS05435-1', 'BC547C', 'NPN'),
#  ('KECCS05435-1', 'BC548A', 'NPN'),
#  ('KECCS05435-1', 'BC548B', 'NPN'),
#  ('KECCS05435-1', 'BC548C', 'NPN'),
#  ('LITES00689-1', 'BC337-16', 'NPN'),
#  ('LITES00689-1', 'BC337-25', 'NPN'),
#  ('LITES00689-1', 'BC337-40', 'NPN'),
#  ('LITES00690-1', 'BC546A', 'NPN'),
#  ('LITES00690-1', 'BC546B', 'NPN'),
#  ('LITES00690-1', 'BC546C', 'NPN'),
#  ('LITES00690-1', 'BC547A', 'NPN'),
#  ('LITES00690-1', 'BC547B', 'NPN'),
#  ('LITES00690-1', 'BC547C', 'NPN'),
#  ('LITES00690-1', 'BC548A', 'NPN'),
#  ('LITES00690-1', 'BC548B', 'NPN'),
#  ('LITES00690-1', 'BC548C', 'NPN'),
#  ('LTSCS02910-1', 'BC818-16', 'NPN'),
#  ('LTSCS02910-1', 'BC818-25', 'NPN'),
#  ('LTSCS02910-1', 'BC818-40', 'NPN'),
#  ('LTSCS02912-1', 'BC846AW', 'NPN'),
#  ('LTSCS02912-1', 'BC846BW', 'NPN'),
#  ('LTSCS02920-1', 'BC857A', 'PNP'),
#  ('LTSCS02920-1', 'BC857B', 'PNP'),
#  ('LTSCS02920-1', 'BC857C', 'PNP'),
#  ('MCCCS09540-1', 'BC847', 'NPN'),
#  ('MCCCS09540-1', 'BC848', 'NPN'),
#  ('MCCCS09540-1', 'BC849', 'NPN'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904-AP', 'NPN'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904-AP-HF', 'NPN'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904-BP', 'NPN'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904-BP-HF', 'NPN'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29A-BP', 'NPN'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29A-BP-HF', 'NPN'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29B-BP', 'NPN'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29B-BP-HF', 'NPN'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29C-BP', 'NPN'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29C-BP-HF', 'NPN'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30A', 'PNP'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30A-BP', 'PNP'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30A-BP-HF', 'PNP'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30B', 'PNP'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30B-BP', 'PNP'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30B-BP-HF', 'PNP'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30C', 'PNP'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30C-BP', 'PNP'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30C-BP-HF', 'PNP'),
#  ('MICROSEMICORPORATION_2N2484UB', '2N2484UA', 'NPN'),
#  ('MICROSEMICORPORATION_2N2484UB', '2N2484UB', 'NPN'),
#  ('MICROSEMICORPORATION_2N2484UB', '2N2484UBC', 'NPN'),
#  ('MMBT3904', '2N3904BU', 'NPN'),
#  ('MMBT3904', '2N3904TA', 'NPN'),
#  ('MMBT3904', '2N3904TAR', 'NPN'),
#  ('MMBT3904', '2N3904TF', 'NPN'),
#  ('MMBT3904', '2N3904TFR', 'NPN'),
#  ('MOTOS03160-1', 'BC182A', 'NPN'),
#  ('MOTOS03160-1', 'BC182B', 'NPN'),
#  ('MOTOS03189-1', 'BC337-16', 'NPN'),
#  ('MOTOS03189-1', 'BC337-25', 'NPN'),
#  ('MOTOS03189-1', 'BC337-40', 'NPN'),
#  ('MOTOS03189-1', 'BC338', 'NPN'),
#  ('MOTOS03189-1', 'BC338-16', 'NPN'),
#  ('MOTOS03189-1', 'BC338-25', 'NPN'),
#  ('MOTOS03189-1', 'BC338-40', 'NPN'),
#  ('NXPUSAINC_PBSS5360PASX', 'PBSS5360PAS', 'PNP'),
#  ('ONSEMICONDUCTOR_MMBT6521LT1', 'MMBT6521LT1G', 'NPN'),
#  ('ONSEMICONDUCTOR_MMBT6521LT1', 'SMMBT6521LT1G', 'NPN'),
#  ('ONSMS04099-1', 'BC237A', 'NPN'),
#  ('ONSMS04099-1', 'BC237B', 'NPN'),
#  ('ONSMS04099-1', 'BC237C', 'NPN'),
#  ('ONSMS04099-1', 'BC238', 'NPN'),
#  ('ONSMS04099-1', 'BC239C', 'NPN'),
#  ('PHGLS18216-1', 'BC847A', 'NPN'),
#  ('PHGLS18216-1', 'BC847AW', 'NPN'),
#  ('PHGLS18216-1', 'BC847B', 'NPN'),
#  ('PHGLS18216-1', 'BC847B/DG', 'NPN'),
#  ('PHGLS18216-1', 'BC847BW', 'NPN'),
#  ('PHGLS18216-1', 'BC847BW/DG', 'NPN'),
#  ('PHGLS18216-1', 'BC847C', 'NPN'),
#  ('PHGLS18216-1', 'BC847CW', 'NPN'),
#  ('PHGLS18216-1', 'BC847W', 'NPN'),
#  ('PHGLS20125-1', 'BC327-16', 'PNP'),
#  ('PHGLS20125-1', 'BC327-25', 'PNP'),
#  ('PHGLS20125-1', 'BC327-40', 'PNP'),
#  ('PHGLS20125-1', 'BC807-16', 'PNP'),
#  ('PHGLS20125-1', 'BC807-16W', 'PNP'),
#  ('PHGLS20125-1', 'BC807-25', 'PNP'),
#  ('PHGLS20125-1', 'BC807-25W', 'PNP'),
#  ('PHGLS20125-1', 'BC807-40', 'PNP'),
#  ('PHGLS20125-1', 'BC807-40W', 'PNP'),
#  ('PHGLS20126-1', 'BC337-16', 'NPN'),
#  ('PHGLS20126-1', 'BC337-25', 'NPN'),
#  ('PHGLS20126-1', 'BC337-40', 'NPN'),
#  ('PHGLS20126-1', 'BC817-16', 'NPN'),
#  ('PHGLS20126-1', 'BC817-16W', 'NPN'),
#  ('PHGLS20126-1', 'BC817-25', 'NPN'),
#  ('PHGLS20126-1', 'BC817-25W', 'NPN'),
#  ('PHGLS20126-1', 'BC817-40', 'NPN'),
#  ('PHGLS20126-1', 'BC817-40W', 'NPN'),
#  ('RECTS00705-1', 'BC546', 'NPN'),
#  ('RECTS00705-1', 'BC546A', 'NPN'),
#  ('RECTS00705-1', 'BC546B', 'NPN'),
#  ('RECTS00705-1', 'BC546C', 'NPN'),
#  ('RECTS00705-1', 'BC547', 'NPN'),
#  ('RECTS00705-1', 'BC547A', 'NPN'),
#  ('RECTS00705-1', 'BC547B', 'NPN'),
#  ('RECTS00705-1', 'BC547C', 'NPN'),
#  ('RECTS00705-1', 'BC548', 'NPN'),
#  ('RECTS00705-1', 'BC548A', 'NPN'),
#  ('RECTS00705-1', 'BC548B', 'NPN'),
#  ('RECTS00705-1', 'BC548C', 'NPN'),
#  ('SCSCS02175-1', 'BC546A', 'NPN'),
#  ('SCSCS02175-1', 'BC546B', 'NPN'),
#  ('SCSCS02175-1', 'BC546C', 'NPN'),
#  ('SCSCS02175-1', 'BC547A', 'NPN'),
#  ('SCSCS02175-1', 'BC547B', 'NPN'),
#  ('SCSCS02175-1', 'BC547C', 'NPN'),
#  ('SCSCS02175-1', 'BC548A', 'NPN'),
#  ('SCSCS02175-1', 'BC548B', 'NPN'),
#  ('SCSCS02175-1', 'BC548C', 'NPN'),
#  ('SGSTS13702-1', 'BC547B-AP', 'NPN'),
#  ('SGSTS13702-1', 'BC547C-AP', 'NPN'),
#  ('SGSTS13734-1', 'BC337-25-AP', 'NPN'),
#  ('SGSTS13734-1', 'BC337-40-AP', 'NPN'),
#  ('SIEMS01215-1', 'BC856', 'PNP'),
#  ('SIEMS01215-1', 'BC856A', 'PNP'),
#  ('SIEMS01215-1', 'BC856B', 'PNP'),
#  ('SIEMS01215-1', 'BC857', 'PNP'),
#  ('SIEMS01215-1', 'BC857A', 'PNP'),
#  ('SIEMS01215-1', 'BC857B', 'PNP'),
#  ('SIEMS01215-1', 'BC857C', 'PNP'),
#  ('SIEMS01215-1', 'BC858', 'PNP'),
#  ('SIEMS01215-1', 'BC858A', 'PNP'),
#  ('SIEMS01215-1', 'BC858B', 'PNP'),
#  ('SIEMS01215-1', 'BC858C', 'PNP'),
#  ('SIEMS01215-1', 'BC859', 'PNP'),
#  ('SIEMS01215-1', 'BC859A', 'PNP'),
#  ('SIEMS01215-1', 'BC859B', 'PNP'),
#  ('SIEMS01215-1', 'BC859C', 'PNP'),
#  ('SIEMS01215-1', 'BC860', 'PNP'),
#  ('SIEMS01215-1', 'BC860B', 'PNP'),
#  ('SIEMS01215-1', 'BC860C', 'PNP'),
#  ('STMICROELECTRONICS_STI130051', 'STI13005-1', 'NPN'),
#  ('TKCGS00622-1', 'DTC114TE', 'NPN'),
#  ('TKCGS00622-1', 'DTC114YE', 'NPN'),
#  ('TKCGS00622-1', 'DTC123EE', 'NPN'),
#  ('TKCGS00622-1', 'DTC124EE', 'NPN'),
#  ('TKCGS00622-1', 'DTC124XE', 'NPN'),
#  ('TKCGS00622-1', 'DTC143EE', 'NPN'),
#  ('TKCGS00622-1', 'DTC143TE', 'NPN'),
#  ('TKCGS00622-1', 'DTC143ZE', 'NPN'),
#  ('TKCGS00622-1', 'DTC144EE', 'NPN'),
#  ('TTELECTRONICSOPTEKTECHNOLOGY_2N2222AUATXV', '2N2222AUA', 'NPN'),
#  ('TTELECTRONICSOPTEKTECHNOLOGY_2N2222AUATXV', '2N2222AUATX', 'NPN'),
#  ('TTELECTRONICSOPTEKTECHNOLOGY_2N2222AUATXV', '2N2222AUATXV', 'NPN'),
#  ('TWSCS04757-1', 'BC807-25', 'PNP'),
#  ('TWSCS04757-1', 'BC807-40', 'PNP'),
#  ('UTCLS01324-1', 'MMBT3904G-AE3-R', 'NPN'),
#  ('UTCLS01324-1', 'MMBT3904G-AL3-R', 'NPN'),
#  ('UTCLS01324-1', 'MMBT3904L-AE3-R', 'NPN'),
#  ('UTCLS01324-1', 'MMBT3904L-AL3-R', 'NPN'),
#  ('UTCLS02155-1', 'BC807', 'PNP'),
#  ('UTCLS02155-1', 'BC807-16', 'PNP'),
#  ('UTCLS02155-1', 'BC807-25', 'PNP'),
#  ('UTCLS02155-1', 'BC807-40', 'PNP'),
#  ('UTCLS02155-1', 'BC808', 'PNP'),
#  ('UTCLS02155-1', 'BC808-16', 'PNP'),
#  ('UTCLS02155-1', 'BC808-25', 'PNP'),
#  ('UTCLS02155-1', 'BC808-40', 'PNP'),
#  ('UTCLS03593-1', 'DTC114EG-AE3-R', 'NPN'),
#  ('UTCLS03593-1', 'DTC114EG-AL3-R', 'NPN'),
#  ('UTCLS03593-1', 'DTC114EG-AN3-R', 'NPN'),
#  ('UTCLS03593-1', 'DTC114EG-T92-B', 'NPN'),
#  ('UTCLS03593-1', 'DTC114EG-T92-K', 'NPN'),
#  ('UTCLS03593-1', 'DTC114EG-T92-R', 'NPN'),
#  ('UTCLS03593-1', 'DTC114EG-T9S-K', 'NPN'),
#  ('UTCLS03593-1', 'DTC114EL-AE3-R', 'NPN'),
#  ('UTCLS03593-1', 'DTC114EL-AL3-R', 'NPN'),
#  ('UTCLS03593-1', 'DTC114EL-AN3-R', 'NPN'),
#  ('UTCLS03593-1', 'DTC114EL-T92-B', 'NPN'),
#  ('UTCLS03593-1', 'DTC114EL-T92-K', 'NPN'),
#  ('UTCLS03593-1', 'DTC114EL-T92-R', 'NPN'),
#  ('UTCLS03593-1', 'DTC114EL-T9S-K', 'NPN'),
#  ('VISHS23888-1', 'BC546A', 'NPN'),
#  ('VISHS23888-1', 'BC546B', 'NPN'),
#  ('VISHS23888-1', 'BC547A', 'NPN'),
#  ('VISHS23888-1', 'BC547B', 'NPN'),
#  ('VISHS23888-1', 'BC547C', 'NPN'),
#  ('VISHS23888-1', 'BC548A', 'NPN'),
#  ('VISHS23888-1', 'BC548B', 'NPN'),
#  ('VISHS23888-1', 'BC548C', 'NPN'),
#  ('VISHS23888-1', 'BC549B', 'NPN'),
#  ('VISHS23888-1', 'BC549C', 'NPN'),
#  ('VSMIS00373-1', 'BC337', 'NPN'),
#  ('VSMIS00373-1', 'BC337-16', 'NPN'),
#  ('VSMIS00373-1', 'BC337-25', 'NPN'),
#  ('VSMIS00373-1', 'BC337-40', 'NPN'),
#  ('VSMIS00373-1', 'BC338', 'NPN'),
#  ('VSMIS00373-1', 'BC338-16', 'NPN'),
#  ('VSMIS00373-1', 'BC338-25', 'NPN'),
#  ('VSMIS00373-1', 'BC338-40', 'NPN'),
#  ('WEILS00082-1', 'BC858', 'PNP'),
#  ('WEILS00082-1', 'BC859', 'PNP'),
#  ('ZETXS01948-1', 'BC856A-3A', 'PNP'),
#  ('ZETXS01948-1', 'BC856B-Z3B', 'PNP'),
#  ('ZETXS01948-1', 'BC857A-Z3E', 'PNP'),
#  ('ZETXS01948-1', 'BC857B-3F', 'PNP'),
#  ('ZETXS01948-1', 'BC857C-3G', 'PNP'),
#  ('ZETXS01948-1', 'BC858A-3J', 'PNP'),
#  ('ZETXS01948-1', 'BC858B-3K', 'PNP'),
#  ('ZETXS01948-1', 'BC858C-3L', 'PNP'),
#  ('ZETXS01948-1', 'BC859A-Z4A', 'PNP'),
#  ('ZETXS01948-1', 'BC859B-4B', 'PNP'),
#  ('ZETXS01948-1', 'BC859C-Z4C', 'PNP'),
#  ('ZETXS01948-1', 'BC860A-Z4E', 'PNP'),
#  ('ZETXS01948-1', 'BC860B-4F', 'PNP'),
#  ('ZETXS01948-1', 'BC860C-4GZ', 'PNP')]
