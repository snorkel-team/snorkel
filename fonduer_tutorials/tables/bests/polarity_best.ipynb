# %% [markdown]
# # HARDWARE

# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

"""
To change attributes:
1) Change ATTRIBUTE and you're good to go
"""
ATTRIBUTE = 'polarity'
COUNTER = 1002
PARALLEL = 30
PARALLEL_EXTRACTION = 8
TRAIN_SIZE = 1000
DEV_SIZE = 125

import os
import sys
sys.path.append(os.environ['SNORKELHOME'] + '/tutorials/tables/')
snorkel_postgres = os.environ['SNORKELDB'].startswith('postgres')
print snorkel_postgres
# Out:
# True

# %%
import os
if snorkel_postgres:
    os.environ['SNORKELDBNAME'] = ATTRIBUTE + str(COUNTER)
    print os.system("dropdb " + os.environ['SNORKELDBNAME'])
    print os.system("createdb " + os.environ['SNORKELDBNAME'])
    print "SNORKELDBNAME = %s" % os.environ['SNORKELDBNAME']
else:
    try:
        os.remove('snorkel.db')
    except:
        pass

from snorkel import SnorkelSession
session = SnorkelSession()
# Out:
# 256
# 0
# SNORKELDBNAME = polarity1002

# %% [markdown]
# ## Parsing

# %%
import os
if snorkel_postgres:
    from snorkel.async_parser import parse_corpus, HTMLParser, AsyncOmniParser
    print "Starting async parse..."
    
    # PARSE TRAIN
    docs_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/train_digikey/html/'
    pdf_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/train_digikey/pdf/'
    doc_parser = HTMLParser()
    context_parser = AsyncOmniParser(blacklist=['style'], flatten=['span','br'], 
                                     tabular=True, lingual=True,
                                     visual=True, pdf_path=pdf_path)
    # %time corpus = parse_corpus(session, 'Hardware Train', docs_path,\
                                doc_parser, context_parser,\
                                max_docs=TRAIN_SIZE, parallel=PARALLEL)
    print "%s contains %d documents" % (corpus, len(corpus))
    
    # PARSE DEV
    docs_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/dev/html/'
    pdf_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/dev/pdf/'
    context_parser = AsyncOmniParser(blacklist=['style'], flatten=['span','br'], 
                                     tabular=True, lingual=True,
                                     visual=True, pdf_path=pdf_path)
    # %time corpus = parse_corpus(session, 'Hardware Dev', docs_path,\
                                doc_parser, context_parser,\
                                max_docs=DEV_SIZE, parallel=PARALLEL)
    print "%s contains %d documents" % (corpus, len(corpus))
else:
    from snorkel.parser import CorpusParser, HTMLParser, OmniParser
    from snorkel.utils import get_ORM_instance
    from snorkel.queries import split_corpus

    print "Starting sync parse..."
    # PARSE TRAIN
    docs_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/train_small/html/'
    pdf_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/train_small/pdf/'
    doc_parser = HTMLParser(path=docs_path)
    context_parser = AsyncOmniParser(blacklist=['style'], flatten=['span','br'], 
                                     tabular=True, lingual=True,
                                     visual=True, pdf_path=pdf_path)
    cp = CorpusParser(doc_parser, context_parser, max_docs=100)

    # %time corpus = cp.parse_corpus(name='Hardware Train', session=session)
    print "%s contains %d documents" % corpus, len(corpus)

    session.add(corpus)
    session.commit()
    
    # PARSE DEV
    docs_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/dev/html/'
    pdf_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/dev/pdf/'
    doc_parser = HTMLParser(path=docs_path)
    context_parser = AsyncOmniParser(blacklist=['style'], flatten=['span','br'], 
                                 tabular=True, lingual=True,
                                 visual=True, pdf_path=pdf_path)
    cp = CorpusParser(doc_parser, context_parser, max_docs=125)

    # %time corpus = cp.parse_corpus(name='Hardware Dev', session=session)
    print "%s contains %d documents" % (corpus, len(corpus))
    session.add(corpus)
    session.commit()
# Out:
# Starting async parse...
# [========================================] 100%
# CPU times: user 764 ms, sys: 520 ms, total: 1.28 s
# Wall time: 3min 42s
# Corpus (Hardware Train) contains 1000 documents
# [========================================] 100%
# CPU times: user 300 ms, sys: 212 ms, total: 512 ms
# Wall time: 55.6 s
# Corpus (Hardware Dev) contains 122 documents

# %% [markdown]
# ### Save Corpus

# %%
# If necessary
if not snorkel_postgres:
    import os
    os.system('cp snorkel.db snorkel.db\ corpus');

# %% [markdown]
# ## Extraction

# %%
# # If necessary:
# import os
# os.remove('snorkel.db');
# os.system('cp snorkel.db\ corpus snorkel.db');

# import sys
# sys.path.append(os.environ['SNORKELHOME'] + '/tutorials/tables/')

# from snorkel import SnorkelSession
# session = SnorkelSession()

# %%
from snorkel.models import candidate_subclass

Part_Attr = candidate_subclass('Part_Attr', ['part','attr'])

# %% [markdown]
# ### Define Matchers

# %%
from hardware_matchers import get_matcher

part_matcher = get_matcher('part')
attr_matcher = get_matcher(ATTRIBUTE)

# %% [markdown]
# ### Define ContextSpaces

# %%
from hardware_spaces import get_space
    
part_ngrams = get_space('part')
attr_ngrams = get_space(ATTRIBUTE)

# %% [markdown]
# ### Define Candidate Throttler

# %%
from hardware_throttlers import get_throttler

throttler = get_throttler(ATTRIBUTE)
# throttler = None

# %% [markdown]
# ### Run CandidateExtractor

# %%
from snorkel.models import Corpus
from snorkel.candidates import CandidateExtractor
from snorkel.utils import get_ORM_instance
from snorkel.async_candidates import parallel_extract

ce = CandidateExtractor(Part_Attr, 
                        [part_ngrams, attr_ngrams], 
                        [part_matcher, attr_matcher], 
                        throttler=throttler)


for corpus_name in ['Hardware Train', 'Hardware Dev']:
    corpus = get_ORM_instance(Corpus, session, corpus_name)
    print "Extracting Candidates from %s" % corpus
    # %time candidates = parallel_extract(session, ce, corpus, \
                                        corpus_name + ' Candidates', \
                                        parallel=PARALLEL_EXTRACTION)
    session.add(candidates)
    print "%s contains %d Candidates" % (candidates, len(candidates))
session.commit()
# Out:
# Extracting Candidates from Corpus (Hardware Train)
# [========================================] 100%
# CPU times: user 128 ms, sys: 192 ms, total: 320 ms
# Wall time: 36min 32s
# Candidate Set (Hardware Train Candidates) contains 67083 Candidates
# Extracting Candidates from Corpus (Hardware Dev)
# [========================================] 100%
# CPU times: user 44 ms, sys: 88 ms, total: 132 ms
# Wall time: 14min 47s
# Candidate Set (Hardware Dev Candidates) contains 19846 Candidates

# %% [markdown]
# ### Second Pass

# %%
# from hardware_utils import get_gold_parts_by_doc, get_manual_parts_by_doc
# from snorkel.utils import get_ORM_instance
# from snorkel.models import Corpus

# corpus = get_ORM_instance(Corpus, session, 'Hardware Dev')

# # parts_by_doc = get_gold_parts_by_doc()
# parts_by_doc = get_manual_parts_by_doc(corpus.documents)
# # parts_by_doc = None

# %%
# import cPickle as pickle
# pickle_file = os.environ['SNORKELHOME'] + '/tutorials/tables/sandbox/parts_by_doc.pkl'

# with open(pickle_file, 'w') as f:
#     pickle.dump(parts_by_doc, f)

# %%
import cPickle as pickle
pickle_file = os.environ['SNORKELHOME'] + '/tutorials/tables/sandbox/parts_by_doc.pkl'
with open(pickle_file, 'r') as f:
    parts_by_doc = pickle.load(f)

# %% [markdown]
# ### Assess Recall

# %%
from snorkel.models import Corpus, CandidateSet
from hardware_utils import entity_level_f1_from_candidates

corpus = get_ORM_instance(Corpus, session, 'Hardware Dev')
candidates = get_ORM_instance(CandidateSet, session, 'Hardware Dev Candidates')
gold_file = os.environ['SNORKELHOME'] + \
    '/tutorials/tables/data/hardware/dev/hardware_dev_gold.csv'
(ctp, cfp, cfn) = entity_level_f1_from_candidates(candidates, gold_file, ATTRIBUTE, \
                                                  corpus=corpus, relation=False, \
                                                  parts_by_doc=parts_by_doc)
# Out:
# Preparing candidates...
# [========================================] 100%
# ========================================
# Scoring on Entity-Level Gold Data
# ========================================
# Corpus Precision 0.843
# Corpus Recall    0.901
# Corpus F1        0.871
# ----------------------------------------
# TP: 835 | FP: 156 | FN: 92
# ========================================

# %%
from pprint import pprint
pprint(cfp)
# Out:
# [(u'BC337', u'BC33716'),
#  (u'BC337', u'BC33725'),
#  (u'BC337', u'BC33740'),
#  (u'BC337', u'BC33740BU'),
#  (u'BC337', u'BC338-16'),
#  (u'BC337', u'BC338-40'),
#  (u'BC337', u'BC33825'),
#  (u'BC337-D', u'BC337-XX'),
#  (u'BC546', u'BC548A'),
#  (u'BC546', u'BC549A'),
#  (u'BC546', u'BC550A'),
#  (u'BC546', u'BC550B'),
#  (u'BC546-BC548C(TO-92)', u'BC546-BC548C'),
#  (u'BC546_DIOTEC', u'BC546C'),
#  (u'BC546_DIOTEC', u'BC549A'),
#  (u'BC547', u'BC548A'),
#  (u'BC547', u'BC548BU'),
#  (u'BC547', u'BC549A'),
#  (u'BC547', u'BC550A'),
#  (u'BC547', u'BC550B'),
#  (u'BC818-40LT1-D', u'BC818-40LT1'),
#  (u'CSEMS05382-1', u'BC546-48ABC'),
#  (u'DIODESINCORPORATED_FCX491ATA', u'AP02001'),
#  (u'DIODESINCORPORATED_FCX491ATA', u'AP02002'),
#  (u'DIODESINCORPORATED_FZT651TC', u'AP02001'),
#  (u'DIODESINCORPORATED_FZT651TC', u'AP02002'),
#  (u'DIODESINCORPORATED_ZXT690BKTC', u'AP02001'),
#  (u'DIODESINCORPORATED_ZXT690BKTC', u'AP02002'),
#  (u'DIODESINCORPORATED_ZXT690BKTC', u'ZXT690B'),
#  (u'DIODS13249-1', u'BC808'),
#  (u'DIODS13249-1', u'BC81840'),
#  (u'DISES00189-1', u'BC546C'),
#  (u'DISES00189-1', u'BC546XBK'),
#  (u'DISES00189-1', u'BC547XBK'),
#  (u'DISES00189-1', u'BC548XBK'),
#  (u'DISES00189-1', u'BC549A'),
#  (u'DISES00189-1', u'BC549XBK'),
#  (u'DISES00490-1', u'BC846WA'),
#  (u'DISES00490-1', u'BC846WB'),
#  (u'DISES00490-1', u'BC846WC'),
#  (u'DISES00490-1', u'BC847WA'),
#  (u'DISES00490-1', u'BC847WB'),
#  (u'DISES00490-1', u'BC847WC'),
#  (u'DISES00490-1', u'BC848WA'),
#  (u'DISES00490-1', u'BC848WB'),
#  (u'DISES00490-1', u'BC848WC'),
#  (u'DISES00490-1', u'BC849WA'),
#  (u'DISES00490-1', u'BC849WB'),
#  (u'DISES00490-1', u'BC849WC'),
#  (u'DISES00616-1', u'BC859A'),
#  (u'DISES00616-1', u'BC860A'),
#  (u'INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', u'AN077'),
#  (u'INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', u'BC817'),
#  (u'INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', u'BC818'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'AN077'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC850'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857-BC860'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857W'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857W-BC860W'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC858W'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC859W'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC860W'),
#  (u'INFNS19372-1', u'AN077'),
#  (u'KECCS03676-1', u'BC856C'),
#  (u'KECCS05435-1', u'BC546C'),
#  (u'LITES00690-1', u'BC556'),
#  (u'LITES00690-1', u'BC556A'),
#  (u'LITES00690-1', u'BC556B'),
#  (u'LITES00690-1', u'BC556C'),
#  (u'LITES00690-1', u'BC557'),
#  (u'LITES00690-1', u'BC557A'),
#  (u'LITES00690-1', u'BC557B'),
#  (u'LITES00690-1', u'BC557C'),
#  (u'LITES00690-1', u'BC558'),
#  (u'LITES00690-1', u'BC558A'),
#  (u'LITES00690-1', u'BC558B'),
#  (u'LITES00690-1', u'BC558C'),
#  (u'LTSCS02910-1', u'BC818-REV'),
#  (u'LTSCS02912-1', u'BC846W-REV'),
#  (u'LTSCS02920-1', u'BC857-REV'),
#  (u'MCCCS09540-1', u'BC846A-BC849C'),
#  (u'ONSEMICONDUCTOR_MMBT6521LT1', u'AN569'),
#  (u'ONSEMICONDUCTOR_MMBT6521LT1', u'AN569A'),
#  (u'ONSMS04099-1', u'BC237BA'),
#  (u'ONSMS04099-1', u'BC237CA'),
#  (u'ONSMS04099-1', u'BC238A'),
#  (u'ONSMS04099-1', u'BC238BA'),
#  (u'ONSMS04099-1', u'BC238CA'),
#  (u'ONSMS04099-1', u'BC239A'),
#  (u'ONSMS04099-1', u'MPS3904'),
#  (u'ONSMS04099-1', u'MPS3904A'),
#  (u'PHGLS18216-1', u'BC557'),
#  (u'PHGLS18216-1', u'BC557B'),
#  (u'PHGLS18216-1', u'BC557C'),
#  (u'PHGLS18216-1', u'BC847DG'),
#  (u'PHGLS18216-1', u'BC857'),
#  (u'PHGLS18216-1', u'BC857A'),
#  (u'PHGLS18216-1', u'BC857AM'),
#  (u'PHGLS18216-1', u'BC857AT'),
#  (u'PHGLS18216-1', u'BC857AW'),
#  (u'PHGLS18216-1', u'BC857B'),
#  (u'PHGLS18216-1', u'BC857BM'),
#  (u'PHGLS18216-1', u'BC857BT'),
#  (u'PHGLS18216-1', u'BC857BW'),
#  (u'PHGLS18216-1', u'BC857C'),
#  (u'PHGLS18216-1', u'BC857CM'),
#  (u'PHGLS18216-1', u'BC857CT'),
#  (u'PHGLS18216-1', u'BC857CW'),
#  (u'PHGLS18216-1', u'BC857T'),
#  (u'PHGLS18216-1', u'BC857W'),
#  (u'PHGLS25601-1', u'BC856'),
#  (u'PHGLS25601-1', u'BC856T'),
#  (u'PHGLS25601-1', u'BC856W'),
#  (u'PNJIS01186-1', u'BC807'),
#  (u'PNJIS01593-1', u'BC846'),
#  (u'PNJIS01593-1', u'BC849'),
#  (u'RECTS01158-1', u'BC807-25LT1'),
#  (u'RECTS01214-1', u'DTC114ECA-1'),
#  (u'RECTS01242-1', u'BC857BLT1'),
#  (u'RECTS01325-1', u'DTC114YCA-1'),
#  (u'TWSCS04757-1', u'BC807'),
#  (u'TWSCS04757-1', u'BC807-XX'),
#  (u'UTCLS01324-1', u'MMBT3904-E'),
#  (u'UTCLS03593-1', u'DTC114E-I'),
#  (u'VISHS23888-1', u'BC546C'),
#  (u'VISHS23888-1', u'BC549A'),
#  (u'VSMIS03793-1', u'BC807'),
#  (u'VSMIS03793-1', u'BC807-16'),
#  (u'VSMIS03793-1', u'BC807-25'),
#  (u'VSMIS03793-1', u'BC807-40'),
#  (u'VSMIS03793-1', u'BC808'),
#  (u'VSMIS03793-1', u'BC808-16'),
#  (u'VSMIS03793-1', u'BC808-25'),
#  (u'VSMIS03793-1', u'BC808-40'),
#  (u'WEITS00252-1', u'BC807-1'),
#  (u'WEITS00252-1', u'BC807-17'),
#  (u'ZETXS01948-1', u'BC856-40'),
#  (u'ZETXS01948-1', u'BC856A'),
#  (u'ZETXS01948-1', u'BC856B'),
#  (u'ZETXS01948-1', u'BC856C'),
#  (u'ZETXS01948-1', u'BC857-40'),
#  (u'ZETXS01948-1', u'BC857A'),
#  (u'ZETXS01948-1', u'BC857B'),
#  (u'ZETXS01948-1', u'BC857C'),
#  (u'ZETXS01948-1', u'BC858-40'),
#  (u'ZETXS01948-1', u'BC858A'),
#  (u'ZETXS01948-1', u'BC858B'),
#  (u'ZETXS01948-1', u'BC858C'),
#  (u'ZETXS01948-1', u'BC859-40'),
#  (u'ZETXS01948-1', u'BC859A'),
#  (u'ZETXS01948-1', u'BC859B'),
#  (u'ZETXS01948-1', u'BC859C'),
#  (u'ZETXS01948-1', u'BC860-40'),
#  (u'ZETXS01948-1', u'BC860A'),
#  (u'ZETXS01948-1', u'BC860B'),
#  (u'ZETXS01948-1', u'BC860C')]

# %%
pprint(cfn)
# Out:
# [('BOURNSINC_BD246BS', 'BD246'),
#  ('BOURNSINC_BD246BS', 'BD246A'),
#  ('BOURNSINC_BD246BS', 'BD246B'),
#  ('BOURNSINC_BD246BS', 'BD246C'),
#  ('BOURNSINC_TIP152S', 'TIP150'),
#  ('BOURNSINC_TIP152S', 'TIP151'),
#  ('BOURNSINC_TIP152S', 'TIP152'),
#  ('CENTRALSEMICONDUCTORCORP_CENU45', 'CEN-U45'),
#  ('CENTRALSEMICONDUCTORCORP_CMPT5401ETR', 'CMPT5401E'),
#  ('CENTRALSEMICONDUCTORCORP_CXT4033TR', 'CXT4033'),
#  ('DIODESINCORPORATED_2DD26527', '2DD2652'),
#  ('DIODESINCORPORATED_2DD26527', '2DD2652-7'),
#  ('DIODESINCORPORATED_FCX491ATA', 'FCX491A'),
#  ('DIODESINCORPORATED_ZXT690BKTC', 'ZXT690BKQTC'),
#  ('DIODESINCORPORATED_ZXT690BKTC', 'ZXT690BKTC'),
#  ('DISES00490-1', 'BC846AW'),
#  ('DISES00490-1', 'BC846BW'),
#  ('DISES00490-1', 'BC847AW'),
#  ('DISES00490-1', 'BC847BW'),
#  ('DISES00490-1', 'BC847CW'),
#  ('DISES00490-1', 'BC848AW'),
#  ('DISES00490-1', 'BC848BW'),
#  ('DISES00490-1', 'BC848CW'),
#  ('DISES00490-1', 'BC849BW'),
#  ('DISES00490-1', 'BC849CW'),
#  ('FAIRCHILDSEMICONDUCTOR_KSC2310YTA', 'KSC2310'),
#  ('FAIRCHILDSEMICONDUCTOR_KSC2310YTA', 'KSC2310O'),
#  ('FAIRCHILDSEMICONDUCTOR_KSC2310YTA', 'KSC2310R'),
#  ('FAIRCHILDSEMICONDUCTOR_KSC2310YTA', 'KSC2310Y'),
#  ('LITES00689-1', 'BC337-25'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904-AP'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904-AP-HF'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904-BP'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904-BP-HF'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29A-BP'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29A-BP-HF'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29B-BP'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29B-BP-HF'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29C-BP'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29C-BP-HF'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30A-BP'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30A-BP-HF'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30B-BP'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30B-BP-HF'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30C-BP'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30C-BP-HF'),
#  ('MICROSEMICORPORATION_2N2484UB', '2N2484UA'),
#  ('MICROSEMICORPORATION_2N2484UB', '2N2484UB'),
#  ('MICROSEMICORPORATION_2N2484UB', '2N2484UBC'),
#  ('NXPUSAINC_PBSS5360PASX', 'PBSS5360PAS'),
#  ('ONSEMICONDUCTOR_MMBT6521LT1', 'MMBT6521LT1G'),
#  ('ONSEMICONDUCTOR_MMBT6521LT1', 'SMMBT6521LT1G'),
#  ('ONSMS04099-1', 'BC239C'),
#  ('RECTS00705-1', 'BC547A'),
#  ('RECTS00705-1', 'BC547B'),
#  ('RECTS00705-1', 'BC548A'),
#  ('RECTS00705-1', 'BC548B'),
#  ('SANKEN_2SC4886', '2SC4886'),
#  ('SANKEN_2SD2643', '2SD2643'),
#  ('SANKEN_STD01N', 'STD01N'),
#  ('SANKEN_STD01N', 'STD01P'),
#  ('SIEMS01215-1', 'BC856'),
#  ('SIEMS01215-1', 'BC856A'),
#  ('SIEMS01215-1', 'BC856B'),
#  ('SIEMS01215-1', 'BC857'),
#  ('SIEMS01215-1', 'BC857A'),
#  ('SIEMS01215-1', 'BC857B'),
#  ('SIEMS01215-1', 'BC857C'),
#  ('SIEMS01215-1', 'BC858'),
#  ('SIEMS01215-1', 'BC858A'),
#  ('SIEMS01215-1', 'BC858B'),
#  ('SIEMS01215-1', 'BC858C'),
#  ('SIEMS01215-1', 'BC859'),
#  ('SIEMS01215-1', 'BC859A'),
#  ('SIEMS01215-1', 'BC859B'),
#  ('SIEMS01215-1', 'BC859C'),
#  ('SIEMS01215-1', 'BC860'),
#  ('SIEMS01215-1', 'BC860B'),
#  ('SIEMS01215-1', 'BC860C'),
#  ('STMICROELECTRONICS_BUV48A', 'BUV48A'),
#  ('STMICROELECTRONICS_STI130051', 'STI13005-1'),
#  ('TTELECTRONICSOPTEKTECHNOLOGY_2N2222AUATXV', '2N2222AUA'),
#  ('TTELECTRONICSOPTEKTECHNOLOGY_2N2222AUATXV', '2N2222AUATX'),
#  ('TTELECTRONICSOPTEKTECHNOLOGY_2N2222AUATXV', '2N2222AUATXV'),
#  ('UTCLS02155-1', 'BC807'),
#  ('UTCLS02155-1', 'BC807-16'),
#  ('UTCLS02155-1', 'BC807-25'),
#  ('UTCLS02155-1', 'BC807-40'),
#  ('UTCLS02155-1', 'BC808'),
#  ('UTCLS02155-1', 'BC808-16'),
#  ('UTCLS02155-1', 'BC808-25'),
#  ('UTCLS02155-1', 'BC808-40')]

# %%
# If necessary
if not snorkel_postgres:
    import os
    os.system('cp snorkel.db snorkel.db\ candidates');

# %% [markdown]
# ## Gold Labels

# %%
# If necessary
# import os
# os.remove('snorkel.db');
# os.system('cp snorkel.db\ candidates snorkel.db');

# import sys
# sys.path.append(os.environ['SNORKELHOME'] + '/tutorials/tables/')

# from snorkel import SnorkelSession
# session = SnorkelSession()

# from snorkel.models import candidate_subclass
# Part_Attr = candidate_subclass('Part_Attr', ['part','attr'])

# %%
import os
from snorkel.models import CandidateSet
from hardware_utils import load_hardware_labels

gold_file = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/dev/hardware_dev_gold.csv'
for set_name in ['Dev']:
    candidate_set_name = 'Hardware %s Candidates' % set_name
    candidates = session.query(CandidateSet).filter(
        CandidateSet.name == candidate_set_name).one()
    label_set_name = 'Hardware %s Candidates -- Gold' % set_name
    annotation_key_name = 'Hardware %s Labels -- Gold' % set_name
    # %time gold_candidates, annotation_key = load_hardware_labels(session,\
                           label_set_name, \
                           annotation_key_name, \
                           candidates, \
                           gold_file, \
                           ATTRIBUTE)
    candidates_gold = session.query(CandidateSet).filter(
        CandidateSet.name == candidate_set_name + ' -- Gold').one()
    print "%d/%d Candidates in %s have positive Labels" % (
        len(candidates_gold), len(candidates), candidates)
# Out:
# Loading 19846 candidate labels
# [========================================] 100%
# CPU times: user 41.9 s, sys: 1.42 s, total: 43.3 s
# Wall time: 55.6 s
# 15932/19846 Candidates in Candidate Set (Hardware Dev Candidates) have positive Labels

# %%
# If necessary
if not snorkel_postgres:
    import os
    os.system('cp snorkel.db snorkel.db\ labels');

# %% [markdown]
# ## Features

# %%
# # If necessary:
# import os
# # os.remove('snorkel.db');
# os.system('cp snorkel.db\ labels snorkel.db');

# from snorkel import SnorkelSession
# session = SnorkelSession()

# from snorkel.models import candidate_subclass
# Part_Attr = candidate_subclass('Part_Attr', ['part','attr'])

# %% [markdown]
# ### Extract Features

# %%
from snorkel.models import CandidateSet
from snorkel.utils import get_ORM_instance

train = get_ORM_instance(CandidateSet, session, 'Hardware Train Candidates')
dev   = get_ORM_instance(CandidateSet, session, 'Hardware Dev Candidates')

if snorkel_postgres:
    from snorkel.async_annotations import annotate
    print "Starting async featurization..."
    # %time F_train = annotate(train, parallel=PARALLEL)
    # %time F_dev   = annotate(dev,   parallel=PARALLEL, keyset = 'Hardware Train Candidates')

else:
    from snorkel.models import CandidateSet
    from snorkel.fast_annotations import FeatureManager
    from snorkel.utils import get_ORM_instance

    print "Starting sync featurization..."
    feature_manager = FeatureManager()
    # %time F_train = feature_manager.create(session, train, 'Train Features')
    # %time F_dev = feature_manager.update(session, dev, 'Train Features', expand_key_set=False)
# Out:
# Starting async featurization...
# [========================================] 100%
# Copying hardware_train_candidates_features to postgres
# COPY 67083
#
# CPU times: user 2min 21s, sys: 4.29 s, total: 2min 25s
# Wall time: 36min 57s
# [========================================] 100%
# Copying hardware_dev_candidates_features to postgres
# COPY 19846
#
# CPU times: user 29.4 s, sys: 2.75 s, total: 32.1 s
# Wall time: 19min 43s

# %%
# If necessary:
if not snorkel_postgres:
    import os
    os.system('cp snorkel.db snorkel.db\ featurized');

# %% [markdown]
# ## LFs

# %%
# If necessary
# import os
# os.remove('snorkel.db');
# os.system('cp snorkel.db\ featurized snorkel.db');

# from snorkel import SnorkelSession
# session = SnorkelSession()

# import sys
# sys.path.append(os.environ['SNORKELHOME'] + '/tutorials/tables/')

# from snorkel.models import candidate_subclass
# Part_Attr = candidate_subclass('Part_Attr', ['part','attr'])

# from snorkel.models import CandidateSet
# train = session.query(CandidateSet).filter(
#     CandidateSet.name == 'Hardware Train Candidates').one()
# dev = session.query(CandidateSet).filter(
#     CandidateSet.name == 'Hardware Dev Candidates').one()

# from snorkel.annotations import FeatureManager, LabelManager
# feature_manager = FeatureManager()
# %time F_train = feature_manager.load(session, train, 'Train Features')
# %time F_dev = feature_manager.load(session, dev, 'Train Features')

# %% [markdown]
# ### Define LFs

# %%
from hardware_lfs import get_lfs

LFs = get_lfs(ATTRIBUTE)

# %% [markdown]
# ### Apply LFs

# %%
if snorkel_postgres:
    from snorkel.async_annotations import annotate
    # %time L_train = annotate(train, parallel=PARALLEL, lfs=LFs)
else:
    from snorkel.fast_annotations import LabelManager
    label_manager = LabelManager()
    # %time L_train = label_manager.create(session, train, 'LF Labels', f=LFs)
L_train
# Out:
# [========================================] 100%
# Copying hardware_train_candidates_labels to postgres
# COPY 67083
#
# CPU times: user 7.5 s, sys: 1.57 s, total: 9.07 s
# Wall time: 20min 55s
# <67083x14 sparse matrix of type '<type 'numpy.float32'>'
# 	with 145088 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Assess LF accuracy

# %%
# %time L_train.lf_stats()
# Out:
# CPU times: user 16 ms, sys: 8 ms, total: 24 ms
# Wall time: 13.3 ms
#                                    conflicts  coverage   j  overlaps
# LF_both_in_top_third                0.190928  0.352876   0  0.352876
# LF_part_complement                  0.037103  0.037103   1  0.037103
# LF_part_num_in_high_col_num         0.009526  0.009526   2  0.009526
# LF_polarity_complement              0.136130  0.136130   3  0.136130
# LF_many_p_siblings                  0.000000  0.000000   4  0.000000
# LF_polarity_in_header_tag           0.131673  0.235127   5  0.235127
# LF_default_positive                 0.414516  1.000000   6  0.707139
# LF_replacement_table                0.000835  0.000835   7  0.000835
# LF_please_to_left                   0.002877  0.002877   8  0.002877
# LF_part_in_header_tag               0.033645  0.068289   9  0.068289
# LF_cheating_with_another_part       0.000000  0.000000  10  0.000000
# LF_polarity_part_tabular_align      0.001953  0.016934  11  0.016934
# LF_cheating_with_another_polarity   0.246173  0.246173  12  0.246173
# LF_polarity_part_horz_align         0.021138  0.056944  13  0.056944

# %%
# If necessary
if not snorkel_postgres:
    import os
    os.system('cp snorkel.db snorkel.db\ features');

# %% [markdown]
# ## Learn and Evaluate

# %%
# If necessary:
# import os
# os.remove('snorkel.db');
# os.system('cp snorkel.db\ features snorkel.db');

# from snorkel import SnorkelSession
# session = SnorkelSession()

# import sys
# sys.path.append(os.environ['SNORKELHOME'] + '/tutorials/tables/')

# from snorkel.models import candidate_subclass
# Part_Attr = candidate_subclass('Part_Attr', ['part','attr'])

# from snorkel.models import CandidateSet
# train = session.query(CandidateSet).filter(
#     CandidateSet.name == 'Hardware Training Candidates').one()
# dev = session.query(CandidateSet).filter(
#     CandidateSet.name == 'Hardware Development Candidates').one()

# from snorkel.annotations import FeatureManager, LabelManager
# feature_manager = FeatureManager()
# %time F_train = feature_manager.load(session, train, 'Train Features')
# %time F_dev = feature_manager.load(session, dev, 'Train Features')

# label_manager = LabelManager()
# %time L_train = label_manager.load(session, train, 'LF Labels')

# %%
from snorkel.learning import NaiveBayes

gen_model = NaiveBayes()
gen_model.train(L_train, n_iter=75000, rate=1e-3, mu=1e-6)
train_marginals = gen_model.marginals(L_train)
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/__init__.py:1173: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# ================================================================================
# Training marginals (!= 0.5):	67083
# Features:			14
# ================================================================================
# Begin training for rate=0.001, mu=1e-06
# 	Learning epoch = 0	Gradient mag. = 0.258102
# 	Learning epoch = 250	Gradient mag. = 0.282685
# 	Learning epoch = 500	Gradient mag. = 0.295057
# 	Learning epoch = 750	Gradient mag. = 0.308812
# 	Learning epoch = 1000	Gradient mag. = 0.323956
# 	Learning epoch = 1250	Gradient mag. = 0.340490
# 	Learning epoch = 1500	Gradient mag. = 0.358405
# 	Learning epoch = 1750	Gradient mag. = 0.377686
# 	Learning epoch = 2000	Gradient mag. = 0.398307
# 	Learning epoch = 2250	Gradient mag. = 0.420236
# 	Learning epoch = 2500	Gradient mag. = 0.443431
# 	Learning epoch = 2750	Gradient mag. = 0.467843
# 	Learning epoch = 3000	Gradient mag. = 0.493414
# 	Learning epoch = 3250	Gradient mag. = 0.520079
# 	Learning epoch = 3500	Gradient mag. = 0.547768
# 	Learning epoch = 3750	Gradient mag. = 0.576406
# 	Learning epoch = 4000	Gradient mag. = 0.605911
# 	Learning epoch = 4250	Gradient mag. = 0.636166
# 	Learning epoch = 4500	Gradient mag. = 0.667128
# 	Learning epoch = 4750	Gradient mag. = 0.698715
# 	Learning epoch = 5000	Gradient mag. = 0.730845
# 	Learning epoch = 5250	Gradient mag. = 0.763438
# 	Learning epoch = 5500	Gradient mag. = 0.796417
# 	Learning epoch = 5750	Gradient mag. = 0.829709
# 	Learning epoch = 6000	Gradient mag. = 0.863231
# 	Learning epoch = 6250	Gradient mag. = 0.896927
# 	Learning epoch = 6500	Gradient mag. = 0.930742
# 	Learning epoch = 6750	Gradient mag. = 0.964621
# 	Learning epoch = 7000	Gradient mag. = 0.998516
# 	Learning epoch = 7250	Gradient mag. = 1.032385
# 	Learning epoch = 7500	Gradient mag. = 1.066189
# 	Learning epoch = 7750	Gradient mag. = 1.099898
# 	Learning epoch = 8000	Gradient mag. = 1.133487
# 	Learning epoch = 8250	Gradient mag. = 1.166937
# 	Learning epoch = 8500	Gradient mag. = 1.200233
# 	Learning epoch = 8750	Gradient mag. = 1.233365
# 	Learning epoch = 9000	Gradient mag. = 1.266328
# 	Learning epoch = 9250	Gradient mag. = 1.299120
# 	Learning epoch = 9500	Gradient mag. = 1.331744
# 	Learning epoch = 9750	Gradient mag. = 1.364204
# 	Learning epoch = 10000	Gradient mag. = 1.372459
# 	Learning epoch = 10250	Gradient mag. = 1.373050
# 	Learning epoch = 10500	Gradient mag. = 1.375388
# 	Learning epoch = 10750	Gradient mag. = 1.379355
# 	Learning epoch = 11000	Gradient mag. = 1.384841
# 	Learning epoch = 11250	Gradient mag. = 1.375573
# 	Learning epoch = 11500	Gradient mag. = 1.350652
# 	Learning epoch = 11750	Gradient mag. = 1.327239
# 	Learning epoch = 12000	Gradient mag. = 1.304332
# 	Learning epoch = 12250	Gradient mag. = 1.277504
# 	Learning epoch = 12500	Gradient mag. = 1.251900
# 	Learning epoch = 12750	Gradient mag. = 1.227483
# 	Learning epoch = 13000	Gradient mag. = 1.204219
# 	Learning epoch = 13250	Gradient mag. = 1.181721
# 	Learning epoch = 13500	Gradient mag. = 1.159805
# 	Learning epoch = 13750	Gradient mag. = 1.137687
# 	Learning epoch = 14000	Gradient mag. = 1.116353
# 	Learning epoch = 14250	Gradient mag. = 1.095900
# 	Learning epoch = 14500	Gradient mag. = 1.076298
# 	Learning epoch = 14750	Gradient mag. = 1.057516
# 	Learning epoch = 15000	Gradient mag. = 1.039525
# 	Learning epoch = 15250	Gradient mag. = 1.022297
# 	Learning epoch = 15500	Gradient mag. = 1.005804
# 	Learning epoch = 15750	Gradient mag. = 0.990020
# 	Learning epoch = 16000	Gradient mag. = 0.974909
# 	Learning epoch = 16250	Gradient mag. = 0.960383
# 	Learning epoch = 16500	Gradient mag. = 0.946487
# 	Learning epoch = 16750	Gradient mag. = 0.932811
# 	Learning epoch = 17000	Gradient mag. = 0.919551
# 	Learning epoch = 17250	Gradient mag. = 0.906830
# 	Learning epoch = 17500	Gradient mag. = 0.894626
# 	Learning epoch = 17750	Gradient mag. = 0.882921
# 	Learning epoch = 18000	Gradient mag. = 0.871694
# 	Learning epoch = 18250	Gradient mag. = 0.860925
# 	Learning epoch = 18500	Gradient mag. = 0.845406
# 	Learning epoch = 18750	Gradient mag. = 0.799376
# 	Learning epoch = 19000	Gradient mag. = 0.759072
# 	Learning epoch = 19250	Gradient mag. = 0.723705
# 	Learning epoch = 19500	Gradient mag. = 0.692579
# 	Learning epoch = 19750	Gradient mag. = 0.665083
# 	Learning epoch = 20000	Gradient mag. = 0.640686
# 	Learning epoch = 20250	Gradient mag. = 0.618927
# 	Learning epoch = 20500	Gradient mag. = 0.599414
# 	Learning epoch = 20750	Gradient mag. = 0.581811
# 	Learning epoch = 21000	Gradient mag. = 0.565833
# 	Learning epoch = 21250	Gradient mag. = 0.551240
# 	Learning epoch = 21500	Gradient mag. = 0.537829
# 	Learning epoch = 21750	Gradient mag. = 0.525430
# 	Learning epoch = 22000	Gradient mag. = 0.513903
# 	Learning epoch = 22250	Gradient mag. = 0.503128
# 	Learning epoch = 22500	Gradient mag. = 0.493005
# 	Learning epoch = 22750	Gradient mag. = 0.483442
# 	Learning epoch = 23000	Gradient mag. = 0.474383
# 	Learning epoch = 23250	Gradient mag. = 0.465769
# 	Learning epoch = 23500	Gradient mag. = 0.457552
# 	Learning epoch = 23750	Gradient mag. = 0.449693
# 	Learning epoch = 24000	Gradient mag. = 0.442157
# 	Learning epoch = 24250	Gradient mag. = 0.434915
# 	Learning epoch = 24500	Gradient mag. = 0.427942
# 	Learning epoch = 24750	Gradient mag. = 0.421219
# 	Learning epoch = 25000	Gradient mag. = 0.414725
# 	Learning epoch = 25250	Gradient mag. = 0.408447
# 	Learning epoch = 25500	Gradient mag. = 0.402369
# 	Learning epoch = 25750	Gradient mag. = 0.396481
# 	Learning epoch = 26000	Gradient mag. = 0.390771
# 	Learning epoch = 26250	Gradient mag. = 0.385231
# 	Learning epoch = 26500	Gradient mag. = 0.379851
# 	Learning epoch = 26750	Gradient mag. = 0.374624
# 	Learning epoch = 27000	Gradient mag. = 0.369543
# 	Learning epoch = 27250	Gradient mag. = 0.364601
# 	Learning epoch = 27500	Gradient mag. = 0.359793
# 	Learning epoch = 27750	Gradient mag. = 0.355113
# 	Learning epoch = 28000	Gradient mag. = 0.350556
# 	Learning epoch = 28250	Gradient mag. = 0.346117
# 	Learning epoch = 28500	Gradient mag. = 0.341792
# 	Learning epoch = 28750	Gradient mag. = 0.337577
# 	Learning epoch = 29000	Gradient mag. = 0.333467
# 	Learning epoch = 29250	Gradient mag. = 0.329458
# 	Learning epoch = 29500	Gradient mag. = 0.325548
# 	Learning epoch = 29750	Gradient mag. = 0.321733
# 	Learning epoch = 30000	Gradient mag. = 0.318009
# 	Learning epoch = 30250	Gradient mag. = 0.314373
# 	Learning epoch = 30500	Gradient mag. = 0.310823
# 	Learning epoch = 30750	Gradient mag. = 0.307355
# 	Learning epoch = 31000	Gradient mag. = 0.303968
# 	Learning epoch = 31250	Gradient mag. = 0.300657
# 	Learning epoch = 31500	Gradient mag. = 0.297421
# 	Learning epoch = 31750	Gradient mag. = 0.294257
# 	Learning epoch = 32000	Gradient mag. = 0.291163
# 	Learning epoch = 32250	Gradient mag. = 0.288137
# 	Learning epoch = 32500	Gradient mag. = 0.285177
# 	Learning epoch = 32750	Gradient mag. = 0.282279
# 	Learning epoch = 33000	Gradient mag. = 0.279444
# 	Learning epoch = 33250	Gradient mag. = 0.276667
# 	Learning epoch = 33500	Gradient mag. = 0.273949
# 	Learning epoch = 33750	Gradient mag. = 0.271286
# 	Learning epoch = 34000	Gradient mag. = 0.268677
# 	Learning epoch = 34250	Gradient mag. = 0.266121
# 	Learning epoch = 34500	Gradient mag. = 0.263616
# 	Learning epoch = 34750	Gradient mag. = 0.261161
# 	Learning epoch = 35000	Gradient mag. = 0.258753
# 	Learning epoch = 35250	Gradient mag. = 0.256392
# 	Learning epoch = 35500	Gradient mag. = 0.254076
# 	Learning epoch = 35750	Gradient mag. = 0.251803
# 	Learning epoch = 36000	Gradient mag. = 0.249574
# 	Learning epoch = 36250	Gradient mag. = 0.247385
# 	Learning epoch = 36500	Gradient mag. = 0.245237
# 	Learning epoch = 36750	Gradient mag. = 0.243128
# 	Learning epoch = 37000	Gradient mag. = 0.241057
# 	Learning epoch = 37250	Gradient mag. = 0.239022
# 	Learning epoch = 37500	Gradient mag. = 0.237024
# 	Learning epoch = 37750	Gradient mag. = 0.235060
# 	Learning epoch = 38000	Gradient mag. = 0.233130
# 	Learning epoch = 38250	Gradient mag. = 0.231233
# 	Learning epoch = 38500	Gradient mag. = 0.229368
# 	Learning epoch = 38750	Gradient mag. = 0.227534
# 	Learning epoch = 39000	Gradient mag. = 0.225730
# 	Learning epoch = 39250	Gradient mag. = 0.223956
# 	Learning epoch = 39500	Gradient mag. = 0.222211
# 	Learning epoch = 39750	Gradient mag. = 0.220494
# 	Learning epoch = 40000	Gradient mag. = 0.218804
# 	Learning epoch = 40250	Gradient mag. = 0.217141
# 	Learning epoch = 40500	Gradient mag. = 0.215504
# 	Learning epoch = 40750	Gradient mag. = 0.213891
# 	Learning epoch = 41000	Gradient mag. = 0.212304
# 	Learning epoch = 41250	Gradient mag. = 0.210741
# 	Learning epoch = 41500	Gradient mag. = 0.209201
# 	Learning epoch = 41750	Gradient mag. = 0.207683
# 	Learning epoch = 42000	Gradient mag. = 0.206189
# 	Learning epoch = 42250	Gradient mag. = 0.204716
# 	Learning epoch = 42500	Gradient mag. = 0.203264
# 	Learning epoch = 42750	Gradient mag. = 0.201833
# 	Learning epoch = 43000	Gradient mag. = 0.200422
# 	Learning epoch = 43250	Gradient mag. = 0.199031
# 	Learning epoch = 43500	Gradient mag. = 0.197659
# 	Learning epoch = 43750	Gradient mag. = 0.196306
# 	Learning epoch = 44000	Gradient mag. = 0.194972
# 	Learning epoch = 44250	Gradient mag. = 0.193656
# 	Learning epoch = 44500	Gradient mag. = 0.192357
# 	Learning epoch = 44750	Gradient mag. = 0.191076
# 	Learning epoch = 45000	Gradient mag. = 0.189811
# 	Learning epoch = 45250	Gradient mag. = 0.188563
# 	Learning epoch = 45500	Gradient mag. = 0.187332
# 	Learning epoch = 45750	Gradient mag. = 0.186116
# 	Learning epoch = 46000	Gradient mag. = 0.184915
# 	Learning epoch = 46250	Gradient mag. = 0.183730
# 	Learning epoch = 46500	Gradient mag. = 0.182559
# 	Learning epoch = 46750	Gradient mag. = 0.181403
# 	Learning epoch = 47000	Gradient mag. = 0.180262
# 	Learning epoch = 47250	Gradient mag. = 0.179134
# 	Learning epoch = 47500	Gradient mag. = 0.178020
# 	Learning epoch = 47750	Gradient mag. = 0.176919
# 	Learning epoch = 48000	Gradient mag. = 0.175832
# 	Learning epoch = 48250	Gradient mag. = 0.174757
# 	Learning epoch = 48500	Gradient mag. = 0.173695
# 	Learning epoch = 48750	Gradient mag. = 0.172645
# 	Learning epoch = 49000	Gradient mag. = 0.171608
# 	Learning epoch = 49250	Gradient mag. = 0.170582
# 	Learning epoch = 49500	Gradient mag. = 0.169568
# 	Learning epoch = 49750	Gradient mag. = 0.168566
# 	Learning epoch = 50000	Gradient mag. = 0.167575
# 	Learning epoch = 50250	Gradient mag. = 0.166595
# 	Learning epoch = 50500	Gradient mag. = 0.165626
# 	Learning epoch = 50750	Gradient mag. = 0.164667
# 	Learning epoch = 51000	Gradient mag. = 0.163719
# 	Learning epoch = 51250	Gradient mag. = 0.162781
# 	Learning epoch = 51500	Gradient mag. = 0.161854
# 	Learning epoch = 51750	Gradient mag. = 0.160936
# 	Learning epoch = 52000	Gradient mag. = 0.160028
# 	Learning epoch = 52250	Gradient mag. = 0.159130
# 	Learning epoch = 52500	Gradient mag. = 0.158241
# 	Learning epoch = 52750	Gradient mag. = 0.157361
# 	Learning epoch = 53000	Gradient mag. = 0.156491
# 	Learning epoch = 53250	Gradient mag. = 0.155629
# 	Learning epoch = 53500	Gradient mag. = 0.154777
# 	Learning epoch = 53750	Gradient mag. = 0.153933
# 	Learning epoch = 54000	Gradient mag. = 0.153097
# 	Learning epoch = 54250	Gradient mag. = 0.152270
# 	Learning epoch = 54500	Gradient mag. = 0.151452
# 	Learning epoch = 54750	Gradient mag. = 0.150641
# 	Learning epoch = 55000	Gradient mag. = 0.149838
# 	Learning epoch = 55250	Gradient mag. = 0.149044
# 	Learning epoch = 55500	Gradient mag. = 0.148257
# 	Learning epoch = 55750	Gradient mag. = 0.147478
# 	Learning epoch = 56000	Gradient mag. = 0.146706
# 	Learning epoch = 56250	Gradient mag. = 0.145942
# 	Learning epoch = 56500	Gradient mag. = 0.145185
# 	Learning epoch = 56750	Gradient mag. = 0.144435
# 	Learning epoch = 57000	Gradient mag. = 0.143692
# 	Learning epoch = 57250	Gradient mag. = 0.142957
# 	Learning epoch = 57500	Gradient mag. = 0.142228
# 	Learning epoch = 57750	Gradient mag. = 0.141506
# 	Learning epoch = 58000	Gradient mag. = 0.140791
# 	Learning epoch = 58250	Gradient mag. = 0.140082
# 	Learning epoch = 58500	Gradient mag. = 0.139380
# 	Learning epoch = 58750	Gradient mag. = 0.138684
# 	Learning epoch = 59000	Gradient mag. = 0.137995
# 	Learning epoch = 59250	Gradient mag. = 0.137311
# 	Learning epoch = 59500	Gradient mag. = 0.136634
# 	Learning epoch = 59750	Gradient mag. = 0.135963
# 	Learning epoch = 60000	Gradient mag. = 0.135299
# 	Learning epoch = 60250	Gradient mag. = 0.134639
# 	Learning epoch = 60500	Gradient mag. = 0.133986
# 	Learning epoch = 60750	Gradient mag. = 0.133339
# 	Learning epoch = 61000	Gradient mag. = 0.132697
# 	Learning epoch = 61250	Gradient mag. = 0.132061
# 	Learning epoch = 61500	Gradient mag. = 0.131430
# 	Learning epoch = 61750	Gradient mag. = 0.130805
# 	Learning epoch = 62000	Gradient mag. = 0.130185
# 	Learning epoch = 62250	Gradient mag. = 0.129571
# 	Learning epoch = 62500	Gradient mag. = 0.128962
# 	Learning epoch = 62750	Gradient mag. = 0.128358
# 	Learning epoch = 63000	Gradient mag. = 0.127759
# 	Learning epoch = 63250	Gradient mag. = 0.127165
# 	Learning epoch = 63500	Gradient mag. = 0.126576
# 	Learning epoch = 63750	Gradient mag. = 0.125992
# 	Learning epoch = 64000	Gradient mag. = 0.125413
# 	Learning epoch = 64250	Gradient mag. = 0.124839
# 	Learning epoch = 64500	Gradient mag. = 0.124270
# 	Learning epoch = 64750	Gradient mag. = 0.123705
# 	Learning epoch = 65000	Gradient mag. = 0.123145
# 	Learning epoch = 65250	Gradient mag. = 0.122589
# 	Learning epoch = 65500	Gradient mag. = 0.122038
# 	Learning epoch = 65750	Gradient mag. = 0.121492
# 	Learning epoch = 66000	Gradient mag. = 0.120950
# 	Learning epoch = 66250	Gradient mag. = 0.120412
# 	Learning epoch = 66500	Gradient mag. = 0.119879
# 	Learning epoch = 66750	Gradient mag. = 0.119350
# 	Learning epoch = 67000	Gradient mag. = 0.118825
# 	Learning epoch = 67250	Gradient mag. = 0.118304
# 	Learning epoch = 67500	Gradient mag. = 0.117788
# 	Learning epoch = 67750	Gradient mag. = 0.117276
# 	Learning epoch = 68000	Gradient mag. = 0.116767
# 	Learning epoch = 68250	Gradient mag. = 0.116263
# 	Learning epoch = 68500	Gradient mag. = 0.115762
# 	Learning epoch = 68750	Gradient mag. = 0.115266
# 	Learning epoch = 69000	Gradient mag. = 0.114773
# 	Learning epoch = 69250	Gradient mag. = 0.114285
# 	Learning epoch = 69500	Gradient mag. = 0.113800
# 	Learning epoch = 69750	Gradient mag. = 0.113318
# 	Learning epoch = 70000	Gradient mag. = 0.112841
# 	Learning epoch = 70250	Gradient mag. = 0.112367
# 	Learning epoch = 70500	Gradient mag. = 0.111897
# 	Learning epoch = 70750	Gradient mag. = 0.111430
# 	Learning epoch = 71000	Gradient mag. = 0.110967
# 	Learning epoch = 71250	Gradient mag. = 0.110507
# 	Learning epoch = 71500	Gradient mag. = 0.110051
# 	Learning epoch = 71750	Gradient mag. = 0.109599
# 	Learning epoch = 72000	Gradient mag. = 0.109149
# 	Learning epoch = 72250	Gradient mag. = 0.108703
# 	Learning epoch = 72500	Gradient mag. = 0.108261
# 	Learning epoch = 72750	Gradient mag. = 0.107822
# 	Learning epoch = 73000	Gradient mag. = 0.107386
# 	Learning epoch = 73250	Gradient mag. = 0.106953
# 	Learning epoch = 73500	Gradient mag. = 0.106523
# 	Learning epoch = 73750	Gradient mag. = 0.106097
# 	Learning epoch = 74000	Gradient mag. = 0.105674
# 	Learning epoch = 74250	Gradient mag. = 0.105254
# 	Learning epoch = 74500	Gradient mag. = 0.104837
# 	Learning epoch = 74750	Gradient mag. = 0.104423
# Final gradient magnitude for rate=0.001, mu=1e-06: 0.104

# %%
from snorkel.learning import LogReg

disc_model = LogReg()
disc_model.train(F_train, train_marginals, n_iter=2000, rate=1e-4)
# Out:
# ================================================================================
# Training marginals (!= 0.5):	67083
# Features:			53845
# ================================================================================
# Using gradient descent...
# 	Learning epoch = 0	Step size = 0.0001
# 	Loss = 46498.392314	Gradient magnitude = 231646.567078
# 	Learning epoch = 100	Step size = 9.04792147114e-05
# 	Loss = 22.730937	Gradient magnitude = 5.756427
# 	Learning epoch = 200	Step size = 8.18648829479e-05
# 	Loss = 22.730934	Gradient magnitude = 5.756427
# 	Learning epoch = 300	Step size = 7.40707032156e-05
# 	Loss = 22.730932	Gradient magnitude = 5.756427
# 	Learning epoch = 400	Step size = 6.70185906007e-05
# 	Loss = 22.730930	Gradient magnitude = 5.756427
# 	Learning epoch = 500	Step size = 6.06378944861e-05
# 	Loss = 22.730928	Gradient magnitude = 5.756427
# 	Learning epoch = 600	Step size = 5.48646907485e-05
# 	Loss = 22.730926	Gradient magnitude = 5.756427
# 	Learning epoch = 700	Step size = 4.96411413431e-05
# 	Loss = 22.730924	Gradient magnitude = 5.756427
# 	Learning epoch = 800	Step size = 4.4914914861e-05
# 	Loss = 22.730923	Gradient magnitude = 5.756427
# 	Learning epoch = 900	Step size = 4.06386622545e-05
# 	Loss = 22.730922	Gradient magnitude = 5.756427
# 	Learning epoch = 1000	Step size = 3.67695424771e-05
# 	Loss = 22.730920	Gradient magnitude = 5.756427
# 	Learning epoch = 1100	Step size = 3.32687932862e-05
# 	Loss = 22.730919	Gradient magnitude = 5.756427
# 	Learning epoch = 1200	Step size = 3.01013429093e-05
# 	Loss = 22.730918	Gradient magnitude = 5.756427
# 	Learning epoch = 1300	Step size = 2.72354586819e-05
# 	Loss = 22.730917	Gradient magnitude = 5.756427
# 	Learning epoch = 1400	Step size = 2.46424291385e-05
# 	Loss = 22.730916	Gradient magnitude = 5.756427
# 	Learning epoch = 1500	Step size = 2.22962763703e-05
# 	Loss = 22.730915	Gradient magnitude = 5.756427
# 	Learning epoch = 1600	Step size = 2.01734957697e-05
# 	Loss = 22.730914	Gradient magnitude = 5.756427
# 	Learning epoch = 1700	Step size = 1.82528205523e-05
# 	Loss = 22.730913	Gradient magnitude = 5.756427
# 	Learning epoch = 1800	Step size = 1.65150086984e-05
# 	Loss = 22.730912	Gradient magnitude = 5.756427
# 	Learning epoch = 1900	Step size = 1.49426501798e-05
# 	Loss = 22.730911	Gradient magnitude = 5.756427

# %%
dev_gold = session.query(CandidateSet).filter(
    CandidateSet.name == 'Hardware Dev Candidates -- Gold').one()

# %%
# if snorkel_postgres:
#     L_dev = annotate(dev, lfs=LFs)
# else:
from snorkel.annotations import LabelManager
label_manager = LabelManager()
L_dev = label_manager.load(session, dev, 'Hardware Dev Labels -- Gold')
L_dev.shape
# Out:
# (19846, 1)

# %%
tp, fp, tn, fn = disc_model.score(F_dev, L_dev, dev_gold)
# Out:
# Calibration plot:
# /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# ========================================
# Recall-corrected Noise-aware Model
# ========================================
# Pos. class accuracy: 1.0
# Neg. class accuracy: 0.0
# Corpus Precision 0.803
# Corpus Recall    1.0
# Corpus F1        0.891
# ----------------------------------------
# TP: 15932 | FP: 3914 | TN: 0 | FN: 0
# ========================================
#
# ========================================
# Recall-corrected Noise-aware Model
# ========================================
# Pos. class accuracy: 0.5
# Neg. class accuracy: 0.0
# Corpus Precision 0.803
# Corpus Recall    0.5
# Corpus F1        0.616
# ----------------------------------------
# TP: 15932 | FP: 3914 | TN: 0 | FN: 15932
# ========================================

# %%
from snorkel.models import Corpus
from hardware_utils import entity_level_f1
import os

gold_file = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/dev/hardware_dev_gold.csv'
corpus = session.query(Corpus).filter(Corpus.name == 'Hardware Dev').one()
(TP, FP, FN) = entity_level_f1(tp, fp, tn, fn, gold_file, corpus, ATTRIBUTE)
# Out:
# ========================================
# Scoring on Entity-Level Gold Data
# ========================================
# Corpus Precision 0.841
# Corpus Recall    0.717
# Corpus F1        0.774
# ----------------------------------------
# TP: 665 | FP: 126 | FN: 262
# ========================================

# %%
from hardware_utils import separate_fns

unfound, misclassified = separate_fns(FN, cfn)
pprint(misclassified)
# Out:
# 262 fns
# 92 unfound
# 170 misclassified
# set([('112823', 'BC546BG', 'NPN'),
#      ('112823', 'BC546BRL1G', 'NPN'),
#      ('112823', 'BC546BZL1G', 'NPN'),
#      ('112823', 'BC547ARLG', 'NPN'),
#      ('112823', 'BC547AZL1G', 'NPN'),
#      ('112823', 'BC547BG', 'NPN'),
#      ('112823', 'BC547BRL1G', 'NPN'),
#      ('112823', 'BC547BZL1G', 'NPN'),
#      ('112823', 'BC547CG', 'NPN'),
#      ('112823', 'BC547CZL1G', 'NPN'),
#      ('112823', 'BC548BG', 'NPN'),
#      ('112823', 'BC548BRL1G', 'NPN'),
#      ('112823', 'BC548BZL1G', 'NPN'),
#      ('112823', 'BC548CG', 'NPN'),
#      ('112823', 'BC548CZL1G', 'NPN'),
#      ('BC337', 'BC337-16', 'NPN'),
#      ('BC337', 'BC337-25', 'NPN'),
#      ('BC337', 'BC337-40', 'NPN'),
#      ('BC337', 'BC338-25', 'NPN'),
#      ('BC546-D', 'BC546BG', 'NPN'),
#      ('BC546-D', 'BC546BRL1G', 'NPN'),
#      ('BC546-D', 'BC546BZL1G', 'NPN'),
#      ('BC546-D', 'BC547ARLG', 'NPN'),
#      ('BC546-D', 'BC547AZL1G', 'NPN'),
#      ('BC546-D', 'BC547BG', 'NPN'),
#      ('BC546-D', 'BC547BRL1G', 'NPN'),
#      ('BC546-D', 'BC547BZL1G', 'NPN'),
#      ('BC546-D', 'BC547CG', 'NPN'),
#      ('BC546-D', 'BC547CZL1G', 'NPN'),
#      ('BC546-D', 'BC548BG', 'NPN'),
#      ('BC546-D', 'BC548BRL1G', 'NPN'),
#      ('BC546-D', 'BC548BZL1G', 'NPN'),
#      ('BC546-D', 'BC548CG', 'NPN'),
#      ('BC546-D', 'BC548CZL1G', 'NPN'),
#      ('BC546_DIOTEC', 'BC546A', 'NPN'),
#      ('BC546_DIOTEC', 'BC546B', 'NPN'),
#      ('BC546_DIOTEC', 'BC547A', 'NPN'),
#      ('BC546_DIOTEC', 'BC547B', 'NPN'),
#      ('BC546_DIOTEC', 'BC547C', 'NPN'),
#      ('BC546_DIOTEC', 'BC548A', 'NPN'),
#      ('BC546_DIOTEC', 'BC548B', 'NPN'),
#      ('BC546_DIOTEC', 'BC548C', 'NPN'),
#      ('BC546_DIOTEC', 'BC549B', 'NPN'),
#      ('BC546_DIOTEC', 'BC549C', 'NPN'),
#      ('BC550', 'BC546A', 'NPN'),
#      ('BC550', 'BC546B', 'NPN'),
#      ('BC550', 'BC546C', 'NPN'),
#      ('BC550', 'BC547A', 'NPN'),
#      ('BC550', 'BC547B', 'NPN'),
#      ('BC550', 'BC547C', 'NPN'),
#      ('BC550', 'BC548A', 'NPN'),
#      ('BC550', 'BC548B', 'NPN'),
#      ('BC550', 'BC548C', 'NPN'),
#      ('BC550', 'BC549A', 'NPN'),
#      ('BC550', 'BC549B', 'NPN'),
#      ('BC550', 'BC549C', 'NPN'),
#      ('BC550', 'BC550A', 'NPN'),
#      ('BC550', 'BC550B', 'NPN'),
#      ('BC550', 'BC550C', 'NPN'),
#      ('BC818', 'BC817-16', 'NPN'),
#      ('BC818', 'BC817-25', 'NPN'),
#      ('BC818', 'BC817-40', 'NPN'),
#      ('BC818', 'BC818-16', 'NPN'),
#      ('BC818', 'BC818-25', 'NPN'),
#      ('BC818', 'BC818-40', 'NPN'),
#      ('DISES00189-1', 'BC546A', 'NPN'),
#      ('DISES00189-1', 'BC546B', 'NPN'),
#      ('DISES00189-1', 'BC547A', 'NPN'),
#      ('DISES00189-1', 'BC547B', 'NPN'),
#      ('DISES00189-1', 'BC547C', 'NPN'),
#      ('DISES00189-1', 'BC548A', 'NPN'),
#      ('DISES00189-1', 'BC548B', 'NPN'),
#      ('DISES00189-1', 'BC548C', 'NPN'),
#      ('DISES00189-1', 'BC549B', 'NPN'),
#      ('DISES00189-1', 'BC549C', 'NPN'),
#      ('DISES00192-1', 'BC807-16', 'PNP'),
#      ('DISES00192-1', 'BC807-25', 'PNP'),
#      ('DISES00192-1', 'BC807-40', 'PNP'),
#      ('DISES00192-1', 'BC808-16', 'PNP'),
#      ('DISES00192-1', 'BC808-25', 'PNP'),
#      ('DISES00192-1', 'BC808-40', 'PNP'),
#      ('DISES00616-1', 'BC856A', 'PNP'),
#      ('DISES00616-1', 'BC856B', 'PNP'),
#      ('DISES00616-1', 'BC856C', 'PNP'),
#      ('DISES00616-1', 'BC857A', 'PNP'),
#      ('DISES00616-1', 'BC857B', 'PNP'),
#      ('DISES00616-1', 'BC857C', 'PNP'),
#      ('DISES00616-1', 'BC858A', 'PNP'),
#      ('DISES00616-1', 'BC858B', 'PNP'),
#      ('DISES00616-1', 'BC858C', 'PNP'),
#      ('DISES00616-1', 'BC859B', 'PNP'),
#      ('DISES00616-1', 'BC859C', 'PNP'),
#      ('DISES00616-1', 'BC860B', 'PNP'),
#      ('DISES00616-1', 'BC860C', 'PNP'),
#      ('DISES00645-1', 'BC817K-16', 'NPN'),
#      ('DISES00645-1', 'BC817K-25', 'NPN'),
#      ('DISES00645-1', 'BC817K-40', 'NPN'),
#      ('DISES00645-1', 'BC818K-16', 'NPN'),
#      ('DISES00645-1', 'BC818K-25', 'NPN'),
#      ('DISES00645-1', 'BC818K-40', 'NPN'),
#      ('FAIRS19194-1', 'BC856A', 'PNP'),
#      ('FAIRS19194-1', 'BC856B', 'PNP'),
#      ('FAIRS19194-1', 'BC856C', 'PNP'),
#      ('FAIRS19194-1', 'BC857A', 'PNP'),
#      ('FAIRS19194-1', 'BC857B', 'PNP'),
#      ('FAIRS19194-1', 'BC857C', 'PNP'),
#      ('FAIRS19194-1', 'BC858A', 'PNP'),
#      ('FAIRS19194-1', 'BC858B', 'PNP'),
#      ('FAIRS19194-1', 'BC858C', 'PNP'),
#      ('FAIRS19194-1', 'BC859A', 'PNP'),
#      ('FAIRS19194-1', 'BC859B', 'PNP'),
#      ('FAIRS19194-1', 'BC859C', 'PNP'),
#      ('FAIRS19194-1', 'BC860A', 'PNP'),
#      ('FAIRS19194-1', 'BC860B', 'PNP'),
#      ('FAIRS19194-1', 'BC860C', 'PNP'),
#      ('FAIRS25065-1', 'BC237A', 'NPN'),
#      ('FAIRS25065-1', 'BC237B', 'NPN'),
#      ('FAIRS25065-1', 'BC237C', 'NPN'),
#      ('FAIRS25065-1', 'BC238A', 'NPN'),
#      ('FAIRS25065-1', 'BC238B', 'NPN'),
#      ('FAIRS25065-1', 'BC238C', 'NPN'),
#      ('FAIRS25065-1', 'BC239A', 'NPN'),
#      ('FAIRS25065-1', 'BC239B', 'NPN'),
#      ('FAIRS25065-1', 'BC239C', 'NPN'),
#      ('KECCS05435-1', 'BC546A', 'NPN'),
#      ('KECCS05435-1', 'BC546B', 'NPN'),
#      ('KECCS05435-1', 'BC547A', 'NPN'),
#      ('KECCS05435-1', 'BC547B', 'NPN'),
#      ('KECCS05435-1', 'BC547C', 'NPN'),
#      ('KECCS05435-1', 'BC548A', 'NPN'),
#      ('KECCS05435-1', 'BC548B', 'NPN'),
#      ('KECCS05435-1', 'BC548C', 'NPN'),
#      ('LITES00689-1', 'BC337-16', 'NPN'),
#      ('LITES00689-1', 'BC337-40', 'NPN'),
#      ('LITES00690-1', 'BC546A', 'NPN'),
#      ('LITES00690-1', 'BC546B', 'NPN'),
#      ('LITES00690-1', 'BC546C', 'NPN'),
#      ('LITES00690-1', 'BC547A', 'NPN'),
#      ('LITES00690-1', 'BC547B', 'NPN'),
#      ('LITES00690-1', 'BC547C', 'NPN'),
#      ('LITES00690-1', 'BC548A', 'NPN'),
#      ('LITES00690-1', 'BC548B', 'NPN'),
#      ('LITES00690-1', 'BC548C', 'NPN'),
#      ('PHGLS25601-1', 'BC846BT', 'NPN'),
#      ('PNJIS01593-1', 'BC856A', 'PNP'),
#      ('PNJIS01593-1', 'BC856B', 'PNP'),
#      ('PNJIS01593-1', 'BC857A', 'PNP'),
#      ('PNJIS01593-1', 'BC857B', 'PNP'),
#      ('PNJIS01593-1', 'BC857C', 'PNP'),
#      ('PNJIS01593-1', 'BC858A', 'PNP'),
#      ('PNJIS01593-1', 'BC858B', 'PNP'),
#      ('PNJIS01593-1', 'BC858C', 'PNP'),
#      ('PNJIS01593-1', 'BC859B', 'PNP'),
#      ('PNJIS01593-1', 'BC859C', 'PNP'),
#      ('VISHS23888-1', 'BC546A', 'NPN'),
#      ('VISHS23888-1', 'BC546B', 'NPN'),
#      ('VISHS23888-1', 'BC547A', 'NPN'),
#      ('VISHS23888-1', 'BC547B', 'NPN'),
#      ('VISHS23888-1', 'BC547C', 'NPN'),
#      ('VISHS23888-1', 'BC548A', 'NPN'),
#      ('VISHS23888-1', 'BC548B', 'NPN'),
#      ('VISHS23888-1', 'BC548C', 'NPN'),
#      ('VISHS23888-1', 'BC549B', 'NPN'),
#      ('VISHS23888-1', 'BC549C', 'NPN'),
#      ('VSMIS00373-1', 'BC337-16', 'NPN'),
#      ('VSMIS00373-1', 'BC337-25', 'NPN'),
#      ('VSMIS00373-1', 'BC337-40', 'NPN'),
#      ('VSMIS00373-1', 'BC338-16', 'NPN'),
#      ('VSMIS00373-1', 'BC338-25', 'NPN'),
#      ('VSMIS00373-1', 'BC338-40', 'NPN')])

# %%
from pprint import pprint
pprint(FP)
# Out:
# [(u'BC337', u'BC33716', u'NPN'),
#  (u'BC337', u'BC33725', u'NPN'),
#  (u'BC337', u'BC33740', u'NPN'),
#  (u'BC337', u'BC33740BU', u'NPN'),
#  (u'BC337', u'BC33825', u'NPN'),
#  (u'BC546-BC548C(TO-92)', u'BC546-BC548C', u'NPN'),
#  (u'BC547', u'BC548BU', u'NPN'),
#  (u'BC818-40LT1-D', u'BC818-40LT1', u'NPN'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N3576', u'NPN'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N3672', u'NPN'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N3700', u'PNP'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N3701', u'PNP'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N3798A', u'NPN'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N3799A', u'NPN'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N3829', u'NPN'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N3946', u'PNP'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N3947', u'PNP'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N3962', u'NPN'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N3963', u'NPN'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N3964', u'NPN'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N3965', u'NPN'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N4013', u'PNP'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N4014', u'PNP'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N4026', u'NPN'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N4027', u'NPN'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N4028', u'NPN'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N4029', u'NPN'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N4034', u'NPN'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N4035', u'NPN'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N4068', u'PNP'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N4137', u'PNP'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N4207', u'NPN'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N4208', u'NPN'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N4209', u'NPN'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N4269', u'PNP'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N4359', u'NPN'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N4384', u'PNP'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N4386', u'PNP'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N4390', u'PNP'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N4413A', u'NPN'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N4415A', u'NPN'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N4962', u'PNP'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N4963', u'PNP'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N5056', u'NPN'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'2N5057', u'NPN'),
#  (u'CENTRALSEMICONDUCTORCORP_2N4013', u'CM4209', u'NPN'),
#  (u'CSEMS05382-1', u'BC546-48ABC', u'NPN'),
#  (u'DIODESINCORPORATED_FCX491ATA', u'AP02001', u'NPN'),
#  (u'DIODESINCORPORATED_FCX491ATA', u'AP02002', u'NPN'),
#  (u'DIODESINCORPORATED_FZT651TC', u'AP02001', u'NPN'),
#  (u'DIODESINCORPORATED_FZT651TC', u'AP02002', u'NPN'),
#  (u'DIODESINCORPORATED_ZXT690BKTC', u'AP02001', u'NPN'),
#  (u'DIODESINCORPORATED_ZXT690BKTC', u'AP02002', u'NPN'),
#  (u'DIODESINCORPORATED_ZXT690BKTC', u'ZXT690B', u'NPN'),
#  (u'DIODS13249-1', u'BC808', u'NPN'),
#  (u'DIODS13249-1', u'BC81840', u'NPN'),
#  (u'DISES00189-1', u'BC546XBK', u'NPN'),
#  (u'DISES00189-1', u'BC547XBK', u'NPN'),
#  (u'DISES00189-1', u'BC548XBK', u'NPN'),
#  (u'DISES00189-1', u'BC549XBK', u'NPN'),
#  (u'INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', u'AN077', u'NPN'),
#  (u'INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', u'BC817', u'NPN'),
#  (u'INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', u'BC818', u'NPN'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'AN077',
#   u'PNP'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC850',
#   u'PNP'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857-BC860',
#   u'PNP'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857W',
#   u'PNP'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857W-BC860W',
#   u'PNP'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC858W',
#   u'PNP'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC859W',
#   u'PNP'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC860W',
#   u'PNP'),
#  (u'INFNS19372-1', u'AN077', u'NPN'),
#  (u'LITES00690-1', u'BC556', u'NPN'),
#  (u'LITES00690-1', u'BC557', u'NPN'),
#  (u'LITES00690-1', u'BC558', u'NPN'),
#  (u'LTSCS02910-1', u'BC818-REV', u'NPN'),
#  (u'LTSCS02912-1', u'BC846W-REV', u'NPN'),
#  (u'LTSCS02920-1', u'BC857-REV', u'PNP'),
#  (u'MCCCS09540-1', u'BC846A-BC849C', u'NPN'),
#  (u'MICROCOMMERCIALCO_TIP29ABP', u'TIP29', u'PNP'),
#  (u'MICROCOMMERCIALCO_TIP29ABP', u'TIP29A', u'PNP'),
#  (u'MICROCOMMERCIALCO_TIP29ABP', u'TIP29B', u'PNP'),
#  (u'MICROCOMMERCIALCO_TIP29ABP', u'TIP29C', u'PNP'),
#  (u'MICROCOMMERCIALCO_TIP29ABP', u'TIP30', u'NPN'),
#  (u'MICROCOMMERCIALCO_TIP29ABP', u'TIP30A', u'NPN'),
#  (u'MICROCOMMERCIALCO_TIP29ABP', u'TIP30B', u'NPN'),
#  (u'MICROCOMMERCIALCO_TIP29ABP', u'TIP30C', u'NPN'),
#  (u'ONSEMICONDUCTOR_MMBT6521LT1', u'AN569', u'NPN'),
#  (u'ONSMS04099-1', u'MPS3904', u'NPN'),
#  (u'PHGLS18216-1', u'BC557', u'NPN'),
#  (u'PHGLS18216-1', u'BC557B', u'NPN'),
#  (u'PHGLS18216-1', u'BC557C', u'NPN'),
#  (u'PHGLS18216-1', u'BC847DG', u'NPN'),
#  (u'PHGLS18216-1', u'BC857', u'NPN'),
#  (u'PHGLS18216-1', u'BC857A', u'NPN'),
#  (u'PHGLS18216-1', u'BC857AM', u'NPN'),
#  (u'PHGLS18216-1', u'BC857AT', u'NPN'),
#  (u'PHGLS18216-1', u'BC857AW', u'NPN'),
#  (u'PHGLS18216-1', u'BC857B', u'NPN'),
#  (u'PHGLS18216-1', u'BC857BM', u'NPN'),
#  (u'PHGLS18216-1', u'BC857BT', u'NPN'),
#  (u'PHGLS18216-1', u'BC857BW', u'NPN'),
#  (u'PHGLS18216-1', u'BC857C', u'NPN'),
#  (u'PHGLS18216-1', u'BC857CM', u'NPN'),
#  (u'PHGLS18216-1', u'BC857CT', u'NPN'),
#  (u'PHGLS18216-1', u'BC857CW', u'NPN'),
#  (u'PHGLS18216-1', u'BC857T', u'NPN'),
#  (u'PHGLS18216-1', u'BC857W', u'NPN'),
#  (u'PHGLS25601-1', u'BC856', u'NPN'),
#  (u'PHGLS25601-1', u'BC856T', u'NPN'),
#  (u'PHGLS25601-1', u'BC856W', u'NPN'),
#  (u'PNJIS01186-1', u'BC807', u'PNP'),
#  (u'PNJIS01593-1', u'BC846', u'PNP'),
#  (u'PNJIS01593-1', u'BC849', u'PNP'),
#  (u'RECTS01158-1', u'BC807-25LT1', u'PNP'),
#  (u'RECTS01214-1', u'DTC114ECA-1', u'NPN'),
#  (u'RECTS01242-1', u'BC857BLT1', u'PNP'),
#  (u'RECTS01325-1', u'DTC114YCA-1', u'NPN'),
#  (u'TWSCS04757-1', u'BC807', u'PNP'),
#  (u'TWSCS04757-1', u'BC807-XX', u'PNP'),
#  (u'UTCLS01324-1', u'MMBT3904-E', u'NPN'),
#  (u'UTCLS03593-1', u'DTC114E-I', u'NPN'),
#  (u'VSMIS03793-1', u'BC807', u'NPN'),
#  (u'VSMIS03793-1', u'BC808', u'NPN'),
#  (u'WEITS00252-1', u'BC807-1', u'PNP'),
#  (u'ZETXS01948-1', u'BC860C', u'PNP')]

# %%
from pprint import pprint
pprint(FN)
# Out:
# [('112823', 'BC546BG', 'NPN'),
#  ('112823', 'BC546BRL1G', 'NPN'),
#  ('112823', 'BC546BZL1G', 'NPN'),
#  ('112823', 'BC547ARLG', 'NPN'),
#  ('112823', 'BC547AZL1G', 'NPN'),
#  ('112823', 'BC547BG', 'NPN'),
#  ('112823', 'BC547BRL1G', 'NPN'),
#  ('112823', 'BC547BZL1G', 'NPN'),
#  ('112823', 'BC547CG', 'NPN'),
#  ('112823', 'BC547CZL1G', 'NPN'),
#  ('112823', 'BC548BG', 'NPN'),
#  ('112823', 'BC548BRL1G', 'NPN'),
#  ('112823', 'BC548BZL1G', 'NPN'),
#  ('112823', 'BC548CG', 'NPN'),
#  ('112823', 'BC548CZL1G', 'NPN'),
#  ('BC337', 'BC337-16', 'NPN'),
#  ('BC337', 'BC337-25', 'NPN'),
#  ('BC337', 'BC337-40', 'NPN'),
#  ('BC337', 'BC338-25', 'NPN'),
#  ('BC546-D', 'BC546BG', 'NPN'),
#  ('BC546-D', 'BC546BRL1G', 'NPN'),
#  ('BC546-D', 'BC546BZL1G', 'NPN'),
#  ('BC546-D', 'BC547ARLG', 'NPN'),
#  ('BC546-D', 'BC547AZL1G', 'NPN'),
#  ('BC546-D', 'BC547BG', 'NPN'),
#  ('BC546-D', 'BC547BRL1G', 'NPN'),
#  ('BC546-D', 'BC547BZL1G', 'NPN'),
#  ('BC546-D', 'BC547CG', 'NPN'),
#  ('BC546-D', 'BC547CZL1G', 'NPN'),
#  ('BC546-D', 'BC548BG', 'NPN'),
#  ('BC546-D', 'BC548BRL1G', 'NPN'),
#  ('BC546-D', 'BC548BZL1G', 'NPN'),
#  ('BC546-D', 'BC548CG', 'NPN'),
#  ('BC546-D', 'BC548CZL1G', 'NPN'),
#  ('BC546_DIOTEC', 'BC546A', 'NPN'),
#  ('BC546_DIOTEC', 'BC546B', 'NPN'),
#  ('BC546_DIOTEC', 'BC547A', 'NPN'),
#  ('BC546_DIOTEC', 'BC547B', 'NPN'),
#  ('BC546_DIOTEC', 'BC547C', 'NPN'),
#  ('BC546_DIOTEC', 'BC548A', 'NPN'),
#  ('BC546_DIOTEC', 'BC548B', 'NPN'),
#  ('BC546_DIOTEC', 'BC548C', 'NPN'),
#  ('BC546_DIOTEC', 'BC549B', 'NPN'),
#  ('BC546_DIOTEC', 'BC549C', 'NPN'),
#  ('BC550', 'BC546A', 'NPN'),
#  ('BC550', 'BC546B', 'NPN'),
#  ('BC550', 'BC546C', 'NPN'),
#  ('BC550', 'BC547A', 'NPN'),
#  ('BC550', 'BC547B', 'NPN'),
#  ('BC550', 'BC547C', 'NPN'),
#  ('BC550', 'BC548A', 'NPN'),
#  ('BC550', 'BC548B', 'NPN'),
#  ('BC550', 'BC548C', 'NPN'),
#  ('BC550', 'BC549A', 'NPN'),
#  ('BC550', 'BC549B', 'NPN'),
#  ('BC550', 'BC549C', 'NPN'),
#  ('BC550', 'BC550A', 'NPN'),
#  ('BC550', 'BC550B', 'NPN'),
#  ('BC550', 'BC550C', 'NPN'),
#  ('BC818', 'BC817-16', 'NPN'),
#  ('BC818', 'BC817-25', 'NPN'),
#  ('BC818', 'BC817-40', 'NPN'),
#  ('BC818', 'BC818-16', 'NPN'),
#  ('BC818', 'BC818-25', 'NPN'),
#  ('BC818', 'BC818-40', 'NPN'),
#  ('BOURNSINC_BD246BS', 'BD246', 'PNP'),
#  ('BOURNSINC_BD246BS', 'BD246A', 'PNP'),
#  ('BOURNSINC_BD246BS', 'BD246B', 'PNP'),
#  ('BOURNSINC_BD246BS', 'BD246C', 'PNP'),
#  ('BOURNSINC_TIP152S', 'TIP150', 'NPN'),
#  ('BOURNSINC_TIP152S', 'TIP151', 'NPN'),
#  ('BOURNSINC_TIP152S', 'TIP152', 'NPN'),
#  ('CENTRALSEMICONDUCTORCORP_CENU45', 'CEN-U45', 'NPN'),
#  ('CENTRALSEMICONDUCTORCORP_CMPT5401ETR', 'CMPT5401E', 'PNP'),
#  ('CENTRALSEMICONDUCTORCORP_CXT4033TR', 'CXT4033', 'PNP'),
#  ('DIODESINCORPORATED_2DD26527', '2DD2652', 'NPN'),
#  ('DIODESINCORPORATED_2DD26527', '2DD2652-7', 'NPN'),
#  ('DIODESINCORPORATED_FCX491ATA', 'FCX491A', 'NPN'),
#  ('DIODESINCORPORATED_ZXT690BKTC', 'ZXT690BKQTC', 'NPN'),
#  ('DIODESINCORPORATED_ZXT690BKTC', 'ZXT690BKTC', 'NPN'),
#  ('DISES00189-1', 'BC546A', 'NPN'),
#  ('DISES00189-1', 'BC546B', 'NPN'),
#  ('DISES00189-1', 'BC547A', 'NPN'),
#  ('DISES00189-1', 'BC547B', 'NPN'),
#  ('DISES00189-1', 'BC547C', 'NPN'),
#  ('DISES00189-1', 'BC548A', 'NPN'),
#  ('DISES00189-1', 'BC548B', 'NPN'),
#  ('DISES00189-1', 'BC548C', 'NPN'),
#  ('DISES00189-1', 'BC549B', 'NPN'),
#  ('DISES00189-1', 'BC549C', 'NPN'),
#  ('DISES00192-1', 'BC807-16', 'PNP'),
#  ('DISES00192-1', 'BC807-25', 'PNP'),
#  ('DISES00192-1', 'BC807-40', 'PNP'),
#  ('DISES00192-1', 'BC808-16', 'PNP'),
#  ('DISES00192-1', 'BC808-25', 'PNP'),
#  ('DISES00192-1', 'BC808-40', 'PNP'),
#  ('DISES00490-1', 'BC846AW', 'NPN'),
#  ('DISES00490-1', 'BC846BW', 'NPN'),
#  ('DISES00490-1', 'BC847AW', 'NPN'),
#  ('DISES00490-1', 'BC847BW', 'NPN'),
#  ('DISES00490-1', 'BC847CW', 'NPN'),
#  ('DISES00490-1', 'BC848AW', 'NPN'),
#  ('DISES00490-1', 'BC848BW', 'NPN'),
#  ('DISES00490-1', 'BC848CW', 'NPN'),
#  ('DISES00490-1', 'BC849BW', 'NPN'),
#  ('DISES00490-1', 'BC849CW', 'NPN'),
#  ('DISES00616-1', 'BC856A', 'PNP'),
#  ('DISES00616-1', 'BC856B', 'PNP'),
#  ('DISES00616-1', 'BC856C', 'PNP'),
#  ('DISES00616-1', 'BC857A', 'PNP'),
#  ('DISES00616-1', 'BC857B', 'PNP'),
#  ('DISES00616-1', 'BC857C', 'PNP'),
#  ('DISES00616-1', 'BC858A', 'PNP'),
#  ('DISES00616-1', 'BC858B', 'PNP'),
#  ('DISES00616-1', 'BC858C', 'PNP'),
#  ('DISES00616-1', 'BC859B', 'PNP'),
#  ('DISES00616-1', 'BC859C', 'PNP'),
#  ('DISES00616-1', 'BC860B', 'PNP'),
#  ('DISES00616-1', 'BC860C', 'PNP'),
#  ('DISES00645-1', 'BC817K-16', 'NPN'),
#  ('DISES00645-1', 'BC817K-25', 'NPN'),
#  ('DISES00645-1', 'BC817K-40', 'NPN'),
#  ('DISES00645-1', 'BC818K-16', 'NPN'),
#  ('DISES00645-1', 'BC818K-25', 'NPN'),
#  ('DISES00645-1', 'BC818K-40', 'NPN'),
#  ('FAIRCHILDSEMICONDUCTOR_KSC2310YTA', 'KSC2310', 'NPN'),
#  ('FAIRCHILDSEMICONDUCTOR_KSC2310YTA', 'KSC2310O', 'NPN'),
#  ('FAIRCHILDSEMICONDUCTOR_KSC2310YTA', 'KSC2310R', 'NPN'),
#  ('FAIRCHILDSEMICONDUCTOR_KSC2310YTA', 'KSC2310Y', 'NPN'),
#  ('FAIRS19194-1', 'BC856A', 'PNP'),
#  ('FAIRS19194-1', 'BC856B', 'PNP'),
#  ('FAIRS19194-1', 'BC856C', 'PNP'),
#  ('FAIRS19194-1', 'BC857A', 'PNP'),
#  ('FAIRS19194-1', 'BC857B', 'PNP'),
#  ('FAIRS19194-1', 'BC857C', 'PNP'),
#  ('FAIRS19194-1', 'BC858A', 'PNP'),
#  ('FAIRS19194-1', 'BC858B', 'PNP'),
#  ('FAIRS19194-1', 'BC858C', 'PNP'),
#  ('FAIRS19194-1', 'BC859A', 'PNP'),
#  ('FAIRS19194-1', 'BC859B', 'PNP'),
#  ('FAIRS19194-1', 'BC859C', 'PNP'),
#  ('FAIRS19194-1', 'BC860A', 'PNP'),
#  ('FAIRS19194-1', 'BC860B', 'PNP'),
#  ('FAIRS19194-1', 'BC860C', 'PNP'),
#  ('FAIRS25065-1', 'BC237A', 'NPN'),
#  ('FAIRS25065-1', 'BC237B', 'NPN'),
#  ('FAIRS25065-1', 'BC237C', 'NPN'),
#  ('FAIRS25065-1', 'BC238A', 'NPN'),
#  ('FAIRS25065-1', 'BC238B', 'NPN'),
#  ('FAIRS25065-1', 'BC238C', 'NPN'),
#  ('FAIRS25065-1', 'BC239A', 'NPN'),
#  ('FAIRS25065-1', 'BC239B', 'NPN'),
#  ('FAIRS25065-1', 'BC239C', 'NPN'),
#  ('KECCS05435-1', 'BC546A', 'NPN'),
#  ('KECCS05435-1', 'BC546B', 'NPN'),
#  ('KECCS05435-1', 'BC547A', 'NPN'),
#  ('KECCS05435-1', 'BC547B', 'NPN'),
#  ('KECCS05435-1', 'BC547C', 'NPN'),
#  ('KECCS05435-1', 'BC548A', 'NPN'),
#  ('KECCS05435-1', 'BC548B', 'NPN'),
#  ('KECCS05435-1', 'BC548C', 'NPN'),
#  ('LITES00689-1', 'BC337-16', 'NPN'),
#  ('LITES00689-1', 'BC337-25', 'NPN'),
#  ('LITES00689-1', 'BC337-40', 'NPN'),
#  ('LITES00690-1', 'BC546A', 'NPN'),
#  ('LITES00690-1', 'BC546B', 'NPN'),
#  ('LITES00690-1', 'BC546C', 'NPN'),
#  ('LITES00690-1', 'BC547A', 'NPN'),
#  ('LITES00690-1', 'BC547B', 'NPN'),
#  ('LITES00690-1', 'BC547C', 'NPN'),
#  ('LITES00690-1', 'BC548A', 'NPN'),
#  ('LITES00690-1', 'BC548B', 'NPN'),
#  ('LITES00690-1', 'BC548C', 'NPN'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904-AP', 'NPN'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904-AP-HF', 'NPN'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904-BP', 'NPN'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904-BP-HF', 'NPN'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29A-BP', 'NPN'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29A-BP-HF', 'NPN'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29B-BP', 'NPN'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29B-BP-HF', 'NPN'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29C-BP', 'NPN'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29C-BP-HF', 'NPN'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30A-BP', 'PNP'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30A-BP-HF', 'PNP'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30B-BP', 'PNP'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30B-BP-HF', 'PNP'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30C-BP', 'PNP'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30C-BP-HF', 'PNP'),
#  ('MICROSEMICORPORATION_2N2484UB', '2N2484UA', 'NPN'),
#  ('MICROSEMICORPORATION_2N2484UB', '2N2484UB', 'NPN'),
#  ('MICROSEMICORPORATION_2N2484UB', '2N2484UBC', 'NPN'),
#  ('NXPUSAINC_PBSS5360PASX', 'PBSS5360PAS', 'PNP'),
#  ('ONSEMICONDUCTOR_MMBT6521LT1', 'MMBT6521LT1G', 'NPN'),
#  ('ONSEMICONDUCTOR_MMBT6521LT1', 'SMMBT6521LT1G', 'NPN'),
#  ('ONSMS04099-1', 'BC239C', 'NPN'),
#  ('PHGLS25601-1', 'BC846BT', 'NPN'),
#  ('PNJIS01593-1', 'BC856A', 'PNP'),
#  ('PNJIS01593-1', 'BC856B', 'PNP'),
#  ('PNJIS01593-1', 'BC857A', 'PNP'),
#  ('PNJIS01593-1', 'BC857B', 'PNP'),
#  ('PNJIS01593-1', 'BC857C', 'PNP'),
#  ('PNJIS01593-1', 'BC858A', 'PNP'),
#  ('PNJIS01593-1', 'BC858B', 'PNP'),
#  ('PNJIS01593-1', 'BC858C', 'PNP'),
#  ('PNJIS01593-1', 'BC859B', 'PNP'),
#  ('PNJIS01593-1', 'BC859C', 'PNP'),
#  ('RECTS00705-1', 'BC547A', 'NPN'),
#  ('RECTS00705-1', 'BC547B', 'NPN'),
#  ('RECTS00705-1', 'BC548A', 'NPN'),
#  ('RECTS00705-1', 'BC548B', 'NPN'),
#  ('SANKEN_2SC4886', '2SC4886', 'NPN'),
#  ('SANKEN_2SD2643', '2SD2643', 'NPN'),
#  ('SANKEN_STD01N', 'STD01N', 'NPN'),
#  ('SANKEN_STD01N', 'STD01P', 'PNP'),
#  ('SIEMS01215-1', 'BC856', 'PNP'),
#  ('SIEMS01215-1', 'BC856A', 'PNP'),
#  ('SIEMS01215-1', 'BC856B', 'PNP'),
#  ('SIEMS01215-1', 'BC857', 'PNP'),
#  ('SIEMS01215-1', 'BC857A', 'PNP'),
#  ('SIEMS01215-1', 'BC857B', 'PNP'),
#  ('SIEMS01215-1', 'BC857C', 'PNP'),
#  ('SIEMS01215-1', 'BC858', 'PNP'),
#  ('SIEMS01215-1', 'BC858A', 'PNP'),
#  ('SIEMS01215-1', 'BC858B', 'PNP'),
#  ('SIEMS01215-1', 'BC858C', 'PNP'),
#  ('SIEMS01215-1', 'BC859', 'PNP'),
#  ('SIEMS01215-1', 'BC859A', 'PNP'),
#  ('SIEMS01215-1', 'BC859B', 'PNP'),
#  ('SIEMS01215-1', 'BC859C', 'PNP'),
#  ('SIEMS01215-1', 'BC860', 'PNP'),
#  ('SIEMS01215-1', 'BC860B', 'PNP'),
#  ('SIEMS01215-1', 'BC860C', 'PNP'),
#  ('STMICROELECTRONICS_BUV48A', 'BUV48A', 'NPN'),
#  ('STMICROELECTRONICS_STI130051', 'STI13005-1', 'NPN'),
#  ('TTELECTRONICSOPTEKTECHNOLOGY_2N2222AUATXV', '2N2222AUA', 'NPN'),
#  ('TTELECTRONICSOPTEKTECHNOLOGY_2N2222AUATXV', '2N2222AUATX', 'NPN'),
#  ('TTELECTRONICSOPTEKTECHNOLOGY_2N2222AUATXV', '2N2222AUATXV', 'NPN'),
#  ('UTCLS02155-1', 'BC807', 'PNP'),
#  ('UTCLS02155-1', 'BC807-16', 'PNP'),
#  ('UTCLS02155-1', 'BC807-25', 'PNP'),
#  ('UTCLS02155-1', 'BC807-40', 'PNP'),
#  ('UTCLS02155-1', 'BC808', 'PNP'),
#  ('UTCLS02155-1', 'BC808-16', 'PNP'),
#  ('UTCLS02155-1', 'BC808-25', 'PNP'),
#  ('UTCLS02155-1', 'BC808-40', 'PNP'),
#  ('VISHS23888-1', 'BC546A', 'NPN'),
#  ('VISHS23888-1', 'BC546B', 'NPN'),
#  ('VISHS23888-1', 'BC547A', 'NPN'),
#  ('VISHS23888-1', 'BC547B', 'NPN'),
#  ('VISHS23888-1', 'BC547C', 'NPN'),
#  ('VISHS23888-1', 'BC548A', 'NPN'),
#  ('VISHS23888-1', 'BC548B', 'NPN'),
#  ('VISHS23888-1', 'BC548C', 'NPN'),
#  ('VISHS23888-1', 'BC549B', 'NPN'),
#  ('VISHS23888-1', 'BC549C', 'NPN'),
#  ('VSMIS00373-1', 'BC337-16', 'NPN'),
#  ('VSMIS00373-1', 'BC337-25', 'NPN'),
#  ('VSMIS00373-1', 'BC337-40', 'NPN'),
#  ('VSMIS00373-1', 'BC338-16', 'NPN'),
#  ('VSMIS00373-1', 'BC338-25', 'NPN'),
#  ('VSMIS00373-1', 'BC338-40', 'NPN')]

# %%
from pprint import pprint
pprint([(unicode(x[0]), x[1]) for x in disc_model.get_feature_weights(F_dev)[:100]])
# Out:
# [(u'CORE_e2_SPAN_TYPE_[EXPLICIT]', 3.2667769300335356),
#  (u'CORE_e2_STARTS_WITH_CAPITAL', 3.2667769300335356),
#  (u'CORE_e2_LENGTH_1', 3.2667769300335356),
#  (u'STR_e1_TAG_p', 2.933699011836862),
#  (u'CORE_e1_LENGTH_1', 2.807212130074842),
#  (u'STR_e1_PARENT_TAG_td', 2.745219025096593),
#  (u'TAB_e1_ROW_SPAN_[1]', 2.7307489799196194),
#  (u'STR_e1_LAST_NODE', 2.729523433373055),
#  (u'TAB_e1_COL_SPAN_[1]', 2.7139426309643926),
#  (u'CORE_e1_SPAN_TYPE_[EXPLICIT]', 2.7124267611010784),
#  (u'DDL_e1_POS_SEQ_[NN]', 2.701705748914759),
#  (u'DDL_e1_W_LEFT_POS_1_[NN]', 2.6208968415927796),
#  (u'STR_e1_FIRST_NODE', 2.5383048261731687),
#  (u'VIZ_e2_PAGE_[1]', 2.520335361523529),
#  (u'DDL_e2_W_LEFT_POS_1_[NN]', 2.479608885372566),
#  (u'STR_e1_ANCESTOR_TAG_[html body table tr td p]', 2.4496578078238924),
#  (u'STR_e1_ANCESTOR_ID_[None None None None None None]', 2.4496578078238924),
#  (u'DDL_e2_DEP_SEQ_[compound]', 2.380584668791523),
#  (u'VIZ_e1_PAGE_[1]', 2.349741604095509),
#  (u'STR_e2_TAG_p', 2.3214039302864076),
#  (u'DDL_e1_DEP_SEQ_[ROOT]', 2.2824102806090227),
#  (u'TAB_e1_COL_NUM_[0]', 2.1821969737064832),
#  (u'STR_COMMON_ANCESTOR_[ html body]', 2.1694578806215397),
#  (u'DDL_e2_WORD_SEQ_[NPN]', 2.0176799045666525),
#  (u'DDL_e2_POS_SEQ_[NNP]', 1.9983869742848754),
#  (u'VIZ_SAME_PAGE', 1.9837975330647908),
#  (u'STR_e2_LAST_NODE', 1.957857971265813),
#  (u'STR_e2_PARENT_TAG_td', 1.8761966540656485),
#  (u'TAB_e2_ROW_SPAN_[1]', 1.8760471885933288),
#  (u'TAB_e2_COL_SPAN_[1]', 1.8718153522096828),
#  (u'VIZ_e2_ALIGNED_npn', 1.8581906132942907),
#  (u'TAB_e1_ROW_WORDS_[-]', 1.845959450525251),
#  (u'STR_e2_ANCESTOR_TAG_[html body table tr td p]', 1.83861293947123),
#  (u'STR_e2_ANCESTOR_ID_[None None None None None None]', 1.83861293947123),
#  (u'STR_e2_FIRST_NODE', 1.7715045504547249),
#  (u'TAB_e1_COL_WORDS_[.]', 1.7529358751270234),
#  (u'TAB_e1_COL_HEAD_WORDS_[.]', 1.7454479489716215),
#  (u'TAB_e1_COL_HEAD_WORDS_[type]', 1.7444981855663955),
#  (u'TAB_e1_COL_WORDS_[type]', 1.7444981855663955),
#  (u'TAB_e1_COL_HEAD_WORDS_[type no]', 1.7423282428634022),
#  (u'TAB_e1_COL_WORDS_[no]', 1.7423282428634022),
#  (u'TAB_e1_COL_WORDS_[no .]', 1.7423282428634022),
#  (u'TAB_e1_COL_HEAD_WORDS_[no]', 1.7423282428634022),
#  (u'TAB_e1_COL_WORDS_[type no]', 1.7423282428634022),
#  (u'TAB_e1_COL_HEAD_WORDS_[no .]', 1.7423282428634022),
#  (u'VIZ_e2_ALIGNED_LEFT_npn', 1.7216705714731122),
#  (u'TAB_e2_COL_NUM_[1]', 1.7162057987980963),
#  (u'TAB_e2_COL_WORDS_[npn]', 1.63867615071221),
#  (u'TAB_e2_COL_WORDS_[pnp]', 1.6384686228644416),
#  (u'STR_e2_HTML_ATTR_class=s7', 1.6316186721959514),
#  (u'VIZ_e2_ALIGNED_CENTER_npn', 1.6010801268821044),
#  (u'TAB_e2_COL_WORDS_[low]', 1.6009056082654054),
#  (u'TAB_e2_COL_WORDS_[description]', 1.6008136805643176),
#  (u'TAB_e2_COL_WORDS_[sat]', 1.6007060208469759),
#  (u'TAB_e2_COL_WORDS_[npn low]', 1.6006140931459003),
#  (u'TAB_e2_COL_WORDS_[noise]', 1.6006140931459003),
#  (u'TAB_e2_COL_WORDS_[ampl/switch]', 1.6006140931459003),
#  (u'TAB_e2_COL_WORDS_[npn ampl/switch]', 1.6006140931459003),
#  (u'TAB_e2_COL_WORDS_[pnp ampl/switch]', 1.6006140931459003),
#  (u'TAB_e2_COL_WORDS_[switch]', 1.6006140931459003),
#  (u'TAB_e2_COL_WORDS_[sat switch]', 1.6006140931459003),
#  (u'TAB_e2_COL_HEAD_WORDS_[description]', 1.6006140931459003),
#  (u'TAB_e2_COL_WORDS_[low noise]', 1.6006140931459003),
#  (u'TAB_e2_COL_WORDS_[pnp low]', 1.6006140931459003),
#  (u'VIZ_e2_ALIGNED_RIGHT_npn', 1.5884293550117108),
#  (u'STR_e2_ANCESTOR_CLASS_[None None None None None s7]', 1.5801239808888579),
#  (u'TAB_e2_COL_WORDS_[npn sat]', 1.5608529005621616),
#  (u'DDL_e2_LEMMA_SEQ_[NPN]', 1.5471421667023),
#  (u'TAB_e1_ROW_WORDS_[- -]', 1.5271496973507508),
#  (u'STR_e1_HTML_ATTR_class=s7', 1.5236579448831),
#  (u'VIZ_e2_ALIGNED_LEFT_low', 1.4745257565889422),
#  (u'VIZ_e2_ALIGNED_low', 1.4745257565889422),
#  (u'VIZ_e2_ALIGNED_LEFT_noise', 1.4736633380681134),
#  (u'VIZ_e2_ALIGNED_noise', 1.4736633380681134),
#  (u'TAB_e2_ROW_WORDS_[-]', 1.4708915155249975),
#  (u'TAB_e2_ROW_WORDS_[- -]', 1.4706997941146907),
#  (u'STR_e1_ANCESTOR_CLASS_[None None None None None s7]', 1.444137891591637),
#  (u'VIZ_e2_ALIGNED_pnp', 1.4166026433680936),
#  (u'VIZ_e2_ALIGNED_LEFT_pnp', 1.3858267783937412),
#  (u'TAB_e1_ROW_WORDS_[5.0]', 1.3535621431112954),
#  (u'TAB_e1_ROW_WORDS_[100]', 1.3473015827088495),
#  (u'TAB_e2_COL_WORDS_[/]', 1.3142261936218684),
#  (u'TAB_e2_COL_WORDS_[ampl]', 1.3140266062034351),
#  (u'TAB_e2_COL_WORDS_[/ switch]', 1.3140266062034351),
#  (u'TAB_e2_COL_WORDS_[ampl /]', 1.3140266062034351),
#  (u'TAB_e2_ROW_WORDS_[5.0]', 1.2935488497566094),
#  (u'TAB_e1_COL_WORDS_[2n3393]', 1.2834999192655498),
#  (u'TAB_e1_COL_WORDS_[2n3392]', 1.283404651601259),
#  (u'TAB_e1_COL_WORDS_[2n2925]', 1.2832632438538694),
#  (u'TAB_e1_COL_WORDS_[2n2712]', 1.2832632438538685),
#  (u'TAB_e1_COL_WORDS_[2n2923]', 1.2832632438538643),
#  (u'TAB_e1_COL_WORDS_[2n2714]', 1.2832632438538636),
#  (u'TAB_e1_COL_WORDS_[2n2926]', 1.283263243853863),
#  (u'TAB_e1_COL_WORDS_[2n2924]', 1.283263243853856),
#  (u'TAB_e1_COL_WORDS_[2n3391a]', 1.2830627545576767),
#  (u'TAB_e1_COL_WORDS_[2n3395]', 1.282326207358635),
#  (u'TAB_e1_COL_WORDS_[2n3906]', 1.2821642821485293),
#  (u'TAB_e1_COL_WORDS_[2n4124]', 1.2818021615487678),
#  (u'TAB_e1_COL_WORDS_[2n4123]', 1.2818021615487671),
#  (u'TAB_e1_COL_WORDS_[2n3417]', 1.2818021593189435)]

# %%
from hardware_utils import entity_to_candidates

entity = FP[0]
print entity
print

matches = entity_to_candidates(entity, fp)
print "# Matches: %d" % len(matches)
print

candidate = matches[0]
print candidate
print

# throttler = get_part_throttler()
# print throttler(candidate)
# print disc_model.get_candidate_score(candidate, F_dev)
# print
# pprint(disc_model.get_candidate_feature_weights(candidate, F_dev))
# Out:
# (u'BC337', u'BC33716', u'NPN')
#
# # Matches: 18
#
# Part_Attr(Span("BC33716", parent=1260562, chars=[0,6], words=[0,0]), Span("NPN", parent=1258357, chars=[14,16], words=[3,3]))

# %%
# from hardware_utils import part_error_analysis
# part_error_analysis(candidate)

# %%
# If necessary:
# import os
# os.system('cp snorkel.db snorkel.db\ final');
