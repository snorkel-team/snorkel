# %% [markdown]
# # HARDWARE

# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

"""
To change attributes:
1) Change ATTRIBUTE and you're good to go
"""
ATTRIBUTE = 'stg_temp_min'
COUNTER = 1002
PARALLEL = 15
PARALLEL_EXTRACTION = 8
TRAIN_SIZE = 1000
DEV_SIZE = 125
TEST_SIZE = 0

import os
import sys
sys.path.append(os.environ['SNORKELHOME'] + '/tutorials/tables/')
snorkel_postgres = os.environ['SNORKELDB'].startswith('postgres')
print snorkel_postgres
# Out:
# True

# %%
import os
if snorkel_postgres:
    os.environ['SNORKELDBNAME'] = ATTRIBUTE + str(COUNTER)
    print os.system("dropdb " + os.environ['SNORKELDBNAME'])
    print os.system("createdb " + os.environ['SNORKELDBNAME'])
    print "SNORKELDBNAME = %s" % os.environ['SNORKELDBNAME']
else:
    try:
        os.remove('snorkel.db')
    except:
        pass

from snorkel import SnorkelSession
session = SnorkelSession()
# Out:
# 256
# 0
# SNORKELDBNAME = stg_temp_min1002

# %% [markdown]
# ## Parsing

# %%
import os
if snorkel_postgres:
    from snorkel.async_parser import parse_corpus, HTMLParser, AsyncOmniParser
    print "Starting async parse..."
    
    # PARSE TRAIN
    docs_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/train_digikey/html/'
    pdf_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/train_digikey/pdf/'
    doc_parser = HTMLParser()
    context_parser = AsyncOmniParser(blacklist=['style'], flatten=['span','br'], 
                                     tabular=True, lingual=True,
                                     visual=True, pdf_path=pdf_path)
    # %time corpus = parse_corpus(session, 'Hardware Train', docs_path,\
                                doc_parser, context_parser,\
                                max_docs=TRAIN_SIZE, parallel=PARALLEL)
    print "%s contains %d documents" % (corpus, len(corpus))
    
    # PARSE DEV
    docs_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/dev/html/'
    pdf_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/dev/pdf/'
    context_parser = AsyncOmniParser(blacklist=['style'], flatten=['span','br'], 
                                     tabular=True, lingual=True,
                                     visual=True, pdf_path=pdf_path)
    # %time corpus = parse_corpus(session, 'Hardware Dev', docs_path,\
                                doc_parser, context_parser,\
                                max_docs=DEV_SIZE, parallel=PARALLEL)
    print "%s contains %d documents" % (corpus, len(corpus))
    
    if TEST_SIZE:
        # PARSE TEST
        docs_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/test/html/'
        pdf_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/test/pdf/'
        context_parser = AsyncOmniParser(blacklist=['style'], flatten=['span','br'], 
                                         tabular=True, lingual=True,
                                         visual=True, pdf_path=pdf_path)
        # %time corpus = parse_corpus(session, 'Hardware Test', docs_path,\
                                    doc_parser, context_parser,\
                                    max_docs=TEST_SIZE, parallel=PARALLEL)
        print "%s contains %d documents" % (corpus, len(corpus))
else:
    from snorkel.parser import CorpusParser, HTMLParser, OmniParser
    from snorkel.utils import get_ORM_instance
    from snorkel.queries import split_corpus

    print "Starting sync parse..."
    # PARSE TRAIN
    docs_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/train_small/html/'
    pdf_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/train_small/pdf/'
    doc_parser = HTMLParser(path=docs_path)
    context_parser = AsyncOmniParser(blacklist=['style'], flatten=['span','br'], 
                                     tabular=True, lingual=True,
                                     visual=True, pdf_path=pdf_path)
    cp = CorpusParser(doc_parser, context_parser, max_docs=100)

    # %time corpus = cp.parse_corpus(name='Hardware Train', session=session)
    print "%s contains %d documents" % corpus, len(corpus)

    session.add(corpus)
    session.commit()
    
    # PARSE DEV
    docs_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/dev/html/'
    pdf_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/dev/pdf/'
    doc_parser = HTMLParser(path=docs_path)
    context_parser = AsyncOmniParser(blacklist=['style'], flatten=['span','br'], 
                                 tabular=True, lingual=True,
                                 visual=True, pdf_path=pdf_path)
    cp = CorpusParser(doc_parser, context_parser, max_docs=125)

    # %time corpus = cp.parse_corpus(name='Hardware Dev', session=session)
    print "%s contains %d documents" % (corpus, len(corpus))
    session.add(corpus)
    session.commit()
# Out:
# Starting async parse...
# [========================================] 100%
# CPU times: user 1.02 s, sys: 452 ms, total: 1.47 s
# Wall time: 7min 16s
# Corpus (Hardware Train) contains 1000 documents
# [========================================] 100%
# CPU times: user 292 ms, sys: 184 ms, total: 476 ms
# Wall time: 1min 13s
# Corpus (Hardware Dev) contains 122 documents

# %% [markdown]
# ### Save Corpus

# %%
# If necessary
if not snorkel_postgres:
    import os
    os.system('cp snorkel.db snorkel.db\ corpus');

# %% [markdown]
# ## Extraction

# %%
# # If necessary:
# import os
# os.remove('snorkel.db');
# os.system('cp snorkel.db\ corpus snorkel.db');

# import sys
# sys.path.append(os.environ['SNORKELHOME'] + '/tutorials/tables/')

# from snorkel import SnorkelSession
# session = SnorkelSession()

# %%
from snorkel.models import candidate_subclass

Part_Attr = candidate_subclass('Part_Attr', ['part','attr'])

# %% [markdown]
# ### Define Matchers

# %%
from hardware_matchers import get_matcher

part_matcher = get_matcher('part')
attr_matcher = get_matcher(ATTRIBUTE)

# %% [markdown]
# ### Define ContextSpaces

# %%
from hardware_spaces import get_space
    
part_ngrams = get_space('part')
attr_ngrams = get_space(ATTRIBUTE)

# %% [markdown]
# ### Define Candidate Throttler

# %%
from hardware_throttlers import get_throttler

throttler = get_throttler(ATTRIBUTE)
# throttler = None

# %% [markdown]
# ### Run CandidateExtractor

# %%
from snorkel.models import Corpus
from snorkel.candidates import CandidateExtractor
from snorkel.utils import get_ORM_instance
from snorkel.async_candidates import parallel_extract

ce = CandidateExtractor(Part_Attr, 
                        [part_ngrams, attr_ngrams], 
                        [part_matcher, attr_matcher], 
                        throttler=throttler)

corpus_names = ['Hardware Train', 'Hardware Dev']
if TEST_SIZE:
    corpus_names.append('Hardware Test')
for corpus_name in corpus_names:
    corpus = get_ORM_instance(Corpus, session, corpus_name)
    print "Extracting Candidates from %s" % corpus
    # %time candidates = parallel_extract(session, ce, corpus, \
                                        corpus_name + ' Candidates', \
                                        parallel=PARALLEL_EXTRACTION)
    session.add(candidates)
    print "%s contains %d Candidates" % (candidates, len(candidates))
session.commit()
# Out:
# Extracting Candidates from Corpus (Hardware Train)
# [========================================] 100%
# CPU times: user 3.87 s, sys: 2.93 s, total: 6.8 s
# Wall time: 43min 28s
# Candidate Set (Hardware Train Candidates) contains 25994 Candidates
# Extracting Candidates from Corpus (Hardware Dev)
# [========================================] 100%
# CPU times: user 1.16 s, sys: 568 ms, total: 1.72 s
# Wall time: 12min 58s
# Candidate Set (Hardware Dev Candidates) contains 12857 Candidates

# %% [markdown]
# ### Second Pass

# %%
# from hardware_utils import get_gold_parts_by_doc, get_manual_parts_by_doc
# from snorkel.utils import get_ORM_instance
# from snorkel.models import Corpus

# corpus = get_ORM_instance(Corpus, session, 'Hardware Dev')

# # parts_by_doc = get_gold_parts_by_doc()
# parts_by_doc = get_manual_parts_by_doc(corpus.documents)
# # parts_by_doc = None

# %%
# import cPickle as pickle
# pickle_file = os.environ['SNORKELHOME'] + '/tutorials/tables/sandbox/parts_by_doc.pkl'

# with open(pickle_file, 'w') as f:
#     pickle.dump(parts_by_doc, f)

# %%
import cPickle as pickle
pickle_file = os.environ['SNORKELHOME'] + '/tutorials/tables/sandbox/parts_by_doc.pkl'
with open(pickle_file, 'r') as f:
    parts_by_doc = pickle.load(f)

# %% [markdown]
# ### Assess Recall

# %%
from snorkel.models import Corpus, CandidateSet
from hardware_utils import entity_level_f1

corpus = get_ORM_instance(Corpus, session, 'Hardware Dev')
candidates = get_ORM_instance(CandidateSet, session, 'Hardware Dev Candidates')
gold_file = os.environ['SNORKELHOME'] + \
    '/tutorials/tables/data/hardware/dev/hardware_dev_gold.csv'
(ctp, cfp, cfn) = entity_level_f1(candidates, gold_file, ATTRIBUTE, corpus, parts_by_doc)
# Out:
# Preparing candidates...
# [========================================] 100%
# ========================================
# Scoring on Entity-Level Gold Data
# ========================================
# Corpus Precision 0.585
# Corpus Recall    0.921
# Corpus F1        0.715
# ----------------------------------------
# TP: 819 | FP: 582 | FN: 70
# ========================================

# %%
from pprint import pprint
pprint(cfp)
# Out:
# [(u'2N3906', u'2N3906', u'-50'),
#  (u'2N3906', u'2N3906BU', u'-50'),
#  (u'2N3906', u'2N3906TA', u'-50'),
#  (u'2N3906', u'2N3906TAR', u'-50'),
#  (u'2N3906', u'2N3906TF', u'-50'),
#  (u'2N3906', u'2N3906TFR', u'-50'),
#  (u'2N3906', u'MMBT3906', u'-50'),
#  (u'2N3906', u'PZT3906', u'-50'),
#  (u'AUKCS04635-1', u'2N3906', u'-50'),
#  (u'BC337', u'BC33716', u'-55'),
#  (u'BC337', u'BC33725', u'-55'),
#  (u'BC337', u'BC33740', u'-55'),
#  (u'BC337', u'BC33740BU', u'-55'),
#  (u'BC337', u'BC338-16', u'-55'),
#  (u'BC337', u'BC338-40', u'-55'),
#  (u'BC337', u'BC33825', u'-55'),
#  (u'BC337-D', u'BC337-XX', u'-55'),
#  (u'BC546', u'BC548A', u'-65'),
#  (u'BC546', u'BC549A', u'-65'),
#  (u'BC546', u'BC550A', u'-65'),
#  (u'BC546', u'BC550B', u'-65'),
#  (u'BC546-BC548C(TO-92)', u'BC546-BC548C', u'-55'),
#  (u'BC546_DIOTEC', u'BC546C', u'-55'),
#  (u'BC546_DIOTEC', u'BC549A', u'-55'),
#  (u'BC547', u'BC548A', u'-65'),
#  (u'BC547', u'BC548BU', u'-65'),
#  (u'BC547', u'BC549A', u'-65'),
#  (u'BC547', u'BC550A', u'-65'),
#  (u'BC547', u'BC550B', u'-65'),
#  (u'BC818-40LT1-D', u'BC818-40LT1', u'-55'),
#  (u'BOURNSINC_BD246BS', u'BD246', u'-55'),
#  (u'BOURNSINC_BD246BS', u'BD246', u'-60'),
#  (u'BOURNSINC_BD246BS', u'BD246A', u'-55'),
#  (u'BOURNSINC_BD246BS', u'BD246A', u'-60'),
#  (u'BOURNSINC_BD246BS', u'BD246B', u'-55'),
#  (u'BOURNSINC_BD246BS', u'BD246B', u'-60'),
#  (u'BOURNSINC_BD246BS', u'BD246C', u'-55'),
#  (u'BOURNSINC_BD246BS', u'BD246C', u'-60'),
#  (u'BOURNSINC_TIP152S', u'TIP150', u'-50'),
#  (u'BOURNSINC_TIP152S', u'TIP151', u'-50'),
#  (u'BOURNSINC_TIP152S', u'TIP152', u'-50'),
#  (u'CSEMS05382-1', u'BC546-48ABC', u'-65'),
#  (u'DIODESINCORPORATED_FCX491ATA', u'AP02001', u'-65'),
#  (u'DIODESINCORPORATED_FCX491ATA', u'AP02002', u'-65'),
#  (u'DIODESINCORPORATED_FZT651TC', u'AP02001', u'-55'),
#  (u'DIODESINCORPORATED_FZT651TC', u'AP02002', u'-55'),
#  (u'DIODESINCORPORATED_ZTX789ASTZ', u'ZTX789A', u'-50'),
#  (u'DIODESINCORPORATED_ZTX953STZ', u'ZTX953', u'-50'),
#  (u'DIODESINCORPORATED_ZXT690BKTC', u'AP02001', u'-55'),
#  (u'DIODESINCORPORATED_ZXT690BKTC', u'AP02002', u'-55'),
#  (u'DIODESINCORPORATED_ZXT690BKTC', u'ZXT690B', u'-55'),
#  (u'DIODS00215-1', u'2N4124', u'-60'),
#  (u'DIODS13249-1', u'BC808', u'-55'),
#  (u'DIODS13249-1', u'BC81840', u'-55'),
#  (u'DISES00023-1', u'2N3906', u'-50'),
#  (u'DISES00189-1', u'BC546C', u'-55'),
#  (u'DISES00189-1', u'BC546XBK', u'-55'),
#  (u'DISES00189-1', u'BC547XBK', u'-55'),
#  (u'DISES00189-1', u'BC548XBK', u'-55'),
#  (u'DISES00189-1', u'BC549A', u'-55'),
#  (u'DISES00189-1', u'BC549XBK', u'-55'),
#  (u'DISES00242-1', u'MMBT3904', u'-50'),
#  (u'DISES00490-1', u'BC846WA', u'-55'),
#  (u'DISES00490-1', u'BC846WB', u'-55'),
#  (u'DISES00490-1', u'BC846WC', u'-55'),
#  (u'DISES00490-1', u'BC847WA', u'-55'),
#  (u'DISES00490-1', u'BC847WB', u'-55'),
#  (u'DISES00490-1', u'BC847WC', u'-55'),
#  (u'DISES00490-1', u'BC848WA', u'-55'),
#  (u'DISES00490-1', u'BC848WB', u'-55'),
#  (u'DISES00490-1', u'BC848WC', u'-55'),
#  (u'DISES00490-1', u'BC849WA', u'-55'),
#  (u'DISES00490-1', u'BC849WB', u'-55'),
#  (u'DISES00490-1', u'BC849WC', u'-55'),
#  (u'DISES00616-1', u'BC859A', u'-55'),
#  (u'DISES00616-1', u'BC860A', u'-55'),
#  (u'FAIRS19194-1', u'BC856', u'-50'),
#  (u'FAIRS19194-1', u'BC856A', u'-50'),
#  (u'FAIRS19194-1', u'BC856B', u'-50'),
#  (u'FAIRS19194-1', u'BC856C', u'-50'),
#  (u'FAIRS19194-1', u'BC857', u'-50'),
#  (u'FAIRS19194-1', u'BC857A', u'-50'),
#  (u'FAIRS19194-1', u'BC857B', u'-50'),
#  (u'FAIRS19194-1', u'BC857C', u'-50'),
#  (u'FAIRS19194-1', u'BC858', u'-50'),
#  (u'FAIRS19194-1', u'BC858A', u'-50'),
#  (u'FAIRS19194-1', u'BC858B', u'-50'),
#  (u'FAIRS19194-1', u'BC858C', u'-50'),
#  (u'FAIRS19194-1', u'BC859', u'-50'),
#  (u'FAIRS19194-1', u'BC859A', u'-50'),
#  (u'FAIRS19194-1', u'BC859B', u'-50'),
#  (u'FAIRS19194-1', u'BC859C', u'-50'),
#  (u'FAIRS19194-1', u'BC860', u'-50'),
#  (u'FAIRS19194-1', u'BC860A', u'-50'),
#  (u'FAIRS19194-1', u'BC860B', u'-50'),
#  (u'FAIRS19194-1', u'BC860C', u'-50'),
#  (u'INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', u'AN077', u'-50'),
#  (u'INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', u'AN077', u'-65'),
#  (u'INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', u'BC817', u'-50'),
#  (u'INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', u'BC817', u'-65'),
#  (u'INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', u'BC817K', u'-50'),
#  (u'INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', u'BC817K-16', u'-50'),
#  (u'INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', u'BC817K-16W', u'-50'),
#  (u'INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', u'BC817K-25', u'-50'),
#  (u'INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', u'BC817K-25W', u'-50'),
#  (u'INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', u'BC817K-40', u'-50'),
#  (u'INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', u'BC817K-40W', u'-50'),
#  (u'INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', u'BC817KW', u'-50'),
#  (u'INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', u'BC818', u'-50'),
#  (u'INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', u'BC818', u'-65'),
#  (u'INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', u'BC818K', u'-50'),
#  (u'INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', u'BC818K-16W', u'-50'),
#  (u'INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', u'BC818K-40', u'-50'),
#  (u'INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', u'BC818KW', u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'AN077',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'AN077',
#   u'-65'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC850',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC850',
#   u'-65'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857-BC860',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857-BC860',
#   u'-65'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857A',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857B',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857BL3',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857BW',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857C',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857CW',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857W',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857W',
#   u'-65'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857W-BC860W',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857W-BC860W',
#   u'-65'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC858',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC858A',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC858B',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC858BW',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC858C',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC858CW',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC858W',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC858W',
#   u'-65'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC859',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC859C',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC859W',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC859W',
#   u'-65'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC860',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC860B',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC860BW',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC860CW',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC860W',
#   u'-50'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC860W',
#   u'-65'),
#  (u'INFNS19372-1', u'AN077', u'-55'),
#  (u'INFNS19372-1', u'AN077', u'-65'),
#  (u'INFNS19372-1', u'MMBT3904', u'-55'),
#  (u'INFNS19372-1', u'SMBT3904', u'-55'),
#  (u'INFNS19372-1', u'SMBT3904S', u'-55'),
#  (u'KECCS03676-1', u'BC856', u'-50'),
#  (u'KECCS03676-1', u'BC856', u'-65'),
#  (u'KECCS03676-1', u'BC856A', u'-50'),
#  (u'KECCS03676-1', u'BC856A', u'-65'),
#  (u'KECCS03676-1', u'BC856B', u'-50'),
#  (u'KECCS03676-1', u'BC856B', u'-65'),
#  (u'KECCS03676-1', u'BC856C', u'-50'),
#  (u'KECCS03676-1', u'BC856C', u'-55'),
#  (u'KECCS03676-1', u'BC856C', u'-65'),
#  (u'KECCS03676-1', u'BC857', u'-50'),
#  (u'KECCS03676-1', u'BC857', u'-65'),
#  (u'KECCS03676-1', u'BC857A', u'-50'),
#  (u'KECCS03676-1', u'BC857A', u'-65'),
#  (u'KECCS03676-1', u'BC857B', u'-50'),
#  (u'KECCS03676-1', u'BC857B', u'-65'),
#  (u'KECCS03676-1', u'BC857C', u'-50'),
#  (u'KECCS03676-1', u'BC857C', u'-65'),
#  (u'KECCS03676-1', u'BC858', u'-50'),
#  (u'KECCS03676-1', u'BC858', u'-65'),
#  (u'KECCS03676-1', u'BC858A', u'-50'),
#  (u'KECCS03676-1', u'BC858A', u'-65'),
#  (u'KECCS03676-1', u'BC858B', u'-50'),
#  (u'KECCS03676-1', u'BC858B', u'-65'),
#  (u'KECCS03676-1', u'BC858C', u'-50'),
#  (u'KECCS03676-1', u'BC858C', u'-65'),
#  (u'KECCS05435-1', u'BC546C', u'-55'),
#  (u'LITES00686-1', u'2N4124', u'-60'),
#  (u'LITES00689-1', u'BC337', u'-50'),
#  (u'LITES00689-1', u'BC337-16', u'-50'),
#  (u'LITES00689-1', u'BC337-40', u'-50'),
#  (u'LITES00690-1', u'BC546', u'-50'),
#  (u'LITES00690-1', u'BC546A', u'-50'),
#  (u'LITES00690-1', u'BC546B', u'-50'),
#  (u'LITES00690-1', u'BC546C', u'-50'),
#  (u'LITES00690-1', u'BC547', u'-50'),
#  (u'LITES00690-1', u'BC547A', u'-50'),
#  (u'LITES00690-1', u'BC547B', u'-50'),
#  (u'LITES00690-1', u'BC547C', u'-50'),
#  (u'LITES00690-1', u'BC548', u'-50'),
#  (u'LITES00690-1', u'BC548A', u'-50'),
#  (u'LITES00690-1', u'BC548B', u'-50'),
#  (u'LITES00690-1', u'BC548C', u'-50'),
#  (u'LITES00690-1', u'BC556', u'-50'),
#  (u'LITES00690-1', u'BC556', u'-65'),
#  (u'LITES00690-1', u'BC556A', u'-50'),
#  (u'LITES00690-1', u'BC556A', u'-65'),
#  (u'LITES00690-1', u'BC556B', u'-50'),
#  (u'LITES00690-1', u'BC556B', u'-65'),
#  (u'LITES00690-1', u'BC556C', u'-50'),
#  (u'LITES00690-1', u'BC556C', u'-65'),
#  (u'LITES00690-1', u'BC557', u'-50'),
#  (u'LITES00690-1', u'BC557', u'-65'),
#  (u'LITES00690-1', u'BC557A', u'-50'),
#  (u'LITES00690-1', u'BC557A', u'-65'),
#  (u'LITES00690-1', u'BC557B', u'-50'),
#  (u'LITES00690-1', u'BC557B', u'-65'),
#  (u'LITES00690-1', u'BC557C', u'-50'),
#  (u'LITES00690-1', u'BC557C', u'-65'),
#  (u'LITES00690-1', u'BC558', u'-50'),
#  (u'LITES00690-1', u'BC558', u'-65'),
#  (u'LITES00690-1', u'BC558A', u'-50'),
#  (u'LITES00690-1', u'BC558A', u'-65'),
#  (u'LITES00690-1', u'BC558B', u'-50'),
#  (u'LITES00690-1', u'BC558B', u'-65'),
#  (u'LITES00690-1', u'BC558C', u'-50'),
#  (u'LITES00690-1', u'BC558C', u'-65'),
#  (u'LTSCS02910-1', u'BC818-REV', u'-55'),
#  (u'LTSCS02912-1', u'BC846W-REV', u'-55'),
#  (u'LTSCS02920-1', u'BC857', u'-50'),
#  (u'LTSCS02920-1', u'BC857-REV', u'-50'),
#  (u'LTSCS02920-1', u'BC857-REV', u'-65'),
#  (u'LTSCS02920-1', u'BC857A', u'-50'),
#  (u'LTSCS02920-1', u'BC857B', u'-50'),
#  (u'LTSCS02920-1', u'BC857C', u'-50'),
#  (u'MCCCS09540-1', u'BC846A-BC849C', u'-55'),
#  (u'MICROSEMICORPORATION_2N2484UB', u'2N2484', u'-65'),
#  (u'ONSEMICONDUCTOR_MMBT6521LT1', u'AN569', u'-55'),
#  (u'ONSEMICONDUCTOR_MMBT6521LT1', u'AN569A', u'-55'),
#  (u'ONSMS04099-1', u'BC237', u'-65'),
#  (u'ONSMS04099-1', u'BC237A', u'-65'),
#  (u'ONSMS04099-1', u'BC237B', u'-65'),
#  (u'ONSMS04099-1', u'BC237BA', u'-55'),
#  (u'ONSMS04099-1', u'BC237BA', u'-65'),
#  (u'ONSMS04099-1', u'BC237C', u'-65'),
#  (u'ONSMS04099-1', u'BC237CA', u'-55'),
#  (u'ONSMS04099-1', u'BC237CA', u'-65'),
#  (u'ONSMS04099-1', u'BC238', u'-65'),
#  (u'ONSMS04099-1', u'BC238A', u'-55'),
#  (u'ONSMS04099-1', u'BC238A', u'-65'),
#  (u'ONSMS04099-1', u'BC238B', u'-65'),
#  (u'ONSMS04099-1', u'BC238BA', u'-55'),
#  (u'ONSMS04099-1', u'BC238BA', u'-65'),
#  (u'ONSMS04099-1', u'BC238C', u'-65'),
#  (u'ONSMS04099-1', u'BC238CA', u'-55'),
#  (u'ONSMS04099-1', u'BC238CA', u'-65'),
#  (u'ONSMS04099-1', u'BC239', u'-65'),
#  (u'ONSMS04099-1', u'BC239A', u'-55'),
#  (u'ONSMS04099-1', u'BC239A', u'-65'),
#  (u'ONSMS04099-1', u'MPS3904', u'-55'),
#  (u'ONSMS04099-1', u'MPS3904', u'-65'),
#  (u'ONSMS04099-1', u'MPS3904A', u'-55'),
#  (u'ONSMS04099-1', u'MPS3904A', u'-65'),
#  (u'PHGLS18216-1', u'BC547', u'-55'),
#  (u'PHGLS18216-1', u'BC547B', u'-55'),
#  (u'PHGLS18216-1', u'BC547C', u'-55'),
#  (u'PHGLS18216-1', u'BC557', u'-55'),
#  (u'PHGLS18216-1', u'BC557', u'-65'),
#  (u'PHGLS18216-1', u'BC557B', u'-55'),
#  (u'PHGLS18216-1', u'BC557B', u'-65'),
#  (u'PHGLS18216-1', u'BC557C', u'-55'),
#  (u'PHGLS18216-1', u'BC557C', u'-65'),
#  (u'PHGLS18216-1', u'BC847', u'-55'),
#  (u'PHGLS18216-1', u'BC847A', u'-55'),
#  (u'PHGLS18216-1', u'BC847AM', u'-55'),
#  (u'PHGLS18216-1', u'BC847AT', u'-55'),
#  (u'PHGLS18216-1', u'BC847AT/DG', u'-55'),
#  (u'PHGLS18216-1', u'BC847AW', u'-55'),
#  (u'PHGLS18216-1', u'BC847B', u'-55'),
#  (u'PHGLS18216-1', u'BC847B/DG', u'-55'),
#  (u'PHGLS18216-1', u'BC847BM', u'-55'),
#  (u'PHGLS18216-1', u'BC847BT', u'-55'),
#  (u'PHGLS18216-1', u'BC847BW', u'-55'),
#  (u'PHGLS18216-1', u'BC847BW/DG', u'-55'),
#  (u'PHGLS18216-1', u'BC847C', u'-55'),
#  (u'PHGLS18216-1', u'BC847CM', u'-55'),
#  (u'PHGLS18216-1', u'BC847CT', u'-55'),
#  (u'PHGLS18216-1', u'BC847CW', u'-55'),
#  (u'PHGLS18216-1', u'BC847DG', u'-55'),
#  (u'PHGLS18216-1', u'BC847DG', u'-65'),
#  (u'PHGLS18216-1', u'BC847T', u'-55'),
#  (u'PHGLS18216-1', u'BC847W', u'-55'),
#  (u'PHGLS18216-1', u'BC857', u'-55'),
#  (u'PHGLS18216-1', u'BC857', u'-65'),
#  (u'PHGLS18216-1', u'BC857A', u'-55'),
#  (u'PHGLS18216-1', u'BC857A', u'-65'),
#  (u'PHGLS18216-1', u'BC857AM', u'-55'),
#  (u'PHGLS18216-1', u'BC857AM', u'-65'),
#  (u'PHGLS18216-1', u'BC857AT', u'-55'),
#  (u'PHGLS18216-1', u'BC857AT', u'-65'),
#  (u'PHGLS18216-1', u'BC857AW', u'-55'),
#  (u'PHGLS18216-1', u'BC857AW', u'-65'),
#  (u'PHGLS18216-1', u'BC857B', u'-55'),
#  (u'PHGLS18216-1', u'BC857B', u'-65'),
#  (u'PHGLS18216-1', u'BC857BM', u'-55'),
#  (u'PHGLS18216-1', u'BC857BM', u'-65'),
#  (u'PHGLS18216-1', u'BC857BT', u'-55'),
#  (u'PHGLS18216-1', u'BC857BT', u'-65'),
#  (u'PHGLS18216-1', u'BC857BW', u'-55'),
#  (u'PHGLS18216-1', u'BC857BW', u'-65'),
#  (u'PHGLS18216-1', u'BC857C', u'-55'),
#  (u'PHGLS18216-1', u'BC857C', u'-65'),
#  (u'PHGLS18216-1', u'BC857CM', u'-55'),
#  (u'PHGLS18216-1', u'BC857CM', u'-65'),
#  (u'PHGLS18216-1', u'BC857CT', u'-55'),
#  (u'PHGLS18216-1', u'BC857CT', u'-65'),
#  (u'PHGLS18216-1', u'BC857CW', u'-55'),
#  (u'PHGLS18216-1', u'BC857CW', u'-65'),
#  (u'PHGLS18216-1', u'BC857T', u'-55'),
#  (u'PHGLS18216-1', u'BC857T', u'-65'),
#  (u'PHGLS18216-1', u'BC857W', u'-55'),
#  (u'PHGLS18216-1', u'BC857W', u'-65'),
#  (u'PHGLS19500-1', u'MMBT3904', u'-55'),
#  (u'PHGLS20125-1', u'BC327', u'-50'),
#  (u'PHGLS20125-1', u'BC327', u'-55'),
#  (u'PHGLS20125-1', u'BC327-16', u'-50'),
#  (u'PHGLS20125-1', u'BC327-16', u'-55'),
#  (u'PHGLS20125-1', u'BC327-25', u'-50'),
#  (u'PHGLS20125-1', u'BC327-25', u'-55'),
#  (u'PHGLS20125-1', u'BC327-40', u'-50'),
#  (u'PHGLS20125-1', u'BC327-40', u'-55'),
#  (u'PHGLS20125-1', u'BC807', u'-50'),
#  (u'PHGLS20125-1', u'BC807', u'-55'),
#  (u'PHGLS20125-1', u'BC807-16', u'-50'),
#  (u'PHGLS20125-1', u'BC807-16', u'-55'),
#  (u'PHGLS20125-1', u'BC807-16W', u'-50'),
#  (u'PHGLS20125-1', u'BC807-16W', u'-55'),
#  (u'PHGLS20125-1', u'BC807-25', u'-50'),
#  (u'PHGLS20125-1', u'BC807-25', u'-55'),
#  (u'PHGLS20125-1', u'BC807-25W', u'-50'),
#  (u'PHGLS20125-1', u'BC807-25W', u'-55'),
#  (u'PHGLS20125-1', u'BC807-40', u'-50'),
#  (u'PHGLS20125-1', u'BC807-40', u'-55'),
#  (u'PHGLS20125-1', u'BC807-40W', u'-50'),
#  (u'PHGLS20125-1', u'BC807-40W', u'-55'),
#  (u'PHGLS20125-1', u'BC807W', u'-50'),
#  (u'PHGLS20125-1', u'BC807W', u'-55'),
#  (u'PHGLS20126-1', u'BC337', u'-55'),
#  (u'PHGLS20126-1', u'BC337-16', u'-55'),
#  (u'PHGLS20126-1', u'BC337-25', u'-55'),
#  (u'PHGLS20126-1', u'BC337-40', u'-55'),
#  (u'PHGLS20126-1', u'BC817', u'-55'),
#  (u'PHGLS20126-1', u'BC817-16', u'-55'),
#  (u'PHGLS20126-1', u'BC817-16W', u'-55'),
#  (u'PHGLS20126-1', u'BC817-25', u'-55'),
#  (u'PHGLS20126-1', u'BC817-25W', u'-55'),
#  (u'PHGLS20126-1', u'BC817-40', u'-55'),
#  (u'PHGLS20126-1', u'BC817-40W', u'-55'),
#  (u'PHGLS20126-1', u'BC817W', u'-55'),
#  (u'PHGLS25601-1', u'BC846', u'-55'),
#  (u'PHGLS25601-1', u'BC846A', u'-55'),
#  (u'PHGLS25601-1', u'BC846AT', u'-55'),
#  (u'PHGLS25601-1', u'BC846AW', u'-55'),
#  (u'PHGLS25601-1', u'BC846B', u'-55'),
#  (u'PHGLS25601-1', u'BC846BT', u'-55'),
#  (u'PHGLS25601-1', u'BC846BW', u'-55'),
#  (u'PHGLS25601-1', u'BC846T', u'-55'),
#  (u'PHGLS25601-1', u'BC846W', u'-55'),
#  (u'PHGLS25601-1', u'BC856', u'-55'),
#  (u'PHGLS25601-1', u'BC856', u'-65'),
#  (u'PHGLS25601-1', u'BC856T', u'-55'),
#  (u'PHGLS25601-1', u'BC856T', u'-65'),
#  (u'PHGLS25601-1', u'BC856W', u'-55'),
#  (u'PHGLS25601-1', u'BC856W', u'-65'),
#  (u'PNJIS00254-1', u'BC807-16W', u'-50'),
#  (u'PNJIS00254-1', u'BC807-25W', u'-50'),
#  (u'PNJIS00254-1', u'BC807-40W', u'-50'),
#  (u'PNJIS01186-1', u'BC807', u'-50'),
#  (u'PNJIS01186-1', u'BC807', u'-55'),
#  (u'PNJIS01186-1', u'BC807-16', u'-50'),
#  (u'PNJIS01186-1', u'BC807-25', u'-50'),
#  (u'PNJIS01186-1', u'BC807-40', u'-50'),
#  (u'PNJIS01593-1', u'BC846', u'-50'),
#  (u'PNJIS01593-1', u'BC846', u'-65'),
#  (u'PNJIS01593-1', u'BC849', u'-50'),
#  (u'PNJIS01593-1', u'BC849', u'-65'),
#  (u'PNJIS01593-1', u'BC856', u'-65'),
#  (u'PNJIS01593-1', u'BC856A', u'-65'),
#  (u'PNJIS01593-1', u'BC856B', u'-65'),
#  (u'PNJIS01593-1', u'BC857', u'-65'),
#  (u'PNJIS01593-1', u'BC857A', u'-65'),
#  (u'PNJIS01593-1', u'BC857B', u'-65'),
#  (u'PNJIS01593-1', u'BC857C', u'-65'),
#  (u'PNJIS01593-1', u'BC858', u'-65'),
#  (u'PNJIS01593-1', u'BC858A', u'-65'),
#  (u'PNJIS01593-1', u'BC858B', u'-65'),
#  (u'PNJIS01593-1', u'BC858C', u'-65'),
#  (u'PNJIS01593-1', u'BC859', u'-65'),
#  (u'PNJIS01593-1', u'BC859B', u'-65'),
#  (u'PNJIS01593-1', u'BC859C', u'-65'),
#  (u'RECTS01158-1', u'BC807-25', u'-50'),
#  (u'RECTS01158-1', u'BC807-25LT1', u'-50'),
#  (u'RECTS01158-1', u'BC807-25LT1', u'-55'),
#  (u'RECTS01214-1', u'DTC114ECA-1', u'-55'),
#  (u'RECTS01242-1', u'BC857B', u'-50'),
#  (u'RECTS01242-1', u'BC857BLT1', u'-50'),
#  (u'RECTS01242-1', u'BC857BLT1', u'-55'),
#  (u'RECTS01325-1', u'DTC114YCA-1', u'-55'),
#  (u'SANKEN_2SC4886', u'2SC4886O', u'-55'),
#  (u'SANKEN_2SC4886', u'2SC4886Y', u'-55'),
#  (u'SANKEN_2SD2643', u'2SD2643O', u'-55'),
#  (u'SANKEN_2SD2643', u'2SD2643Y', u'-55'),
#  (u'TTELECTRONICSOPTEKTECHNOLOGY_2N2222AUATXV', u'2N2222AUA', u'-55'),
#  (u'TWSCS04757-1', u'BC807', u'-50'),
#  (u'TWSCS04757-1', u'BC807', u'-55'),
#  (u'TWSCS04757-1', u'BC807-16', u'-50'),
#  (u'TWSCS04757-1', u'BC807-25', u'-50'),
#  (u'TWSCS04757-1', u'BC807-40', u'-50'),
#  (u'TWSCS04757-1', u'BC807-XX', u'-50'),
#  (u'TWSCS04757-1', u'BC807-XX', u'-55'),
#  (u'UTCLS01324-1', u'MMBT3904-E', u'-55'),
#  (u'UTCLS02155-1', u'BC807', u'-50'),
#  (u'UTCLS02155-1', u'BC807-16', u'-50'),
#  (u'UTCLS02155-1', u'BC807-25', u'-50'),
#  (u'UTCLS02155-1', u'BC807-40', u'-50'),
#  (u'UTCLS02155-1', u'BC808', u'-50'),
#  (u'UTCLS02155-1', u'BC808-16', u'-50'),
#  (u'UTCLS02155-1', u'BC808-25', u'-50'),
#  (u'UTCLS02155-1', u'BC808-40', u'-50'),
#  (u'UTCLS03593-1', u'DTC114E-I', u'-55'),
#  (u'VISHS23888-1', u'BC546C', u'-65'),
#  (u'VISHS23888-1', u'BC549A', u'-65'),
#  (u'VSMIS03793-1', u'BC807', u'-50'),
#  (u'VSMIS03793-1', u'BC807', u'-65'),
#  (u'VSMIS03793-1', u'BC807-16', u'-50'),
#  (u'VSMIS03793-1', u'BC807-16', u'-65'),
#  (u'VSMIS03793-1', u'BC807-25', u'-50'),
#  (u'VSMIS03793-1', u'BC807-25', u'-65'),
#  (u'VSMIS03793-1', u'BC807-40', u'-50'),
#  (u'VSMIS03793-1', u'BC807-40', u'-65'),
#  (u'VSMIS03793-1', u'BC808', u'-50'),
#  (u'VSMIS03793-1', u'BC808', u'-65'),
#  (u'VSMIS03793-1', u'BC808-16', u'-50'),
#  (u'VSMIS03793-1', u'BC808-16', u'-65'),
#  (u'VSMIS03793-1', u'BC808-25', u'-50'),
#  (u'VSMIS03793-1', u'BC808-25', u'-65'),
#  (u'VSMIS03793-1', u'BC808-40', u'-50'),
#  (u'VSMIS03793-1', u'BC808-40', u'-65'),
#  (u'VSMIS03793-1', u'BC817', u'-50'),
#  (u'VSMIS03793-1', u'BC817-16', u'-50'),
#  (u'VSMIS03793-1', u'BC817-25', u'-50'),
#  (u'VSMIS03793-1', u'BC817-40', u'-50'),
#  (u'VSMIS03793-1', u'BC818', u'-50'),
#  (u'VSMIS03793-1', u'BC818-16', u'-50'),
#  (u'VSMIS03793-1', u'BC818-25', u'-50'),
#  (u'VSMIS03793-1', u'BC818-40', u'-50'),
#  (u'WEILS00082-1', u'BC856', u'-50'),
#  (u'WEILS00082-1', u'BC856', u'-65'),
#  (u'WEILS00082-1', u'BC856A', u'-50'),
#  (u'WEILS00082-1', u'BC856A', u'-65'),
#  (u'WEILS00082-1', u'BC856B', u'-50'),
#  (u'WEILS00082-1', u'BC856B', u'-65'),
#  (u'WEILS00082-1', u'BC857', u'-50'),
#  (u'WEILS00082-1', u'BC857', u'-65'),
#  (u'WEILS00082-1', u'BC857A', u'-50'),
#  (u'WEILS00082-1', u'BC857A', u'-65'),
#  (u'WEILS00082-1', u'BC857B', u'-50'),
#  (u'WEILS00082-1', u'BC857B', u'-65'),
#  (u'WEILS00082-1', u'BC857C', u'-50'),
#  (u'WEILS00082-1', u'BC857C', u'-65'),
#  (u'WEILS00082-1', u'BC858', u'-50'),
#  (u'WEILS00082-1', u'BC858', u'-65'),
#  (u'WEILS00082-1', u'BC858A', u'-50'),
#  (u'WEILS00082-1', u'BC858A', u'-65'),
#  (u'WEILS00082-1', u'BC858B', u'-50'),
#  (u'WEILS00082-1', u'BC858B', u'-65'),
#  (u'WEILS00082-1', u'BC858C', u'-50'),
#  (u'WEILS00082-1', u'BC858C', u'-65'),
#  (u'WEILS00082-1', u'BC859', u'-50'),
#  (u'WEILS00082-1', u'BC859', u'-65'),
#  (u'WEILS00082-1', u'BC859B', u'-50'),
#  (u'WEILS00082-1', u'BC859B', u'-65'),
#  (u'WEILS00082-1', u'BC859C', u'-50'),
#  (u'WEILS00082-1', u'BC859C', u'-65'),
#  (u'WEITS00252-1', u'BC807-1', u'-50'),
#  (u'WEITS00252-1', u'BC807-1', u'-55'),
#  (u'WEITS00252-1', u'BC807-16', u'-50'),
#  (u'WEITS00252-1', u'BC807-17', u'-50'),
#  (u'WEITS00252-1', u'BC807-17', u'-55'),
#  (u'WEITS00252-1', u'BC807-25', u'-50'),
#  (u'WEITS00252-1', u'BC807-40', u'-50'),
#  (u'ZETXS01948-1', u'BC856', u'-50'),
#  (u'ZETXS01948-1', u'BC856', u'-65'),
#  (u'ZETXS01948-1', u'BC856-40', u'-50'),
#  (u'ZETXS01948-1', u'BC856-40', u'-55'),
#  (u'ZETXS01948-1', u'BC856-40', u'-65'),
#  (u'ZETXS01948-1', u'BC856A', u'-50'),
#  (u'ZETXS01948-1', u'BC856A', u'-55'),
#  (u'ZETXS01948-1', u'BC856A', u'-65'),
#  (u'ZETXS01948-1', u'BC856A-3A', u'-50'),
#  (u'ZETXS01948-1', u'BC856A-3A', u'-65'),
#  (u'ZETXS01948-1', u'BC856B', u'-50'),
#  (u'ZETXS01948-1', u'BC856B', u'-55'),
#  (u'ZETXS01948-1', u'BC856B', u'-65'),
#  (u'ZETXS01948-1', u'BC856B-Z3B', u'-50'),
#  (u'ZETXS01948-1', u'BC856B-Z3B', u'-65'),
#  (u'ZETXS01948-1', u'BC856C', u'-50'),
#  (u'ZETXS01948-1', u'BC856C', u'-55'),
#  (u'ZETXS01948-1', u'BC856C', u'-65'),
#  (u'ZETXS01948-1', u'BC857', u'-50'),
#  (u'ZETXS01948-1', u'BC857', u'-65'),
#  (u'ZETXS01948-1', u'BC857-40', u'-50'),
#  (u'ZETXS01948-1', u'BC857-40', u'-55'),
#  (u'ZETXS01948-1', u'BC857-40', u'-65'),
#  (u'ZETXS01948-1', u'BC857A', u'-50'),
#  (u'ZETXS01948-1', u'BC857A', u'-55'),
#  (u'ZETXS01948-1', u'BC857A', u'-65'),
#  (u'ZETXS01948-1', u'BC857A-Z3E', u'-50'),
#  (u'ZETXS01948-1', u'BC857A-Z3E', u'-65'),
#  (u'ZETXS01948-1', u'BC857B', u'-50'),
#  (u'ZETXS01948-1', u'BC857B', u'-55'),
#  (u'ZETXS01948-1', u'BC857B', u'-65'),
#  (u'ZETXS01948-1', u'BC857B-3F', u'-50'),
#  (u'ZETXS01948-1', u'BC857B-3F', u'-65'),
#  (u'ZETXS01948-1', u'BC857C', u'-50'),
#  (u'ZETXS01948-1', u'BC857C', u'-55'),
#  (u'ZETXS01948-1', u'BC857C', u'-65'),
#  (u'ZETXS01948-1', u'BC857C-3G', u'-50'),
#  (u'ZETXS01948-1', u'BC857C-3G', u'-65'),
#  (u'ZETXS01948-1', u'BC858', u'-50'),
#  (u'ZETXS01948-1', u'BC858', u'-65'),
#  (u'ZETXS01948-1', u'BC858-40', u'-50'),
#  (u'ZETXS01948-1', u'BC858-40', u'-55'),
#  (u'ZETXS01948-1', u'BC858-40', u'-65'),
#  (u'ZETXS01948-1', u'BC858A', u'-50'),
#  (u'ZETXS01948-1', u'BC858A', u'-55'),
#  (u'ZETXS01948-1', u'BC858A', u'-65'),
#  (u'ZETXS01948-1', u'BC858A-3J', u'-50'),
#  (u'ZETXS01948-1', u'BC858A-3J', u'-65'),
#  (u'ZETXS01948-1', u'BC858B', u'-50'),
#  (u'ZETXS01948-1', u'BC858B', u'-55'),
#  (u'ZETXS01948-1', u'BC858B', u'-65'),
#  (u'ZETXS01948-1', u'BC858B-3K', u'-50'),
#  (u'ZETXS01948-1', u'BC858B-3K', u'-65'),
#  (u'ZETXS01948-1', u'BC858C', u'-50'),
#  (u'ZETXS01948-1', u'BC858C', u'-55'),
#  (u'ZETXS01948-1', u'BC858C', u'-65'),
#  (u'ZETXS01948-1', u'BC858C-3L', u'-50'),
#  (u'ZETXS01948-1', u'BC858C-3L', u'-65'),
#  (u'ZETXS01948-1', u'BC859', u'-50'),
#  (u'ZETXS01948-1', u'BC859', u'-65'),
#  (u'ZETXS01948-1', u'BC859-40', u'-50'),
#  (u'ZETXS01948-1', u'BC859-40', u'-55'),
#  (u'ZETXS01948-1', u'BC859-40', u'-65'),
#  (u'ZETXS01948-1', u'BC859A', u'-50'),
#  (u'ZETXS01948-1', u'BC859A', u'-55'),
#  (u'ZETXS01948-1', u'BC859A', u'-65'),
#  (u'ZETXS01948-1', u'BC859A-Z4A', u'-50'),
#  (u'ZETXS01948-1', u'BC859A-Z4A', u'-65'),
#  (u'ZETXS01948-1', u'BC859B', u'-50'),
#  (u'ZETXS01948-1', u'BC859B', u'-55'),
#  (u'ZETXS01948-1', u'BC859B', u'-65'),
#  (u'ZETXS01948-1', u'BC859B-4B', u'-50'),
#  (u'ZETXS01948-1', u'BC859B-4B', u'-65'),
#  (u'ZETXS01948-1', u'BC859C', u'-50'),
#  (u'ZETXS01948-1', u'BC859C', u'-55'),
#  (u'ZETXS01948-1', u'BC859C', u'-65'),
#  (u'ZETXS01948-1', u'BC859C-Z4C', u'-50'),
#  (u'ZETXS01948-1', u'BC859C-Z4C', u'-65'),
#  (u'ZETXS01948-1', u'BC860', u'-50'),
#  (u'ZETXS01948-1', u'BC860', u'-65'),
#  (u'ZETXS01948-1', u'BC860-40', u'-50'),
#  (u'ZETXS01948-1', u'BC860-40', u'-55'),
#  (u'ZETXS01948-1', u'BC860-40', u'-65'),
#  (u'ZETXS01948-1', u'BC860A', u'-50'),
#  (u'ZETXS01948-1', u'BC860A', u'-55'),
#  (u'ZETXS01948-1', u'BC860A', u'-65'),
#  (u'ZETXS01948-1', u'BC860A-Z4E', u'-50'),
#  (u'ZETXS01948-1', u'BC860A-Z4E', u'-65'),
#  (u'ZETXS01948-1', u'BC860B', u'-50'),
#  (u'ZETXS01948-1', u'BC860B', u'-55'),
#  (u'ZETXS01948-1', u'BC860B', u'-65'),
#  (u'ZETXS01948-1', u'BC860B-4F', u'-50'),
#  (u'ZETXS01948-1', u'BC860B-4F', u'-65'),
#  (u'ZETXS01948-1', u'BC860C', u'-50'),
#  (u'ZETXS01948-1', u'BC860C', u'-55'),
#  (u'ZETXS01948-1', u'BC860C', u'-65'),
#  (u'ZETXS01948-1', u'BC860C-4GZ', u'-50'),
#  (u'ZETXS01948-1', u'BC860C-4GZ', u'-65')]

# %%
pprint(cfn)
# Out:
# [('CENTRALSEMICONDUCTORCORP_CENU45', 'CEN-U45', '-65'),
#  ('CENTRALSEMICONDUCTORCORP_CMPT5401ETR', 'CMPT5401E', '-65'),
#  ('CENTRALSEMICONDUCTORCORP_CXT4033TR', 'CXT4033', '-65'),
#  ('DIODESINCORPORATED_2DD26527', '2DD2652', '-55'),
#  ('DIODESINCORPORATED_2DD26527', '2DD2652-7', '-55'),
#  ('DIODESINCORPORATED_FCX491ATA', 'FCX491A', '-65'),
#  ('DIODESINCORPORATED_ZXT690BKTC', 'ZXT690BKQTC', '-55'),
#  ('DIODESINCORPORATED_ZXT690BKTC', 'ZXT690BKTC', '-55'),
#  ('DISES00490-1', 'BC846AW', '-55'),
#  ('DISES00490-1', 'BC846BW', '-55'),
#  ('DISES00490-1', 'BC847AW', '-55'),
#  ('DISES00490-1', 'BC847BW', '-55'),
#  ('DISES00490-1', 'BC847CW', '-55'),
#  ('DISES00490-1', 'BC848AW', '-55'),
#  ('DISES00490-1', 'BC848BW', '-55'),
#  ('DISES00490-1', 'BC848CW', '-55'),
#  ('DISES00490-1', 'BC849BW', '-55'),
#  ('DISES00490-1', 'BC849CW', '-55'),
#  ('FAIRCHILDSEMICONDUCTOR_KSC2310YTA', 'KSC2310', '-55'),
#  ('FAIRCHILDSEMICONDUCTOR_KSC2310YTA', 'KSC2310O', '-55'),
#  ('FAIRCHILDSEMICONDUCTOR_KSC2310YTA', 'KSC2310R', '-55'),
#  ('FAIRCHILDSEMICONDUCTOR_KSC2310YTA', 'KSC2310Y', '-55'),
#  ('LITES00689-1', 'BC337-25', '-55'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904', '-55'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904-AP', '-55'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904-AP-HF', '-55'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904-BP', '-55'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904-BP-HF', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29A-BP', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29A-BP-HF', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29B-BP', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29B-BP-HF', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29C-BP', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29C-BP-HF', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30A-BP', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30A-BP-HF', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30B-BP', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30B-BP-HF', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30C-BP', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30C-BP-HF', '-55'),
#  ('NXPUSAINC_PBSS5360PASX', 'PBSS5360PAS', '-65'),
#  ('ONSEMICONDUCTOR_MMBT6521LT1', 'MMBT6521LT1G', '-55'),
#  ('ONSEMICONDUCTOR_MMBT6521LT1', 'SMMBT6521LT1G', '-55'),
#  ('ONSMS04099-1', 'BC239C', '-55'),
#  ('RECTS00705-1', 'BC547A', '-55'),
#  ('RECTS00705-1', 'BC547B', '-55'),
#  ('RECTS00705-1', 'BC548A', '-55'),
#  ('RECTS00705-1', 'BC548B', '-55'),
#  ('SCSCS02324-1', 'MMBT3904', '-55'),
#  ('SIEMS01215-1', 'BC856', '-65'),
#  ('SIEMS01215-1', 'BC856A', '-65'),
#  ('SIEMS01215-1', 'BC856B', '-65'),
#  ('SIEMS01215-1', 'BC857', '-65'),
#  ('SIEMS01215-1', 'BC857A', '-65'),
#  ('SIEMS01215-1', 'BC857B', '-65'),
#  ('SIEMS01215-1', 'BC857C', '-65'),
#  ('SIEMS01215-1', 'BC858', '-65'),
#  ('SIEMS01215-1', 'BC858A', '-65'),
#  ('SIEMS01215-1', 'BC858B', '-65'),
#  ('SIEMS01215-1', 'BC858C', '-65'),
#  ('SIEMS01215-1', 'BC859', '-65'),
#  ('SIEMS01215-1', 'BC859A', '-65'),
#  ('SIEMS01215-1', 'BC859B', '-65'),
#  ('SIEMS01215-1', 'BC859C', '-65'),
#  ('SIEMS01215-1', 'BC860', '-65'),
#  ('SIEMS01215-1', 'BC860B', '-65'),
#  ('SIEMS01215-1', 'BC860C', '-65'),
#  ('STMICROELECTRONICS_STI130051', 'STI13005-1', '-65'),
#  ('TTELECTRONICSOPTEKTECHNOLOGY_2N2222AUATXV', '2N2222AUATX', '-65'),
#  ('TTELECTRONICSOPTEKTECHNOLOGY_2N2222AUATXV', '2N2222AUATXV', '-65')]

# %%
# If necessary
if not snorkel_postgres:
    import os
    os.system('cp snorkel.db snorkel.db\ candidates');

# %% [markdown]
# ## Gold Labels

# %%
# If necessary
# import os
# os.remove('snorkel.db');
# os.system('cp snorkel.db\ candidates snorkel.db');

# import sys
# sys.path.append(os.environ['SNORKELHOME'] + '/tutorials/tables/')

# from snorkel import SnorkelSession
# session = SnorkelSession()

# from snorkel.models import candidate_subclass
# Part_Attr = candidate_subclass('Part_Attr', ['part','attr'])

# %%
import os
from snorkel.models import CandidateSet
from hardware_utils import load_hardware_labels

data_sets = ['Dev']
gold_file = {}
gold_file['Dev'] = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/dev/hardware_dev_gold.csv'
if TEST_SIZE:
    data_sets.append('Test')
    gold_file['Test'] = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/test/hardware_test_gold.csv'
for data_set in data_sets:
    candidate_set_name = 'Hardware %s Candidates' % data_set
    candidates = session.query(CandidateSet).filter(
        CandidateSet.name == candidate_set_name).one()
    label_set_name = 'Hardware %s Candidates -- Gold' % data_set
    annotation_key_name = 'Hardware %s Labels -- Gold' % data_set
    # %time gold_candidates, annotation_key = load_hardware_labels(session,\
                           label_set_name, \
                           annotation_key_name, \
                           candidates, \
                           gold_file[data_set], \
                           ATTRIBUTE)
    candidates_gold = session.query(CandidateSet).filter(
        CandidateSet.name == candidate_set_name + ' -- Gold').one()
    print "%d/%d Candidates in %s have positive Labels" % (
        len(candidates_gold), len(candidates), candidates)
# Out:
# Loading 12857 candidate labels
# [========================================] 100%
# CPU times: user 30.4 s, sys: 1.12 s, total: 31.5 s
# Wall time: 39.2 s
# 5465/12857 Candidates in Candidate Set (Hardware Dev Candidates) have positive Labels

# %%
# If necessary
if not snorkel_postgres:
    import os
    os.system('cp snorkel.db snorkel.db\ labels');

# %% [markdown]
# ## Features

# %%
# # If necessary:
# import os
# # os.remove('snorkel.db');
# os.system('cp snorkel.db\ labels snorkel.db');

# from snorkel import SnorkelSession
# session = SnorkelSession()

# from snorkel.models import candidate_subclass
# Part_Attr = candidate_subclass('Part_Attr', ['part','attr'])

# %% [markdown]
# ### Extract Features

# %%
from snorkel.models import CandidateSet
from snorkel.utils import get_ORM_instance

train = get_ORM_instance(CandidateSet, session, 'Hardware Train Candidates')
dev   = get_ORM_instance(CandidateSet, session, 'Hardware Dev Candidates')
test  = get_ORM_instance(CandidateSet, session, 'Hardware Test Candidates')

if snorkel_postgres:
    from snorkel.async_annotations import annotate
    print "Starting async featurization..."
    # %time F_train = annotate(train, parallel=PARALLEL)
    # %time F_dev   = annotate(dev,   parallel=PARALLEL, keyset = 'Hardware Train Candidates')
    if TEST_SIZE:
        # %time F_test  = annotate(test,  parallel=PARALLEL, keyset = 'Hardware Train Candidates')
    
else:
    from snorkel.models import CandidateSet
    from snorkel.fast_annotations import FeatureManager
    from snorkel.utils import get_ORM_instance

    print "Starting sync featurization..."
    feature_manager = FeatureManager()
    # %time F_train = feature_manager.create(session, train, 'Train Features')
    # %time F_dev = feature_manager.update(session, dev, 'Train Features', expand_key_set=False)
# Out:
# Starting async featurization...
# [========================================] 100%
# Copying hardware_train_candidates_features to postgres
# COPY 25994
#
# CPU times: user 50.4 s, sys: 1.78 s, total: 52.2 s
# Wall time: 52min 53s
# [========================================] 100%
# Copying hardware_dev_candidates_features to postgres
# COPY 12857
#
# CPU times: user 19.8 s, sys: 1.2 s, total: 21 s
# Wall time: 25min 10s

# %%
# If necessary:
if not snorkel_postgres:
    import os
    os.system('cp snorkel.db snorkel.db\ featurized');

# %% [markdown]
# ## LFs

# %%
# If necessary
# import os
# os.remove('snorkel.db');
# os.system('cp snorkel.db\ featurized snorkel.db');

# from snorkel import SnorkelSession
# session = SnorkelSession()

# import sys
# sys.path.append(os.environ['SNORKELHOME'] + '/tutorials/tables/')

# from snorkel.models import candidate_subclass
# Part_Attr = candidate_subclass('Part_Attr', ['part','attr'])

# from snorkel.models import CandidateSet
# train = session.query(CandidateSet).filter(
#     CandidateSet.name == 'Hardware Train Candidates').one()
# dev = session.query(CandidateSet).filter(
#     CandidateSet.name == 'Hardware Dev Candidates').one()

# from snorkel.annotations import FeatureManager, LabelManager
# feature_manager = FeatureManager()
# %time F_train = feature_manager.load(session, train, 'Train Features')
# %time F_dev = feature_manager.load(session, dev, 'Train Features')

# %% [markdown]
# ### Define LFs

# %%
from hardware_lfs import get_lfs

LFs = get_lfs(ATTRIBUTE)

# %% [markdown]
# ### Apply LFs

# %%
if snorkel_postgres:
    from snorkel.async_annotations import annotate
    # %time L_train = annotate(train, parallel=PARALLEL, lfs=LFs)
else:
    from snorkel.fast_annotations import LabelManager
    label_manager = LabelManager()
    # %time L_train = label_manager.create(session, train, 'LF Labels', f=LFs)
L_train
# Out:
# [========================================] 100%
# Copying hardware_train_candidates_labels to postgres
# COPY 25994
#
# CPU times: user 6.62 s, sys: 744 ms, total: 7.36 s
# Wall time: 43min 59s
# <25994x25 sparse matrix of type '<type 'numpy.float32'>'
# 	with 144981 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Assess LF accuracy

# %%
# %time L_train.lf_stats()
# Out:
# CPU times: user 12 ms, sys: 4 ms, total: 16 ms
# Wall time: 9.61 ms
#                                conflicts  coverage   j  overlaps
# LF_part_complement              0.039894  0.046049   0  0.046049
# LF_positive_number_right        0.179426  0.179426   1  0.179426
# LF_typ_row                      0.000000  0.000654   2  0.000654
# LF_voltage_row_part             0.063976  0.217627   3  0.217627
# LF_collector_aligned            0.045934  0.173271   4  0.173271
# LF_part_num_in_high_col_num     0.012311  0.027083   5  0.027083
# LF_operating_row                0.366892  0.366892   6  0.366892
# LF_temp_outside_table           0.638493  1.000000   7  1.000000
# LF_to_right                     0.472340  0.472340   8  0.472340
# LF_many_p_siblings              0.000000  0.000000   9  0.000000
# LF_complement_left_row          0.000000  0.000000  10  0.000000
# LF_other_minus_signs_in_row     0.031238  0.101677  11  0.101677
# LF_current_aligned              0.046203  0.157344  12  0.157344
# LF_tstg_row                     0.437024  0.437024  13  0.437024
# LF_replacement_table            0.002039  0.007886  14  0.007886
# LF_not_temp_relevant            0.182311  0.543741  15  0.543741
# LF_voltage_row_temp             0.063976  0.217627  16  0.217627
# LF_please_to_left               0.008002  0.035123  17  0.035123
# LF_test_condition_aligned       0.008310  0.037739  18  0.037739
# LF_too_many_numbers_row         0.076248  0.177772  19  0.177772
# LF_part_in_header_tag           0.172617  0.172617  20  0.172617
# LF_temp_on_high_page_num        0.116565  0.335731  21  0.335731
# LF_cheating_with_another_part   0.000000  0.000000  22  0.000000
# LF_temperature_row              0.435293  0.435293  23  0.435293
# LF_storage_row                  0.434562  0.434562  24  0.434562

# %%
# If necessary
if not snorkel_postgres:
    import os
    os.system('cp snorkel.db snorkel.db\ features');

# %% [markdown]
# ## Learn and Evaluate

# %%
# If necessary:
# import os
# os.remove('snorkel.db');
# os.system('cp snorkel.db\ features snorkel.db');

# from snorkel import SnorkelSession
# session = SnorkelSession()

# import sys
# sys.path.append(os.environ['SNORKELHOME'] + '/tutorials/tables/')

# from snorkel.models import candidate_subclass
# Part_Attr = candidate_subclass('Part_Attr', ['part','attr'])

# from snorkel.models import CandidateSet
# train = session.query(CandidateSet).filter(
#     CandidateSet.name == 'Hardware Training Candidates').one()
# dev = session.query(CandidateSet).filter(
#     CandidateSet.name == 'Hardware Development Candidates').one()

# from snorkel.annotations import FeatureManager, LabelManager
# feature_manager = FeatureManager()
# %time F_train = feature_manager.load(session, train, 'Train Features')
# %time F_dev = feature_manager.load(session, dev, 'Train Features')

# label_manager = LabelManager()
# %time L_train = label_manager.load(session, train, 'LF Labels')

# %%
from snorkel.learning import NaiveBayes

gen_model = NaiveBayes()
gen_model.train(L_train, n_iter=100000, rate=1e-3, mu=1e-6)
train_marginals = gen_model.marginals(L_train)
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/__init__.py:1173: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# ================================================================================
# Training marginals (!= 0.5):	25994
# Features:			25
# ================================================================================
# Begin training for rate=0.001, mu=1e-06
# 	Learning epoch = 0	Gradient mag. = 0.514932
# 	Learning epoch = 250	Gradient mag. = 0.557429
# 	Learning epoch = 500	Gradient mag. = 0.573649
# 	Learning epoch = 750	Gradient mag. = 0.590557
# 	Learning epoch = 1000	Gradient mag. = 0.607987
# 	Learning epoch = 1250	Gradient mag. = 0.625732
# 	Learning epoch = 1500	Gradient mag. = 0.643550
# 	Learning epoch = 1750	Gradient mag. = 0.661162
# 	Learning epoch = 2000	Gradient mag. = 0.678261
# 	Learning epoch = 2250	Gradient mag. = 0.694532
# 	Learning epoch = 2500	Gradient mag. = 0.709665
# 	Learning epoch = 2750	Gradient mag. = 0.723388
# 	Learning epoch = 3000	Gradient mag. = 0.735487
# 	Learning epoch = 3250	Gradient mag. = 0.745826
# 	Learning epoch = 3500	Gradient mag. = 0.754357
# 	Learning epoch = 3750	Gradient mag. = 0.761111
# 	Learning epoch = 4000	Gradient mag. = 0.766188
# 	Learning epoch = 4250	Gradient mag. = 0.769730
# 	Learning epoch = 4500	Gradient mag. = 0.771908
# 	Learning epoch = 4750	Gradient mag. = 0.772898
# 	Learning epoch = 5000	Gradient mag. = 0.772873
# 	Learning epoch = 5250	Gradient mag. = 0.771993
# 	Learning epoch = 5500	Gradient mag. = 0.770405
# 	Learning epoch = 5750	Gradient mag. = 0.768236
# 	Learning epoch = 6000	Gradient mag. = 0.765595
# 	Learning epoch = 6250	Gradient mag. = 0.762576
# 	Learning epoch = 6500	Gradient mag. = 0.759258
# 	Learning epoch = 6750	Gradient mag. = 0.755707
# 	Learning epoch = 7000	Gradient mag. = 0.751976
# 	Learning epoch = 7250	Gradient mag. = 0.748109
# 	Learning epoch = 7500	Gradient mag. = 0.744142
# 	Learning epoch = 7750	Gradient mag. = 0.740103
# 	Learning epoch = 8000	Gradient mag. = 0.736016
# 	Learning epoch = 8250	Gradient mag. = 0.730266
# 	Learning epoch = 8500	Gradient mag. = 0.719287
# 	Learning epoch = 8750	Gradient mag. = 0.708480
# 	Learning epoch = 9000	Gradient mag. = 0.697849
# 	Learning epoch = 9250	Gradient mag. = 0.687401
# 	Learning epoch = 9500	Gradient mag. = 0.677141
# 	Learning epoch = 9750	Gradient mag. = 0.667071
# 	Learning epoch = 10000	Gradient mag. = 0.657195
# 	Learning epoch = 10250	Gradient mag. = 0.647514
# 	Learning epoch = 10500	Gradient mag. = 0.638031
# 	Learning epoch = 10750	Gradient mag. = 0.628745
# 	Learning epoch = 11000	Gradient mag. = 0.619658
# 	Learning epoch = 11250	Gradient mag. = 0.610769
# 	Learning epoch = 11500	Gradient mag. = 0.602079
# 	Learning epoch = 11750	Gradient mag. = 0.593587
# 	Learning epoch = 12000	Gradient mag. = 0.585291
# 	Learning epoch = 12250	Gradient mag. = 0.577191
# 	Learning epoch = 12500	Gradient mag. = 0.569284
# 	Learning epoch = 12750	Gradient mag. = 0.561570
# 	Learning epoch = 13000	Gradient mag. = 0.554047
# 	Learning epoch = 13250	Gradient mag. = 0.546711
# 	Learning epoch = 13500	Gradient mag. = 0.539561
# 	Learning epoch = 13750	Gradient mag. = 0.532595
# 	Learning epoch = 14000	Gradient mag. = 0.525809
# 	Learning epoch = 14250	Gradient mag. = 0.519201
# 	Learning epoch = 14500	Gradient mag. = 0.512769
# 	Learning epoch = 14750	Gradient mag. = 0.506508
# 	Learning epoch = 15000	Gradient mag. = 0.500416
# 	Learning epoch = 15250	Gradient mag. = 0.494490
# 	Learning epoch = 15500	Gradient mag. = 0.488726
# 	Learning epoch = 15750	Gradient mag. = 0.483122
# 	Learning epoch = 16000	Gradient mag. = 0.477673
# 	Learning epoch = 16250	Gradient mag. = 0.472378
# 	Learning epoch = 16500	Gradient mag. = 0.467232
# 	Learning epoch = 16750	Gradient mag. = 0.462232
# 	Learning epoch = 17000	Gradient mag. = 0.457375
# 	Learning epoch = 17250	Gradient mag. = 0.452657
# 	Learning epoch = 17500	Gradient mag. = 0.448077
# 	Learning epoch = 17750	Gradient mag. = 0.443629
# 	Learning epoch = 18000	Gradient mag. = 0.439312
# 	Learning epoch = 18250	Gradient mag. = 0.435123
# 	Learning epoch = 18500	Gradient mag. = 0.431057
# 	Learning epoch = 18750	Gradient mag. = 0.427114
# 	Learning epoch = 19000	Gradient mag. = 0.423289
# 	Learning epoch = 19250	Gradient mag. = 0.419580
# 	Learning epoch = 19500	Gradient mag. = 0.415984
# 	Learning epoch = 19750	Gradient mag. = 0.412498
# 	Learning epoch = 20000	Gradient mag. = 0.409121
# 	Learning epoch = 20250	Gradient mag. = 0.405849
# 	Learning epoch = 20500	Gradient mag. = 0.402680
# 	Learning epoch = 20750	Gradient mag. = 0.399612
# 	Learning epoch = 21000	Gradient mag. = 0.396641
# 	Learning epoch = 21250	Gradient mag. = 0.393766
# 	Learning epoch = 21500	Gradient mag. = 0.390985
# 	Learning epoch = 21750	Gradient mag. = 0.388295
# 	Learning epoch = 22000	Gradient mag. = 0.385694
# 	Learning epoch = 22250	Gradient mag. = 0.383179
# 	Learning epoch = 22500	Gradient mag. = 0.380749
# 	Learning epoch = 22750	Gradient mag. = 0.378402
# 	Learning epoch = 23000	Gradient mag. = 0.376134
# 	Learning epoch = 23250	Gradient mag. = 0.373945
# 	Learning epoch = 23500	Gradient mag. = 0.371832
# 	Learning epoch = 23750	Gradient mag. = 0.369793
# 	Learning epoch = 24000	Gradient mag. = 0.367826
# 	Learning epoch = 24250	Gradient mag. = 0.365929
# 	Learning epoch = 24500	Gradient mag. = 0.364100
# 	Learning epoch = 24750	Gradient mag. = 0.362337
# 	Learning epoch = 25000	Gradient mag. = 0.360639
# 	Learning epoch = 25250	Gradient mag. = 0.359003
# 	Learning epoch = 25500	Gradient mag. = 0.357428
# 	Learning epoch = 25750	Gradient mag. = 0.355911
# 	Learning epoch = 26000	Gradient mag. = 0.354452
# 	Learning epoch = 26250	Gradient mag. = 0.353048
# 	Learning epoch = 26500	Gradient mag. = 0.351697
# 	Learning epoch = 26750	Gradient mag. = 0.350399
# 	Learning epoch = 27000	Gradient mag. = 0.349150
# 	Learning epoch = 27250	Gradient mag. = 0.347951
# 	Learning epoch = 27500	Gradient mag. = 0.346799
# 	Learning epoch = 27750	Gradient mag. = 0.345692
# 	Learning epoch = 28000	Gradient mag. = 0.344629
# 	Learning epoch = 28250	Gradient mag. = 0.343610
# 	Learning epoch = 28500	Gradient mag. = 0.342631
# 	Learning epoch = 28750	Gradient mag. = 0.341692
# 	Learning epoch = 29000	Gradient mag. = 0.340792
# 	Learning epoch = 29250	Gradient mag. = 0.339930
# 	Learning epoch = 29500	Gradient mag. = 0.339103
# 	Learning epoch = 29750	Gradient mag. = 0.338310
# 	Learning epoch = 30000	Gradient mag. = 0.337552
# 	Learning epoch = 30250	Gradient mag. = 0.336825
# 	Learning epoch = 30500	Gradient mag. = 0.336130
# 	Learning epoch = 30750	Gradient mag. = 0.335465
# 	Learning epoch = 31000	Gradient mag. = 0.334829
# 	Learning epoch = 31250	Gradient mag. = 0.334221
# 	Learning epoch = 31500	Gradient mag. = 0.333640
# 	Learning epoch = 31750	Gradient mag. = 0.333085
# 	Learning epoch = 32000	Gradient mag. = 0.329019
# 	Learning epoch = 32250	Gradient mag. = 0.322453
# 	Learning epoch = 32500	Gradient mag. = 0.316048
# 	Learning epoch = 32750	Gradient mag. = 0.309799
# 	Learning epoch = 33000	Gradient mag. = 0.303704
# 	Learning epoch = 33250	Gradient mag. = 0.297759
# 	Learning epoch = 33500	Gradient mag. = 0.291959
# 	Learning epoch = 33750	Gradient mag. = 0.286302
# 	Learning epoch = 34000	Gradient mag. = 0.280785
# 	Learning epoch = 34250	Gradient mag. = 0.275403
# 	Learning epoch = 34500	Gradient mag. = 0.270153
# 	Learning epoch = 34750	Gradient mag. = 0.265033
# 	Learning epoch = 35000	Gradient mag. = 0.260039
# 	Learning epoch = 35250	Gradient mag. = 0.255168
# 	Learning epoch = 35500	Gradient mag. = 0.250418
# 	Learning epoch = 35750	Gradient mag. = 0.245784
# 	Learning epoch = 36000	Gradient mag. = 0.241266
# 	Learning epoch = 36250	Gradient mag. = 0.236859
# 	Learning epoch = 36500	Gradient mag. = 0.232561
# 	Learning epoch = 36750	Gradient mag. = 0.228370
# 	Learning epoch = 37000	Gradient mag. = 0.224283
# 	Learning epoch = 37250	Gradient mag. = 0.220297
# 	Learning epoch = 37500	Gradient mag. = 0.216410
# 	Learning epoch = 37750	Gradient mag. = 0.212619
# 	Learning epoch = 38000	Gradient mag. = 0.208923
# 	Learning epoch = 38250	Gradient mag. = 0.205319
# 	Learning epoch = 38500	Gradient mag. = 0.201805
# 	Learning epoch = 38750	Gradient mag. = 0.198378
# 	Learning epoch = 39000	Gradient mag. = 0.195037
# 	Learning epoch = 39250	Gradient mag. = 0.191779
# 	Learning epoch = 39500	Gradient mag. = 0.188603
# 	Learning epoch = 39750	Gradient mag. = 0.185506
# 	Learning epoch = 40000	Gradient mag. = 0.182487
# 	Learning epoch = 40250	Gradient mag. = 0.179543
# 	Learning epoch = 40500	Gradient mag. = 0.176674
# 	Learning epoch = 40750	Gradient mag. = 0.173877
# 	Learning epoch = 41000	Gradient mag. = 0.171150
# 	Learning epoch = 41250	Gradient mag. = 0.168492
# 	Learning epoch = 41500	Gradient mag. = 0.165901
# 	Learning epoch = 41750	Gradient mag. = 0.163375
# 	Learning epoch = 42000	Gradient mag. = 0.160914
# 	Learning epoch = 42250	Gradient mag. = 0.158515
# 	Learning epoch = 42500	Gradient mag. = 0.156177
# 	Learning epoch = 42750	Gradient mag. = 0.153899
# 	Learning epoch = 43000	Gradient mag. = 0.151679
# 	Learning epoch = 43250	Gradient mag. = 0.149516
# 	Learning epoch = 43500	Gradient mag. = 0.147408
# 	Learning epoch = 43750	Gradient mag. = 0.145354
# 	Learning epoch = 44000	Gradient mag. = 0.143354
# 	Learning epoch = 44250	Gradient mag. = 0.141405
# 	Learning epoch = 44500	Gradient mag. = 0.139507
# 	Learning epoch = 44750	Gradient mag. = 0.137658
# 	Learning epoch = 45000	Gradient mag. = 0.135858
# 	Learning epoch = 45250	Gradient mag. = 0.134105
# 	Learning epoch = 45500	Gradient mag. = 0.132398
# 	Learning epoch = 45750	Gradient mag. = 0.130736
# 	Learning epoch = 46000	Gradient mag. = 0.129118
# 	Learning epoch = 46250	Gradient mag. = 0.127544
# 	Learning epoch = 46500	Gradient mag. = 0.126012
# 	Learning epoch = 46750	Gradient mag. = 0.124521
# 	Learning epoch = 47000	Gradient mag. = 0.123070
# 	Learning epoch = 47250	Gradient mag. = 0.121659
# 	Learning epoch = 47500	Gradient mag. = 0.120287
# 	Learning epoch = 47750	Gradient mag. = 0.118953
# 	Learning epoch = 48000	Gradient mag. = 0.117656
# 	Learning epoch = 48250	Gradient mag. = 0.116395
# 	Learning epoch = 48500	Gradient mag. = 0.115171
# 	Learning epoch = 48750	Gradient mag. = 0.113981
# 	Learning epoch = 49000	Gradient mag. = 0.112826
# 	Learning epoch = 49250	Gradient mag. = 0.111704
# 	Learning epoch = 49500	Gradient mag. = 0.110616
# 	Learning epoch = 49750	Gradient mag. = 0.109560
# 	Learning epoch = 50000	Gradient mag. = 0.108536
# 	Learning epoch = 50250	Gradient mag. = 0.107543
# 	Learning epoch = 50500	Gradient mag. = 0.106581
# 	Learning epoch = 50750	Gradient mag. = 0.105650
# 	Learning epoch = 51000	Gradient mag. = 0.104748
# 	Learning epoch = 51250	Gradient mag. = 0.103876
# 	Learning epoch = 51500	Gradient mag. = 0.102940
# 	Learning epoch = 51750	Gradient mag. = 0.101733
# 	Learning epoch = 52000	Gradient mag. = 0.100608
# 	Learning epoch = 52250	Gradient mag. = 0.099565
# 	Learning epoch = 52500	Gradient mag. = 0.098603
# 	Learning epoch = 52750	Gradient mag. = 0.097721
# 	Learning epoch = 53000	Gradient mag. = 0.096918
# 	Learning epoch = 53250	Gradient mag. = 0.096194
# 	Learning epoch = 53500	Gradient mag. = 0.095548
# 	Learning epoch = 53750	Gradient mag. = 0.094977
# 	Learning epoch = 54000	Gradient mag. = 0.094479
# 	Learning epoch = 54250	Gradient mag. = 0.094055
# 	Learning epoch = 54500	Gradient mag. = 0.093700
# 	Learning epoch = 54750	Gradient mag. = 0.093412
# 	Learning epoch = 55000	Gradient mag. = 0.093191
# 	Learning epoch = 55250	Gradient mag. = 0.093032
# 	Learning epoch = 55500	Gradient mag. = 0.092933
# 	Learning epoch = 55750	Gradient mag. = 0.092892
# 	Learning epoch = 56000	Gradient mag. = 0.092905
# 	Learning epoch = 56250	Gradient mag. = 0.092970
# 	Learning epoch = 56500	Gradient mag. = 0.093084
# 	Learning epoch = 56750	Gradient mag. = 0.093244
# 	Learning epoch = 57000	Gradient mag. = 0.093447
# 	Learning epoch = 57250	Gradient mag. = 0.093690
# 	Learning epoch = 57500	Gradient mag. = 0.093970
# 	Learning epoch = 57750	Gradient mag. = 0.094284
# 	Learning epoch = 58000	Gradient mag. = 0.094630
# 	Learning epoch = 58250	Gradient mag. = 0.095006
# 	Learning epoch = 58500	Gradient mag. = 0.095407
# 	Learning epoch = 58750	Gradient mag. = 0.095834
# 	Learning epoch = 59000	Gradient mag. = 0.096282
# 	Learning epoch = 59250	Gradient mag. = 0.096749
# 	Learning epoch = 59500	Gradient mag. = 0.097235
# 	Learning epoch = 59750	Gradient mag. = 0.097737
# 	Learning epoch = 60000	Gradient mag. = 0.098253
# 	Learning epoch = 60250	Gradient mag. = 0.098781
# 	Learning epoch = 60500	Gradient mag. = 0.099321
# 	Learning epoch = 60750	Gradient mag. = 0.099871
# 	Learning epoch = 61000	Gradient mag. = 0.100430
# 	Learning epoch = 61250	Gradient mag. = 0.100998
# 	Learning epoch = 61500	Gradient mag. = 0.101572
# 	Learning epoch = 61750	Gradient mag. = 0.102153
# 	Learning epoch = 62000	Gradient mag. = 0.102740
# 	Learning epoch = 62250	Gradient mag. = 0.103332
# 	Learning epoch = 62500	Gradient mag. = 0.103930
# 	Learning epoch = 62750	Gradient mag. = 0.104532
# 	Learning epoch = 63000	Gradient mag. = 0.105139
# 	Learning epoch = 63250	Gradient mag. = 0.105751
# 	Learning epoch = 63500	Gradient mag. = 0.106368
# 	Learning epoch = 63750	Gradient mag. = 0.106989
# 	Learning epoch = 64000	Gradient mag. = 0.107616
# 	Learning epoch = 64250	Gradient mag. = 0.108247
# 	Learning epoch = 64500	Gradient mag. = 0.108884
# 	Learning epoch = 64750	Gradient mag. = 0.109526
# 	Learning epoch = 65000	Gradient mag. = 0.110175
# 	Learning epoch = 65250	Gradient mag. = 0.110829
# 	Learning epoch = 65500	Gradient mag. = 0.111489
# 	Learning epoch = 65750	Gradient mag. = 0.112157
# 	Learning epoch = 66000	Gradient mag. = 0.112831
# 	Learning epoch = 66250	Gradient mag. = 0.113512
# 	Learning epoch = 66500	Gradient mag. = 0.114201
# 	Learning epoch = 66750	Gradient mag. = 0.114897
# 	Learning epoch = 67000	Gradient mag. = 0.115602
# 	Learning epoch = 67250	Gradient mag. = 0.116314
# 	Learning epoch = 67500	Gradient mag. = 0.116463
# 	Learning epoch = 67750	Gradient mag. = 0.115923
# 	Learning epoch = 68000	Gradient mag. = 0.115385
# 	Learning epoch = 68250	Gradient mag. = 0.114847
# 	Learning epoch = 68500	Gradient mag. = 0.114312
# 	Learning epoch = 68750	Gradient mag. = 0.113780
# 	Learning epoch = 69000	Gradient mag. = 0.113251
# 	Learning epoch = 69250	Gradient mag. = 0.112726
# 	Learning epoch = 69500	Gradient mag. = 0.112205
# 	Learning epoch = 69750	Gradient mag. = 0.111690
# 	Learning epoch = 70000	Gradient mag. = 0.111179
# 	Learning epoch = 70250	Gradient mag. = 0.110675
# 	Learning epoch = 70500	Gradient mag. = 0.110176
# 	Learning epoch = 70750	Gradient mag. = 0.109685
# 	Learning epoch = 71000	Gradient mag. = 0.109200
# 	Learning epoch = 71250	Gradient mag. = 0.108722
# 	Learning epoch = 71500	Gradient mag. = 0.108251
# 	Learning epoch = 71750	Gradient mag. = 0.107789
# 	Learning epoch = 72000	Gradient mag. = 0.107334
# 	Learning epoch = 72250	Gradient mag. = 0.106887
# 	Learning epoch = 72500	Gradient mag. = 0.106449
# 	Learning epoch = 72750	Gradient mag. = 0.106019
# 	Learning epoch = 73000	Gradient mag. = 0.105597
# 	Learning epoch = 73250	Gradient mag. = 0.105184
# 	Learning epoch = 73500	Gradient mag. = 0.104780
# 	Learning epoch = 73750	Gradient mag. = 0.104385
# 	Learning epoch = 74000	Gradient mag. = 0.103998
# 	Learning epoch = 74250	Gradient mag. = 0.103621
# 	Learning epoch = 74500	Gradient mag. = 0.103252
# 	Learning epoch = 74750	Gradient mag. = 0.102893
# 	Learning epoch = 75000	Gradient mag. = 0.102542
# 	Learning epoch = 75250	Gradient mag. = 0.102200
# 	Learning epoch = 75500	Gradient mag. = 0.101867
# 	Learning epoch = 75750	Gradient mag. = 0.101543
# 	Learning epoch = 76000	Gradient mag. = 0.101228
# 	Learning epoch = 76250	Gradient mag. = 0.100922
# 	Learning epoch = 76500	Gradient mag. = 0.100624
# 	Learning epoch = 76750	Gradient mag. = 0.100335
# 	Learning epoch = 77000	Gradient mag. = 0.100055
# 	Learning epoch = 77250	Gradient mag. = 0.099783
# 	Learning epoch = 77500	Gradient mag. = 0.099519
# 	Learning epoch = 77750	Gradient mag. = 0.099264
# 	Learning epoch = 78000	Gradient mag. = 0.099017
# 	Learning epoch = 78250	Gradient mag. = 0.098779
# 	Learning epoch = 78500	Gradient mag. = 0.098548
# 	Learning epoch = 78750	Gradient mag. = 0.098325
# 	Learning epoch = 79000	Gradient mag. = 0.098111
# 	Learning epoch = 79250	Gradient mag. = 0.097904
# 	Learning epoch = 79500	Gradient mag. = 0.097704
# 	Learning epoch = 79750	Gradient mag. = 0.097512
# 	Learning epoch = 80000	Gradient mag. = 0.097328
# 	Learning epoch = 80250	Gradient mag. = 0.097151
# 	Learning epoch = 80500	Gradient mag. = 0.096981
# 	Learning epoch = 80750	Gradient mag. = 0.096818
# 	Learning epoch = 81000	Gradient mag. = 0.096662
# 	Learning epoch = 81250	Gradient mag. = 0.096513
# 	Learning epoch = 81500	Gradient mag. = 0.096371
# 	Learning epoch = 81750	Gradient mag. = 0.096235
# 	Learning epoch = 82000	Gradient mag. = 0.096105
# 	Learning epoch = 82250	Gradient mag. = 0.095982
# 	Learning epoch = 82500	Gradient mag. = 0.095866
# 	Learning epoch = 82750	Gradient mag. = 0.095755
# 	Learning epoch = 83000	Gradient mag. = 0.095651
# 	Learning epoch = 83250	Gradient mag. = 0.095552
# 	Learning epoch = 83500	Gradient mag. = 0.095459
# 	Learning epoch = 83750	Gradient mag. = 0.095372
# 	Learning epoch = 84000	Gradient mag. = 0.095290
# 	Learning epoch = 84250	Gradient mag. = 0.095213
# 	Learning epoch = 84500	Gradient mag. = 0.095142
# 	Learning epoch = 84750	Gradient mag. = 0.095077
# 	Learning epoch = 85000	Gradient mag. = 0.095016
# 	Learning epoch = 85250	Gradient mag. = 0.094960
# 	Learning epoch = 85500	Gradient mag. = 0.094909
# 	Learning epoch = 85750	Gradient mag. = 0.094863
# 	Learning epoch = 86000	Gradient mag. = 0.094822
# 	Learning epoch = 86250	Gradient mag. = 0.094785
# 	Learning epoch = 86500	Gradient mag. = 0.094752
# 	Learning epoch = 86750	Gradient mag. = 0.094724
# 	Learning epoch = 87000	Gradient mag. = 0.094700
# 	Learning epoch = 87250	Gradient mag. = 0.094680
# 	Learning epoch = 87500	Gradient mag. = 0.094665
# 	Learning epoch = 87750	Gradient mag. = 0.094653
# 	Learning epoch = 88000	Gradient mag. = 0.094645
# 	Learning epoch = 88250	Gradient mag. = 0.094641
# 	Learning epoch = 88500	Gradient mag. = 0.094641
# 	Learning epoch = 88750	Gradient mag. = 0.094293
# 	Learning epoch = 89000	Gradient mag. = 0.093688
# 	Learning epoch = 89250	Gradient mag. = 0.093089
# 	Learning epoch = 89500	Gradient mag. = 0.092495
# 	Learning epoch = 89750	Gradient mag. = 0.091906
# 	Learning epoch = 90000	Gradient mag. = 0.091321
# 	Learning epoch = 90250	Gradient mag. = 0.090741
# 	Learning epoch = 90500	Gradient mag. = 0.090165
# 	Learning epoch = 90750	Gradient mag. = 0.089595
# 	Learning epoch = 91000	Gradient mag. = 0.089029
# 	Learning epoch = 91250	Gradient mag. = 0.088467
# 	Learning epoch = 91500	Gradient mag. = 0.087910
# 	Learning epoch = 91750	Gradient mag. = 0.087357
# 	Learning epoch = 92000	Gradient mag. = 0.086809
# 	Learning epoch = 92250	Gradient mag. = 0.086266
# 	Learning epoch = 92500	Gradient mag. = 0.085726
# 	Learning epoch = 92750	Gradient mag. = 0.085191
# 	Learning epoch = 93000	Gradient mag. = 0.084660
# 	Learning epoch = 93250	Gradient mag. = 0.084134
# 	Learning epoch = 93500	Gradient mag. = 0.083611
# 	Learning epoch = 93750	Gradient mag. = 0.083093
# 	Learning epoch = 94000	Gradient mag. = 0.082579
# 	Learning epoch = 94250	Gradient mag. = 0.082069
# 	Learning epoch = 94500	Gradient mag. = 0.081563
# 	Learning epoch = 94750	Gradient mag. = 0.081061
# 	Learning epoch = 95000	Gradient mag. = 0.080563
# 	Learning epoch = 95250	Gradient mag. = 0.080068
# 	Learning epoch = 95500	Gradient mag. = 0.079578
# 	Learning epoch = 95750	Gradient mag. = 0.079092
# 	Learning epoch = 96000	Gradient mag. = 0.078609
# 	Learning epoch = 96250	Gradient mag. = 0.078131
# 	Learning epoch = 96500	Gradient mag. = 0.077656
# 	Learning epoch = 96750	Gradient mag. = 0.077185
# 	Learning epoch = 97000	Gradient mag. = 0.076717
# 	Learning epoch = 97250	Gradient mag. = 0.076253
# 	Learning epoch = 97500	Gradient mag. = 0.075793
# 	Learning epoch = 97750	Gradient mag. = 0.075336
# 	Learning epoch = 98000	Gradient mag. = 0.074883
# 	Learning epoch = 98250	Gradient mag. = 0.074434
# 	Learning epoch = 98500	Gradient mag. = 0.073988
# 	Learning epoch = 98750	Gradient mag. = 0.073546
# 	Learning epoch = 99000	Gradient mag. = 0.073106
# 	Learning epoch = 99250	Gradient mag. = 0.072671
# 	Learning epoch = 99500	Gradient mag. = 0.072239
# 	Learning epoch = 99750	Gradient mag. = 0.071810
# Final gradient magnitude for rate=0.001, mu=1e-06: 0.071

# %%
from snorkel.learning import LogReg

disc_model = LogReg()
disc_model.train(F_train, train_marginals, n_iter=2000, rate=1e-4)
# Out:
# ================================================================================
# Training marginals (!= 0.5):	25994
# Features:			52662
# ================================================================================
# Using gradient descent...
# 	Learning epoch = 0	Step size = 0.0001
# 	Loss = 18017.667811	Gradient magnitude = 40773.762789
# 	Learning epoch = 100	Step size = 9.04792147114e-05
# 	Loss = 76.888050	Gradient magnitude = 85.886470
# 	Learning epoch = 200	Step size = 8.18648829479e-05
# 	Loss = 40.741603	Gradient magnitude = 47.339295
# 	Learning epoch = 300	Step size = 7.40707032156e-05
# 	Loss = 27.748822	Gradient magnitude = 35.492405
# 	Learning epoch = 400	Step size = 6.70185906007e-05
# 	Loss = 20.842177	Gradient magnitude = 27.753090
# 	Learning epoch = 500	Step size = 6.06378944861e-05
# 	Loss = 16.945314	Gradient magnitude = 22.436160
# 	Learning epoch = 600	Step size = 5.48646907485e-05
# 	Loss = 14.572721	Gradient magnitude = 18.923300
# 	Learning epoch = 700	Step size = 4.96411413431e-05
# 	Loss = 13.008667	Gradient magnitude = 16.554187
# 	Learning epoch = 800	Step size = 4.4914914861e-05
# 	Loss = 11.909911	Gradient magnitude = 14.889091
# 	Learning epoch = 900	Step size = 4.06386622545e-05
# 	Loss = 11.100729	Gradient magnitude = 13.671249
# 	Learning epoch = 1000	Step size = 3.67695424771e-05
# 	Loss = 10.483812	Gradient magnitude = 12.750797
# 	Learning epoch = 1100	Step size = 3.32687932862e-05
# 	Loss = 10.001130	Gradient magnitude = 12.036790
# 	Learning epoch = 1200	Step size = 3.01013429093e-05
# 	Loss = 9.615970	Gradient magnitude = 11.471389
# 	Learning epoch = 1300	Step size = 2.72354586819e-05
# 	Loss = 9.304056	Gradient magnitude = 11.016563
# 	Learning epoch = 1400	Step size = 2.46424291385e-05
# 	Loss = 9.048676	Gradient magnitude = 10.646299
# 	Learning epoch = 1500	Step size = 2.22962763703e-05
# 	Loss = 8.837795	Gradient magnitude = 10.342041
# 	Learning epoch = 1600	Step size = 2.01734957697e-05
# 	Loss = 8.662602	Gradient magnitude = 10.090295
# 	Learning epoch = 1700	Step size = 1.82528205523e-05
# 	Loss = 8.516482	Gradient magnitude = 9.881039
# 	Learning epoch = 1800	Step size = 1.65150086984e-05
# 	Loss = 8.394393	Gradient magnitude = 9.706700
# 	Learning epoch = 1900	Step size = 1.49426501798e-05
# 	Loss = 8.292477	Gradient magnitude = 9.561425

# %%
dev_gold = session.query(CandidateSet).filter(
    CandidateSet.name == 'Hardware Dev Candidates -- Gold').one()

# %%
from snorkel.annotations import LabelManager
label_manager = LabelManager()
L_dev = label_manager.load(session, dev, 'Hardware Dev Labels -- Gold')
L_dev.shape
# Out:
# (12857, 1)

# %%
tp, fp, tn, fn = disc_model.score(F_dev, L_dev, dev_gold)
# Out:
# Calibration plot:
# /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# ========================================
# Recall-corrected Noise-aware Model
# ========================================
# Pos. class accuracy: 0.670631290027
# Neg. class accuracy: 0.982278138528
# Corpus Precision 0.965
# Corpus Recall    0.671
# Corpus F1        0.791
# ----------------------------------------
# TP: 3665 | FP: 131 | TN: 7261 | FN: 1800
# ========================================
#
# ========================================
# Recall-corrected Noise-aware Model
# ========================================
# Pos. class accuracy: 0.335315645014
# Neg. class accuracy: 0.982278138528
# Corpus Precision 0.965
# Corpus Recall    0.335
# Corpus F1        0.498
# ----------------------------------------
# TP: 3665 | FP: 131 | TN: 7261 | FN: 7265
# ========================================

# %%
from snorkel.models import Corpus
from hardware_utils import entity_level_f1
import os

gold_file = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/dev/hardware_dev_gold.csv'
corpus = session.query(Corpus).filter(Corpus.name == 'Hardware Dev').one()
(TP, FP, FN) = entity_level_f1(tp.union(fp), gold_file, ATTRIBUTE, corpus, parts_by_doc=None)
(TP, FP, FN) = entity_level_f1(tp.union(fp), gold_file, ATTRIBUTE, corpus, parts_by_doc=parts_by_doc)
# Out:
# Preparing candidates...
# [========================================] 100%
# ========================================
# Scoring on Entity-Level Gold Data
# ========================================
# Corpus Precision 0.909
# Corpus Recall    0.71
# Corpus F1        0.797
# ----------------------------------------
# TP: 631 | FP: 63 | FN: 258
# ========================================
#
# Preparing candidates...
# [========================================] 100%
# ========================================
# Scoring on Entity-Level Gold Data
# ========================================
# Corpus Precision 0.849
# Corpus Recall    0.903
# Corpus F1        0.875
# ----------------------------------------
# TP: 803 | FP: 143 | FN: 86
# ========================================

# %% [markdown]
# ### Error Analysis

# %%
# from hardware_utils import separate_fns

# unfound, misclassified = separate_fns(FN, cfn)

# %%
# pprint(misclassified)

# %%
# pprint(unfound)

# %%
# from hardware_utils import separate_fps

# bad_part, bad_relation = separate_fps(FP, corpus, gold_file)

# %%
# pprint(bad_relation)

# %%
# pprint(bad_part)

# %%
# from pprint import pprint
# pprint([(unicode(x[0]), x[1]) for x in disc_model.get_feature_weights(F_dev)[:100]])

# %%
# from hardware_utils import entity_to_candidates

# entity = FP[0]
# print entity
# print

# matches = entity_to_candidates(entity, fp)
# print "# Matches: %d" % len(matches)
# print

# candidate = matches[0]
# print candidate
# print

# from hardware_utils import part_error_analysis
# part_error_analysis(candidate)

# pprint(disc_model.get_candidate_feature_weights(candidate, F_dev))

# %% [markdown]
# ### Oracle

# %%
from hardware_utils import get_gold_parts_by_doc, get_manual_parts_by_doc
from snorkel.utils import get_ORM_instance
from snorkel.models import Corpus

parts_by_doc = get_gold_parts_by_doc()
(TP, FP, FN) = entity_level_f1(tp.union(fp), gold_file, ATTRIBUTE, corpus, parts_by_doc)
# Out:
# Preparing candidates...
# [========================================] 100%
# ========================================
# Scoring on Entity-Level Gold Data
# ========================================
# Corpus Precision 0.929
# Corpus Recall    0.928
# Corpus F1        0.929
# ----------------------------------------
# TP: 825 | FP: 63 | FN: 64
# ========================================

# %% [markdown]
# ### Test Results

# %%
if TEST_SIZE:
    from snorkel.annotations import LabelManager
    label_manager = LabelManager()
    L_test = label_manager.load(session, dev, 'Hardware Test Labels -- Gold')
    L_test.shape
    
    tp, fp, tn, fn = disc_model.score(F_test, L_test, dev_gold)
    
    from hardware_utils import get_gold_parts_by_doc, get_manual_parts_by_doc
    from snorkel.utils import get_ORM_instance
    from snorkel.models import Corpus

    corpus = get_ORM_instance(Corpus, session, 'Hardware Test')

    # parts_by_doc = get_gold_parts_by_doc()
    parts_by_doc = get_manual_parts_by_doc(corpus.documents.all())
    # parts_by_doc = None
    
    from snorkel.models import Corpus
    from hardware_utils import entity_level_f1
    import os

    gold_file = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/test/hardware_test_gold.csv'
    corpus = session.query(Corpus).filter(Corpus.name == 'Hardware Dev').one()
    (TP, FP, FN) = entity_level_f1(tp.union(fp), gold_file, ATTRIBUTE, corpus, parts_by_doc)
