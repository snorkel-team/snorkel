# %% [markdown]
# # polarity

# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import sys
sys.path.append(os.environ['SNORKELHOME'] + '/tutorials/tables/')

# %% [markdown]
# ## Clearing db

# %%
from snorkel.models.meta import clear_database
clear_database()

# %% [markdown]
# ## Parsing

# %%
from snorkel import SnorkelSession
session = SnorkelSession()

# %% [markdown]
# ### Define Parser

# %%
import os
from snorkel.parser import CorpusParser, HTMLParser, OmniParser
from snorkel.utils import get_ORM_instance
from snorkel.queries import split_corpus

docs_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/hardware100_html/'
pdf_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/hardware100_pdf/'
doc_parser = HTMLParser(path=docs_path)
context_parser = OmniParser(pdf_path=pdf_path, visual=True)
cp = CorpusParser(doc_parser, context_parser, max_docs=10)

# %% [markdown]
# ### Run Parser

# %%
# %time corpus = cp.parse_corpus(name='Hardware', session=session)

session.add(corpus)
session.commit()
# Out:
# [========================================] 100%
# CPU times: user 3.09 s, sys: 200 ms, total: 3.29 s
# Wall time: 14.3 s

# %% [markdown]
# ### Split Corpus

# %%
from snorkel.models import Corpus

corpus = get_ORM_instance(Corpus, session, 'Hardware')
split_corpus(session, corpus, train=0.6, development=0.4, test=0, seed=3)
# Out:
# 6 Documents added to corpus Hardware Training
# 4 Documents added to corpus Hardware Development

# %% [markdown]
# ## Extraction

# %%
from snorkel.models import candidate_subclass

Part_Polarity = candidate_subclass('Part_Polarity', ['part','polarity'])

# %% [markdown]
# ### Define Matchers

# %%
from snorkel.matchers import RegexMatchSpan, Union

eeca_matcher = RegexMatchSpan(rgx='([b]{1}[abcdefklnpqruyz]{1}[\swxyz]?[0-9]{3,5}[\s]?[A-Z\/]{0,5}[0-9]?[A-Z]?([-][A-Z0-9]{1,7})?([-][A-Z0-9]{1,2})?)')
jedec_matcher = RegexMatchSpan(rgx='([123]N\d{3,4}[A-Z]{0,5}[0-9]?[A-Z]?)')
jis_matcher = RegexMatchSpan(rgx='(2S[abcdefghjkmqrstvz]{1}[\d]{2,4})')
others_matcher = RegexMatchSpan(rgx='((NSVBC|SMBT|MJ|MJE|MPS|MRF|RCA|TIP|ZTX|ZT|TIS|TIPL|DTC|MMBT|PZT){1}[\d]{2,4}[A-Z]{0,3}([-][A-Z0-9]{0,6})?([-][A-Z0-9]{0,1})?)')
parts_matcher = Union(eeca_matcher, jedec_matcher, jis_matcher, others_matcher)

polarity_matcher = RegexMatchSpan(rgx=r'(pnp|npn)', ignore_case=True)

# %% [markdown]
# ### Define ContextSpaces

# %%
from snorkel.candidates import OmniNgrams
from hardware_utils import OmniNgramsPart, get_gold_dict
from collections import defaultdict
import os

# Make parts list
gold_file = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/hardware_gold.csv'
gold_parts = get_gold_dict(gold_file, doc_on=True, part_on=True, val_on=False)
parts_by_doc = defaultdict(set)
for part in gold_parts:
    parts_by_doc[part[0]].add(part[1])

part_ngrams = OmniNgramsPart(n_max=3, parts_by_doc=None) # NOTE: linking is turned off
polarity_ngrams = OmniNgrams(n_max=1)

# %% [markdown]
# ### Run CandidateExtractor

# %%
from snorkel.models import Corpus
from snorkel.candidates import CandidateExtractor
from snorkel.utils import get_ORM_instance
ce = CandidateExtractor(Part_Polarity, 
                        [part_ngrams, polarity_ngrams], 
                        [parts_matcher, polarity_matcher], 
                        throttler=None)

for corpus_name in ['Hardware Training', 'Hardware Development']:
    corpus = get_ORM_instance(Corpus, session, corpus_name)
    print "Extracting Candidates from %s" % corpus
    # %time candidates = ce.extract(\
        corpus.documents, corpus_name + ' Candidates', session)
    session.add(candidates)
    print "%s contains %d Candidates" % (candidates, len(candidates))
session.commit()
# Out:
# Extracting Candidates from Corpus (Hardware Training)
# [========================================] 100%
# CPU times: user 860 ms, sys: 32 ms, total: 892 ms
# Wall time: 1.09 s
# Candidate Set (Hardware Training Candidates) contains 385 Candidates
# Extracting Candidates from Corpus (Hardware Development)
# [========================================] 100%
# CPU times: user 388 ms, sys: 16 ms, total: 404 ms
# Wall time: 483 ms
# Candidate Set (Hardware Development Candidates) contains 130 Candidates

# %% [markdown]
# ### Assess Recall

# %%
from snorkel.models import Candidate
from hardware_utils import entity_level_total_recall

all_candidates = session.query(Candidate).all()
gold_file = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/hardware_gold.csv'
(tp, fp, fn) = entity_level_total_recall(
    all_candidates, gold_file, 'polarity', relation=True)
# Out:
# Preparing candidates...
# [========================================] 100%
# ========================================
# Scoring on Entity-Level Total Recall
# ========================================
# Entity-level Candidates extracted: 93
# Entity-level Gold: 829
# Intersection Candidates: 52
# ----------------------------------------
# Overlap with Gold:  0.0627
# ========================================

# %%
from pprint import pprint
pprint(fn)
print len(fn)
# Out:
# set([('112823', 'BC546', 'NPN'),
#      ('112823', 'BC546B', 'NPN'),
#      ('112823', 'BC546BG', 'NPN'),
#      ('112823', 'BC546BRL1', 'NPN'),
#      ('112823', 'BC546BRL1G', 'NPN'),
#      ('112823', 'BC546BZL1G', 'NPN'),
#      ('112823', 'BC547', 'NPN'),
#      ('112823', 'BC547A', 'NPN'),
#      ('112823', 'BC547ARL', 'NPN'),
#      ('112823', 'BC547ARLG', 'NPN'),
#      ('112823', 'BC547AZL1G', 'NPN'),
#      ('112823', 'BC547B', 'NPN'),
#      ('112823', 'BC547BG', 'NPN'),
#      ('112823', 'BC547BRL1G', 'NPN'),
#      ('112823', 'BC547BZL1G', 'NPN'),
#      ('112823', 'BC547C', 'NPN'),
#      ('112823', 'BC547CG', 'NPN'),
#      ('112823', 'BC547CZL1G', 'NPN'),
#      ('112823', 'BC548', 'NPN'),
#      ('112823', 'BC548B', 'NPN'),
#      ('112823', 'BC548BG', 'NPN'),
#      ('112823', 'BC548BRL1G', 'NPN'),
#      ('112823', 'BC548BZL1G', 'NPN'),
#      ('112823', 'BC548C', 'NPN'),
#      ('112823', 'BC548CG', 'NPN'),
#      ('112823', 'BC548CZL1G', 'NPN'),
#      ('2N3906', '2N3906', 'PNP'),
#      ('2N3906', '2N3906BU', 'PNP'),
#      ('2N3906', '2N3906TA', 'PNP'),
#      ('2N3906', '2N3906TAR', 'PNP'),
#      ('2N3906', '2N3906TF', 'PNP'),
#      ('2N3906', '2N3906TFR', 'PNP'),
#      ('2N3906', 'MMBT3906', 'PNP'),
#      ('2N3906', 'PZT3906', 'PNP'),
#      ('2N3906-D', '2N3906', 'PNP'),
#      ('2N3906-D', '2N3906G', 'PNP'),
#      ('2N3906-D', '2N3906RL1', 'PNP'),
#      ('2N3906-D', '2N3906RL1G', 'PNP'),
#      ('2N3906-D', '2N3906RLRA', 'PNP'),
#      ('2N3906-D', '2N3906RLRAG', 'PNP'),
#      ('2N3906-D', '2N3906RLRM', 'PNP'),
#      ('2N3906-D', '2N3906RLRMG', 'PNP'),
#      ('2N3906-D', '2N3906RLRP', 'PNP'),
#      ('2N3906-D', '2N3906RLRPG', 'PNP'),
#      ('2N4123-D', '2N4123', 'NPN'),
#      ('2N4123-D', '2N4123RLRM', 'NPN'),
#      ('2N4123-D', '2N4124', 'NPN'),
#      ('2N4123-D', '2N4124G', 'NPN'),
#      ('2N4124', '2N4124', 'NPN'),
#      ('2N4124', 'MMBT4124', 'NPN'),
#      ('2N6426-D', '2N6426', 'NPN'),
#      ('2N6426-D', '2N6426G', 'NPN'),
#      ('2N6426-D', '2N6426RLRAG', 'NPN'),
#      ('2N6426-D', '2N6427', 'NPN'),
#      ('2N6426-D', '2N6427G', 'NPN'),
#      ('2N6426-D', '2N6427RLRAG', 'NPN'),
#      ('2N6427', '2N6427', 'NPN'),
#      ('2N6427', 'MMBT6427', 'NPN'),
#      ('AUKCS04635-1', '2N3906', 'PNP'),
#      ('BC182', 'BC182', 'NPN'),
#      ('BC337', 'BC337', 'NPN'),
#      ('BC337', 'BC337-16', 'NPN'),
#      ('BC337', 'BC337-25', 'NPN'),
#      ('BC337', 'BC337-40', 'NPN'),
#      ('BC337', 'BC33716BU', 'NPN'),
#      ('BC337', 'BC33716TA', 'NPN'),
#      ('BC337', 'BC33716TFR', 'NPN'),
#      ('BC337', 'BC33725BU', 'NPN'),
#      ('BC337', 'BC33725TA', 'NPN'),
#      ('BC337', 'BC33725TAR', 'NPN'),
#      ('BC337', 'BC33725TF', 'NPN'),
#      ('BC337', 'BC33725TFR', 'NPN'),
#      ('BC337', 'BC33740TA', 'NPN'),
#      ('BC337', 'BC338', 'NPN'),
#      ('BC337', 'BC338-25', 'NPN'),
#      ('BC337', 'BC33825TA', 'NPN'),
#      ('BC337-D', 'BC337', 'NPN'),
#      ('BC337-D', 'BC337-025G', 'NPN'),
#      ('BC337-D', 'BC337-040G', 'NPN'),
#      ('BC337-D', 'BC337-25', 'NPN'),
#      ('BC337-D', 'BC337-25RL1G', 'NPN'),
#      ('BC337-D', 'BC337-25RLRAG', 'NPN'),
#      ('BC337-D', 'BC337-25ZL1G', 'NPN'),
#      ('BC337-D', 'BC337-40', 'NPN'),
#      ('BC337-D', 'BC337-40RL1G', 'NPN'),
#      ('BC337-D', 'BC337-40ZL1G', 'NPN'),
#      ('BC337-D', 'BC337G', 'NPN'),
#      ('BC337-D', 'BC337RL1G', 'NPN'),
#      ('BC546', 'BC546', 'NPN'),
#      ('BC546', 'BC546A', 'NPN'),
#      ('BC546', 'BC546ABU', 'NPN'),
#      ('BC546', 'BC546ATA', 'NPN'),
#      ('BC546', 'BC546B', 'NPN'),
#      ('BC546', 'BC546BTA', 'NPN'),
#      ('BC546', 'BC546BTF', 'NPN'),
#      ('BC546', 'BC546C', 'NPN'),
#      ('BC546', 'BC546CTA', 'NPN'),
#      ('BC546', 'BC547', 'NPN'),
#      ('BC546', 'BC547A', 'NPN'),
#      ('BC546', 'BC547ATA', 'NPN'),
#      ('BC546', 'BC547B', 'NPN'),
#      ('BC546', 'BC547BBU', 'NPN'),
#      ('BC546', 'BC547BTA', 'NPN'),
#      ('BC546', 'BC547BTF', 'NPN'),
#      ('BC546', 'BC547C', 'NPN'),
#      ('BC546', 'BC547CBU', 'NPN'),
#      ('BC546', 'BC547CTA', 'NPN'),
#      ('BC546', 'BC547CTFR', 'NPN'),
#      ('BC546', 'BC548', 'NPN'),
#      ('BC546', 'BC548B', 'NPN'),
#      ('BC546', 'BC548BTA', 'NPN'),
#      ('BC546', 'BC548BU', 'NPN'),
#      ('BC546', 'BC548C', 'NPN'),
#      ('BC546', 'BC548CTA', 'NPN'),
#      ('BC546', 'BC549', 'NPN'),
#      ('BC546', 'BC549B', 'NPN'),
#      ('BC546', 'BC549BTA', 'NPN'),
#      ('BC546', 'BC549BTF', 'NPN'),
#      ('BC546', 'BC549C', 'NPN'),
#      ('BC546', 'BC549CTA', 'NPN'),
#      ('BC546', 'BC550', 'NPN'),
#      ('BC546', 'BC550C', 'NPN'),
#      ('BC546', 'BC550CBU', 'NPN'),
#      ('BC546', 'BC550CTA', 'NPN'),
#      ('BC546-BC548C(TO-92)', 'BC546', 'NPN'),
#      ('BC546-BC548C(TO-92)', 'BC546B', 'NPN'),
#      ('BC546-BC548C(TO-92)', 'BC547', 'NPN'),
#      ('BC546-BC548C(TO-92)', 'BC547A', 'NPN'),
#      ('BC546-BC548C(TO-92)', 'BC547B', 'NPN'),
#      ('BC546-BC548C(TO-92)', 'BC547C', 'NPN'),
#      ('BC546-BC548C(TO-92)', 'BC548', 'NPN'),
#      ('BC546-BC548C(TO-92)', 'BC548A', 'NPN'),
#      ('BC546-BC548C(TO-92)', 'BC548B', 'NPN'),
#      ('BC546-BC548C(TO-92)', 'BC548C', 'NPN'),
#      ('BC546-D', 'BC546', 'NPN'),
#      ('BC546-D', 'BC546B', 'NPN'),
#      ('BC546-D', 'BC546BG', 'NPN'),
#      ('BC546-D', 'BC546BRL1', 'NPN'),
#      ('BC546-D', 'BC546BRL1G', 'NPN'),
#      ('BC546-D', 'BC546BZL1G', 'NPN'),
#      ('BC546-D', 'BC547', 'NPN'),
#      ('BC546-D', 'BC547A', 'NPN'),
#      ('BC546-D', 'BC547ARL', 'NPN'),
#      ('BC546-D', 'BC547ARLG', 'NPN'),
#      ('BC546-D', 'BC547AZL1G', 'NPN'),
#      ('BC546-D', 'BC547B', 'NPN'),
#      ('BC546-D', 'BC547BG', 'NPN'),
#      ('BC546-D', 'BC547BRL1G', 'NPN'),
#      ('BC546-D', 'BC547BZL1G', 'NPN'),
#      ('BC546-D', 'BC547C', 'NPN'),
#      ('BC546-D', 'BC547CG', 'NPN'),
#      ('BC546-D', 'BC547CZL1G', 'NPN'),
#      ('BC546-D', 'BC548', 'NPN'),
#      ('BC546-D', 'BC548B', 'NPN'),
#      ('BC546-D', 'BC548BG', 'NPN'),
#      ('BC546-D', 'BC548BRL1G', 'NPN'),
#      ('BC546-D', 'BC548BZL1G', 'NPN'),
#      ('BC546-D', 'BC548C', 'NPN'),
#      ('BC546-D', 'BC548CG', 'NPN'),
#      ('BC546-D', 'BC548CZL1G', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC546', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC546A', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC546B', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC546C', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC547', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC547A', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC547B', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC547C', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC548', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC548A', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC548B', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC548C', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC549', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC549A', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC549B', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC549C', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC550', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC550A', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC550B', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC550C', 'NPN'),
#      ('BC546_DIOTEC', 'BC546', 'NPN'),
#      ('BC546_DIOTEC', 'BC546A', 'NPN'),
#      ('BC546_DIOTEC', 'BC546B', 'NPN'),
#      ('BC546_DIOTEC', 'BC547', 'NPN'),
#      ('BC546_DIOTEC', 'BC547A', 'NPN'),
#      ('BC546_DIOTEC', 'BC547B', 'NPN'),
#      ('BC546_DIOTEC', 'BC547C', 'NPN'),
#      ('BC546_DIOTEC', 'BC548', 'NPN'),
#      ('BC546_DIOTEC', 'BC548A', 'NPN'),
#      ('BC546_DIOTEC', 'BC548B', 'NPN'),
#      ('BC546_DIOTEC', 'BC548C', 'NPN'),
#      ('BC546_DIOTEC', 'BC549', 'NPN'),
#      ('BC546_DIOTEC', 'BC549B', 'NPN'),
#      ('BC546_DIOTEC', 'BC549C', 'NPN'),
#      ('BC547', 'BC546', 'NPN'),
#      ('BC547', 'BC546A', 'NPN'),
#      ('BC547', 'BC546ABU', 'NPN'),
#      ('BC547', 'BC546ATA', 'NPN'),
#      ('BC547', 'BC546B', 'NPN'),
#      ('BC547', 'BC546BTA', 'NPN'),
#      ('BC547', 'BC546BTF', 'NPN'),
#      ('BC547', 'BC546C', 'NPN'),
#      ('BC547', 'BC546CTA', 'NPN'),
#      ('BC547', 'BC547', 'NPN'),
#      ('BC547', 'BC547A', 'NPN'),
#      ('BC547', 'BC547ATA', 'NPN'),
#      ('BC547', 'BC547B', 'NPN'),
#      ('BC547', 'BC547BBU', 'NPN'),
#      ('BC547', 'BC547BTA', 'NPN'),
#      ('BC547', 'BC547BTF', 'NPN'),
#      ('BC547', 'BC547C', 'NPN'),
#      ('BC547', 'BC547CBU', 'NPN'),
#      ('BC547', 'BC547CTA', 'NPN'),
#      ('BC547', 'BC547CTFR', 'NPN'),
#      ('BC547', 'BC548', 'NPN'),
#      ('BC547', 'BC548B', 'NPN'),
#      ('BC547', 'BC548BTA', 'NPN'),
#      ('BC547', 'BC548C', 'NPN'),
#      ('BC547', 'BC548CTA', 'NPN'),
#      ('BC547', 'BC549', 'NPN'),
#      ('BC547', 'BC549B', 'NPN'),
#      ('BC547', 'BC549BTA', 'NPN'),
#      ('BC547', 'BC549BTF', 'NPN'),
#      ('BC547', 'BC549C', 'NPN'),
#      ('BC547', 'BC549CTA', 'NPN'),
#      ('BC547', 'BC550', 'NPN'),
#      ('BC547', 'BC550C', 'NPN'),
#      ('BC547', 'BC550CBU', 'NPN'),
#      ('BC547', 'BC550CTA', 'NPN'),
#      ('BC550', 'BC546', 'NPN'),
#      ('BC550', 'BC546A', 'NPN'),
#      ('BC550', 'BC546B', 'NPN'),
#      ('BC550', 'BC546C', 'NPN'),
#      ('BC550', 'BC547', 'NPN'),
#      ('BC550', 'BC547A', 'NPN'),
#      ('BC550', 'BC547B', 'NPN'),
#      ('BC550', 'BC547C', 'NPN'),
#      ('BC550', 'BC548', 'NPN'),
#      ('BC550', 'BC548A', 'NPN'),
#      ('BC550', 'BC548B', 'NPN'),
#      ('BC550', 'BC548C', 'NPN'),
#      ('BC550', 'BC549', 'NPN'),
#      ('BC550', 'BC549A', 'NPN'),
#      ('BC550', 'BC549B', 'NPN'),
#      ('BC550', 'BC549C', 'NPN'),
#      ('BC550', 'BC550', 'NPN'),
#      ('BC550', 'BC550A', 'NPN'),
#      ('BC550', 'BC550B', 'NPN'),
#      ('BC550', 'BC550C', 'NPN'),
#      ('BC818', 'BC817', 'NPN'),
#      ('BC818', 'BC817-16', 'NPN'),
#      ('BC818', 'BC817-25', 'NPN'),
#      ('BC818', 'BC817-40', 'NPN'),
#      ('BC818', 'BC81716MTF', 'NPN'),
#      ('BC818', 'BC81725MTF', 'NPN'),
#      ('BC818', 'BC81740MTF', 'NPN'),
#      ('BC818', 'BC818', 'NPN'),
#      ('BC818', 'BC818-16', 'NPN'),
#      ('BC818', 'BC818-25', 'NPN'),
#      ('BC818', 'BC818-40', 'NPN'),
#      ('BC818', 'BC81816MTF', 'NPN'),
#      ('BC818', 'BC81825MTF', 'NPN'),
#      ('BC818', 'BC81840MTF', 'NPN'),
#      ('BC818-40LT1-D', 'BC818-40L', 'NPN'),
#      ('BC818-40LT1-D', 'BC818-40LT1G', 'NPN'),
#      ('BC818-40LT1-D', 'NSVBC818-40L', 'NPN'),
#      ('BC818-40LT1-D', 'NSVBC818-40LT1G', 'NPN'),
#      ('CSEMS02742-1', 'BC846', 'NPN'),
#      ('CSEMS02742-1', 'BC846A', 'NPN'),
#      ('CSEMS02742-1', 'BC846B', 'NPN'),
#      ('CSEMS02742-1', 'BC847', 'NPN'),
#      ('CSEMS02742-1', 'BC847A', 'NPN'),
#      ('CSEMS02742-1', 'BC847B', 'NPN'),
#      ('CSEMS02742-1', 'BC847C', 'NPN'),
#      ('CSEMS02742-1', 'BC848', 'NPN'),
#      ('CSEMS02742-1', 'BC848A', 'NPN'),
#      ('CSEMS02742-1', 'BC848B', 'NPN'),
#      ('CSEMS02742-1', 'BC848C', 'NPN'),
#      ('CSEMS03485-1', '2N3905', 'PNP'),
#      ('CSEMS03485-1', '2N3906', 'PNP'),
#      ('CSEMS05382-1', 'BC546', 'NPN'),
#      ('CSEMS05382-1', 'BC546A', 'NPN'),
#      ('CSEMS05382-1', 'BC546B', 'NPN'),
#      ('CSEMS05382-1', 'BC547', 'NPN'),
#      ('CSEMS05382-1', 'BC547A', 'NPN'),
#      ('CSEMS05382-1', 'BC547B', 'NPN'),
#      ('CSEMS05382-1', 'BC547C', 'NPN'),
#      ('CSEMS05382-1', 'BC548', 'NPN'),
#      ('CSEMS05382-1', 'BC548A', 'NPN'),
#      ('CSEMS05382-1', 'BC548B', 'NPN'),
#      ('CSEMS05382-1', 'BC548C', 'NPN'),
#      ('CSEMS05383-1', 'BC817', 'NPN'),
#      ('CSEMS05383-1', 'BC817-16', 'NPN'),
#      ('CSEMS05383-1', 'BC817-25', 'NPN'),
#      ('CSEMS05383-1', 'BC817-40', 'NPN'),
#      ('CSEMS05383-1', 'BC818', 'NPN'),
#      ('CSEMS05383-1', 'BC818-16', 'NPN'),
#      ('CSEMS05383-1', 'BC818-25', 'NPN'),
#      ('CSEMS05383-1', 'BC818-40', 'NPN'),
#      ('DIODS00215-1', '2N4124', 'NPN'),
#      ('DISES00023-1', '2N3906', 'PNP'),
#      ('DISES00189-1', 'BC546', 'NPN'),
#      ('DISES00189-1', 'BC546A', 'NPN'),
#      ('DISES00189-1', 'BC546B', 'NPN'),
#      ('DISES00189-1', 'BC547', 'NPN'),
#      ('DISES00189-1', 'BC547A', 'NPN'),
#      ('DISES00189-1', 'BC547B', 'NPN'),
#      ('DISES00189-1', 'BC547C', 'NPN'),
#      ('DISES00189-1', 'BC548', 'NPN'),
#      ('DISES00189-1', 'BC548A', 'NPN'),
#      ('DISES00189-1', 'BC548B', 'NPN'),
#      ('DISES00189-1', 'BC548C', 'NPN'),
#      ('DISES00189-1', 'BC549', 'NPN'),
#      ('DISES00189-1', 'BC549B', 'NPN'),
#      ('DISES00189-1', 'BC549C', 'NPN'),
#      ('DISES00192-1', 'BC807', 'PNP'),
#      ('DISES00192-1', 'BC807-16', 'PNP'),
#      ('DISES00192-1', 'BC807-25', 'PNP'),
#      ('DISES00192-1', 'BC807-40', 'PNP'),
#      ('DISES00192-1', 'BC808', 'PNP'),
#      ('DISES00192-1', 'BC808-16', 'PNP'),
#      ('DISES00192-1', 'BC808-25', 'PNP'),
#      ('DISES00192-1', 'BC808-40', 'PNP'),
#      ('DISES00242-1', 'MMBT3904', 'NPN'),
#      ('DISES00490-1', 'BC846AW', 'NPN'),
#      ('DISES00490-1', 'BC846BW', 'NPN'),
#      ('DISES00490-1', 'BC846W', 'NPN'),
#      ('DISES00490-1', 'BC847AW', 'NPN'),
#      ('DISES00490-1', 'BC847BW', 'NPN'),
#      ('DISES00490-1', 'BC847CW', 'NPN'),
#      ('DISES00490-1', 'BC847W', 'NPN'),
#      ('DISES00490-1', 'BC848AW', 'NPN'),
#      ('DISES00490-1', 'BC848BW', 'NPN'),
#      ('DISES00490-1', 'BC848CW', 'NPN'),
#      ('DISES00490-1', 'BC848W', 'NPN'),
#      ('DISES00490-1', 'BC849BW', 'NPN'),
#      ('DISES00490-1', 'BC849CW', 'NPN'),
#      ('DISES00490-1', 'BC849W', 'NPN'),
#      ('DISES00616-1', 'BC856', 'PNP'),
#      ('DISES00616-1', 'BC856A', 'PNP'),
#      ('DISES00616-1', 'BC856B', 'PNP'),
#      ('DISES00616-1', 'BC856C', 'PNP'),
#      ('DISES00616-1', 'BC857', 'PNP'),
#      ('DISES00616-1', 'BC857A', 'PNP'),
#      ('DISES00616-1', 'BC857B', 'PNP'),
#      ('DISES00616-1', 'BC857C', 'PNP'),
#      ('DISES00616-1', 'BC858', 'PNP'),
#      ('DISES00616-1', 'BC858A', 'PNP'),
#      ('DISES00616-1', 'BC858B', 'PNP'),
#      ('DISES00616-1', 'BC858C', 'PNP'),
#      ('DISES00616-1', 'BC859', 'PNP'),
#      ('DISES00616-1', 'BC859B', 'PNP'),
#      ('DISES00616-1', 'BC859C', 'PNP'),
#      ('DISES00616-1', 'BC860', 'PNP'),
#      ('DISES00616-1', 'BC860B', 'PNP'),
#      ('DISES00616-1', 'BC860C', 'PNP'),
#      ('DTC114W', 'DTC114W', 'NPN'),
#      ('DTC114W', 'DTC114WE', 'NPN'),
#      ('DTC114W', 'DTC114WKA', 'NPN'),
#      ('DTC114W', 'DTC114WUA', 'NPN'),
#      ('FAIRS19194-1', 'BC856A', 'PNP'),
#      ('FAIRS19194-1', 'BC856B', 'PNP'),
#      ('FAIRS19194-1', 'BC856C', 'PNP'),
#      ('FAIRS19194-1', 'BC857A', 'PNP'),
#      ('FAIRS19194-1', 'BC857B', 'PNP'),
#      ('FAIRS19194-1', 'BC857C', 'PNP'),
#      ('FAIRS19194-1', 'BC858A', 'PNP'),
#      ('FAIRS19194-1', 'BC858B', 'PNP'),
#      ('FAIRS19194-1', 'BC858C', 'PNP'),
#      ('FAIRS19194-1', 'BC859A', 'PNP'),
#      ('FAIRS19194-1', 'BC859B', 'PNP'),
#      ('FAIRS19194-1', 'BC859C', 'PNP'),
#      ('FAIRS19194-1', 'BC860A', 'PNP'),
#      ('FAIRS19194-1', 'BC860B', 'PNP'),
#      ('FAIRS19194-1', 'BC860C', 'PNP'),
#      ('FAIRS25065-1', 'BC237', 'NPN'),
#      ('FAIRS25065-1', 'BC237A', 'NPN'),
#      ('FAIRS25065-1', 'BC237B', 'NPN'),
#      ('FAIRS25065-1', 'BC237C', 'NPN'),
#      ('FAIRS25065-1', 'BC238', 'NPN'),
#      ('FAIRS25065-1', 'BC238A', 'NPN'),
#      ('FAIRS25065-1', 'BC238B', 'NPN'),
#      ('FAIRS25065-1', 'BC238C', 'NPN'),
#      ('FAIRS25065-1', 'BC239', 'NPN'),
#      ('FAIRS25065-1', 'BC239A', 'NPN'),
#      ('FAIRS25065-1', 'BC239B', 'NPN'),
#      ('FAIRS25065-1', 'BC239C', 'NPN'),
#      ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K', 'NPN'),
#      ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-16', 'NPN'),
#      ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-16W', 'NPN'),
#      ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-25', 'NPN'),
#      ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-25W', 'NPN'),
#      ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-40', 'NPN'),
#      ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-40W', 'NPN'),
#      ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817KW', 'NPN'),
#      ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC818K', 'NPN'),
#      ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC818K-16W', 'NPN'),
#      ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC818K-40', 'NPN'),
#      ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC818KW', 'NPN'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC857',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC857A',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC857B',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC857BL3',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC857BW',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC857C',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC857CW',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC858',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC858A',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC858B',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC858BW',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC858C',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC858CW',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC859',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC859C',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC860',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC860B',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC860BW',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC860CW',
#       'PNP'),
#      ('INFNS19372-1', 'MMBT3904', 'NPN'),
#      ('INFNS19372-1', 'SMBT3904', 'NPN'),
#      ('INFNS19372-1', 'SMBT3904S', 'NPN'),
#      ('JCSTS01155-1', '2N4124', 'NPN'),
#      ('KECCS03676-1', 'BC856', 'PNP'),
#      ('KECCS03676-1', 'BC856A', 'PNP'),
#      ('KECCS03676-1', 'BC856B', 'PNP'),
#      ('KECCS03676-1', 'BC857', 'PNP'),
#      ('KECCS03676-1', 'BC857A', 'PNP'),
#      ('KECCS03676-1', 'BC857B', 'PNP'),
#      ('KECCS03676-1', 'BC857C', 'PNP'),
#      ('KECCS03676-1', 'BC858', 'PNP'),
#      ('KECCS03676-1', 'BC858A', 'PNP'),
#      ('KECCS03676-1', 'BC858B', 'PNP'),
#      ('KECCS03676-1', 'BC858C', 'PNP'),
#      ('KECCS05435-1', 'BC546A', 'NPN'),
#      ('KECCS05435-1', 'BC546B', 'NPN'),
#      ('KECCS05435-1', 'BC547A', 'NPN'),
#      ('KECCS05435-1', 'BC547B', 'NPN'),
#      ('KECCS05435-1', 'BC547C', 'NPN'),
#      ('KECCS05435-1', 'BC548A', 'NPN'),
#      ('KECCS05435-1', 'BC548B', 'NPN'),
#      ('KECCS05435-1', 'BC548C', 'NPN'),
#      ('LITES00424-1', '2N3906', 'PNP'),
#      ('LITES00686-1', '2N4124', 'NPN'),
#      ('LITES00689-1', 'BC337', 'NPN'),
#      ('LITES00689-1', 'BC337-16', 'NPN'),
#      ('LITES00689-1', 'BC337-25', 'NPN'),
#      ('LITES00689-1', 'BC337-40', 'NPN'),
#      ('LITES00690-1', 'BC546', 'NPN'),
#      ('LITES00690-1', 'BC546A', 'NPN'),
#      ('LITES00690-1', 'BC546B', 'NPN'),
#      ('LITES00690-1', 'BC546C', 'NPN'),
#      ('LITES00690-1', 'BC547', 'NPN'),
#      ('LITES00690-1', 'BC547A', 'NPN'),
#      ('LITES00690-1', 'BC547B', 'NPN'),
#      ('LITES00690-1', 'BC547C', 'NPN'),
#      ('LITES00690-1', 'BC548', 'NPN'),
#      ('LITES00690-1', 'BC548A', 'NPN'),
#      ('LITES00690-1', 'BC548B', 'NPN'),
#      ('LITES00690-1', 'BC548C', 'NPN'),
#      ('LTSCS02910-1', 'BC818', 'NPN'),
#      ('LTSCS02910-1', 'BC818-16', 'NPN'),
#      ('LTSCS02910-1', 'BC818-25', 'NPN'),
#      ('LTSCS02910-1', 'BC818-40', 'NPN'),
#      ('LTSCS02912-1', 'BC846AW', 'NPN'),
#      ('LTSCS02912-1', 'BC846BW', 'NPN'),
#      ('LTSCS02912-1', 'BC846W', 'NPN'),
#      ('LTSCS02920-1', 'BC857', 'PNP'),
#      ('LTSCS02920-1', 'BC857A', 'PNP'),
#      ('LTSCS02920-1', 'BC857B', 'PNP'),
#      ('LTSCS02920-1', 'BC857C', 'PNP'),
#      ('MCCCS08610-1', '2N4123', 'NPN'),
#      ('MCCCS08610-1', '2N4124', 'NPN'),
#      ('MCCCS08984-1', 'MMBT3904', 'NPN'),
#      ('MCCCS09540-1', 'BC846', 'NPN'),
#      ('MCCCS09540-1', 'BC846A', 'NPN'),
#      ('MCCCS09540-1', 'BC846B', 'NPN'),
#      ('MCCCS09540-1', 'BC847', 'NPN'),
#      ('MCCCS09540-1', 'BC847A', 'NPN'),
#      ('MCCCS09540-1', 'BC847B', 'NPN'),
#      ('MCCCS09540-1', 'BC847C', 'NPN'),
#      ('MCCCS09540-1', 'BC848', 'NPN'),
#      ('MCCCS09540-1', 'BC848A', 'NPN'),
#      ('MCCCS09540-1', 'BC848B', 'NPN'),
#      ('MCCCS09540-1', 'BC848C', 'NPN'),
#      ('MCCCS09540-1', 'BC849', 'NPN'),
#      ('MCCCS09540-1', 'BC849B', 'NPN'),
#      ('MCCCS09540-1', 'BC849C', 'NPN'),
#      ('MINDS00015-1', '2N3904', 'NPN'),
#      ('MINDS00015-1', 'MMBT3904', 'NPN'),
#      ('MMMCS17742-1', 'BC807-16W', 'PNP'),
#      ('MMMCS17742-1', 'BC807-25W', 'PNP'),
#      ('MMMCS17742-1', 'BC807-40W', 'PNP'),
#      ('MOTOS03160-1', 'BC182', 'NPN'),
#      ('MOTOS03160-1', 'BC182A', 'NPN'),
#      ('MOTOS03160-1', 'BC182B', 'NPN'),
#      ('MOTOS03160-1', 'BC183', 'NPN'),
#      ('MOTOS03160-1', 'BC184', 'NPN'),
#      ('MOTOS03189-1', 'BC337', 'NPN'),
#      ('MOTOS03189-1', 'BC337-16', 'NPN'),
#      ('MOTOS03189-1', 'BC337-25', 'NPN'),
#      ('MOTOS03189-1', 'BC337-40', 'NPN'),
#      ('MOTOS03189-1', 'BC338', 'NPN'),
#      ('MOTOS03189-1', 'BC338-16', 'NPN'),
#      ('MOTOS03189-1', 'BC338-25', 'NPN'),
#      ('MOTOS03189-1', 'BC338-40', 'NPN'),
#      ('MOTOS04676-1', '2N4123', 'NPN'),
#      ('MOTOS04676-1', '2N4124', 'NPN'),
#      ('MOTOS04796-1', '2N6426', 'NPN'),
#      ('MOTOS04796-1', '2N6427', 'NPN'),
#      ('ONSMS04099-1', 'BC237', 'NPN'),
#      ('ONSMS04099-1', 'BC237A', 'NPN'),
#      ('ONSMS04099-1', 'BC237B', 'NPN'),
#      ('ONSMS04099-1', 'BC237C', 'NPN'),
#      ('ONSMS04099-1', 'BC238', 'NPN'),
#      ('ONSMS04099-1', 'BC238B', 'NPN'),
#      ('ONSMS04099-1', 'BC238C', 'NPN'),
#      ('ONSMS04099-1', 'BC239', 'NPN'),
#      ('ONSMS04099-1', 'BC239C', 'NPN'),
#      ('PHGLS18216-1', 'BC547', 'NPN'),
#      ('PHGLS18216-1', 'BC547B', 'NPN'),
#      ('PHGLS18216-1', 'BC547C', 'NPN'),
#      ('PHGLS18216-1', 'BC847', 'NPN'),
#      ('PHGLS18216-1', 'BC847A', 'NPN'),
#      ('PHGLS18216-1', 'BC847AM', 'NPN'),
#      ('PHGLS18216-1', 'BC847AT', 'NPN'),
#      ('PHGLS18216-1', 'BC847AT/DG', 'NPN'),
#      ('PHGLS18216-1', 'BC847AW', 'NPN'),
#      ('PHGLS18216-1', 'BC847B', 'NPN'),
#      ('PHGLS18216-1', 'BC847B/DG', 'NPN'),
#      ('PHGLS18216-1', 'BC847BM', 'NPN'),
#      ('PHGLS18216-1', 'BC847BT', 'NPN'),
#      ('PHGLS18216-1', 'BC847BW', 'NPN'),
#      ('PHGLS18216-1', 'BC847BW/DG', 'NPN'),
#      ('PHGLS18216-1', 'BC847C', 'NPN'),
#      ('PHGLS18216-1', 'BC847CM', 'NPN'),
#      ('PHGLS18216-1', 'BC847CT', 'NPN'),
#      ('PHGLS18216-1', 'BC847CW', 'NPN'),
#      ('PHGLS18216-1', 'BC847T', 'NPN'),
#      ('PHGLS18216-1', 'BC847W', 'NPN'),
#      ('PHGLS19500-1', 'MMBT3904', 'NPN'),
#      ('PHGLS20125-1', 'BC327', 'PNP'),
#      ('PHGLS20125-1', 'BC327-16', 'PNP'),
#      ('PHGLS20125-1', 'BC327-25', 'PNP'),
#      ('PHGLS20125-1', 'BC327-40', 'PNP'),
#      ('PHGLS20125-1', 'BC807', 'PNP'),
#      ('PHGLS20125-1', 'BC807-16', 'PNP'),
#      ('PHGLS20125-1', 'BC807-16W', 'PNP'),
#      ('PHGLS20125-1', 'BC807-25', 'PNP'),
#      ('PHGLS20125-1', 'BC807-25W', 'PNP'),
#      ('PHGLS20125-1', 'BC807-40', 'PNP'),
#      ('PHGLS20125-1', 'BC807-40W', 'PNP'),
#      ('PHGLS20125-1', 'BC807W', 'PNP'),
#      ('PHGLS20126-1', 'BC337', 'NPN'),
#      ('PHGLS20126-1', 'BC337-16', 'NPN'),
#      ('PHGLS20126-1', 'BC337-25', 'NPN'),
#      ('PHGLS20126-1', 'BC337-40', 'NPN'),
#      ('PHGLS20126-1', 'BC817', 'NPN'),
#      ('PHGLS20126-1', 'BC817-16', 'NPN'),
#      ('PHGLS20126-1', 'BC817-16W', 'NPN'),
#      ('PHGLS20126-1', 'BC817-25', 'NPN'),
#      ('PHGLS20126-1', 'BC817-25W', 'NPN'),
#      ('PHGLS20126-1', 'BC817-40', 'NPN'),
#      ('PHGLS20126-1', 'BC817-40W', 'NPN'),
#      ('PHGLS20126-1', 'BC817W', 'NPN'),
#      ('PHGLS20267-1', '2N4124', 'NPN'),
#      ('PHGLS25601-1', 'BC846', 'NPN'),
#      ('PHGLS25601-1', 'BC846A', 'NPN'),
#      ('PHGLS25601-1', 'BC846AT', 'NPN'),
#      ('PHGLS25601-1', 'BC846AW', 'NPN'),
#      ('PHGLS25601-1', 'BC846B', 'NPN'),
#      ('PHGLS25601-1', 'BC846BT', 'NPN'),
#      ('PHGLS25601-1', 'BC846BW', 'NPN'),
#      ('PHGLS25601-1', 'BC846T', 'NPN'),
#      ('PHGLS25601-1', 'BC846W', 'NPN'),
#      ('PJECS00521-1', 'MMBT3904', 'NPN'),
#      ('PNJIS00254-1', 'BC807-16W', 'PNP'),
#      ('PNJIS00254-1', 'BC807-25W', 'PNP'),
#      ('PNJIS00254-1', 'BC807-40W', 'PNP'),
#      ('PNJIS01186-1', 'BC807-16', 'PNP'),
#      ('PNJIS01186-1', 'BC807-25', 'PNP'),
#      ('PNJIS01186-1', 'BC807-40', 'PNP'),
#      ('PNJIS01305-1', 'MMBT3904', 'NPN'),
#      ('PNJIS01453-1', 'BC846', 'NPN'),
#      ('PNJIS01453-1', 'BC846A', 'NPN'),
#      ('PNJIS01453-1', 'BC846B', 'NPN'),
#      ('PNJIS01453-1', 'BC847', 'NPN'),
#      ('PNJIS01453-1', 'BC847A', 'NPN'),
#      ('PNJIS01453-1', 'BC847B', 'NPN'),
#      ('PNJIS01453-1', 'BC847C', 'NPN'),
#      ('PNJIS01453-1', 'BC848', 'NPN'),
#      ('PNJIS01453-1', 'BC848A', 'NPN'),
#      ('PNJIS01453-1', 'BC848B', 'NPN'),
#      ('PNJIS01453-1', 'BC848C', 'NPN'),
#      ('PNJIS01453-1', 'BC849', 'NPN'),
#      ('PNJIS01453-1', 'BC849B', 'NPN'),
#      ('PNJIS01453-1', 'BC849C', 'NPN'),
#      ('PNJIS01453-1', 'BC850', 'NPN'),
#      ('PNJIS01453-1', 'BC850B', 'NPN'),
#      ('PNJIS01453-1', 'BC850C', 'NPN'),
#      ('PNJIS01593-1', 'BC856', 'PNP'),
#      ('PNJIS01593-1', 'BC856A', 'PNP'),
#      ('PNJIS01593-1', 'BC856B', 'PNP'),
#      ('PNJIS01593-1', 'BC857', 'PNP'),
#      ('PNJIS01593-1', 'BC857A', 'PNP'),
#      ('PNJIS01593-1', 'BC857B', 'PNP'),
#      ('PNJIS01593-1', 'BC857C', 'PNP'),
#      ('PNJIS01593-1', 'BC858', 'PNP'),
#      ('PNJIS01593-1', 'BC858A', 'PNP'),
#      ('PNJIS01593-1', 'BC858B', 'PNP'),
#      ('PNJIS01593-1', 'BC858C', 'PNP'),
#      ('PNJIS01593-1', 'BC859', 'PNP'),
#      ('PNJIS01593-1', 'BC859B', 'PNP'),
#      ('PNJIS01593-1', 'BC859C', 'PNP'),
#      ('RECTS00705-1', 'BC546', 'NPN'),
#      ('RECTS00705-1', 'BC546A', 'NPN'),
#      ('RECTS00705-1', 'BC546B', 'NPN'),
#      ('RECTS00705-1', 'BC546C', 'NPN'),
#      ('RECTS00705-1', 'BC547', 'NPN'),
#      ('RECTS00705-1', 'BC547A', 'NPN'),
#      ('RECTS00705-1', 'BC547B', 'NPN'),
#      ('RECTS00705-1', 'BC547C', 'NPN'),
#      ('RECTS00705-1', 'BC548', 'NPN'),
#      ('RECTS00705-1', 'BC548A', 'NPN'),
#      ('RECTS00705-1', 'BC548B', 'NPN'),
#      ('RECTS00705-1', 'BC548C', 'NPN'),
#      ('RECTS01002-1', 'MMBT3904', 'NPN'),
#      ('RECTS01158-1', 'BC807-25', 'PNP'),
#      ('RECTS01242-1', 'BC857B', 'PNP'),
#      ('RECTS01325-1', 'DTC114YUA', 'NPN'),
#      ('SAMSD00049-518', 'BC546', 'NPN'),
#      ('SAMSD00049-518', 'BC546A', 'NPN'),
#      ('SAMSD00049-518', 'BC546B', 'NPN'),
#      ('SAMSD00049-518', 'BC546C', 'NPN'),
#      ('SAMSD00049-518', 'BC547', 'NPN'),
#      ('SAMSD00049-518', 'BC547A', 'NPN'),
#      ('SAMSD00049-518', 'BC547B', 'NPN'),
#      ('SAMSD00049-518', 'BC547C', 'NPN'),
#      ('SAMSD00049-518', 'BC548', 'NPN'),
#      ('SAMSD00049-518', 'BC548A', 'NPN'),
#      ('SAMSD00049-518', 'BC548B', 'NPN'),
#      ('SAMSD00049-518', 'BC548C', 'NPN'),
#      ('SAMSD00049-518', 'BC549', 'NPN'),
#      ('SAMSD00049-518', 'BC549A', 'NPN'),
#      ('SAMSD00049-518', 'BC549B', 'NPN'),
#      ('SAMSD00049-518', 'BC549C', 'NPN'),
#      ('SAMSD00049-518', 'BC550', 'NPN'),
#      ('SAMSD00049-518', 'BC550A', 'NPN'),
#      ('SAMSD00049-518', 'BC550B', 'NPN'),
#      ('SAMSD00049-518', 'BC550C', 'NPN'),
#      ('SCSCS02175-1', 'BC546', 'NPN'),
#      ('SCSCS02175-1', 'BC546A', 'NPN'),
#      ('SCSCS02175-1', 'BC546B', 'NPN'),
#      ('SCSCS02175-1', 'BC546C', 'NPN'),
#      ('SCSCS02175-1', 'BC547', 'NPN'),
#      ('SCSCS02175-1', 'BC547A', 'NPN'),
#      ('SCSCS02175-1', 'BC547B', 'NPN'),
#      ('SCSCS02175-1', 'BC547C', 'NPN'),
#      ('SCSCS02175-1', 'BC548', 'NPN'),
#      ('SCSCS02175-1', 'BC548A', 'NPN'),
#      ('SCSCS02175-1', 'BC548B', 'NPN'),
#      ('SCSCS02175-1', 'BC548C', 'NPN'),
#      ('SCSCS02324-1', 'MMBT3904', 'NPN'),
#      ('SGSTS13702-1', 'BC547B', 'NPN'),
#      ('SGSTS13702-1', 'BC547B-AP', 'NPN'),
#      ('SGSTS13702-1', 'BC547C', 'NPN'),
#      ('SGSTS13702-1', 'BC547C-AP', 'NPN'),
#      ('SGSTS13734-1', 'BC337-25', 'NPN'),
#      ('SGSTS13734-1', 'BC337-25-AP', 'NPN'),
#      ('SGSTS13734-1', 'BC337-40', 'NPN'),
#      ('SGSTS13734-1', 'BC337-40-AP', 'NPN'),
#      ('SIEMS01215-1', 'BC856', 'PNP'),
#      ('SIEMS01215-1', 'BC856A', 'PNP'),
#      ('SIEMS01215-1', 'BC856B', 'PNP'),
#      ('SIEMS01215-1', 'BC857', 'PNP'),
#      ('SIEMS01215-1', 'BC857A', 'PNP'),
#      ('SIEMS01215-1', 'BC857B', 'PNP'),
#      ('SIEMS01215-1', 'BC857C', 'PNP'),
#      ('SIEMS01215-1', 'BC858', 'PNP'),
#      ('SIEMS01215-1', 'BC858A', 'PNP'),
#      ('SIEMS01215-1', 'BC858B', 'PNP'),
#      ('SIEMS01215-1', 'BC858C', 'PNP'),
#      ('SIEMS01215-1', 'BC859', 'PNP'),
#      ('SIEMS01215-1', 'BC859A', 'PNP'),
#      ('SIEMS01215-1', 'BC859B', 'PNP'),
#      ('SIEMS01215-1', 'BC859C', 'PNP'),
#      ('SIEMS01215-1', 'BC860', 'PNP'),
#      ('SIEMS01215-1', 'BC860B', 'PNP'),
#      ('SIEMS01215-1', 'BC860C', 'PNP'),
#      ('TKCGS00622-1', 'DTC114EE', 'NPN'),
#      ('TKCGS00622-1', 'DTC114TE', 'NPN'),
#      ('TKCGS00622-1', 'DTC114YE', 'NPN'),
#      ('TKCGS00622-1', 'DTC123EE', 'NPN'),
#      ('TKCGS00622-1', 'DTC123JE', 'NPN'),
#      ('TKCGS00622-1', 'DTC124EE', 'NPN'),
#      ('TKCGS00622-1', 'DTC124XE', 'NPN'),
#      ('TKCGS00622-1', 'DTC143EE', 'NPN'),
#      ('TKCGS00622-1', 'DTC143TE', 'NPN'),
#      ('TKCGS00622-1', 'DTC143ZE', 'NPN'),
#      ('TKCGS00622-1', 'DTC144EE', 'NPN'),
#      ('TWSCS04757-1', 'BC807-16', 'PNP'),
#      ('TWSCS04757-1', 'BC807-25', 'PNP'),
#      ('TWSCS04757-1', 'BC807-40', 'PNP'),
#      ('UTCLS02155-1', 'BC807', 'PNP'),
#      ('UTCLS02155-1', 'BC807-16', 'PNP'),
#      ('UTCLS02155-1', 'BC807-25', 'PNP'),
#      ('UTCLS02155-1', 'BC807-40', 'PNP'),
#      ('UTCLS02155-1', 'BC808', 'PNP'),
#      ('UTCLS02155-1', 'BC808-16', 'PNP'),
#      ('UTCLS02155-1', 'BC808-25', 'PNP'),
#      ('UTCLS02155-1', 'BC808-40', 'PNP'),
#      ('UTCLS03593-1', 'DTC114E', 'NPN'),
#      ('VISHS23888-1', 'BC546', 'NPN'),
#      ('VISHS23888-1', 'BC546A', 'NPN'),
#      ('VISHS23888-1', 'BC546B', 'NPN'),
#      ('VISHS23888-1', 'BC547', 'NPN'),
#      ('VISHS23888-1', 'BC547A', 'NPN'),
#      ('VISHS23888-1', 'BC547B', 'NPN'),
#      ('VISHS23888-1', 'BC547C', 'NPN'),
#      ('VISHS23888-1', 'BC548', 'NPN'),
#      ('VISHS23888-1', 'BC548A', 'NPN'),
#      ('VISHS23888-1', 'BC548B', 'NPN'),
#      ('VISHS23888-1', 'BC548C', 'NPN'),
#      ('VISHS23888-1', 'BC549', 'NPN'),
#      ('VISHS23888-1', 'BC549B', 'NPN'),
#      ('VISHS23888-1', 'BC549C', 'NPN'),
#      ('VSMIS00373-1', 'BC337', 'NPN'),
#      ('VSMIS00373-1', 'BC337-16', 'NPN'),
#      ('VSMIS00373-1', 'BC337-25', 'NPN'),
#      ('VSMIS00373-1', 'BC337-40', 'NPN'),
#      ('VSMIS00373-1', 'BC338', 'NPN'),
#      ('VSMIS00373-1', 'BC338-16', 'NPN'),
#      ('VSMIS00373-1', 'BC338-25', 'NPN'),
#      ('VSMIS00373-1', 'BC338-40', 'NPN'),
#      ('VSMIS03793-1', 'BC817', 'NPN'),
#      ('VSMIS03793-1', 'BC817-16', 'NPN'),
#      ('VSMIS03793-1', 'BC817-25', 'NPN'),
#      ('VSMIS03793-1', 'BC817-40', 'NPN'),
#      ('VSMIS03793-1', 'BC818', 'NPN'),
#      ('VSMIS03793-1', 'BC818-16', 'NPN'),
#      ('VSMIS03793-1', 'BC818-25', 'NPN'),
#      ('VSMIS03793-1', 'BC818-40', 'NPN'),
#      ('WEILS00082-1', 'BC856', 'PNP'),
#      ('WEILS00082-1', 'BC856A', 'PNP'),
#      ('WEILS00082-1', 'BC856B', 'PNP'),
#      ('WEILS00082-1', 'BC857', 'PNP'),
#      ('WEILS00082-1', 'BC857A', 'PNP'),
#      ('WEILS00082-1', 'BC857B', 'PNP'),
#      ('WEILS00082-1', 'BC857C', 'PNP'),
#      ('WEILS00082-1', 'BC858', 'PNP'),
#      ('WEILS00082-1', 'BC858A', 'PNP'),
#      ('WEILS00082-1', 'BC858B', 'PNP'),
#      ('WEILS00082-1', 'BC858C', 'PNP'),
#      ('WEILS00082-1', 'BC859', 'PNP'),
#      ('WEILS00082-1', 'BC859B', 'PNP'),
#      ('WEILS00082-1', 'BC859C', 'PNP'),
#      ('WEITS00252-1', 'BC807-16', 'PNP'),
#      ('WEITS00252-1', 'BC807-25', 'PNP'),
#      ('WEITS00252-1', 'BC807-40', 'PNP'),
#      ('ZETXS01948-1', 'BC856', 'PNP'),
#      ('ZETXS01948-1', 'BC856A-3A', 'PNP'),
#      ('ZETXS01948-1', 'BC856B-Z3B', 'PNP'),
#      ('ZETXS01948-1', 'BC857', 'PNP'),
#      ('ZETXS01948-1', 'BC857A-Z3E', 'PNP'),
#      ('ZETXS01948-1', 'BC857B-3F', 'PNP'),
#      ('ZETXS01948-1', 'BC857C-3G', 'PNP'),
#      ('ZETXS01948-1', 'BC858', 'PNP'),
#      ('ZETXS01948-1', 'BC858A-3J', 'PNP'),
#      ('ZETXS01948-1', 'BC858B-3K', 'PNP'),
#      ('ZETXS01948-1', 'BC858C-3L', 'PNP'),
#      ('ZETXS01948-1', 'BC859', 'PNP'),
#      ('ZETXS01948-1', 'BC859A-Z4A', 'PNP'),
#      ('ZETXS01948-1', 'BC859B-4B', 'PNP'),
#      ('ZETXS01948-1', 'BC859C-Z4C', 'PNP'),
#      ('ZETXS01948-1', 'BC860', 'PNP'),
#      ('ZETXS01948-1', 'BC860A-Z4E', 'PNP'),
#      ('ZETXS01948-1', 'BC860B-4F', 'PNP'),
#      ('ZETXS01948-1', 'BC860C-4GZ', 'PNP')])
# 777

# %% [markdown]
# ## Gold Labels

# %%
import os
from snorkel.models import CandidateSet
from hardware_utils import load_hardware_labels

gold_file = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/hardware_gold.csv'
for set_name in ['Training', 'Development']:
    candidate_set_name = 'Hardware %s Candidates' % set_name
    candidates = session.query(CandidateSet).filter(
        CandidateSet.name == candidate_set_name).one()
    label_set_name = 'Hardware %s Candidates -- Gold' % set_name
    annotation_key_name = 'Hardware %s Labels -- Gold' % set_name
    # %time gold_candidates, annotation_key = load_hardware_labels(session,\
                           label_set_name, \
                           annotation_key_name, \
                           candidates, \
                           gold_file, \
                           'polarity')
    candidates_gold = session.query(CandidateSet).filter(
        CandidateSet.name == candidate_set_name + ' -- Gold').one()
    print "%d/%d Candidates in %s have positive Labels" % (
        len(candidates_gold), len(candidates), candidates)
# Out:
# Loading 385 candidate labels
# [========================================] 100%
# CPU times: user 1.04 s, sys: 40 ms, total: 1.08 s
# Wall time: 1.22 s
# 327/385 Candidates in Candidate Set (Hardware Training Candidates) have positive Labels
# Loading 130 candidate labels
# [========================================] 100%
# CPU times: user 532 ms, sys: 32 ms, total: 564 ms
# Wall time: 610 ms
# 67/130 Candidates in Candidate Set (Hardware Development Candidates) have positive Labels

# %% [markdown]
# ### Assess Baseline Performance

# %%
# from snorkel.models import Corpus, Candidate
# from snorkel.utils import get_ORM_instance
# from snorkel.lf_helpers import *
# from hardware_utils import entity_level_f1
# from itertools import chain

# def LF_all_true(c):
#     return True

# def LF_complement_nearby(c):
#     return 1 if set(['complement','complementary']).isdisjoint(
#         chain.from_iterable(
#             [get_phrase_ngrams(c.part), 
#              get_phrase_ngrams(c.polarity),
#              get_neighbor_phrase_ngrams(c.polarity)])) else 0

# candidates = session.query(Candidate).all()
# (tp, fp, tn, fn) = baseline(candidates, LF_complement_nearby)

# corpus = get_ORM_instance(Corpus, session, 'Hardware')
# gold_file = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/hardware_gold.csv'
# (TP, FP, FN) = entity_level_f1(tp, fp, tn, fn, gold_file, corpus, 'polarity')

# %%
# from pprint import pprint
# pprint(FP)

# %%
# pprint(FN)

# %%
# from hardware_utils import entity_to_candidates

# print len(candidates)
# matches = entity_to_candidates((u'SIEMS01215-1', u'BC856', u'NPN'), candidates)
# c = matches[0]
# print c

# %%
# from snorkel.models import ImplicitSpan
# from snorkel.lf_helpers import *
# phrases = []
# print list(get_neighbor_phrase_ngrams(c.polarity))
# print c.polarity.parent
# print phrases
# print "SPAN_TYPE_[%s]" % ('IMPLICIT' if isinstance(c.polarity, ImplicitSpan) else 'EXPLICIT')
# # list(get_phrase_ngrams(c.polarity))

# %% [markdown]
# ## Features

# %% [markdown]
# ### Extract Features

# %%
# from snorkel.models import CandidateSet
# from snorkel.async_annotations import annotate
# from snorkel.utils import get_ORM_instance

# # Run batch extraction jobs
# train = get_ORM_instance(CandidateSet, session, 'Hardware Training Candidates')
# dev   = get_ORM_instance(CandidateSet, session, 'Hardware Development Candidates')

# %time F_train = annotate(train, parallel=4)
# %time F_dev = annotate(dev, parallel=4, keyset = 'Hardware Training Candidates')

# print 'Training features hash:', hash(frozenset(F_train.keys)),'of length', len(F_train.keys)

# %%
from snorkel.models import CandidateSet
from snorkel.fast_annotations import FeatureManager
from snorkel.utils import get_ORM_instance

train = get_ORM_instance(CandidateSet, session, 'Hardware Training Candidates')
dev   = get_ORM_instance(CandidateSet, session, 'Hardware Development Candidates')

feature_manager = FeatureManager()
# %time F_train = feature_manager.create(session, train, 'Train Features')
# %time F_dev = feature_manager.update(session, dev, 'Train Features', expand_key_set=False)
# Out:
# [========================================] 100%
# Bulk upserting 38002 annotations...
# Done.
# Loading sparse Feature matrix...
# CPU times: user 8.53 s, sys: 280 ms, total: 8.81 s
# Wall time: 11.1 s
# [========================================] 100%
# Bulk upserting 4752 annotations...
# Done.
# Loading sparse Feature matrix...
# CPU times: user 3.12 s, sys: 108 ms, total: 3.23 s
# Wall time: 3.56 s

# %% [markdown]
# ## LFs

# %%
# If necessary
# import os
# os.remove('snorkel.db');
# os.system('cp snorkel.db\ featurized snorkel.db');

# from snorkel import SnorkelSession
# session = SnorkelSession()

# import sys
# sys.path.append(os.environ['SNORKELHOME'] + '/tutorials/tables/')

# from snorkel.models import candidate_subclass
# Part_Polarity = candidate_subclass('Part_Polarity', ['part','polarity'])

# from snorkel.models import CandidateSet
# train = session.query(CandidateSet).filter(
#     CandidateSet.name == 'Hardware Training Candidates').one()

# %% [markdown]
# ### Define LFs

# %%
from snorkel.fast_annotations import LabelManager
from snorkel.lf_helpers import *
import re
label_manager = LabelManager()

LFs = []

def LF_complement_phrase_part(c):
    return -1 if overlap(['complement','complementary'], 
                         get_phrase_ngrams(c.part)) else 0
LFs.append(LF_complement_phrase_part)

def LF_complement_phrase_polarity(c):
    return -1 if overlap(['complement','complementary'], 
                         get_phrase_ngrams(c.polarity)) else 0
LFs.append(LF_complement_phrase_polarity)

def LF_complement_neighbor_polarity(c):
    return -1 if overlap(['complement','complementary'], 
                         get_neighbor_phrase_ngrams(c.polarity)) else 0
LFs.append(LF_complement_neighbor_polarity)

def LF_top_mark_col_part(c):
    return -1 if overlap(['top','mark'],
                         get_col_ngrams(c.part)) else 0
LFs.append(LF_top_mark_col_part)

def LF_endswith_D_part(c):
    return -1 if c.part.get_span().endswith('D') else 0
LFs.append(LF_endswith_D_part)

def LF_default_positive(c):
    return 1 if not overlap(['complement','complementary'],
                            chain.from_iterable([
                            get_phrase_ngrams(c.part),
                            get_phrase_ngrams(c.polarity),
                            get_neighbor_phrase_ngrams(c.polarity)])) else 0
LFs.append(LF_default_positive)

# %%
from snorkel.models import Candidate
from hardware_utils import entity_to_candidates

candidates = session.query(Candidate).all()
print len(candidates)
# matches = entity_to_candidates((u'SIEMS01215-1', u'BC856', u'NPN'), candidates)
# c = matches[0]
c = candidates[0]
print candidates[0]

print LF_complement_phrase_part(c)
print LF_complement_phrase_polarity(c)
print LF_complement_neighbor_polarity(c)
print LF_top_mark_col_part(c)
print LF_endswith_D_part(c)
print LF_default_positive(c)
# Out:
# 515
# Part_Polarity(Span("DTC114YE", parent=12, chars=[0,7], words=[0,0]), Span("NPN", parent=17, chars=[0,2], words=[0,0]))
# 0
# 0
# 0
# 0
# 0
# 1

# %% [markdown]
# ### Apply LFs

# %%
# %time L_train = label_manager.create(session, train, 'LF Labels', f=LFs)
L_train
# Out:
# [========================================] 100%
# Bulk upserting 2310 annotations...
# Done.
# Loading sparse Label matrix...
# CPU times: user 1.56 s, sys: 76 ms, total: 1.64 s
# Wall time: 1.87 s
# <385x6 sparse matrix of type '<type 'numpy.float64'>'
# 	with 400 stored elements in Compressed Sparse Row format>

# %%
# from snorkel.async_annotations import annotate
# %time L_train = annotate(train, lfs=LFs)
# L_train

# %% [markdown]
# ### Assess LF accuracy

# %%
train_gold = session.query(CandidateSet).filter(
    CandidateSet.name == 'Hardware Training Candidates -- Gold').one()
# %time L_train.lf_stats(train_gold)
# Out:
# [========================================] 100%
# CPU times: user 40 ms, sys: 0 ns, total: 40 ms
# Wall time: 42.3 ms
#                                  accuracy  conflicts  coverage  j  overlaps
# LF_complement_phrase_part        1.000000   0.000000  0.036364  0  0.036364
# LF_complement_phrase_polarity    1.000000   0.000000  0.064935  1  0.000000
# LF_complement_neighbor_polarity  0.104348   0.000000  0.597403  2  0.036364
# LF_top_mark_col_part                  NaN   0.000000  0.000000  3  0.000000
# LF_endswith_D_part               1.000000   0.002597  0.002597  4  0.002597
# LF_default_positive              0.930769   0.002597  0.337662  5  0.002597

# %% [markdown]
# ## Learn and Evaluate

# %%
# If necessary:
# import os
# os.remove('snorkel.db');
# os.system('cp snorkel.db\ features snorkel.db');

# from snorkel import SnorkelSession
# session = SnorkelSession()

# import sys
# sys.path.append(os.environ['SNORKELHOME'] + '/tutorials/tables/')

# from snorkel.models import candidate_subclass
# Part_Polarity = candidate_subclass('Part_Polarity', ['part','polarity'])

# from snorkel.models import CandidateSet
# train = session.query(CandidateSet).filter(
#     CandidateSet.name == 'Hardware Training Candidates').one()
# dev = session.query(CandidateSet).filter(
#     CandidateSet.name == 'Hardware Development Candidates').one()

# from snorkel.annotations import FeatureManager, LabelManager
# feature_manager = FeatureManager()
# %time F_train = feature_manager.load(session, train, 'Train Features')
# %time F_dev = feature_manager.load(session, dev, 'Train Features')

# label_manager = LabelManager()
# %time L_train = label_manager.load(session, train, 'LF Labels')

# %%
from snorkel.learning import NaiveBayes

gen_model = NaiveBayes()
gen_model.train(L_train, n_iter=15000, rate=1e-2)

#%time gen_model.save(session, 'Generative Params')
train_marginals = gen_model.marginals(L_train)
# Out:
# ================================================================================
# Training marginals (!= 0.5):	385
# Features:			6
# ================================================================================
# Begin training for rate=0.01, mu=1e-06
# 	Learning epoch = 0	Gradient mag. = 0.042124
# /home/xiao/software/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:1318: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# 	Learning epoch = 250	Gradient mag. = 0.047074
# 	Learning epoch = 500	Gradient mag. = 0.049861
# 	Learning epoch = 750	Gradient mag. = 0.052691
# 	Learning epoch = 1000	Gradient mag. = 0.055555
# 	Learning epoch = 1250	Gradient mag. = 0.058446
# 	Learning epoch = 1500	Gradient mag. = 0.061358
# 	Learning epoch = 1750	Gradient mag. = 0.064285
# 	Learning epoch = 2000	Gradient mag. = 0.067225
# 	Learning epoch = 2250	Gradient mag. = 0.070176
# 	Learning epoch = 2500	Gradient mag. = 0.073135
# 	Learning epoch = 2750	Gradient mag. = 0.076103
# 	Learning epoch = 3000	Gradient mag. = 0.079078
# 	Learning epoch = 3250	Gradient mag. = 0.082061
# 	Learning epoch = 3500	Gradient mag. = 0.085050
# 	Learning epoch = 3750	Gradient mag. = 0.088048
# 	Learning epoch = 4000	Gradient mag. = 0.091052
# 	Learning epoch = 4250	Gradient mag. = 0.094062
# 	Learning epoch = 4500	Gradient mag. = 0.097079
# 	Learning epoch = 4750	Gradient mag. = 0.100103
# 	Learning epoch = 5000	Gradient mag. = 0.103131
# 	Learning epoch = 5250	Gradient mag. = 0.106165
# 	Learning epoch = 5500	Gradient mag. = 0.109204
# 	Learning epoch = 5750	Gradient mag. = 0.112247
# 	Learning epoch = 6000	Gradient mag. = 0.115294
# 	Learning epoch = 6250	Gradient mag. = 0.118344
# 	Learning epoch = 6500	Gradient mag. = 0.121398
# 	Learning epoch = 6750	Gradient mag. = 0.124454
# 	Learning epoch = 7000	Gradient mag. = 0.127513
# 	Learning epoch = 7250	Gradient mag. = 0.122580
# 	Learning epoch = 7500	Gradient mag. = 0.113301
# 	Learning epoch = 7750	Gradient mag. = 0.104876
# 	Learning epoch = 8000	Gradient mag. = 0.097237
# 	Learning epoch = 8250	Gradient mag. = 0.090322
# 	Learning epoch = 8500	Gradient mag. = 0.084075
# 	Learning epoch = 8750	Gradient mag. = 0.078443
# 	Learning epoch = 9000	Gradient mag. = 0.073377
# 	Learning epoch = 9250	Gradient mag. = 0.068833
# 	Learning epoch = 9500	Gradient mag. = 0.064768
# 	Learning epoch = 9750	Gradient mag. = 0.061143
# 	Learning epoch = 10000	Gradient mag. = 0.057921
# 	Learning epoch = 10250	Gradient mag. = 0.055066
# 	Learning epoch = 10500	Gradient mag. = 0.052546
# 	Learning epoch = 10750	Gradient mag. = 0.050329
# 	Learning epoch = 11000	Gradient mag. = 0.048385
# 	Learning epoch = 11250	Gradient mag. = 0.046687
# 	Learning epoch = 11500	Gradient mag. = 0.045209
# 	Learning epoch = 11750	Gradient mag. = 0.043926
# 	Learning epoch = 12000	Gradient mag. = 0.042816
# 	Learning epoch = 12250	Gradient mag. = 0.041859
# 	Learning epoch = 12500	Gradient mag. = 0.041035
# 	Learning epoch = 12750	Gradient mag. = 0.040327
# 	Learning epoch = 13000	Gradient mag. = 0.039721
# 	Learning epoch = 13250	Gradient mag. = 0.039202
# 	Learning epoch = 13500	Gradient mag. = 0.038759
# 	Learning epoch = 13750	Gradient mag. = 0.038381
# 	Learning epoch = 14000	Gradient mag. = 0.038058
# 	Learning epoch = 14250	Gradient mag. = 0.037784
# 	Learning epoch = 14500	Gradient mag. = 0.037550
# 	Learning epoch = 14750	Gradient mag. = 0.037351
# Final gradient magnitude for rate=0.01, mu=1e-06: 0.037

# %%
from snorkel.learning import LogReg

disc_model = LogReg()
disc_model.train(F_train, train_marginals, n_iter=2000, rate=1e-5)
#%time disc_model.save(session, "Discriminative Params")
# Out:
# ================================================================================
# Training marginals (!= 0.5):	385
# Features:			1712
# ================================================================================
# Using gradient descent...
# 	Learning epoch = 0	Step size = 1e-05
# 	Loss = 266.861665	Gradient magnitude = 661.145610
# 	Learning epoch = 100	Step size = 9.04792147114e-06
# 	Loss = 157.547831	Gradient magnitude = 179.657840
# 	Learning epoch = 200	Step size = 8.18648829479e-06
# 	Loss = 139.460515	Gradient magnitude = 119.338701
# 	Learning epoch = 300	Step size = 7.40707032156e-06
# 	Loss = 131.176967	Gradient magnitude = 91.536962
# 	Learning epoch = 400	Step size = 6.70185906007e-06
# 	Loss = 126.486050	Gradient magnitude = 75.627731
# 	Learning epoch = 500	Step size = 6.06378944861e-06
# 	Loss = 123.483437	Gradient magnitude = 65.569161
# 	Learning epoch = 600	Step size = 5.48646907485e-06
# 	Loss = 121.401519	Gradient magnitude = 58.741918
# 	Learning epoch = 700	Step size = 4.96411413431e-06
# 	Loss = 119.877859	Gradient magnitude = 53.856199
# 	Learning epoch = 800	Step size = 4.4914914861e-06
# 	Loss = 118.725374	Gradient magnitude = 50.204432
# 	Learning epoch = 900	Step size = 4.06386622545e-06
# 	Loss = 117.827788	Gradient magnitude = 47.402958
# 	Learning epoch = 1000	Step size = 3.67695424771e-06
# 	Loss = 117.112237	Gradient magnitude = 45.207596
# 	Learning epoch = 1100	Step size = 3.32687932862e-06
# 	Loss = 116.532914	Gradient magnitude = 43.456504
# 	Learning epoch = 1200	Step size = 3.01013429093e-06
# 	Loss = 116.058558	Gradient magnitude = 42.041374
# 	Learning epoch = 1300	Step size = 2.72354586819e-06
# 	Loss = 115.666958	Gradient magnitude = 40.886910
# 	Learning epoch = 1400	Step size = 2.46424291385e-06
# 	Loss = 115.341828	Gradient magnitude = 39.939077
# 	Learning epoch = 1500	Step size = 2.22962763703e-06
# 	Loss = 115.070912	Gradient magnitude = 39.158088
# 	Learning epoch = 1600	Step size = 2.01734957697e-06
# 	Loss = 114.844805	Gradient magnitude = 38.513328
# 	Learning epoch = 1700	Step size = 1.82528205523e-06
# 	Loss = 114.656376	Gradient magnitude = 37.982644
# 	Learning epoch = 1800	Step size = 1.65150086984e-06
# 	Loss = 114.499910	Gradient magnitude = 37.548319
# 	Learning epoch = 1900	Step size = 1.49426501798e-06
# 	Loss = 114.370596	Gradient magnitude = 37.196088

# %%
train_gold = session.query(CandidateSet).filter(
    CandidateSet.name == 'Hardware Training Candidates -- Gold').one()

# %%
dev_gold = session.query(CandidateSet).filter(
    CandidateSet.name == 'Hardware Development Candidates -- Gold').one()

# %%
from snorkel.models import CandidateSet
from snorkel.annotations import LabelManager
label_manager = LabelManager()
L_dev = label_manager.load(session, dev, 'Hardware Development Labels -- Gold')

# %%
tp, fp, tn, fn = disc_model.score(F_dev, L_dev, dev_gold)
# Out:
# Calibration plot:
# /home/xiao/software/anaconda/lib/python2.7/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# ========================================
# Recall-corrected Noise-aware Model
# ========================================
# Pos. class accuracy: 0.0
# Neg. class accuracy: 1.0
# Corpus Precision nan
# Corpus Recall    0.0
# Corpus F1        nan
# ----------------------------------------
# TP: 0 | FP: 0 | TN: 63 | FN: 67
# ========================================
#
# ========================================
# Recall-corrected Noise-aware Model
# ========================================
# Pos. class accuracy: 0.0
# Neg. class accuracy: 1.0
# Corpus Precision nan
# Corpus Recall    0.0
# Corpus F1        nan
# ----------------------------------------
# TP: 0 | FP: 0 | TN: 63 | FN: 67
# ========================================

# %%
from snorkel.models import Corpus
from hardware_utils import entity_level_f1
import os

gold_file = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/hardware_gold.csv'
corpus = session.query(Corpus).filter(Corpus.name == 'Hardware Development').one()
(TP, FP, FN) = entity_level_f1(tp, fp, tn, fn, gold_file, corpus, 'polarity')
# Out:
# ========================================
# Scoring on Entity-Level Gold Data
# ========================================
# Corpus Precision nan
# Corpus Recall    0.0
# Corpus F1        nan
# ----------------------------------------
# TP: 0 | FP: 0 | FN: 32
# ========================================

# %%
from pprint import pprint
FP_list = sorted(list(FP))
pprint(FP_list[:10])
# Out:
# []

# %%
print '\n'.join(str(x) for x in disc_model.get_feature_weights(F_dev))
# Out:
# (u'DDL_e2_LEMMA_SEQ_[NPN]', 0.11832145048775143)
# (u'DDL_e2_W_RIGHT_3_[Epitaxial Silicon Transistor]', -0.10533551727120409)
# (u'DDL_e2_W_RIGHT_POS_3_[NNP NNP NNP]', -0.10533551727120409)
# (u'DDL_e2_LEMMA_SEQ_[PNP]', -0.10533551727120409)
# (u'DDL_e2_W_RIGHT_1_[Epitaxial]', -0.10533551727120409)
# (u'DDL_e2_W_RIGHT_2_[Epitaxial Silicon]', -0.10533551727120409)
# (u'CORE_e1_STARTS_WITH_CAPITAL', -0.10507790455547653)
# (u'DDL_e2_WORD_SEQ_[PNP]', -0.10260806006979047)
# (u'CORE_e1_SPAN_TYPE_[IMPLICIT]', -0.10218163733466484)
# (u'DDL_e2_W_RIGHT_2_[General-Purpose Amplifier]', 0.08930649358228797)
# (u'DDL_e2_W_RIGHT_1_[General-Purpose]', 0.08930649358228797)
# (u'STR_e2_HTML_ATTR_style=text-indent: 0pt;line-height: 12pt;text-align: left;', -0.08746862365416548)
# (u'DDL_e2_DEP_SEQ_[ROOT]', -0.08221414511435865)
# (u'DDL_e2_LEMMA_SEQ_[npn]', -0.08221414511435865)
# (u'DDL_e2_W_LEFT_POS_1_[NN]', -0.08221414511435865)
# (u'DDL_e2_W_LEFT_1_[npn]', -0.08221414511435865)
# (u'VIZ_e2_PAGE_[1]', -0.08037222096500315)
# (u'DDL_e2_POS_SEQ_[NN]', -0.07948668791294441)
# (u'STR_e2_ANCESTOR_CLASS_[None None None]', -0.07574742635549771)
# (u'STR_e2_ANCESTOR_ID_[None None None]', -0.07574742635549771)
# (u'DDL_e1_W_LEFT_POS_1_[CD]', -0.07388188371930746)
# (u'DDL_e1_W_LEFT_POS_2_[: CD]', -0.07388188371930746)
# (u'CORE_e2_SPAN_TYPE_[EXPLICIT]', -0.0665007546963972)
# (u'CORE_e2_LENGTH_1', -0.0665007546963972)
# (u'CORE_e2_STARTS_WITH_CAPITAL', -0.0665007546963972)
# (u'STR_e1_TAG_p', -0.0648100116087356)
# (u'DDL_e2_W_LEMMA_L_3_R_2_[bc856/857/858 / 859/860]_[Epitaxial Silicon]', -0.05621654812790012)
# (u'DDL_e2_W_LEFT_1_[859/860]', -0.05621654812790012)
# (u'DDL_e2_W_LEFT_POS_2_[: CD]', -0.05621654812790012)
# (u'DDL_e2_W_POS_L_3_R_2_[NN : CD]_[NNP NNP]', -0.05621654812790012)
# (u'DDL_e2_W_POS_L_2_R_1_[: CD]_[NNP]', -0.05621654812790012)
# (u'DDL_e2_W_LEMMA_L_3_R_1_[bc856/857/858 / 859/860]_[Epitaxial]', -0.05621654812790012)
# (u'DDL_e2_W_POS_L_1_R_2_[CD]_[NNP NNP]', -0.05621654812790012)
# (u'DDL_e2_W_LEMMA_L_3_R_3_[bc856/857/858 / 859/860]_[Epitaxial Silicon Transistor]', -0.05621654812790012)
# (u'DDL_e2_W_LEMMA_L_2_R_2_[/ 859/860]_[Epitaxial Silicon]', -0.05621654812790012)
# (u'DDL_e2_W_LEMMA_L_2_R_3_[/ 859/860]_[Epitaxial Silicon Transistor]', -0.05621654812790012)
# (u'DDL_e2_W_LEFT_2_[/ 859/860]', -0.05621654812790012)
# (u'DDL_e2_W_LEFT_POS_3_[NN : CD]', -0.05621654812790012)
# (u'DDL_e2_W_POS_L_1_R_3_[CD]_[NNP NNP NNP]', -0.05621654812790012)
# (u'DDL_e2_W_POS_L_3_R_1_[NN : CD]_[NNP]', -0.05621654812790012)
# (u'DDL_e2_W_POS_L_1_R_1_[CD]_[NNP]', -0.05621654812790012)
# (u'DDL_e2_W_POS_L_2_R_3_[: CD]_[NNP NNP NNP]', -0.05621654812790012)
# (u'DDL_e2_W_LEMMA_L_2_R_1_[/ 859/860]_[Epitaxial]', -0.05621654812790012)
# (u'DDL_e2_W_POS_L_3_R_3_[NN : CD]_[NNP NNP NNP]', -0.05621654812790012)
# (u'DDL_e2_W_LEMMA_L_1_R_2_[859/860]_[Epitaxial Silicon]', -0.05621654812790012)
# (u'DDL_e2_W_POS_L_2_R_2_[: CD]_[NNP NNP]', -0.05621654812790012)
# (u'DDL_e2_W_LEFT_3_[bc856/857/858 / 859/860]', -0.05621654812790012)
# (u'DDL_e2_W_LEMMA_L_1_R_1_[859/860]_[Epitaxial]', -0.05621654812790012)
# (u'DDL_e2_W_LEMMA_L_1_R_3_[859/860]_[Epitaxial Silicon Transistor]', -0.05621654812790012)
# (u'DDL_e2_W_LEFT_POS_1_[CD]', -0.05621654812790012)
# (u'STR_e2_NEXT_SIB_TAG_style', -0.05621654812790012)
# (u'STR_e2_NEXT_SIB_TAG_p', 0.05301815173693084)
# (u'STR_e1_PREV_SIB_TAG_p', -0.05285549604572964)
# (u'DDL_e2_W_POS_L_1_R_1_[:]_[NNP]', 0.050803257992033814)
# (u'DDL_e2_W_LEFT_POS_1_[:]', 0.050803257992033814)
# (u'DDL_e2_W_POS_L_2_R_1_[NN :]_[NNP]', 0.050803257992033814)
# (u'DDL_e2_W_POS_L_2_R_2_[NN :]_[NNP NNP]', 0.050803257992033814)
# (u'DDL_e2_W_POS_L_1_R_2_[:]_[NNP NNP]', 0.050803257992033814)
# (u'DDL_e2_W_LEFT_POS_2_[NN :]', 0.050803257992033814)
# (u'STR_COMMON_ANCESTOR_[ html body]', -0.047374323958725255)
# (u'STR_LOWEST_ANCESTOR_DEPTH_[1]', -0.047374323958725255)
# (u'DDL_e2_W_POS_L_1_R_3_[NNP]_[NNP NNP NNP]', -0.047119969309552395)
# (u'VIZ_e2_ALIGNED_CENTER_and', -0.047119969309552395)
# (u'VIZ_e2_ALIGNED_RIGHT_switching', -0.047119969309552395)
# (u'DDL_e2_W_LEFT_1_[Transistor]', -0.047119969309552395)
# (u'STR_e2_NEXT_SIB_TAG_table', -0.047119969309552395)
# (u'DDL_e2_W_LEMMA_L_1_R_3_[Transistor]_[Epitaxial Silicon Transistor]', -0.047119969309552395)
# (u'VIZ_e2_ALIGNED_application', -0.047119969309552395)
# (u'VIZ_e2_ALIGNED_RIGHT_and', -0.047119969309552395)
# (u'VIZ_e2_ALIGNED_CENTER_amplifier', -0.047119969309552395)
# (u'STR_e2_HTML_ATTR_style=padding-left: 24pt;text-indent: 0pt;text-align: left;', -0.047119969309552395)
# (u'VIZ_e2_ALIGNED_LEFT_switching', -0.047119969309552395)
# (u'DDL_e2_W_POS_L_2_R_3_[NNP NNP]_[NNP NNP NNP]', -0.047119969309552395)
# (u'DDL_e2_W_LEMMA_L_1_R_2_[Transistor]_[Epitaxial Silicon]', -0.047119969309552395)
# (u'VIZ_e2_ALIGNED_RIGHT_amplifier', -0.047119969309552395)
# (u'VIZ_e2_ALIGNED_switching', -0.047119969309552395)
# (u'DDL_e2_W_POS_L_3_R_3_[NNP NNP NNP]_[NNP NNP NNP]', -0.047119969309552395)
# (u'DDL_e2_W_LEFT_3_[Epitaxial Silicon Transistor]', -0.047119969309552395)
# (u'DDL_e2_W_LEMMA_L_2_R_1_[Silicon Transistor]_[Epitaxial]', -0.047119969309552395)
# (u'VIZ_e2_ALIGNED_LEFT_application', -0.047119969309552395)
# (u'DDL_e2_W_LEMMA_L_3_R_3_[Epitaxial Silicon Transistor]_[Epitaxial Silicon Transistor]', -0.047119969309552395)
# (u'DDL_e2_W_LEMMA_L_2_R_3_[Silicon Transistor]_[Epitaxial Silicon Transistor]', -0.047119969309552395)
# (u'VIZ_e2_ALIGNED_RIGHT_application', -0.047119969309552395)
# (u'STR_e2_NODE_POS_13', -0.047119969309552395)
# (u'VIZ_e2_ALIGNED_CENTER_switching', -0.047119969309552395)
# (u'DDL_e2_W_LEMMA_L_3_R_2_[Epitaxial Silicon Transistor]_[Epitaxial Silicon]', -0.047119969309552395)
# (u'VIZ_e2_ALIGNED_and', -0.047119969309552395)
# (u'VIZ_e2_ALIGNED_LEFT_and', -0.047119969309552395)
# (u'DDL_e2_W_LEMMA_L_1_R_1_[Transistor]_[Epitaxial]', -0.047119969309552395)
# (u'VIZ_e2_ALIGNED_CENTER_application', -0.047119969309552395)
# (u'DDL_e2_W_LEMMA_L_3_R_1_[Epitaxial Silicon Transistor]_[Epitaxial]', -0.047119969309552395)
# (u'DDL_e2_W_LEFT_2_[Silicon Transistor]', -0.047119969309552395)
# (u'DDL_e2_W_LEMMA_L_2_R_2_[Silicon Transistor]_[Epitaxial Silicon]', -0.047119969309552395)
# (u'CORE_e1_LENGTH_3', -0.046555069453123085)
# (u'STR_e1_NEXT_SIB_TAG_p', -0.04497622654467203)
# (u'VIZ_SAME_PAGE', -0.043456257677795526)
# (u'VIZ_e2_ALIGNED_npn', -0.04284091877001881)
# (u'STR_e2_NODE_POS_10', -0.04284091877001881)
# (u'VIZ_e2_ALIGNED_Y_npn', -0.04284091877001881)
# (u'STR_e2_PREV_SIB_TAG_h2', -0.04284091877001881)
# (u'STR_e2_NODE_POS_6', -0.042628705050395226)
# (u'STR_e2_NEXT_SIB_TAG_h1', -0.042628705050395226)
# (u'STR_e2_PARENT_TAG_body', -0.04200697922877054)
# (u'STR_e1_LAST_NODE', -0.03877872309641126)
# (u'DDL_e1_W_LEFT_POS_3_[NN : CD]', -0.038438093583563385)
# (u'DDL_e1_W_LEFT_2_[/ 859/860]', -0.038438093583563385)
# (u'DDL_e1_W_LEFT_1_[859/860]', -0.038438093583563385)
# (u'DDL_e1_W_LEFT_3_[bc856/857/858 / 859/860]', -0.038438093583563385)
# (u'STR_e1_ANCESTOR_TAG_[html body p]', -0.038391419479093934)
# (u'DDL_e1_W_LEFT_1_[bc818k]', -0.03831279250974627)
# (u'VIZ_e1_PAGE_[2]', -0.03726326297833481)
# (u'STR_e2_NODE_POS_9', 0.036504235756502565)
# (u'DDL_e2_W_LEMMA_L_3_R_1_[NPN General-Purpose Amplifier]_[General-Purpose]', 0.036504235756502565)
# (u'DDL_e2_W_LEFT_2_[General-Purpose Amplifier]', 0.036504235756502565)
# (u'STR_e2_HTML_ATTR_style=padding-top: 1pt;padding-left: 23pt;text-indent: 0pt;text-align: left;', 0.036504235756502565)
# (u'DDL_e2_W_LEFT_1_[Amplifier]', 0.036504235756502565)
# (u'DDL_e2_W_LEMMA_L_2_R_1_[General-Purpose Amplifier]_[General-Purpose]', 0.036504235756502565)
# (u'DDL_e2_W_LEMMA_L_2_R_2_[General-Purpose Amplifier]_[General-Purpose Amplifier]', 0.036504235756502565)
# (u'DDL_e2_W_LEMMA_L_1_R_2_[Amplifier]_[General-Purpose Amplifier]', 0.036504235756502565)
# (u'DDL_e2_W_LEFT_3_[NPN General-Purpose Amplifier]', 0.036504235756502565)
# (u'STR_e2_PREV_SIB_TAG_h1', 0.036504235756502565)
# (u'DDL_e2_W_LEMMA_L_1_R_1_[Amplifier]_[General-Purpose]', 0.036504235756502565)
# (u'DDL_e2_W_LEMMA_L_3_R_2_[NPN General-Purpose Amplifier]_[General-Purpose Amplifier]', 0.036504235756502565)
# (u'STR_e1_ANCESTOR_CLASS_[None None None]', -0.034178116600278724)
# (u'DDL_e2_WORD_SEQ_[NPN]', 0.034142271692508934)
# (u'CORE_e1_SPAN_TYPE_[EXPLICIT]', 0.0337438213000589)
# (u'DDL_e1_W_LEFT_2_[/ bc818k]', -0.03344479030199252)
# (u'DDL_e1_W_LEFT_3_[bc817k / bc818k]', -0.03344479030199252)
# (u'DDL_e1_W_LEFT_POS_3_[CD : CD]', -0.03344479030199252)
# (u'DDL_e1_W_LEFT_POS_1_[NN]', 0.03249507390871199)
# (u'STR_e2_NODE_POS_2', -0.03174144729297519)
# (u'STR_e2_ANCESTOR_TAG_[html head title]', -0.03174144729297519)
# (u'STR_e2_TAG_title', -0.03174144729297519)
# (u'STR_e2_PREV_SIB_TAG_meta', -0.03174144729297519)
# (u'STR_e2_PARENT_TAG_head', -0.03174144729297519)
# (u'STR_e2_PREV_SIB_TAG_p', -0.030415817675447394)
# (u'DDL_e1_POS_SEQ_[NN]', 0.03006675026843429)
# (u'STR_e1_NODE_POS_3', -0.02979347897628829)
# (u'VIZ_e1_PAGE_[1]', -0.029517522334432382)
# (u'TAB_e1_COL_HEAD_WORDS_[parameter]', -0.029277048092950692)
# (u'TAB_e1_COL_WORDS_[:]', -0.029277048092950692)
# (u'TAB_e1_COL_WORDS_[collector-emitter]', -0.029277048092950692)
# (u'TAB_e1_COL_WORDS_[collector]', -0.029277048092950692)
# (u'STR_e1_HTML_ATTR_class=s7', -0.029277048092950692)
# (u'TAB_e1_COL_WORDS_[dc]', -0.029277048092950692)
# (u'TAB_e1_COL_WORDS_[current]', -0.029277048092950692)
# (u'TAB_e1_COL_WORDS_[voltage]', -0.029277048092950692)
# (u'STR_e1_ANCESTOR_CLASS_[None None None None None s7]', -0.029277048092950692)
# (u'TAB_e1_COL_WORDS_[parameter]', -0.029277048092950692)
# (u'CORE_e1_LENGTH_2', -0.028433001909674058)
# (u'STR_e1_PARENT_TAG_body', -0.028023082210668987)
# (u'DDL_e1_LEMMA_SEQ_[2n3904]', 0.02702196926925618)
# (u'DDL_e1_WORD_SEQ_[2N3904]', 0.02702196926925618)
# (u'DDL_e2_W_LEMMA_L_2_R_2_[pzt3904 --]_[General-Purpose Amplifier]', 0.026328157157109174)
# (u'DDL_e2_W_LEMMA_L_3_R_2_[/ pzt3904 --]_[General-Purpose Amplifier]', 0.026328157157109174)
# (u'DDL_e2_W_LEMMA_L_2_R_1_[pzt3904 --]_[General-Purpose]', 0.026328157157109174)
# (u'DDL_e2_W_LEMMA_L_1_R_1_[--]_[General-Purpose]', 0.026328157157109174)
# (u'DDL_e2_W_LEMMA_L_3_R_1_[/ pzt3904 --]_[General-Purpose]', 0.026328157157109174)
# (u'DDL_e2_W_LEFT_1_[--]', 0.026328157157109174)
# (u'DDL_e2_W_POS_L_3_R_2_[: NN :]_[NNP NNP]', 0.026328157157109174)
# (u'STR_e2_HTML_ATTR_style=padding-left: 1pt;text-indent: 0pt;line-height: 13pt;text-align: left;', 0.026328157157109174)
# (u'DDL_e2_W_POS_L_3_R_1_[: NN :]_[NNP]', 0.026328157157109174)
# (u'DDL_e2_W_LEFT_2_[pzt3904 --]', 0.026328157157109174)
# (u'DDL_e2_W_LEFT_3_[/ pzt3904 --]', 0.026328157157109174)
# (u'DDL_e2_W_LEMMA_L_1_R_2_[--]_[General-Purpose Amplifier]', 0.026328157157109174)
# (u'DDL_e2_W_LEFT_POS_3_[: NN :]', 0.026328157157109174)
# (u'STR_e1_HTML_ATTR_class=s10', 0.02544226268192676)
# (u'STR_e1_ANCESTOR_CLASS_[None None None None None s10]', 0.02544226268192676)
# (u'TDL_INV_BETWEEN-MENTION-and-MENTION[LEN:0-2]', -0.02527041568170388)
# (u'TDL_INV_LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[None]', -0.02527041568170388)
# (u'STR_e1_HTML_ATTR_style=padding-left: 1pt;text-indent: 0pt;line-height: 15pt;text-align: left;', -0.024814932510762278)
# (u'TDL_INV_DEP_LABEL:BETWEEN-MENTION-and-MENTION[ROOT]', -0.024186495290329756)
# (u'DDL_e1_POS_SEQ_[NN : CD]', -0.023949424813309188)
# (u'DDL_e1_WORD_SEQ_[BC856/857/858 / 859/860]', -0.023949424813309188)
# (u'DDL_e1_LEMMA_SEQ_[bc856/857/858 / 859/860]', -0.023949424813309188)
# (u'STR_e2_TAG_h1', -0.023942624277741447)
# (u'STR_e2_ANCESTOR_TAG_[html body h1]', -0.023942624277741447)
# (u'TAB_e1_ROW_WORDS_[v]', -0.023045824015414607)
# (u'DDL_e2_W_LEFT_2_[NPN Silicon]', 0.023023763952419604)
# (u'STR_e2_NODE_POS_5', 0.023023763952419604)
# (u'VIZ_e2_ALIGNED_LEFT_transistor', 0.023023763952419604)
# (u'DDL_e2_W_LEFT_1_[Silicon]', 0.023023763952419604)
# (u'DDL_e2_W_LEMMA_L_2_R_1_[NPN Silicon]_[Silicon]', 0.023023763952419604)
# (u'DDL_e2_W_RIGHT_1_[Silicon]', 0.023023763952419604)
# (u'STR_e2_HTML_ATTR_style=padding-top: 7pt;padding-left: 6pt;text-indent: 0pt;text-align: left;', 0.023023763952419604)
# (u'DDL_e2_W_LEMMA_L_1_R_1_[Silicon]_[Silicon]', 0.023023763952419604)
# (u'VIZ_e2_ALIGNED_transistor', 0.023023763952419604)
# (u'DDL_e1_W_RIGHT_POS_2_[: CD]', -0.022919187109441002)
# (u'TAB_e1_ROW_WORDS_[3l]', 0.022820221231796233)
# (u'DDL_e2_W_LEMMA_L_1_R_2_[-]_[General-Purpose Amplifier]', 0.02247610100117348)
# (u'DDL_e2_W_LEFT_2_[pzt3904 -]', 0.02247610100117348)
# (u'DDL_e2_W_LEMMA_L_3_R_2_[mmbt3904 pzt3904 -]_[General-Purpose Amplifier]', 0.02247610100117348)
# (u'DDL_e2_W_POS_L_3_R_1_[NN NN :]_[NNP]', 0.02247610100117348)
# (u'DDL_e2_W_LEFT_POS_3_[NN NN :]', 0.02247610100117348)
# (u'STR_e2_NEXT_SIB_TAG_meta', 0.02247610100117348)
# (u'DDL_e2_W_LEMMA_L_3_R_1_[mmbt3904 pzt3904 -]_[General-Purpose]', 0.02247610100117348)
# (u'DDL_e2_W_LEFT_3_[mmbt3904 pzt3904 -]', 0.02247610100117348)
# (u'DDL_e2_W_POS_L_3_R_2_[NN NN :]_[NNP NNP]', 0.02247610100117348)
# (u'DDL_e2_W_LEMMA_L_2_R_1_[pzt3904 -]_[General-Purpose]', 0.02247610100117348)
# (u'DDL_e2_W_LEMMA_L_1_R_1_[-]_[General-Purpose]', 0.02247610100117348)
# (u'DDL_e2_W_LEMMA_L_2_R_2_[pzt3904 -]_[General-Purpose Amplifier]', 0.02247610100117348)
# (u'DDL_e2_W_LEFT_1_[-]', 0.02247610100117348)
# (u'VIZ_e2_ALIGNED_LEFT_amplifier', -0.022097205523382207)
# (u'VIZ_e2_ALIGNED_amplifier', -0.022097205523382207)
# (u'STR_e1_FIRST_NODE', -0.021969096675428155)
# (u'DDL_e1_W_RIGHT_POS_1_[CD]', -0.021851413624670482)
# (u'VIZ_HORZ_ALIGNED', 0.021431675874307794)
# (u'STR_e1_ANCESTOR_ID_[None None None]', -0.021085759144819773)
# (u'DDL_e1_LEMMA_SEQ_[pzt3904]', 0.02062618291784282)
# (u'DDL_e1_WORD_SEQ_[PZT3904]', 0.02062618291784282)
# (u'TAB_e1_ROW_WORDS_[to-92 3l]', 0.020541190781674885)
# (u'TAB_e1_ROW_WORDS_[to-92]', 0.020541190781674885)
# (u'DDL_e1_W_LEFT_1_[:]', -0.020165463813345146)
# (u'DDL_e1_LEMMA_SEQ_[mmbt3904]', 0.02001351592737067)
# (u'DDL_e1_WORD_SEQ_[MMBT3904]', 0.02001351592737067)
# (u'STR_e1_NEXT_SIB_TAG_meta', 0.019555203828524027)
# (u'DDL_e1_POS_SEQ_[CD]', -0.01939661349438943)
# (u'DDL_e1_W_LEFT_1_[2n3904]', 0.019340188180323403)
# (u'DDL_e1_DEP_SEQ_[ROOT punct dep]', -0.019212497454352644)
# (u'STR_e1_HTML_ATTR_style=padding-left: 1pt;text-indent: 0pt;line-height: 13pt;text-align: left;', 0.01896157380702652)
# (u'TAB_e1_COL_NUM_[0]', 0.01894064515394098)
# (u'STR_e2_ANCESTOR_TAG_[html body h2]', -0.018792812318693366)
# (u'STR_e2_TAG_h2', -0.018792812318693366)
# (u'DDL_e1_W_POS_L_1_R_2_[CD]_[: CD]', -0.01824526042552103)
# (u'DDL_e1_W_POS_L_1_R_1_[CD]_[:]', -0.01824526042552103)
# (u'DDL_e1_W_POS_L_2_R_1_[: CD]_[:]', -0.01824526042552103)
# (u'DDL_e1_W_POS_L_2_R_2_[: CD]_[: CD]', -0.01824526042552103)
# (u'DDL_e1_DEP_SEQ_[dep]', 0.01804909787282776)
# (u'TAB_e1_ROW_WORDS_[:]', -0.018013621404479537)
# (u'TAB_e1_CELL_WORDS_[:]', -0.018013621404479537)
# (u'TAB_e1_ROW_WORDS_[2000]', 0.017806446167798064)
# (u'DDL_e1_W_POS_L_2_R_1_[CC NN]_[JJ]', -0.017480351295848257)
# (u'DDL_e1_W_POS_L_1_R_1_[NN]_[JJ]', -0.017480351295848257)
# (u'DDL_e1_W_POS_L_3_R_1_[NN CC NN]_[JJ]', -0.017480351295848257)
# (u'DDL_e1_W_RIGHT_POS_2_[JJ NN]', -0.017480351295848257)
# (u'DDL_e1_W_POS_L_3_R_2_[NN CC NN]_[JJ NN]', -0.017480351295848257)
# (u'DDL_e1_W_POS_L_3_R_3_[NN CC NN]_[JJ NN CC]', -0.017480351295848257)
# (u'DDL_e1_W_POS_L_1_R_3_[NN]_[JJ NN CC]', -0.017480351295848257)
# (u'DDL_e1_W_LEFT_POS_2_[CC NN]', -0.017480351295848257)
# (u'DDL_e1_W_POS_L_1_R_2_[NN]_[JJ NN]', -0.017480351295848257)
# (u'DDL_e1_W_RIGHT_1_[=]', -0.017480351295848257)
# (u'DDL_e1_W_RIGHT_POS_1_[JJ]', -0.017480351295848257)
# (u'DDL_e1_W_LEFT_POS_3_[NN CC NN]', -0.017480351295848257)
# (u'DDL_e1_W_RIGHT_POS_3_[JJ NN CC]', -0.017480351295848257)
# (u'DDL_e1_W_POS_L_2_R_2_[CC NN]_[JJ NN]', -0.017480351295848257)
# (u'DDL_e1_W_POS_L_2_R_3_[CC NN]_[JJ NN CC]', -0.017480351295848257)
# (u'STR_e1_HTML_ATTR_style=padding-top: 5pt;padding-left: 8pt;text-indent: 0pt;text-align: justify;', -0.017480351295848257)
# (u'DDL_e1_W_POS_L_1_R_1_[CD]_[CD]', -0.01733059469444025)
# (u'DDL_e1_W_POS_L_2_R_1_[: CD]_[CD]', -0.01733059469444025)
# (u'STR_e1_HTML_ATTR_style=display: inline;', -0.017144491513581068)
# (u'STR_e1_PARENT_TAG_li', -0.017144491513581068)
# (u'STR_e1_ANCESTOR_ID_[None None l1 None None]', -0.017144491513581068)
# (u'VIZ_e1_ALIGNED_LEFT_for', -0.017144491513581068)
# (u'VIZ_e1_ALIGNED_suitable', -0.017144491513581068)
# (u'STR_e1_ANCESTOR_CLASS_[None None None None None]', -0.017144491513581068)
# (u'VIZ_e1_ALIGNED_LEFT_suitable', -0.017144491513581068)
# (u'STR_e1_ANCESTOR_TAG_[html body ul li p]', -0.017144491513581068)
# (u'VIZ_e1_ALIGNED_for', -0.017144491513581068)
# (u'DDL_e1_W_POS_L_1_R_1_[:]_[:]', 0.017075178244214027)
# (u'DDL_e1_W_POS_L_2_R_1_[NN :]_[:]', 0.017075178244214027)
# (u'STR_e1_ANCESTOR_ID_[None None None None]', -0.01699740358818572)
# (u'DDL_e1_W_RIGHT_POS_2_[: NN]', 0.016982245812906877)
# (u'TAB_e1_COL_NUM_[1]', -0.016293038233597512)
# (u'DDL_e1_WORD_SEQ_[BC856/857/858]', -0.016007929458311643)
# (u'DDL_e1_LEMMA_SEQ_[bc856/857/858]', -0.016007929458311643)
# (u'STR_e1_TAG_a', -0.01577093566648107)
# (u'STR_e1_ANCESTOR_TAG_[html body h1 a]', -0.01577093566648107)
# (u'STR_e1_ANCESTOR_CLASS_[None None None None]', -0.01577093566648107)
# (u'STR_e1_PARENT_TAG_h1', -0.01577093566648107)
# (u'STR_e1_HTML_ATTR_name=bookmark0', -0.01577093566648107)
# (u'TAB_e1_COL_WORDS_[emitter-base]', -0.01565099827381372)
# (u'TAB_e1_COL_WORDS_[dissipation]', -0.01565099827381372)
# (u'TAB_e1_COL_WORDS_[bc858/859]', -0.01565099827381372)
# (u'TAB_e1_COL_WORDS_[power]', -0.01565099827381372)
# (u'TAB_e1_COL_WORDS_[collector-emitter voltage]', -0.01565099827381372)
# (u'TAB_e1_COL_WORDS_[storage temperature]', -0.01565099827381372)
# (u'TAB_e1_COL_WORDS_[temperature]', -0.01565099827381372)
# (u'TAB_e1_COL_WORDS_[power dissipation]', -0.01565099827381372)
# (u'TAB_e1_COL_WORDS_[)]', -0.01565099827381372)
# (u'TAB_e1_COL_WORDS_[collector current]', -0.01565099827381372)
# (u'TAB_e1_COL_WORDS_[emitter-base voltage]', -0.01565099827381372)
# (u'TAB_e1_COL_WORDS_[junction]', -0.01565099827381372)
# (u'TAB_e1_COL_WORDS_[collector power]', -0.01565099827381372)
# (u'TAB_e1_COL_WORDS_[: bc858/859]', -0.01565099827381372)
# (u'TAB_e1_COL_WORDS_[(]', -0.01565099827381372)
# (u'TAB_e1_COL_WORDS_[current (]', -0.01565099827381372)
# (u'TAB_e1_COL_WORDS_[: bc856]', -0.01565099827381372)
# (u'TAB_e1_COL_WORDS_[: bc857/860]', -0.01565099827381372)
# (u'TAB_e1_COL_WORDS_[bc856]', -0.01565099827381372)
# (u'TAB_e1_COL_WORDS_[( dc]', -0.01565099827381372)
# (u'TAB_e1_COL_WORDS_[bc857/860]', -0.01565099827381372)
# (u'TAB_e1_COL_WORDS_[junction temperature]', -0.01565099827381372)
# (u'TAB_e1_COL_WORDS_[collector-base]', -0.01565099827381372)
# (u'TAB_e1_COL_WORDS_[storage]', -0.01565099827381372)
# (u'TAB_e1_COL_WORDS_[collector-base voltage]', -0.01565099827381372)
# (u'TAB_e1_COL_WORDS_[dc )]', -0.01565099827381372)
# (u'DDL_e1_LEMMA_SEQ_[bc817k / bc818k]', -0.015642743084243276)
# (u'DDL_e1_WORD_SEQ_[BC817K / BC818K]', -0.015642743084243276)
# (u'DDL_e1_POS_SEQ_[CD : CD]', -0.015642743084243276)
# (u'DDL_e1_DEP_SEQ_[ROOT punct nummod]', -0.015642743084243276)
# (u'DDL_e1_W_LEFT_1_[mmbt3904]', 0.015470464116504892)
# (u'DDL_e1_DEP_SEQ_[ROOT]', 0.015331075817835467)
# (u'STR_e2_NODE_POS_4', 0.015184148089920533)
# (u'DDL_e1_LEMMA_SEQ_[bc818k]', -0.014903115712677889)
# (u'DDL_e1_WORD_SEQ_[BC818K]', -0.014903115712677889)
# (u'TAB_e1_ROW_HEAD_WORDS_[v]', -0.014870071194605119)
# (u'TDL_LEMMA:SEQ-BETWEEN[859/860]', -0.014626838004093791)
# (u'TDL_LEMMA:RIGHT-OF-MENTION[/]', -0.014478884579858698)
# (u'DDL_e1_W_LEFT_3_[Epitaxial Silicon Transistor]', -0.014478884579858698)
# (u'DDL_e1_W_LEFT_2_[Silicon Transistor]', -0.014478884579858698)
# (u'DDL_e1_W_LEFT_1_[Transistor]', -0.014478884579858698)
# (u'DDL_e1_W_RIGHT_POS_3_[: NN :]', 0.01441292732034133)
# (u'TDL_LEMMA:LEFT-OF-MENTION[/]', 0.014281507929570019)
# (u'STR_LOWEST_ANCESTOR_DEPTH_[2]', -0.01423110184318689)
# (u'STR_COMMON_ANCESTOR_[ html]', -0.01423110184318689)
# (u'DDL_e2_W_RIGHT_POS_2_[NNP NNP]', -0.01403002385516756)
# (u'DDL_e1_W_LEFT_POS_1_[:]', -0.014005096985165963)
# (u'VIZ_e1_ALIGNED_number', 0.01356473716511618)
# (u'DDL_e1_W_RIGHT_2_[/ 859/860]', -0.01355768711997644)
# (u'VIZ_e1_ALIGNED_CENTER_parameter', -0.013529605466795007)
# (u'VIZ_e1_ALIGNED_parameter', -0.013529605466795007)
# (u'DDL_e2_W_LEFT_POS_2_[NNP NNP]', 0.013527067337564935)
# (u'DDL_e2_W_POS_L_1_R_1_[NNP]_[NNP]', 0.013527067337564935)
# (u'DDL_e2_W_LEFT_POS_1_[NNP]', 0.013527067337564935)
# (u'DDL_e2_W_POS_L_2_R_1_[NNP NNP]_[NNP]', 0.013527067337564935)
# (u'DDL_e1_LEMMA_SEQ_[bc856/857/858 /]', -0.013410866396388207)
# (u'DDL_e1_WORD_SEQ_[BC856/857/858 /]', -0.013410866396388207)
# (u'DDL_e1_W_RIGHT_1_[859/860]', -0.013410866396388207)
# (u'DDL_e1_W_LEFT_POS_2_[NN NN]', 0.01329865659278849)
# (u'DDL_e1_W_LEFT_2_[2n3904 mmbt3904]', 0.013191433666383359)
# (u'TAB_e1_ROW_WORDS_[reel]', 0.013153480972680192)
# (u'TAB_e1_ROW_WORDS_[tape]', 0.013153480972680192)
# (u'STR_e1_HTML_ATTR_style=padding-top: 3pt;text-indent: 0pt;text-align: right;', -0.012987086407218346)
# (u'STR_e1_NODE_POS_55', -0.012987086407218346)
# (u'TDL_DEP_LABEL:BETWEEN-MENTION-and-MENTION[dep]', 0.012797682781962071)
# (u'STR_e1_HTML_ATTR_style=padding-top: 3pt;padding-left: 5pt;text-indent: 0pt;text-align: left;', -0.012722881899471458)
# (u'STR_e1_NEXT_SIB_TAG_style', -0.012617880762677154)
# (u'TAB_e1_COL_HEAD_WORDS_[part number]', 0.012458252822575127)
# (u'TAB_e1_COL_WORDS_[part number]', 0.012458252822575127)
# (u'TAB_e1_COL_WORDS_[part]', 0.012458252822575127)
# (u'TAB_e1_COL_WORDS_[number]', 0.012458252822575127)
# (u'TAB_e1_COL_HEAD_WORDS_[number]', 0.012458252822575127)
# (u'TAB_e1_COL_HEAD_WORDS_[part]', 0.012458252822575127)
# (u'STR_e1_NODE_POS_8', 0.012448061180951629)
# (u'DDL_e1_LEMMA_SEQ_[bc817k]', -0.012417205650619734)
# (u'DDL_e1_WORD_SEQ_[BC817K]', -0.012417205650619734)
# (u'DDL_e1_DEP_SEQ_[compound]', -0.012075503103628874)
# (u'DDL_e2_POS_SEQ_[NNP]', 0.012052009564715152)
# (u'VIZ_e1_ALIGNED_CENTER_mhz', -0.011944591467052375)
# (u'VIZ_e1_ALIGNED_mhz', -0.011944591467052375)
# (u'VIZ_e2_PAGE_[2]', 0.01189644251279316)
# (u'TAB_e1_COL_WORDS_[collector cut-off]', -0.011627049985390705)
# (u'TAB_e1_COL_WORDS_[current gain]', -0.011627049985390705)
# (u'TAB_e1_COL_WORDS_[noise]', -0.011627049985390705)
# (u'TAB_e1_COL_WORDS_[output capacitance]', -0.011627049985390705)
# (u'TAB_e1_COL_WORDS_[on]', -0.011627049985390705)
# (u'TAB_e1_COL_WORDS_[on voltage]', -0.011627049985390705)
# (u'TAB_e1_COL_WORDS_[base-emitter]', -0.011627049985390705)
# (u'TAB_e1_COL_WORDS_[collector-emitter saturation]', -0.011627049985390705)
# (u'TAB_e1_COL_WORDS_[product]', -0.011627049985390705)
# (u'TAB_e1_COL_WORDS_[bandwidth]', -0.011627049985390705)
# (u'TAB_e1_ROW_WORDS_[db]', -0.011627049985390705)
# (u'TAB_e1_COL_WORDS_[dc current]', -0.011627049985390705)
# (u'TAB_e1_COL_WORDS_[gain]', -0.011627049985390705)
# (u'TAB_e1_COL_WORDS_[output]', -0.011627049985390705)
# (u'TAB_e1_COL_WORDS_[bandwidth product]', -0.011627049985390705)
# (u'TAB_e1_COL_WORDS_[capacitance]', -0.011627049985390705)
# (u'TAB_e1_ROW_WORDS_[=]', -0.011627049985390705)
# (u'TAB_e1_COL_WORDS_[saturation]', -0.011627049985390705)
# (u'TAB_e1_COL_WORDS_[base-emitter saturation]', -0.011627049985390705)
# (u'TAB_e1_COL_WORDS_[base-emitter on]', -0.011627049985390705)
# (u'TAB_e1_COL_WORDS_[cut-off]', -0.011627049985390705)
# (u'TAB_e1_ROW_WORDS_[,]', -0.011627049985390705)
# (u'TAB_e1_COL_WORDS_[saturation voltage]', -0.011627049985390705)
# (u'TAB_e1_ROW_HEAD_WORDS_[=]', -0.011627049985390705)
# (u'TAB_e1_COL_WORDS_[gain bandwidth]', -0.011627049985390705)
# (u'TAB_e1_ROW_HEAD_WORDS_[,]', -0.011627049985390705)
# (u'TAB_e1_COL_WORDS_[cut-off current]', -0.011627049985390705)
# (u'STR_e1_NODE_POS_5', -0.011624161239052749)
# (u'STR_e1_HTML_ATTR_style=padding-top: 8pt;padding-left: 153pt;text-indent: 0pt;text-align: left;', -0.011624161239052749)
# (u'VIZ_e1_ALIGNED_LEFT_t', -0.0113799189481513)
# (u'VIZ_e1_ALIGNED_t', -0.0113799189481513)
# (u'STR_e1_NODE_POS_24', -0.0113799189481513)
# (u'DDL_e2_DEP_SEQ_[compound]', 0.011099056960248864)
# (u'STR_e1_ANCESTOR_CLASS_[None None s1]', 0.01109335762170965)
# (u'STR_e1_HTML_ATTR_style=padding-left: 6pt;text-indent: 0pt;line-height: 22pt;text-align: left;', 0.01109335762170965)
# (u'STR_e1_HTML_ATTR_class=s1', 0.01109335762170965)
# (u'TAB_e1_ROW_WORDS_[tape and]', 0.011026301447148017)
# (u'TAB_e1_ROW_WORDS_[and]', 0.011026301447148017)
# (u'TAB_e1_ROW_WORDS_[and reel]', 0.011026301447148017)
# (u'TAB_e1_COL_HEAD_WORDS_[marking]', 0.01098501002560612)
# (u'TAB_e1_COL_WORDS_[1a]', 0.01098501002560612)
# (u'TAB_e1_COL_WORDS_[2n3904]', 0.01098501002560612)
# (u'STR_e1_HTML_ATTR_style=padding-top: 1pt;padding-left: 30pt;text-indent: 0pt;text-align: left;', 0.01098501002560612)
# (u'TAB_e1_COL_WORDS_[3904]', 0.01098501002560612)
# (u'TAB_e1_COL_WORDS_[marking]', 0.01098501002560612)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[=]', -0.01086007578975399)
# (u'TAB_e1_COL_WORDS_[2n3904tf]', 0.010766887029666392)
# (u'TAB_e1_COL_WORDS_[2n3904tfr]', 0.010734810142274048)
# (u'DDL_e1_W_LEFT_2_[mmbt3904 /]', 0.010692204176702675)
# (u'DDL_e1_W_LEFT_3_[/ mmbt3904 /]', 0.010692204176702675)
# (u'TAB_e1_COL_WORDS_[: bc859]', -0.010637893031812808)
# (u'TAB_e1_COL_WORDS_[bc859]', -0.010637893031812808)
# (u'TAB_e1_COL_WORDS_[bc860]', -0.010556849902823622)
# (u'TAB_e1_COL_WORDS_[: bc860]', -0.010556849902823622)
# (u'TAB_e1_COL_WORDS_[2n3904ta]', 0.010451686014307236)
# (u'TAB_e1_ROW_WORDS_[-30]', -0.010433743871621801)
# (u'TAB_e1_COL_WORDS_[2n3904tar]', 0.010422337702367715)
# (u'DDL_e1_POS_SEQ_[: NN]', -0.010408328464487507)
# (u'TAB_e1_COL_WORDS_[2n3904bu]', 0.010359362468188466)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[or 6cr]', -0.010347699539913106)
# (u'TDL_INV_LEMMA:RIGHT-OF-MENTION[=]', -0.010347699539913106)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[or]', -0.010347699539913106)
# (u'TDL_INV_LEMMA:LEFT-OF-MENTION[=]', -0.010347699539913106)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[6cr]', -0.010347699539913106)
# (u'STR_e1_NEXT_SIB_TAG_h1', 0.010316871878839637)
# (u'STR_e1_HTML_ATTR_style=padding-top: 2pt;padding-left: 23pt;text-indent: 0pt;text-align: left;', 0.010316871878839637)
# (u'TAB_e1_COL_WORDS_[mmbt3904]', 0.010179222372453625)
# (u'VIZ_e1_ALIGNED_part', 0.010179222372453625)
# (u'VIZ_e1_ALIGNED_CENTER_number', 0.010179222372453625)
# (u'VIZ_e1_ALIGNED_CENTER_part', 0.010179222372453625)
# (u'VIZ_VERT_ALIGNED', 0.010155447077145793)
# (u'TDL_INV_SEQ-BETWEEN[LEN:0-4]', -0.010106230853188873)
# (u'DDL_e1_DEP_SEQ_[ROOT punct]', -0.010073534407007633)
# (u'DDL_e1_DEP_SEQ_[nummod]', -0.010035113504923969)
# (u'DDL_e1_W_LEFT_POS_3_[CD CD :]', -0.010035113504923969)
# (u'DDL_e1_W_LEFT_2_[bc817k /]', -0.010035113504923969)
# (u'DDL_e1_W_LEFT_3_[bc818k bc817k /]', -0.010035113504923969)
# (u'DDL_e1_W_LEFT_POS_2_[CD :]', -0.010035113504923969)
# (u'TAB_e1_COL_WORDS_[pzt3904]', 0.009836211372444522)
# (u'TDL_INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|bc817k]', -0.009402927330279639)
# (u'TDL_INV_LEMMA:BETWEEN-MENTION-and-MENTION[bc817k]', -0.009402927330279639)
# (u'DDL_e1_W_LEMMA_L_2_R_1_[2n3904 /]_[/]', 0.009379307322531354)
# (u'DDL_e1_W_POS_L_2_R_2_[NN :]_[: NN]', 0.009379307322531354)
# (u'DDL_e1_W_LEFT_2_[2n3904 /]', 0.009379307322531354)
# (u'DDL_e1_W_LEMMA_L_1_R_1_[/]_[/]', 0.009379307322531354)
# (u'DDL_e1_W_LEMMA_L_2_R_2_[2n3904 /]_[/ pzt3904]', 0.009379307322531354)
# (u'DDL_e1_W_RIGHT_2_[/ pzt3904]', 0.009379307322531354)
# (u'DDL_e1_W_LEMMA_L_1_R_2_[/]_[/ pzt3904]', 0.009379307322531354)
# (u'DDL_e1_W_POS_L_1_R_2_[:]_[: NN]', 0.009379307322531354)
# (u'TDL_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[dep|mmbt3904]', 0.009298999025482778)
# (u'TDL_LEMMA:BETWEEN-MENTION-and-MENTION[mmbt3904]', 0.009298999025482778)
# (u'STR_e2_NODE_POS_33', 0.009145009233443338)
# (u'TAB_e1_COL_WORDS_[figure]', -0.009080838544891574)
# (u'TAB_e1_COL_WORDS_[noise figure]', -0.009080838544891574)
# (u'DDL_e1_W_LEFT_3_[Amplifier 2n3904 mmbt3904]', 0.00906530410789919)
# (u'DDL_e1_W_LEFT_POS_3_[NNP NN NN]', 0.00906530410789919)
# (u'DDL_e1_W_LEMMA_L_3_R_1_[bc856/857/858 / 859/860]_[859/860]', -0.008890047466157168)
# (u'DDL_e1_W_LEMMA_L_1_R_1_[859/860]_[859/860]', -0.008890047466157168)
# (u'DDL_e1_W_POS_L_3_R_1_[NN : CD]_[CD]', -0.008890047466157168)
# (u'DDL_e1_W_LEMMA_L_2_R_1_[/ 859/860]_[859/860]', -0.008890047466157168)
# (u'DDL_e1_W_LEMMA_L_3_R_2_[bc856/857/858 / 859/860]_[/ 859/860]', -0.008883760436055682)
# (u'DDL_e1_W_LEMMA_L_3_R_1_[bc856/857/858 / 859/860]_[/]', -0.008883760436055682)
# (u'DDL_e1_W_LEMMA_L_1_R_1_[859/860]_[/]', -0.008883760436055682)
# (u'DDL_e1_W_LEMMA_L_2_R_1_[/ 859/860]_[/]', -0.008883760436055682)
# (u'DDL_e1_W_POS_L_3_R_1_[NN : CD]_[:]', -0.008883760436055682)
# (u'DDL_e1_W_LEMMA_L_2_R_2_[/ 859/860]_[/ 859/860]', -0.008883760436055682)
# (u'DDL_e1_W_LEMMA_L_1_R_2_[859/860]_[/ 859/860]', -0.008883760436055682)
# (u'DDL_e1_W_POS_L_3_R_2_[NN : CD]_[: CD]', -0.008883760436055682)
# (u'CORE_e1_LENGTH_1', 0.008854320285369838)
# (u'DDL_e1_POS_SEQ_[NN :]', -0.00882775799048191)
# (u'DDL_e1_W_RIGHT_POS_3_[: NNP NNP]', 0.00867052998533829)
# (u'DDL_e1_W_RIGHT_POS_2_[: NNP]', 0.00867052998533829)
# (u'DDL_e2_W_POS_L_3_R_2_[NNP NNP NNP]_[NNP NNP]', -0.008616733719301843)
# (u'DDL_e2_W_POS_L_1_R_2_[NNP]_[NNP NNP]', -0.008616733719301843)
# (u'DDL_e2_W_POS_L_2_R_2_[NNP NNP]_[NNP NNP]', -0.008616733719301843)
# (u'DDL_e2_W_LEFT_POS_3_[NNP NNP NNP]', -0.008616733719301843)
# (u'DDL_e2_W_POS_L_3_R_1_[NNP NNP NNP]_[NNP]', -0.008616733719301843)
# (u'STR_e1_NODE_POS_33', 0.00850696517200139)
# (u'DDL_e1_W_LEFT_2_[, bc182b]', 0.008467147733761794)
# (u'DDL_e1_W_LEFT_3_[bc182 , bc182b]', 0.008467147733761794)
# (u'DDL_e1_W_LEFT_POS_3_[NN , NN]', 0.008467147733761794)
# (u'DDL_e1_W_LEFT_POS_2_[, NN]', 0.008467147733761794)
# (u'DDL_e1_W_LEFT_1_[bc182b]', 0.008467147733761794)
# (u'DDL_e2_W_RIGHT_POS_1_[NNP]', 0.008261673379165592)
# (u'VIZ_e1_ALIGNED_low', -0.008233558232848444)
# (u'VIZ_e1_ALIGNED_noise', -0.008233558232848444)
# (u'VIZ_e1_ALIGNED_LEFT_low', -0.008233558232848444)
# (u'VIZ_e1_ALIGNED_LEFT_noise', -0.008233558232848444)
# (u'DDL_e1_W_LEFT_1_[pzt3904]', 0.008108544444986612)
# (u'TAB_e1_ROW_NUM_[0]', -0.007923707868905087)
# (u'TAB_e1_COL_WORDS_[v]', -0.007923707868905087)
# (u'STR_e1_HTML_ATTR_class=s8', -0.007923707868905087)
# (u'STR_e1_ANCESTOR_CLASS_[None None None None None s8]', -0.007923707868905087)
# (u'DDL_e1_DEP_SEQ_[punct ROOT]', -0.007879409755486429)
# (u'TDL_INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|2n3904]', 0.007868408991387644)
# (u'TDL_INV_LEMMA:BETWEEN-MENTION-and-MENTION[2n3904]', 0.007868408991387644)
# (u'DDL_e1_W_RIGHT_POS_1_[NN]', 0.007846343207442614)
# (u'STR_e1_NODE_POS_72', -0.007832217659566513)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[mmbt3904]', 0.00783182171702355)
# (u'STR_e1_NODE_POS_73', -0.007649133802532411)
# (u'DDL_e1_POS_SEQ_[NN : NN]', -0.007596200641731109)
# (u'VIZ_VERT_ALIGNED_LEFT', 0.007588650507851469)
# (u'TAB_e1_COL_WORDS_[bc859/860]', -0.007585729690231629)
# (u'VIZ_e1_ALIGNED_collector', -0.007585729690231629)
# (u'TAB_e1_COL_WORDS_[: bc859/860]', -0.007585729690231629)
# (u'VIZ_e1_ALIGNED_current', -0.007585729690231629)
# (u'TDL_LEMMA:BETWEEN-MENTION-and-MENTION[pzt3904]', 0.007583190150867845)
# (u'TDL_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|pzt3904]', 0.007583190150867845)
# (u'TAB_e1_ROW_WORDS_[2n3904]', 0.007557180922322782)
# (u'TAB_e1_ROW_WORDS_[ammo]', 0.007555037261623318)
# (u'DDL_e1_W_LEMMA_L_2_R_1_[/ bc818k]_[/]', -0.00736250015571716)
# (u'DDL_e1_W_POS_L_3_R_2_[CD : CD]_[: CD]', -0.00736250015571716)
# (u'DDL_e1_W_LEMMA_L_2_R_2_[/ bc818k]_[/ bc818k]', -0.00736250015571716)
# (u'DDL_e1_W_RIGHT_2_[/ bc818k]', -0.00736250015571716)
# (u'DDL_e1_W_LEMMA_L_1_R_2_[bc818k]_[/ bc818k]', -0.00736250015571716)
# (u'DDL_e1_W_LEMMA_L_1_R_1_[bc818k]_[/]', -0.00736250015571716)
# (u'DDL_e1_W_LEMMA_L_3_R_2_[bc817k / bc818k]_[/ bc818k]', -0.00736250015571716)
# (u'DDL_e1_W_POS_L_3_R_1_[CD : CD]_[:]', -0.00736250015571716)
# (u'DDL_e1_W_LEMMA_L_3_R_1_[bc817k / bc818k]_[/]', -0.00736250015571716)
# (u'TDL_LEMMA:SEQ-BETWEEN[pzt3904]', 0.00729017232767093)
# (u'STR_e1_HTML_ATTR_style=padding-top: 3pt;padding-left: 98pt;text-indent: 0pt;text-align: left;', 0.007233558060330883)
# (u'STR_e1_NODE_POS_15', 0.007233558060330883)
# (u'TDL_LEMMA:SEQ-BETWEEN[mmbt3904]', 0.007219778496415826)
# (u'TAB_e1_ROW_WORDS_[bulk]', 0.007218137111495474)
# (u'DDL_e1_W_RIGHT_2_[/ mmbt3904]', 0.007207934352884132)
# (u'DDL_e1_W_RIGHT_3_[/ mmbt3904 /]', 0.007207934352884132)
# (u'TDL_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[dep|Amplifier]', 0.007121939406756524)
# (u'TDL_LEMMA:RIGHT-OF-MENTION[General-Purpose]', 0.007121939406756524)
# (u'TDL_LEMMA:BETWEEN-MENTION-and-MENTION[Amplifier]', 0.007121939406756524)
# (u'TDL_SEQ-BETWEEN[LEN:0-4]', 0.006953249998588946)
# (u'STR_e2_TAG_p', 0.006796204858530323)
# (u'TDL_LEMMA:LEFT-OF-MENTION[859/860]', -0.006786195114700071)
# (u'TDL_LEMMA:RIGHT-OF-MENTION[Epitaxial]', -0.006786195114700071)
# (u'TDL_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|Transistor]', -0.006786195114700071)
# (u'TDL_LEMMA:BETWEEN-MENTION-and-MENTION[Transistor]', -0.006786195114700071)
# (u'DDL_e1_W_LEFT_3_[NPN General-Purpose Amplifier]', 0.006764605416422493)
# (u'DDL_e1_W_LEFT_2_[General-Purpose Amplifier]', 0.006764605416422493)
# (u'DDL_e1_W_LEFT_1_[Amplifier]', 0.006764605416422493)
# (u'DDL_e1_W_LEFT_POS_1_[TO]', -0.006653984897489172)
# (u'DDL_e1_W_LEFT_POS_3_[NN NN TO]', -0.006653984897489172)
# (u'DDL_e1_W_LEFT_POS_2_[NN TO]', -0.006653984897489172)
# (u'DDL_e1_W_LEFT_2_[complement to]', -0.006653984897489172)
# (u'DDL_e1_W_LEFT_3_[bc850 complement to]', -0.006653984897489172)
# (u'DDL_e1_W_LEFT_1_[to]', -0.006653984897489172)
# (u'TAB_e1_ROW_WORDS_[2]', -0.006596572736653228)
# (u'DDL_e1_W_POS_L_1_R_1_[NN]_[NN]', 0.0065725169166785564)
# (u'TAB_e1_COL_WORDS_[figure :]', -0.006551919835889472)
# (u'TAB_e1_ROW_WORDS_[v ,]', -0.006515529607663944)
# (u'TAB_e1_ROW_WORDS_[a]', -0.006515529607663944)
# (u'TAB_e1_ROW_HEAD_WORDS_[a]', -0.006515529607663944)
# (u'TAB_e1_ROW_WORDS_[c]', -0.006515529607663944)
# (u'TAB_e1_ROW_WORDS_[, i]', -0.006515529607663944)
# (u'TAB_e1_ROW_HEAD_WORDS_[, i]', -0.006515529607663944)
# (u'TAB_e1_ROW_WORDS_[= -200]', -0.006515529607663944)
# (u'TAB_e1_ROW_HEAD_WORDS_[c]', -0.006515529607663944)
# (u'TAB_e1_ROW_WORDS_[-200]', -0.006515529607663944)
# (u'TAB_e1_ROW_HEAD_WORDS_[-5 v]', -0.006515529607663944)
# (u'TAB_e1_ROW_WORDS_[-5]', -0.006515529607663944)
# (u'TAB_e1_ROW_WORDS_[i]', -0.006515529607663944)
# (u'TAB_e1_ROW_HEAD_WORDS_[v ,]', -0.006515529607663944)
# (u'TAB_e1_ROW_WORDS_[ce]', -0.006515529607663944)
# (u'TAB_e1_ROW_HEAD_WORDS_[= -5]', -0.006515529607663944)
# (u'TAB_e1_ROW_HEAD_WORDS_[= -200]', -0.006515529607663944)
# (u'TAB_e1_ROW_WORDS_[-5 v]', -0.006515529607663944)
# (u'TAB_e1_ROW_HEAD_WORDS_[i]', -0.006515529607663944)
# (u'TAB_e1_ROW_HEAD_WORDS_[-200]', -0.006515529607663944)
# (u'TAB_e1_ROW_WORDS_[= -5]', -0.006515529607663944)
# (u'TAB_e1_ROW_HEAD_WORDS_[ce]', -0.006515529607663944)
# (u'TAB_e1_ROW_HEAD_WORDS_[-5]', -0.006515529607663944)
# (u'DDL_e1_W_LEMMA_L_3_R_1_[bc817k / bc818k]_[bc818k]', -0.006441547394534913)
# (u'DDL_e1_POS_SEQ_[CD :]', -0.006441547394534913)
# (u'DDL_e1_LEMMA_SEQ_[bc817k /]', -0.006441547394534913)
# (u'DDL_e1_W_LEMMA_L_2_R_1_[/ bc818k]_[bc818k]', -0.006441547394534913)
# (u'DDL_e1_WORD_SEQ_[BC817K /]', -0.006441547394534913)
# (u'DDL_e1_W_POS_L_3_R_1_[CD : CD]_[CD]', -0.006441547394534913)
# (u'DDL_e1_W_LEMMA_L_1_R_1_[bc818k]_[bc818k]', -0.006441547394534913)
# (u'DDL_e1_W_RIGHT_1_[bc818k]', -0.006441547394534913)
# (u'TAB_e1_ROW_WORDS_[collector-emitter]', -0.006355541753189467)
# (u'TAB_e1_ROW_WORDS_[-45]', -0.006355541753189467)
# (u'TAB_e1_ROW_WORDS_[voltage]', -0.006355541753189467)
# (u'TAB_e1_CELL_WORDS_[collector-emitter voltage]', -0.006355541753189467)
# (u'TAB_e1_CELL_WORDS_[collector-emitter]', -0.006355541753189467)
# (u'TAB_e1_ROW_WORDS_[collector-emitter voltage]', -0.006355541753189467)
# (u'TAB_e1_ROW_WORDS_[ceo]', -0.006355541753189467)
# (u'TAB_e1_ROW_HEAD_WORDS_[ceo]', -0.006355541753189467)
# (u'TAB_e1_CELL_WORDS_[voltage]', -0.006355541753189467)
# (u'TAB_e1_ROW_WORDS_[v v]', -0.006355541753189467)
# (u'TAB_e1_ROW_WORDS_[-65]', -0.006355541753189467)
# (u'TDL_LEMMA:SEQ-BETWEEN[/ 859/860]', -0.006348895588047224)
# (u'TDL_LEMMA:RIGHT-OF-MENTION[--]', 0.00629374268560502)
# (u'TDL_LEMMA:LEFT-OF-MENTION[:]', -0.006183822291830753)
# (u'STR_e1_HTML_ATTR_style=text-indent: 0pt;line-height: 9pt;text-align: center;', -0.006176752987062506)
# (u'DDL_e1_W_POS_L_3_R_1_[NNP NN NN]_[NNP]', 0.006091645210494976)
# (u'DDL_e1_W_POS_L_1_R_2_[NN]_[NNP NNP]', 0.006091645210494976)
# (u'DDL_e1_W_POS_L_2_R_1_[NN NN]_[NNP]', 0.006091645210494976)
# (u'DDL_e1_W_POS_L_1_R_1_[NN]_[NNP]', 0.006091645210494976)
# (u'DDL_e1_W_POS_L_2_R_2_[NN NN]_[NNP NNP]', 0.006091645210494976)
# (u'DDL_e1_W_POS_L_3_R_2_[NNP NN NN]_[NNP NNP]', 0.006091645210494976)
# (u'DDL_e1_W_LEFT_1_[/]', 0.005776904500640583)
# (u'DDL_e1_W_LEFT_POS_2_[NNP NNP]', -0.005715279329684593)
# (u'DDL_e1_W_LEFT_POS_1_[NNP]', -0.005715279329684593)
# (u'DDL_e1_W_LEFT_POS_3_[NNP NNP NNP]', -0.005715279329684593)
# (u'DDL_e1_W_POS_L_3_R_1_[: NN :]_[:]', 0.005696871087933992)
# (u'DDL_e1_W_POS_L_1_R_2_[:]_[: NNP]', 0.005696871087933992)
# (u'DDL_e1_W_LEMMA_L_2_R_3_[mmbt3904 /]_[-- NPN General-Purpose]', 0.005696871087933992)
# (u'DDL_e1_W_LEMMA_L_2_R_2_[mmbt3904 /]_[-- NPN]', 0.005696871087933992)
# (u'DDL_e1_W_POS_L_1_R_3_[:]_[: NNP NNP]', 0.005696871087933992)
# (u'DDL_e1_W_LEMMA_L_3_R_2_[/ mmbt3904 /]_[-- NPN]', 0.005696871087933992)
# (u'DDL_e1_W_POS_L_2_R_2_[NN :]_[: NNP]', 0.005696871087933992)
# (u'DDL_e1_W_RIGHT_2_[-- NPN]', 0.005696871087933992)
# (u'DDL_e1_W_LEMMA_L_1_R_1_[/]_[--]', 0.005696871087933992)
# (u'DDL_e1_W_RIGHT_3_[-- NPN General-Purpose]', 0.005696871087933992)
# (u'DDL_e1_W_LEMMA_L_1_R_3_[/]_[-- NPN General-Purpose]', 0.005696871087933992)
# (u'DDL_e1_W_RIGHT_1_[--]', 0.005696871087933992)
# (u'DDL_e1_W_LEMMA_L_3_R_1_[/ mmbt3904 /]_[--]', 0.005696871087933992)
# (u'DDL_e1_W_LEMMA_L_3_R_3_[/ mmbt3904 /]_[-- NPN General-Purpose]', 0.005696871087933992)
# (u'DDL_e1_W_LEMMA_L_2_R_1_[mmbt3904 /]_[--]', 0.005696871087933992)
# (u'DDL_e1_W_POS_L_2_R_3_[NN :]_[: NNP NNP]', 0.005696871087933992)
# (u'DDL_e1_W_POS_L_3_R_3_[: NN :]_[: NNP NNP]', 0.005696871087933992)
# (u'DDL_e1_W_LEMMA_L_1_R_2_[/]_[-- NPN]', 0.005696871087933992)
# (u'DDL_e1_W_POS_L_3_R_2_[: NN :]_[: NNP]', 0.005696871087933992)
# (u'TDL_DEP_LABEL:BETWEEN-MENTION-and-MENTION[ROOT dep]', 0.00558179819792535)
# (u'VIZ_e1_ALIGNED_gain', -0.005526372654086112)
# (u'VIZ_e1_ALIGNED_CENTER_voltage', -0.005526372654086112)
# (u'VIZ_e1_ALIGNED_capacitance', -0.005526372654086112)
# (u'VIZ_e1_ALIGNED_bandwidth', -0.005526372654086112)
# (u'VIZ_e1_ALIGNED_LEFT_product', -0.005526372654086112)
# (u'VIZ_e1_ALIGNED_Y_nf', -0.005526372654086112)
# (u'VIZ_e1_ALIGNED_LEFT_dc', -0.005526372654086112)
# (u'VIZ_e1_ALIGNED_product', -0.005526372654086112)
# (u'VIZ_e1_ALIGNED_LEFT_voltage', -0.005526372654086112)
# (u'VIZ_e1_ALIGNED_dc', -0.005526372654086112)
# (u'VIZ_e1_ALIGNED_LEFT_saturation', -0.005526372654086112)
# (u'STR_e1_HTML_ATTR_style=padding-left: 4pt;text-indent: 0pt;text-align: left;', -0.005526372654086112)
# (u'VIZ_e1_ALIGNED_LEFT_capacitance', -0.005526372654086112)
# (u'VIZ_e1_ALIGNED_output', -0.005526372654086112)
# (u'TAB_e1_ROW_WORDS_[noise]', -0.005526372654086112)
# (u'VIZ_e1_ALIGNED_voltage', -0.005526372654086112)
# (u'VIZ_e1_ALIGNED_LEFT_current', -0.005526372654086112)
# (u'VIZ_e1_ALIGNED_LEFT_collector', -0.005526372654086112)
# (u'VIZ_e1_ALIGNED_LEFT_output', -0.005526372654086112)
# (u'VIZ_e1_ALIGNED_LEFT_bandwidth', -0.005526372654086112)
# (u'TAB_e1_ROW_WORDS_[10]', -0.005526372654086112)
# (u'VIZ_e1_ALIGNED_saturation', -0.005526372654086112)
# (u'VIZ_e1_ALIGNED_nf', -0.005526372654086112)
# (u'TAB_e1_CELL_WORDS_[noise]', -0.005526372654086112)
# (u'VIZ_e1_ALIGNED_on', -0.005526372654086112)
# (u'VIZ_e1_ALIGNED_LEFT_on', -0.005526372654086112)
# (u'VIZ_e1_ALIGNED_LEFT_gain', -0.005526372654086112)
# (u'TAB_e1_ROW_NUM_[9]', -0.005526372654086112)
# (u'VIZ_e1_ALIGNED_mark', 0.00547345485870734)
# (u'VIZ_e1_ALIGNED_CENTER_mark', 0.00547345485870734)
# (u'TDL_INV_LEMMA:RIGHT-OF-MENTION[:]', -0.005385616478438674)
# (u'TAB_e1_ROW_WORDS_[bc856]', -0.005353852645980798)
# (u'TAB_e1_ROW_WORDS_[: bc856]', -0.005353852645980798)
# (u'TAB_e1_CELL_WORDS_[bc856]', -0.005353852645980798)
# (u'TAB_e1_CELL_WORDS_[: bc856]', -0.005353852645980798)
# (u'STR_e1_HTML_ATTR_style=text-indent: 0pt;text-align: center;', -0.005353852645980798)
# (u'STR_e1_ANCESTOR_TAG_[html head title]', 0.005289986793182115)
# (u'STR_e1_PARENT_TAG_head', 0.005289986793182115)
# (u'STR_e1_PREV_SIB_TAG_meta', 0.005289986793182115)
# (u'STR_e1_TAG_title', 0.005289986793182115)
# (u'DDL_e1_W_LEMMA_L_3_R_2_[Epitaxial Silicon Transistor]_[PNP Epitaxial]', -0.00528413896570587)
# (u'DDL_e1_W_POS_L_1_R_3_[NNP]_[NNP NNP NNP]', -0.00528413896570587)
# (u'DDL_e1_W_LEMMA_L_2_R_2_[Silicon Transistor]_[PNP Epitaxial]', -0.00528413896570587)
# (u'DDL_e1_W_LEMMA_L_1_R_2_[Transistor]_[PNP Epitaxial]', -0.00528413896570587)
# (u'DDL_e1_W_POS_L_3_R_2_[NNP NNP NNP]_[NNP NNP]', -0.00528413896570587)
# (u'DDL_e1_W_LEMMA_L_1_R_3_[Transistor]_[PNP Epitaxial Silicon]', -0.00528413896570587)
# (u'DDL_e1_W_POS_L_2_R_3_[NNP NNP]_[NNP NNP NNP]', -0.00528413896570587)
# (u'DDL_e1_W_LEMMA_L_2_R_3_[Silicon Transistor]_[PNP Epitaxial Silicon]', -0.00528413896570587)
# (u'DDL_e1_W_POS_L_1_R_1_[NNP]_[NNP]', -0.00528413896570587)
# (u'DDL_e1_W_RIGHT_3_[PNP Epitaxial Silicon]', -0.00528413896570587)
# (u'DDL_e1_DEP_SEQ_[compound punct nummod]', -0.00528413896570587)
# (u'DDL_e1_W_LEMMA_L_3_R_1_[Epitaxial Silicon Transistor]_[PNP]', -0.00528413896570587)
# (u'DDL_e1_W_POS_L_3_R_1_[NNP NNP NNP]_[NNP]', -0.00528413896570587)
# (u'DDL_e1_W_POS_L_2_R_1_[NNP NNP]_[NNP]', -0.00528413896570587)
# (u'DDL_e1_W_POS_L_2_R_2_[NNP NNP]_[NNP NNP]', -0.00528413896570587)
# (u'DDL_e1_W_POS_L_3_R_3_[NNP NNP NNP]_[NNP NNP NNP]', -0.00528413896570587)
# (u'DDL_e1_W_POS_L_1_R_2_[NNP]_[NNP NNP]', -0.00528413896570587)
# (u'DDL_e1_W_RIGHT_2_[PNP Epitaxial]', -0.00528413896570587)
# (u'DDL_e1_W_LEMMA_L_3_R_3_[Epitaxial Silicon Transistor]_[PNP Epitaxial Silicon]', -0.00528413896570587)
# (u'DDL_e1_W_LEMMA_L_2_R_1_[Silicon Transistor]_[PNP]', -0.00528413896570587)
# (u'DDL_e1_W_LEMMA_L_1_R_1_[Transistor]_[PNP]', -0.00528413896570587)
# (u'DDL_e1_W_RIGHT_1_[PNP]', -0.00528413896570587)
# (u'STR_e1_ANCESTOR_ID_[None None None None None None]', -0.005276100948560363)
# (u'TAB_e1_COL_SPAN_[1]', -0.005276100948560363)
# (u'TAB_e1_ROW_SPAN_[1]', -0.005276100948560363)
# (u'STR_e1_ANCESTOR_TAG_[html body table tr td p]', -0.005276100948560363)
# (u'STR_e1_PARENT_TAG_td', -0.005276100948560363)
# (u'TDL_LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[2n3904]', 0.005216884750285188)
# (u'TDL_LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[None 2n3904]', 0.005216884750285188)
# (u'DDL_e1_W_POS_L_3_R_2_[NNP NN :]_[: NN]', 0.005205993133705621)
# (u'DDL_e1_W_LEMMA_L_2_R_3_[2n3904 /]_[/ pzt3904 --]', 0.005205993133705621)
# (u'DDL_e1_W_LEMMA_L_1_R_3_[/]_[/ pzt3904 --]', 0.005205993133705621)
# (u'DDL_e1_W_POS_L_2_R_3_[NN :]_[: NN :]', 0.005205993133705621)
# (u'DDL_e1_W_LEMMA_L_3_R_1_[Amplifier 2n3904 /]_[/]', 0.005205993133705621)
# (u'DDL_e1_W_POS_L_3_R_3_[NNP NN :]_[: NN :]', 0.005205993133705621)
# (u'DDL_e1_W_RIGHT_3_[/ pzt3904 --]', 0.005205993133705621)
# (u'DDL_e1_W_LEMMA_L_3_R_2_[Amplifier 2n3904 /]_[/ pzt3904]', 0.005205993133705621)
# (u'DDL_e1_W_LEFT_POS_3_[NNP NN :]', 0.005205993133705621)
# (u'DDL_e1_W_POS_L_3_R_1_[NNP NN :]_[:]', 0.005205993133705621)
# (u'DDL_e1_W_LEMMA_L_3_R_3_[Amplifier 2n3904 /]_[/ pzt3904 --]', 0.005205993133705621)
# (u'DDL_e1_W_LEFT_3_[Amplifier 2n3904 /]', 0.005205993133705621)
# (u'DDL_e1_W_POS_L_1_R_3_[:]_[: NN :]', 0.005205993133705621)
# (u'TDL_LEMMA:RIGHT-OF-MENTION[=]', -0.005133651922186623)
# (u'DDL_e1_W_LEMMA_L_2_R_1_[or 6ct]_[=]', -0.005133651922186623)
# (u'DDL_e1_W_LEMMA_L_1_R_1_[6ct]_[=]', -0.005133651922186623)
# (u'DDL_e1_W_LEFT_2_[or 6ct]', -0.005133651922186623)
# (u'DDL_e1_W_LEFT_1_[6ct]', -0.005133651922186623)
# (u'DDL_e1_WORD_SEQ_[BC846 ... BC850]', -0.0050499892012320635)
# (u'DDL_e1_DEP_SEQ_[nmod punct ROOT]', -0.0050499892012320635)
# (u'DDL_e1_LEMMA_SEQ_[bc846 ... bc850]', -0.0050499892012320635)
# (u'TAB_e1_ROW_NUM_[1]', 0.005039640298037575)
# (u'TDL_INV_LEMMA:BETWEEN-MENTION-and-MENTION[mmbt3904]', 0.004841511710981374)
# (u'DDL_e1_W_RIGHT_1_[mmbt3904]', 0.004831025223268692)
# (u'STR_e1_NODE_POS_4', 0.004824254780862795)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[6a]', -0.004788416706492047)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[= 6a]', -0.004788416706492047)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[6a or 6cr]', -0.004788416706492047)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[= 6a or]', -0.004788416706492047)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[6a or]', -0.004788416706492047)
# (u'DDL_e1_W_LEFT_POS_2_[: NN]', -0.004732185320488802)
# (u'TDL_INV_SEQ-BETWEEN[LEN:8-13]', -0.004717286544681)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[6e or 6cr]', -0.004716574198597559)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[6e]', -0.004716574198597559)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[= 6e]', -0.004716574198597559)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[6e or]', -0.004716574198597559)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[= 6e or]', -0.004716574198597559)
# (u'TAB_e1_ROW_WORDS_[92]', 0.0044833924976184275)
# (u'TAB_e1_ROW_WORDS_[(]', 0.0044833924976184275)
# (u'TAB_e1_ROW_WORDS_[)]', 0.0044833924976184275)
# (u'TAB_e1_ROW_WORDS_[\u2212]', 0.0044833924976184275)
# (u'TAB_e1_ROW_WORDS_[( pb]', 0.0044833924976184275)
# (u'TAB_e1_ROW_WORDS_[pb \u2212]', 0.0044833924976184275)
# (u'TAB_e1_ROW_WORDS_[to \u2212]', 0.0044833924976184275)
# (u'TAB_e1_ROW_WORDS_[/]', 0.0044833924976184275)
# (u'TAB_e1_COL_HEAD_WORDS_[device]', 0.0044833924976184275)
# (u'TAB_e1_ROW_WORDS_[to]', 0.0044833924976184275)
# (u'TAB_e1_ROW_WORDS_[free )]', 0.0044833924976184275)
# (u'TAB_e1_COL_WORDS_[device]', 0.0044833924976184275)
# (u'TAB_e1_ROW_WORDS_[\u2212 92]', 0.0044833924976184275)
# (u'TAB_e1_ROW_WORDS_[\u2212 free]', 0.0044833924976184275)
# (u'STR_e1_HTML_ATTR_class=s6', 0.0044833924976184275)
# (u'TAB_e1_ROW_WORDS_[free]', 0.0044833924976184275)
# (u'TAB_e1_ROW_WORDS_[pb]', 0.0044833924976184275)
# (u'STR_e1_ANCESTOR_CLASS_[None None None None None s6]', 0.0044833924976184275)
# (u'TDL_INV_LEMMA:BETWEEN-MENTION-and-MENTION[6c]', -0.004477716163365959)
# (u'TDL_INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|6c]', -0.004477716163365959)
# (u'TDL_INV_LEMMA:LEFT-OF-MENTION[/]', -0.004393613407982582)
# (u'TDL_INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|6g]', -0.004383359792636715)
# (u'TDL_INV_LEMMA:BETWEEN-MENTION-and-MENTION[6g]', -0.004383359792636715)
# (u'STR_e1_NODE_POS_2', 0.004378216632515655)
# (u'DDL_e1_W_LEMMA_L_2_R_1_[or 6cr]_[=]', -0.004275328110567802)
# (u'DDL_e1_W_LEFT_2_[or 6cr]', -0.004275328110567802)
# (u'DDL_e1_W_LEFT_1_[6cr]', -0.004275328110567802)
# (u'DDL_e1_W_LEMMA_L_1_R_1_[6cr]_[=]', -0.004275328110567802)
# (u'TDL_INV_LEMMA:RIGHT-OF-MENTION[mmbt3904]', 0.0042345683738511785)
# (u'TDL_INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|pzt3904]', 0.0042345683738511785)
# (u'TDL_INV_LEMMA:BETWEEN-MENTION-and-MENTION[pzt3904]', 0.0042345683738511785)
# (u'STR_e1_TAG_h4', 0.004166238302431314)
# (u'STR_e1_ANCESTOR_TAG_[html body h4]', 0.004166238302431314)
# (u'DDL_e1_W_POS_L_1_R_1_[NN]_[:]', 0.004121883498649618)
# (u'TAB_e1_COL_WORDS_[bc856/857/858]', -0.004101677497553033)
# (u'TAB_e1_COL_WORDS_[: bc856/857/858]', -0.004101677497553033)
# (u'TDL_LEMMA:LEFT-OF-MENTION[-]', 0.004084506394388203)
# (u'TDL_LEMMA:SEQ-BETWEEN[General-Purpose]', 0.004084506394388203)
# (u'DDL_e1_W_LEMMA_L_2_R_1_[or 6cs]_[=]', -0.004073371595594019)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[or 6cs]', -0.004073371595594019)
# (u'DDL_e1_W_LEFT_2_[or 6cs]', -0.004073371595594019)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[6cs]', -0.004073371595594019)
# (u'DDL_e1_W_LEMMA_L_1_R_1_[6cs]_[=]', -0.004073371595594019)
# (u'DDL_e1_W_LEFT_1_[6cs]', -0.004073371595594019)
# (u'DDL_e1_W_POS_L_1_R_2_[NNP]_[: NN]', 0.004060709917887641)
# (u'DDL_e1_W_POS_L_3_R_2_[NNP NNP NNP]_[: NN]', 0.004060709917887641)
# (u'DDL_e1_W_LEMMA_L_3_R_2_[NPN General-Purpose Amplifier]_[/ mmbt3904]', 0.004060709917887641)
# (u'DDL_e1_W_LEMMA_L_3_R_3_[NPN General-Purpose Amplifier]_[/ mmbt3904 /]', 0.004060709917887641)
# (u'DDL_e1_W_POS_L_1_R_3_[NNP]_[: NN :]', 0.004060709917887641)
# (u'DDL_e1_W_POS_L_2_R_3_[NNP NNP]_[: NN :]', 0.004060709917887641)
# (u'DDL_e1_W_LEMMA_L_1_R_3_[Amplifier]_[/ mmbt3904 /]', 0.004060709917887641)
# (u'DDL_e1_W_LEMMA_L_2_R_2_[General-Purpose Amplifier]_[/ mmbt3904]', 0.004060709917887641)
# (u'DDL_e1_W_LEMMA_L_2_R_1_[General-Purpose Amplifier]_[/]', 0.004060709917887641)
# (u'DDL_e1_W_LEMMA_L_1_R_2_[Amplifier]_[/ mmbt3904]', 0.004060709917887641)
# (u'DDL_e1_W_LEMMA_L_1_R_1_[Amplifier]_[/]', 0.004060709917887641)
# (u'DDL_e1_W_POS_L_3_R_3_[NNP NNP NNP]_[: NN :]', 0.004060709917887641)
# (u'DDL_e1_W_LEMMA_L_2_R_3_[General-Purpose Amplifier]_[/ mmbt3904 /]', 0.004060709917887641)
# ...
# (u'DDL_e1_W_LEMMA_L_1_R_3_[6cs]_[= 6c or]', -0.001066163915229123)
# (u'DDL_e1_W_RIGHT_3_[= 6c or]', -0.001066163915229123)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[6b]', -0.001066163915229123)
# (u'DDL_e1_W_RIGHT_2_[= 6c]', -0.001066163915229123)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[bc817k-25 =]', -0.001066163915229123)
# (u'DDL_e1_W_LEMMA_L_3_R_3_[6b or 6cs]_[= 6c or]', -0.001066163915229123)
# (u'DDL_e1_W_LEMMA_L_3_R_2_[6f or 6cs]_[= 6g]', -0.0010082078466156625)
# (u'DDL_e1_W_LEMMA_L_3_R_3_[6f or 6cs]_[= 6g or]', -0.0010082078466156625)
# (u'DDL_e1_LEMMA_SEQ_[bc818k-40]', -0.0010082078466156625)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[bc818k-25]', -0.0010082078466156625)
# (u'DDL_e1_W_LEMMA_L_3_R_1_[6f or 6cs]_[=]', -0.0010082078466156625)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[6f]', -0.0010082078466156625)
# (u'DDL_e1_W_RIGHT_2_[= 6g]', -0.0010082078466156625)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[6cr bc818k-25 =]', -0.0010082078466156625)
# (u'DDL_e1_W_LEFT_3_[6f or 6cs]', -0.0010082078466156625)
# (u'DDL_e1_W_LEMMA_L_2_R_2_[or 6cs]_[= 6g]', -0.0010082078466156625)
# (u'DDL_e1_W_RIGHT_3_[= 6g or]', -0.0010082078466156625)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[6f or]', -0.0010082078466156625)
# (u'DDL_e1_W_LEMMA_L_2_R_3_[or 6cs]_[= 6g or]', -0.0010082078466156625)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[bc818k-25 =]', -0.0010082078466156625)
# (u'DDL_e1_W_LEMMA_L_1_R_3_[6cs]_[= 6g or]', -0.0010082078466156625)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[= 6f or]', -0.0010082078466156625)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[= 6f]', -0.0010082078466156625)
# (u'DDL_e1_WORD_SEQ_[BC818K-40]', -0.0010082078466156625)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[6cr bc818k-25]', -0.0010082078466156625)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[6f or 6cs]', -0.0010082078466156625)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[or 6cr bc818k-25]', -0.0010082078466156625)
# (u'DDL_e1_W_LEMMA_L_1_R_2_[6cs]_[= 6g]', -0.0010082078466156625)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[bc818k-25 = 6f]', -0.0010082078466156625)
# (u'TAB_e1_ROW_NUM_[3]', 0.0010044105710190067)
# (u'DDL_e1_W_POS_L_2_R_1_[NN NN]_[:]', 0.0009746590636534666)
# (u'DDL_e1_W_LEMMA_L_3_R_2_[Amplifier 2n3904 mmbt3904]_[- NPN]', 0.0009746590636534666)
# (u'DDL_e1_W_POS_L_1_R_3_[NN]_[: NNP NNP]', 0.0009746590636534666)
# (u'DDL_e1_W_POS_L_3_R_1_[NNP NN NN]_[:]', 0.0009746590636534666)
# (u'DDL_e1_W_LEMMA_L_3_R_3_[Amplifier 2n3904 mmbt3904]_[- NPN General-Purpose]', 0.0009746590636534666)
# (u'DDL_e1_W_LEMMA_L_3_R_1_[Amplifier 2n3904 mmbt3904]_[-]', 0.0009746590636534666)
# (u'DDL_e1_W_RIGHT_1_[-]', 0.0009746590636534666)
# (u'DDL_e1_W_LEMMA_L_2_R_3_[2n3904 mmbt3904]_[- NPN General-Purpose]', 0.0009746590636534666)
# (u'DDL_e1_W_LEMMA_L_1_R_1_[mmbt3904]_[-]', 0.0009746590636534666)
# (u'DDL_e1_W_LEMMA_L_1_R_2_[mmbt3904]_[- NPN]', 0.0009746590636534666)
# (u'DDL_e1_W_POS_L_3_R_3_[NNP NN NN]_[: NNP NNP]', 0.0009746590636534666)
# (u'DDL_e1_W_POS_L_2_R_2_[NN NN]_[: NNP]', 0.0009746590636534666)
# (u'DDL_e1_W_LEMMA_L_2_R_1_[2n3904 mmbt3904]_[-]', 0.0009746590636534666)
# (u'DDL_e1_W_RIGHT_2_[- NPN]', 0.0009746590636534666)
# (u'DDL_e1_W_RIGHT_3_[- NPN General-Purpose]', 0.0009746590636534666)
# (u'DDL_e1_W_POS_L_3_R_2_[NNP NN NN]_[: NNP]', 0.0009746590636534666)
# (u'DDL_e1_W_POS_L_2_R_3_[NN NN]_[: NNP NNP]', 0.0009746590636534666)
# (u'DDL_e1_W_LEMMA_L_2_R_2_[2n3904 mmbt3904]_[- NPN]', 0.0009746590636534666)
# (u'DDL_e1_W_LEMMA_L_1_R_3_[mmbt3904]_[- NPN General-Purpose]', 0.0009746590636534666)
# (u'DDL_e1_W_POS_L_1_R_2_[NN]_[: NNP]', 0.0009746590636534666)
# (u'DDL_e1_W_RIGHT_1_[bc860]', -0.0009096349491596299)
# (u'TDL_BETWEEN-MENTION-and-MENTION[LEN:0-2]', 0.0009066593300774323)
# (u'STR_LOWEST_ANCESTOR_DEPTH_[4]', -0.0008973292269861791)
# (u'STR_COMMON_ANCESTOR_[]', -0.0008973292269861791)
# (u'DDL_e1_W_LEFT_POS_3_[NN NN NN]', 0.0008902100270986465)
# (u'DDL_e1_WORD_SEQ_[BC859 , BC860]', -0.0008344702233623111)
# (u'DDL_e1_DEP_SEQ_[dep punct appos]', -0.0008344702233623111)
# (u'DDL_e1_LEMMA_SEQ_[bc859 , bc860]', -0.0008344702233623111)
# (u'DDL_e1_W_LEFT_1_[dtc114ye]', 0.0007807235097690108)
# (u'STR_e1_HTML_ATTR_style=padding-top: 15pt;padding-left: 42pt;text-indent: 0pt;text-align: left;', 0.0007807235097690108)
# (u'STR_e1_NODE_POS_18', 0.0007807235097690108)
# (u'TDL_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|figure]', -0.0007806013713745488)
# (u'TDL_LEMMA:BETWEEN-MENTION-and-MENTION[figure]', -0.0007806013713745488)
# (u'TAB_e1_ROW_HEAD_WORDS_[2n3904tar]', 0.0007652268601107139)
# (u'TAB_e1_ROW_WORDS_[2n3904tar]', 0.0007652268601107139)
# (u'TAB_e1_ROW_HEAD_WORDS_[2n3904bu]', 0.000764033951272993)
# (u'TAB_e1_ROW_WORDS_[2n3904bu]', 0.000764033951272993)
# (u'TAB_e1_ROW_HEAD_WORDS_[2n3904ta]', 0.0007483286392872279)
# (u'TAB_e1_ROW_WORDS_[2n3904ta]', 0.0007483286392872279)
# (u'DDL_e1_W_LEMMA_L_2_R_3_[General-Purpose Amplifier]_[mmbt3904 pzt3904 -]', 0.0007048956647852072)
# (u'DDL_e1_W_POS_L_3_R_1_[NNP NNP NNP]_[NN]', 0.0007048956647852072)
# (u'DDL_e1_W_RIGHT_2_[mmbt3904 pzt3904]', 0.0007048956647852072)
# (u'DDL_e1_W_POS_L_3_R_3_[NNP NNP NNP]_[NN NN :]', 0.0007048956647852072)
# (u'DDL_e1_W_POS_L_1_R_2_[NNP]_[NN NN]', 0.0007048956647852072)
# (u'DDL_e1_W_LEMMA_L_2_R_1_[General-Purpose Amplifier]_[mmbt3904]', 0.0007048956647852072)
# (u'DDL_e1_W_LEMMA_L_2_R_2_[General-Purpose Amplifier]_[mmbt3904 pzt3904]', 0.0007048956647852072)
# (u'DDL_e1_W_POS_L_2_R_3_[NNP NNP]_[NN NN :]', 0.0007048956647852072)
# (u'DDL_e1_W_POS_L_1_R_3_[NNP]_[NN NN :]', 0.0007048956647852072)
# (u'DDL_e1_W_LEMMA_L_1_R_2_[Amplifier]_[mmbt3904 pzt3904]', 0.0007048956647852072)
# (u'DDL_e1_W_LEMMA_L_3_R_1_[NPN General-Purpose Amplifier]_[mmbt3904]', 0.0007048956647852072)
# (u'DDL_e1_W_RIGHT_3_[mmbt3904 pzt3904 -]', 0.0007048956647852072)
# (u'DDL_e1_W_LEMMA_L_3_R_3_[NPN General-Purpose Amplifier]_[mmbt3904 pzt3904 -]', 0.0007048956647852072)
# (u'DDL_e1_W_RIGHT_POS_2_[NN NN]', 0.0007048956647852072)
# (u'TDL_LEMMA:RIGHT-OF-MENTION[mmbt3904]', 0.0007048956647852072)
# (u'DDL_e1_W_LEMMA_L_3_R_2_[NPN General-Purpose Amplifier]_[mmbt3904 pzt3904]', 0.0007048956647852072)
# (u'DDL_e1_W_RIGHT_POS_3_[NN NN :]', 0.0007048956647852072)
# (u'DDL_e1_W_POS_L_3_R_2_[NNP NNP NNP]_[NN NN]', 0.0007048956647852072)
# (u'DDL_e1_W_POS_L_2_R_1_[NNP NNP]_[NN]', 0.0007048956647852072)
# (u'DDL_e1_W_POS_L_2_R_2_[NNP NNP]_[NN NN]', 0.0007048956647852072)
# (u'DDL_e1_W_LEMMA_L_1_R_1_[Amplifier]_[mmbt3904]', 0.0007048956647852072)
# (u'DDL_e1_W_POS_L_1_R_1_[NNP]_[NN]', 0.0007048956647852072)
# (u'DDL_e1_W_LEMMA_L_1_R_3_[Amplifier]_[mmbt3904 pzt3904 -]', 0.0007048956647852072)
# (u'DDL_e1_W_RIGHT_POS_3_[NNP NNP NNP]', -0.0007010305598000921)
# (u'DDL_e1_W_LEMMA_L_3_R_1_[bc182 , bc182b]_[bc182b]', 0.0006749520477788505)
# (u'DDL_e1_W_POS_L_3_R_1_[NN , NN]_[NN]', 0.0006749520477788505)
# (u'DDL_e1_W_POS_L_2_R_1_[, NN]_[NN]', 0.0006749520477788505)
# (u'DDL_e1_W_LEMMA_L_1_R_1_[bc182b]_[bc182b]', 0.0006749520477788505)
# (u'DDL_e1_W_LEMMA_L_2_R_1_[, bc182b]_[bc182b]', 0.0006749520477788505)
# (u'DDL_e1_W_RIGHT_1_[bc182b]', 0.0006749520477788505)
# (u'DDL_e1_WORD_SEQ_[BC182 ,]', 0.0006749520477788505)
# (u'DDL_e1_LEMMA_SEQ_[bc182 ,]', 0.0006749520477788505)
# (u'TDL_LEMMA:SEQ-BETWEEN[- NPN]', 0.0006648134189060151)
# (u'TDL_LEMMA:SEQ-BETWEEN[- NPN General-Purpose]', 0.0006648134189060151)
# (u'DDL_e1_WORD_SEQ_[BC860]', -0.0006628635617155138)
# (u'DDL_e1_LEMMA_SEQ_[bc860]', -0.0006628635617155138)
# (u'DDL_e1_LEMMA_SEQ_[bc182b]', 0.0006272100541975063)
# (u'TDL_INV_LEMMA:BETWEEN-MENTION-and-MENTION[bc182]', 0.0006272100541975063)
# (u'DDL_e1_W_LEFT_POS_3_[NN NN ,]', 0.0006272100541975063)
# (u'TDL_INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|bc182]', 0.0006272100541975063)
# (u'DDL_e1_W_LEFT_3_[bc182b bc182 ,]', 0.0006272100541975063)
# (u'DDL_e1_W_LEFT_2_[bc182 ,]', 0.0006272100541975063)
# (u'DDL_e1_WORD_SEQ_[BC182B]', 0.0006272100541975063)
# (u'STR_e1_HTML_ATTR_style=padding-top: 1pt;padding-left: 27pt;text-indent: 0pt;text-align: left;', 0.0006230416163808714)
# (u'TAB_e1_ROW_WORDS_[3904]', 0.0006230416163808714)
# (u'VIZ_e1_ALIGNED_RIGHT_description', 0.0006230416163808714)
# (u'TAB_e1_ROW_WORDS_[4l]', 0.0006230416163808714)
# (u'TAB_e1_ROW_WORDS_[sot-223]', 0.0006230416163808714)
# (u'VIZ_e1_ALIGNED_description', 0.0006230416163808714)
# (u'TAB_e1_ROW_WORDS_[2500]', 0.0006230416163808714)
# (u'TAB_e1_ROW_NUM_[7]', 0.0006230416163808714)
# (u'TAB_e1_ROW_WORDS_[sot-223 4l]', 0.0006230416163808714)
# (u'DDL_e1_LEMMA_SEQ_[bc859]', -0.0005673222476426875)
# (u'DDL_e1_WORD_SEQ_[BC859]', -0.0005673222476426875)
# (u'DDL_e1_W_LEFT_2_[bc856/857/858 noise]', -0.0005472116067493551)
# (u'DDL_e1_LEMMA_SEQ_[figure : bc856/857/858]', -0.0005472116067493551)
# (u'DDL_e1_WORD_SEQ_[Figure : BC856/857/858]', -0.0005472116067493551)
# (u'DDL_e1_W_LEFT_3_[: bc856/857/858 noise]', -0.0005472116067493551)
# (u'DDL_e1_W_LEFT_POS_3_[: NN NN]', -0.0005472116067493551)
# (u'DDL_e1_W_LEFT_2_[noise figure]', -0.000529918875250981)
# (u'DDL_e1_LEMMA_SEQ_[: bc856/857/858]', -0.000529918875250981)
# (u'DDL_e1_DEP_SEQ_[punct dep]', -0.000529918875250981)
# (u'DDL_e1_W_LEFT_1_[figure]', -0.000529918875250981)
# (u'DDL_e1_W_LEFT_3_[bc856/857/858 noise figure]', -0.000529918875250981)
# (u'DDL_e1_WORD_SEQ_[: BC856/857/858]', -0.000529918875250981)
# (u'TDL_LEMMA:SEQ-BETWEEN[mmbt3904 / pzt3904]', 0.0005014437952478136)
# (u'DDL_e1_W_RIGHT_POS_1_[-LRB-]', 0.00047575536253833503)
# (u'DDL_e1_W_LEFT_POS_3_[NN -RRB- .]', 0.00047575536253833503)
# (u'DDL_e1_W_LEMMA_L_1_R_2_[.]_[( sot-523]', 0.00047575536253833503)
# (u'DDL_e1_W_RIGHT_1_[(]', 0.00047575536253833503)
# (u'DDL_e1_W_POS_L_2_R_3_[-RRB- .]_[-LRB- NN -RRB-]', 0.00047575536253833503)
# (u'DDL_e1_W_LEFT_3_[sot-523 ) .]', 0.00047575536253833503)
# (u'DDL_e1_W_POS_L_3_R_3_[NN -RRB- .]_[-LRB- NN -RRB-]', 0.00047575536253833503)
# (u'DDL_e1_W_RIGHT_POS_2_[-LRB- NN]', 0.00047575536253833503)
# (u'DDL_e1_W_POS_L_1_R_3_[.]_[-LRB- NN -RRB-]', 0.00047575536253833503)
# (u'DDL_e1_W_POS_L_1_R_2_[.]_[-LRB- NN]', 0.00047575536253833503)
# (u'DDL_e1_W_LEMMA_L_1_R_3_[.]_[( sot-523 )]', 0.00047575536253833503)
# (u'DDL_e1_W_POS_L_2_R_2_[-RRB- .]_[-LRB- NN]', 0.00047575536253833503)
# (u'DDL_e1_W_LEMMA_L_2_R_1_[) .]_[(]', 0.00047575536253833503)
# (u'DDL_e1_W_RIGHT_2_[( sot-523]', 0.00047575536253833503)
# (u'DDL_e1_W_LEMMA_L_2_R_3_[) .]_[( sot-523 )]', 0.00047575536253833503)
# (u'DDL_e1_W_LEMMA_L_3_R_1_[sot-523 ) .]_[(]', 0.00047575536253833503)
# (u'DDL_e1_W_LEMMA_L_1_R_1_[.]_[(]', 0.00047575536253833503)
# (u'DDL_e1_W_RIGHT_3_[( sot-523 )]', 0.00047575536253833503)
# (u'DDL_e1_W_POS_L_3_R_1_[NN -RRB- .]_[-LRB-]', 0.00047575536253833503)
# (u'DDL_e1_W_POS_L_1_R_1_[.]_[-LRB-]', 0.00047575536253833503)
# (u'DDL_e1_W_RIGHT_POS_3_[-LRB- NN -RRB-]', 0.00047575536253833503)
# (u'DDL_e1_W_LEMMA_L_2_R_2_[) .]_[( sot-523]', 0.00047575536253833503)
# (u'DDL_e1_W_POS_L_3_R_2_[NN -RRB- .]_[-LRB- NN]', 0.00047575536253833503)
# (u'DDL_e1_W_LEMMA_L_3_R_3_[sot-523 ) .]_[( sot-523 )]', 0.00047575536253833503)
# (u'DDL_e1_W_POS_L_2_R_1_[-RRB- .]_[-LRB-]', 0.00047575536253833503)
# (u'DDL_e1_W_LEMMA_L_3_R_2_[sot-523 ) .]_[( sot-523]', 0.00047575536253833503)
# (u'DDL_e1_W_LEFT_POS_2_[-RRB- .]', 0.00047575536253833503)
# (u'DDL_e1_W_LEFT_2_[) .]', 0.00047575536253833503)
# (u'TAB_e1_ROW_WORDS_[figure :]', -0.0004512425045867515)
# (u'DDL_e1_W_LEFT_2_[figure :]', -0.0004512425045867515)
# (u'DDL_e1_W_LEFT_3_[noise figure :]', -0.0004512425045867515)
# (u'TAB_e1_CELL_WORDS_[figure :]', -0.0004512425045867515)
# (u'TAB_e1_ROW_HEAD_WORDS_[2n3904tfr]', 0.00036560098996688386)
# (u'TAB_e1_ROW_WORDS_[2n3904tfr]', 0.00036560098996688386)
# (u'DDL_e1_W_LEMMA_L_1_R_1_[bc182b]_[,]', 0.0003586491710942855)
# (u'DDL_e1_W_POS_L_1_R_1_[NN]_[,]', 0.0003586491710942855)
# (u'DDL_e1_W_RIGHT_2_[, bc182b]', 0.0003586491710942855)
# (u'DDL_e1_W_POS_L_3_R_1_[NN , NN]_[,]', 0.0003586491710942855)
# (u'DDL_e1_W_POS_L_2_R_2_[, NN]_[, NN]', 0.0003586491710942855)
# (u'DDL_e1_W_LEMMA_L_2_R_1_[, bc182b]_[,]', 0.0003586491710942855)
# (u'DDL_e1_W_POS_L_3_R_2_[NN , NN]_[, NN]', 0.0003586491710942855)
# (u'DDL_e1_W_LEMMA_L_1_R_2_[bc182b]_[, bc182b]', 0.0003586491710942855)
# (u'DDL_e1_W_LEMMA_L_3_R_1_[bc182 , bc182b]_[,]', 0.0003586491710942855)
# (u'DDL_e1_W_LEMMA_L_2_R_2_[, bc182b]_[, bc182b]', 0.0003586491710942855)
# (u'DDL_e1_W_POS_L_1_R_2_[NN]_[, NN]', 0.0003586491710942855)
# (u'DDL_e1_W_LEMMA_L_3_R_2_[bc182 , bc182b]_[, bc182b]', 0.0003586491710942855)
# (u'DDL_e1_W_POS_L_2_R_1_[, NN]_[,]', 0.0003586491710942855)
# (u'TAB_e1_ROW_HEAD_WORDS_[2n3904tf]', 0.0003458202499683956)
# (u'TAB_e1_ROW_WORDS_[2n3904tf]', 0.0003458202499683956)
# (u'STR_e1_ANCESTOR_TAG_[html body h1]', 0.00030769152037383486)
# (u'STR_e1_TAG_h1', 0.00030769152037383486)
# (u'TAB_e1_ROW_WORDS_[1a]', 0.0002800306163717476)
# (u'STR_e1_HTML_ATTR_style=padding-top: 1pt;padding-left: 22pt;text-indent: 0pt;text-align: left;', 0.0002800306163717476)
# (u'VIZ_e1_PAGE_[3]', 0.0002800306163717476)
# (u'TAB_e1_ROW_NUM_[6]', 0.0002800306163717476)
# (u'TAB_e1_ROW_WORDS_[sot-23]', 0.0002800306163717476)
# (u'TAB_e1_ROW_WORDS_[sot-23 3l]', 0.0002800306163717476)
# (u'TAB_e1_ROW_WORDS_[3000]', 0.0002800306163717476)
# (u'TDL_SEQ-BETWEEN[LEN:5-7]', 0.00026423333719606594)
# (u'TDL_INV_LEMMA:SEQ-BETWEEN[figure]', -0.00024230083510075345)
# (u'STR_e1_HTML_ATTR_style=padding-top: 3pt;padding-left: 4pt;text-indent: 0pt;text-align: left;', 0.000179496979708073)
# (u'DDL_e1_W_LEFT_1_[bc182bg]', 0.000179496979708073)
# (u'DDL_e1_LEMMA_SEQ_[bc182bg]', 0.000179496979708073)
# (u'DDL_e1_WORD_SEQ_[BC182BG]', 0.000179496979708073)
# (u'STR_e1_HTML_ATTR_style=padding-top: 1pt;padding-left: 3pt;text-indent: 0pt;text-align: left;', 0.0001777161586284976)
# (u'DDL_e1_W_LEFT_1_[bc182g]', 0.0001777161586284976)
# (u'DDL_e1_WORD_SEQ_[BC182G]', 0.0001777161586284976)
# (u'DDL_e1_LEMMA_SEQ_[bc182g]', 0.0001777161586284976)
# (u'DDL_e1_LEMMA_SEQ_[dtc114eua]', 0.00013218946836203303)
# (u'DDL_e1_WORD_SEQ_[DTC114EUA]', 0.00013218946836203303)
# (u'STR_e1_HTML_ATTR_style=padding-left: 5pt;text-indent: 0pt;text-align: left;', 0.00013218946836203303)
# (u'DDL_e1_W_LEFT_1_[dtc114eua]', 0.00013218946836203303)
# (u'DDL_e1_W_LEFT_1_[bc182brl1g]', 0.00012817969178234345)
# (u'TAB_e1_ROW_WORDS_[2000 /]', 0.00012817969178234345)
# (u'TAB_e1_ROW_WORDS_[tape &]', 0.00012817969178234345)
# (u'VIZ_e1_ALIGNED_CENTER_to', 0.00012817969178234345)
# (u'DDL_e1_WORD_SEQ_[BC182BRL1G]', 0.00012817969178234345)
# (u'VIZ_e1_ALIGNED_to', 0.00012817969178234345)
# (u'TAB_e1_ROW_WORDS_[& reel]', 0.00012817969178234345)
# (u'TAB_e1_ROW_WORDS_[&]', 0.00012817969178234345)
# (u'VIZ_e1_ALIGNED_CENTER_case', 0.00012817969178234345)
# (u'VIZ_e1_ALIGNED_CENTER_style', 0.00012817969178234345)
# (u'VIZ_e1_ALIGNED_case', 0.00012817969178234345)
# (u'TAB_e1_ROW_WORDS_[/ tape]', 0.00012817969178234345)
# (u'STR_e1_HTML_ATTR_style=padding-top: 2pt;padding-left: 3pt;text-indent: 0pt;text-align: left;', 0.00012817969178234345)
# (u'VIZ_e1_ALIGNED_style', 0.00012817969178234345)
# (u'DDL_e1_LEMMA_SEQ_[bc182brl1g]', 0.00012817969178234345)
# (u'DDL_e1_W_LEFT_2_[bc856 :]', -0.00012239297326989296)
# (u'DDL_e1_WORD_SEQ_[BC856]', -0.00012239297326989296)
# (u'DDL_e1_W_LEFT_3_[: bc856 :]', -0.00012239297326989296)
# (u'DDL_e1_LEMMA_SEQ_[bc856]', -0.00012239297326989296)
# (u'DDL_e1_W_LEFT_1_[2n3904bu]', 9.989052063688222e-05)
# (u'DDL_e1_WORD_SEQ_[2N3904BU]', 9.989052063688222e-05)
# (u'DDL_e1_LEMMA_SEQ_[2n3904bu]', 9.989052063688222e-05)
# (u'DDL_e1_W_LEFT_1_[bc182]', 6.349937293099255e-05)
# (u'TAB_e1_ROW_WORDS_[1.2]', -6.035720239517508e-05)
# (u'VIZ_e1_ALIGNED_RIGHT_current', -6.035720239517508e-05)
# (u'STR_e1_HTML_ATTR_style=padding-left: 9pt;text-indent: 0pt;line-height: 8pt;text-align: center;', -6.035720239517508e-05)
# (u'VIZ_e1_ALIGNED_RIGHT_collector', -6.035720239517508e-05)
# (u'DDL_e1_LEMMA_SEQ_[: bc859/860]', -4.808938104560906e-05)
# (u'DDL_e1_W_LEFT_2_[: bc859/860]', -4.808938104560906e-05)
# (u'DDL_e1_WORD_SEQ_[: BC859/860]', -4.808938104560906e-05)
# (u'DDL_e1_W_LEFT_1_[bc859/860]', -4.808938104560906e-05)
# (u'DDL_e1_W_LEFT_POS_3_[NN NN :]', 4.559359362599636e-05)
# (u'TDL_INV_LEMMA:BETWEEN-MENTION-and-MENTION[bc859]', -3.8208922548156314e-05)
# (u'DDL_e1_W_LEFT_1_[2n3904tar]', 3.6915286457614676e-05)
# (u'DDL_e1_LEMMA_SEQ_[2n3904tar]', 3.6915286457614676e-05)
# (u'DDL_e1_WORD_SEQ_[2N3904TAR]', 3.6915286457614676e-05)
# (u'DDL_e1_W_LEFT_1_[2n3904ta]', 7.5669745180837875e-06)
# (u'DDL_e1_LEMMA_SEQ_[2n3904ta]', 7.5669745180837875e-06)
# (u'DDL_e1_WORD_SEQ_[2N3904TA]', 7.5669745180837875e-06)

# %%
from hardware_utils import entity_to_candidates

entity = FP_list[0]
matches = entity_to_candidates(entity, fp)
print "Entity: (%d matches)" % len(matches)
print entity

candidate = matches[0]
print "\nCandidate:"
print candidate

print "\nScore:"
print disc_model.get_candidate_score(candidate, F_dev)

print "\nFeatures:"
pprint(disc_model.get_candidate_feature_weights(candidate, F_dev))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-fa7e04ce4e08> in <module>()
#       1 from hardware_utils import entity_to_candidates
#       2
# ----> 3 entity = FP_list[0]
#       4 matches = entity_to_candidates(entity, fp)
#       5 print "Entity: (%d matches)" % len(matches)
#
# IndexError: list index out of range

# %%
from hardware_utils import part_error_analysis
part_error_analysis(candidate)
