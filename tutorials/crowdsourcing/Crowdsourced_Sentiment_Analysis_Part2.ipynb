# %% [markdown]
# # Part II: Crowdsourced Sentiment Analysis with Snorkel - Training an ML Model with Snorkel for Sentiment Analysis over Unseen Tweets

# %% [markdown]
# In [Part I](Crowdsourced_Sentiment_Analysis_Part1.ipynb) of the tutorial we saw how `Snorkel's` generative model can be used to resolve conflicts in crowdsourced answers for a sentiment analysis task. In that part we assumed that we have crowd labels for all our tweets.
#
# In this second part, we will show how the output of `Snorkel's` generative model can be used to provide the necessary labeled data for training a Logistic Regression model that takes as input a tweet **for which no crowd labels are available** and predicts its sentiment. To emulate the above we split our dataset in two parts: one with tweets for which crowd labels are available and one with tweets for which crowd labels are hidden from Snorkel.
#
#
# The following tutorial is broken up into four parts, each covering a step in the pipeline:
# 1. Load files from Part I
# 2. Load and featurize tweets with Snorkel
# 3. Train an ML model with Snorkel
# 4. Evaluation

# %% [markdown]
# ## Step 1: Load Files from Part I
#
# We first load certain dataframes and pickled files from Part I. These files are required in the subsequent steps. For more details on how the files were generated please check [Part I](Crowdsourced_Sentiment_Analysis_Part1.ipynb).

# %%
# Initialize Spark Environment and Spark SQL
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark import SparkContext, SparkConf

spark = SparkSession \
    .builder \
    .master("local") \
    .appName("Snorkel Crowdsourcing Demo") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()

# %%
# Load dataframes from parquet files
worker_labels = spark.read.parquet("data/worker_labels.parquet")
gold_answers = spark.read.parquet("data/gold_answers.parquet")

# Load maps
import pickle
task2ObjMap = pickle.load( open( "data/task2ObjMap.pkl", "rb" ) )
obj2TaskMap = pickle.load( open( "data/obj2TaskMap.pkl", "rb" ) )
worker2LFMap = pickle.load( open( "data/worker2LFMap.pkl", "rb" ) )
lf2WorkerMap = pickle.load( open( "data/lf2WorkerMap.pkl", "rb" ) )
taskLabels = pickle.load( open( "data/taskLabels.pkl", "rb" ) )
taskLabelsMap = pickle.load( open( "data/taskLabelsMap.pkl", "rb" ) )

# %% [markdown]
# ## Step 2: Load and Featurize Tweets
#
# In this part we show how to use `Snorkel` to featurize the tweets.
#
# The first task we need to perfom is load the raw tweet bodies into Snorkel:

# %%
# Load tweet bodies in a dataframe
raw_crowd_answers = spark.read.format("csv").option("header", "true").csv("data/weather-non-agg-DFE.csv")
tweet_bodies = raw_crowd_answers.select("tweet_id", "tweet_body").orderBy("tweet_id").distinct()

# %%
# Initialize a Snorkel session
from snorkel import SnorkelSession
from snorkel.models import candidate_subclass
from snorkel.contrib.models.context import RawText

session = SnorkelSession()

# Define a tweet candidate
Tweet = candidate_subclass('Tweet', ['tweet_body'], values=taskLabels)

# Generate and store the tweet candidates to be classified

# We split the tweets in two sets: one for which the crowd 
# labels are available to Snorkel and one for which we assume
# no crowd labels
total_tweets = tweet_bodies.count()
train_split = total_tweets*0.6

train_tweets = []
test_tweets = []

count = 0
for tweet_entry in tweet_bodies.collect():
    tweet_text = RawText(stable_id=tweet_entry.tweet_id, name=tweet_entry.tweet_id, text=tweet_entry.tweet_body)
    if count < train_split:
        tweet = Tweet(tweet_body=tweet_text, split=0)
        session.add(tweet)
        train_tweets.append(tweet_entry.tweet_id)
    else:
        tweet = Tweet(tweet_body=tweet_text, split=1)
        session.add(tweet)
        test_tweets.append(tweet_entry.tweet_id)
    count += 1
session.commit()
# Out:
# /anaconda/lib/python2.7/site-packages/sqlalchemy/ext/declarative/clsregistry.py:120: SAWarning: This declarative base already contains a class with the same class name and module name as snorkel.models.candidate.Tweet, and will be replaced in the string-lookup table.
#   item.__name__
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-28-131f2a4c802a> in <module>()
#       7
#       8 # Define a tweet candidate
# ----> 9 Tweet = candidate_subclass('Tweet', ['tweet_body'], values=taskLabels)
#      10
#      11 # Generate and store the tweet candidates to be classified
#
# /Users/thodoris/Documents/Research/snorkel/snorkel/models/candidate.pyc in candidate_subclass(class_name, args, table_name, cardinality, values)
#     152
#     153     # Create class
# --> 154     C = type(class_name, (Candidate,), class_attribs)
#     155
#     156     # Create table in DB
#
# /anaconda/lib/python2.7/site-packages/sqlalchemy/ext/declarative/api.pyc in __init__(cls, classname, bases, dict_)
#      62     def __init__(cls, classname, bases, dict_):
#      63         if '_decl_class_registry' not in cls.__dict__:
# ---> 64             _as_declarative(cls, classname, cls.__dict__)
#      65         type.__init__(cls, classname, bases, dict_)
#      66
#
# /anaconda/lib/python2.7/site-packages/sqlalchemy/ext/declarative/base.pyc in _as_declarative(cls, classname, dict_)
#      86         return
#      87
# ---> 88     _MapperConfig.setup_mapping(cls, classname, dict_)
#      89
#      90
#
# /anaconda/lib/python2.7/site-packages/sqlalchemy/ext/declarative/base.pyc in setup_mapping(cls, cls_, classname, dict_)
#     101         else:
#     102             cfg_cls = _MapperConfig
# --> 103         cfg_cls(cls_, classname, dict_)
#     104
#     105     def __init__(self, cls_, classname, dict_):
#
# /anaconda/lib/python2.7/site-packages/sqlalchemy/ext/declarative/base.pyc in __init__(self, cls_, classname, dict_)
#     129         self._extract_declared_columns()
#     130
# --> 131         self._setup_table()
#     132
#     133         self._setup_inheritance()
#
# /anaconda/lib/python2.7/site-packages/sqlalchemy/ext/declarative/base.pyc in _setup_table(self)
#     393                     tablename, cls.metadata,
#     394                     *(tuple(declared_columns) + tuple(args)),
# --> 395                     **table_kw)
#     396         else:
#     397             table = cls.__table__
#
# /anaconda/lib/python2.7/site-packages/sqlalchemy/sql/schema.pyc in __new__(cls, *args, **kw)
#     416                     "to redefine "
#     417                     "options and columns on an "
# --> 418                     "existing Table object." % key)
#     419             table = metadata.tables[key]
#     420             if extend_existing:
#
# InvalidRequestError: Table 'tweet' is already defined for this MetaData instance.  Specify 'extend_existing=True' to redefine options and columns on an existing Table object.

# %% [markdown]
# Now we will generate simple bag-of-word features that will be used by the Logistic Regression model. To do this we will use Snorkel's `FeatureAnnotator` class. All we need to provide as input to that class is a simple user-defined function (UDF) that takes as input a candidate and returns the bag-of-word features.

# %%
# We define a UDF that parses the body of a candidate (a tweet here)
# and returns as features the token of the tweet body
def bow_feature_generator(c):
    for tok in c.get_contexts()[0].text.split():
        yield tok, 1

# We now use the FeatureAnnotaror provided by Snorkel 
# to generate features for all candidates.
from snorkel.annotations import FeatureAnnotator
featurizer = FeatureAnnotator(f=bow_feature_generator)

# %time F_train = featurizer.apply(split=0)
print F_train.shape

# %time F_test = featurizer.apply(split=1)
print F_test.shape
# Out:
# Clearing existing...
# Running UDF...
# [========================================] 100%%
#
# CPU times: user 5.47 s, sys: 151 ms, total: 5.63 s
# Wall time: 6.15 s
# (600, 3639)
# Clearing existing...
# Running UDF...
# [========================================] 100%%
#
# CPU times: user 3.99 s, sys: 129 ms, total: 4.12 s
# Wall time: 4.23 s
# (400, 2641)

# %% [markdown]
# ## Step 3: Train An ML Model with Snorkel
#
# Now we show how to train an end-to-end model with `Snorkel` where crowdsourced labels are used to generate training data.
#
# First we need to train `Snorkel's` generative model over the tweets in the training set. These are the ones for which noisy crowd labels are available.
#
# To this end, we generate the labeling matrix for Snorkel and train the corresponding generative model. Details on these steps are provided in [Part I](Crowdsourced_Sentiment_Analysis_Part2.ipynb).

# %%
# The labeling matrix is represented
# as a sparse scipy array

# Imports
import numpy as np
from scipy import sparse

# Initialize dimensions of labeling matrix
objects = len(train_tweets)
LFs = worker_labels.select("worker_id").distinct().count()

# Initialize empty labeling matrix
L_train = sparse.lil_matrix((objects, LFs), dtype=np.int64)

# Iterate over crowdsourced labels and populate labeling matrix
for assigned_label in worker_labels.select("worker_id", "task_id", "label").collect():
    if assigned_label.task_id in train_tweets:
        oid = task2ObjMap[assigned_label.task_id]
        LFid = worker2LFMap[assigned_label.worker_id]
        label = taskLabelsMap[assigned_label.label]
        L_train[oid, LFid] = label

# %% [markdown]
# We now use the generated labeling matrix to train the generative model.

# %%
# Imports
from snorkel.learning.gen_learning import GenerativeModel

# Initialize Snorkel's generative model for
# learning the different worker accuracies.
gen_model = GenerativeModel(lf_propensity=True)
# Out:
# /anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:1401: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
# Train the generative model
gen_model.train(
    L_train,
    reg_type=2,
    reg_param=0.1,
    epochs=30
)
# Out:
# Inferred cardinality: 5

# %% [markdown]
# The final step is to train a Logistic Regression model to predict the sentiment of each tweet. The corresponding model takes as input: (i) the generated features, and (ii) the marginals estimated by `Snorkel's` generative model.

# %%
from snorkel.learning import SparseLogisticRegression
disc_model_sparse = SparseLogisticRegression()
train_marginals = gen_model.marginals(L_train)

#This is the good one!
#disc_model_sparse.train(F_train, train_marginals, n_epochs=4000, lr=0.001,
#        batch_size=500, l2_penalty=0.01, print_freq=100)

disc_model_sparse.train(F_train, train_marginals, n_epochs=4000, lr=0.001,
        batch_size=500, l2_penalty=0.1, print_freq=100)
# Out:
# [SparseLR] lr=0.001 l1=0.0 l2=0.1
# [SparseLR] Building model
# [SparseLR] Training model
# [SparseLR] #examples=600  #epochs=4000  batch size=500
# [SparseLR] Epoch 0 (1.19s)	Avg. loss=1.768709	NNZ=18195
# [SparseLR] Epoch 100 (3.52s)	Avg. loss=0.579655	NNZ=18195
# [SparseLR] Epoch 200 (5.33s)	Avg. loss=0.371713	NNZ=18195
# [SparseLR] Epoch 300 (7.11s)	Avg. loss=0.305302	NNZ=18195
# [SparseLR] Epoch 400 (8.72s)	Avg. loss=0.274311	NNZ=18195
# [SparseLR] Epoch 500 (10.51s)	Avg. loss=0.256409	NNZ=18195
# [SparseLR] Epoch 600 (12.48s)	Avg. loss=0.244749	NNZ=18195
# [SparseLR] Epoch 700 (14.39s)	Avg. loss=0.236602	NNZ=18195
# [SparseLR] Epoch 800 (16.32s)	Avg. loss=0.230642	NNZ=18195
# [SparseLR] Epoch 900 (18.37s)	Avg. loss=0.226133	NNZ=18195
# [SparseLR] Epoch 1000 (20.21s)	Avg. loss=0.222629	NNZ=18195
# [SparseLR] Epoch 1100 (22.01s)	Avg. loss=0.219845	NNZ=18195
# [SparseLR] Epoch 1200 (23.95s)	Avg. loss=0.217594	NNZ=18195
# [SparseLR] Epoch 1300 (26.89s)	Avg. loss=0.215750	NNZ=18195
# [SparseLR] Epoch 1400 (29.83s)	Avg. loss=0.214224	NNZ=18195
# [SparseLR] Epoch 1500 (32.24s)	Avg. loss=0.212953	NNZ=18195
# [SparseLR] Epoch 1600 (34.09s)	Avg. loss=0.211890	NNZ=18195
# [SparseLR] Epoch 1700 (36.10s)	Avg. loss=0.210998	NNZ=18195
# [SparseLR] Epoch 1800 (38.17s)	Avg. loss=0.210248	NNZ=18195
# [SparseLR] Epoch 1900 (40.19s)	Avg. loss=0.209617	NNZ=18195
# [SparseLR] Epoch 2000 (42.18s)	Avg. loss=0.209085	NNZ=18195
# [SparseLR] Epoch 2100 (44.00s)	Avg. loss=0.208635	NNZ=18195
# [SparseLR] Epoch 2200 (45.91s)	Avg. loss=0.208254	NNZ=18195
# [SparseLR] Epoch 2300 (48.10s)	Avg. loss=0.207930	NNZ=18195

# %% [markdown]
# ## Step 4: Evaluation
#
# Finally, we evaluate the performance of the trained Logistic Regression `Snorkel` model against the groundtruth labels of the tweets in the test set. We assign the final label of each tweet to be the MAP assignment given the marginal distribution returned by the Logistic Regression model.

# %%
# Get MAP assignment for each task
test_marginals = disc_model_sparse.marginals(F_test)
task_map_assignment = np.argmax(test_marginals, axis=1)
inferedLabels = {}
for i in range(len(task_map_assignment)):
    inferedLabels[obj2TaskMap[i+len(train_tweets)]] =  taskLabels[task_map_assignment[i]+1]

# %%
errors = 0
total = 0
for trueLabel in gold_answers.select("tweet_id","sentiment","tweet_body").collect():
    if trueLabel.tweet_id in inferedLabels:
        total += 1.0
        if trueLabel.sentiment != inferedLabels[trueLabel.tweet_id]:
            errors += 1
            print '*** Error ***'
            print 'Original tweet: '+trueLabel.tweet_body
            print 'Groundtruth label: '+trueLabel.sentiment
            print 'Snorkel label: '+inferedLabels[trueLabel.tweet_id]
            print '\n'
print '\n*** Overall Performance Statistics ***'
print 'Wrongly infered labels: '+str(errors)+' out of '+str(total)
print 'Accuracy of Snorkel''s model = ', (total-errors)/total
# Out:
# *** Error ***
# Original tweet: US GAS: Warm-Weather Forecasts Lift Natural Gas Futures {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: Fire Weather Watch issued May 17 at 4:21PM CDT expiring May 19 at 9:00PM CDT by NWS Lubbock... {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: soo I pressed my way out to bible study in this weather! truly a #sacrifice
# Groundtruth label: Negative
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: Nothing like sirens going off in the area to add a sense of immediacy to the weather reports.  At least the worst has passed to the north.
# Groundtruth label: Negative
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: Sunny skies over by KC Library, Plaza branch. But ominous skies over Downtown KC. Sirens still ringing. {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: Lance Berkman with a snow cone diving catch, yeah it happened
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: GD: Light Rain and Windy and 54 F at Grand Island, Central Nebraska Regional Airport, NE Winds are from the North at 26 {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: #storm yeah? {link}/
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: I hope it won't be too hot in the morning! Jacksonville weather be on hell+2 degrees!
# Groundtruth label: Negative
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: hot weather puts me in a bad mood .
# Groundtruth label: Negative
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: After being told no pink for decades USDA now says cooked pork can be pink, @ 145 degrees not 160. Next will they admit alien UFO's are real
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: RT @mention: TORNADO WARNING N central TX TORNADO NEAR SAGINAW...MOVING EAST SOUTHEAST AT 40 MPH.  SOFTBALL SIZED HAIL {link} ...
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: @mention been chatting up a storm on #BlackberryMessenger with a bunch of cool MMA people
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: It is hot ass hell outside
# Groundtruth label: Negative
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: Severe Weather In Dallas Causes Flight Delays, Diversions In SA from KSAT - Local News {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: Dear #sanfrancisco, this weather blows. Rain? In may? Um no thank you. Please, get it together. Thanks
# Groundtruth label: Negative
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: RT @mention: Weather spotters report #tornado moving toward Joplin, Missouri, at 45 mph {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: Watch KNWA now. Dan Skoff & Clint Boone are tracking severe weather in Benton County. Possible tornadoes may be brewing
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: New event. Severe Thunderstorm Warning from 5/25/2011 1:15 PM to 2:15 PM CDT for Christian Coun... Read more at {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: Severe Thunderstorm Warning for Camden and Miller County until 2:00pm. #MidMoWx
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: Shoutout to the sunshine this morning #EastSide #Tacoma
# Groundtruth label: Positive
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: Ohio Tornado Database contains reports of over 950 tornadoes that have touched down in Ohio between 1950-2010. {link} @mention
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: Catch The Fish Folks tomorrow at the Weds Downtown Farmers' Market 4-7.  Weather will be great - Copper River Sockeye salmon at great...
# Groundtruth label: Positive
# Snorkel label: Neutral / author is just sharing information
#
#
# *** Error ***
# Original tweet: It's hot as fuck outside . If y'all going out put on extra deodorant
# Groundtruth label: Negative
# Snorkel label: I can't tell
#
#
# *** Error ***
# Original tweet: @mention ...I am thinking you do not need another coat :p HOWEVER, if the weather there is as bad as my exboyf says, mayhap you do..
# Groundtruth label: Negative
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: Wednesday - Partly sunny. Slight chance of rain showers in the morning...then a slight chance of thunderstorms in...  {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: Its hot as a BITCH outside !
# Groundtruth label: Negative
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: Loving this weather (:
# Groundtruth label: Positive
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: It's too hot out. Fuckin aye
# Groundtruth label: Negative
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: RT @mention: Check out the ENTIRE album here!!! {link} then buy it, cuz it's HOT!!!!!
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: BLOG: Another Day, Another Round Of Thunderstorms {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: - this house is beyond cold..feels like imm layin inside a freezer..can we please turn OFF the A.C.. #freezing
# Groundtruth label: Negative
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: RT @mention: Who's excited for TPC this weekend? Sunshine,  beach & golf - life is good!
# Groundtruth label: Positive
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: RT @mention: RT @mention: BREAKING: Large, wedge tornado on the ground coming into Okla City LIVE on our weather blog {link} ...
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: Tornado season really is nvr over. If its a severe thunderstorm, a tornado can form RT @mention How long is (cont) {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: Listening to KFOR-TV via Weather Channel -- they are reporting tornado is 1/2 mile wide, debris 1.5 miles around tornado
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: Reed Timmer is following Fairview storm right now, while launching 6 probes into large tornado.
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: Needless to say, it is scorching out. I am still hot and I have been back inside for quite some time now.
# Groundtruth label: Negative
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: Now's the time to sign up for ABC 17 severe weather texts: {link} Follow @mention & Facebook: {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: Humidity could make temps feel like 101 today {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: RT @mention: RT @mention: U.S. National Severe Weather Alerts Map - WeatherBug.com {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: @mention storm? Be safe! The weather has been crazy lately!
# Groundtruth label: Negative
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: Just saw Snow White working at Lady Foot Locker, she was looking hot, seriously, she was the fairest of the mall
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Neutral / author is just sharing information
#
#
# *** Error ***
# Original tweet: Cold weather. Taylor Swift is playing. Suddenly sleepy..zzZzZ
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: national storm reports... here are the raw observations for the tornado reports today. {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: "D~""Driven"" aka David Zachary Rumley gettin' his ULTRA swagg on today. Watch OUT!!! He's puttin' out hot fire on... {link}"
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Neutral / author is just sharing information
#
#
# *** Error ***
# Original tweet: Severe Thunderstorm Warning for Fulton, Knox, and Peoria County in IL until 7:45pm CDT. #ilwx
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: Saw the storm damage in La Crosse, as did the gov. A WWII vet shares his storm story @mention on NBC15. {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: @mention yeah at times it's so hard to tell who's in the lifestyle, but then when you find out it's like duh should have known. she hot?
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: False friends are like our shadow, keeping close to us while we walk in the sunshine, but leaving us the instant... {link}
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: #ncwx Conditions for Durham, NC at 12:49 pm EDT: Current Conditions: Partly Cloudy, 86 FForecast: Mon - Isolated Thunderstorms. High:...
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: It WAS going to be sunny and 80 degrees in #Boston today (that's what they said just a few days ago.) How's  58 and rain? #enoughisenough
# Groundtruth label: Negative
# Snorkel label: I can't tell
#
#
# *** Error ***
# Original tweet: The vent next to the toliet in the guest bathroom provides for a perfect doo doo temp. #shittertwits
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: #WEATHER:  5:54 am : 66.0F. Feels F. 29.97% Humidity. 0.0MPH North Wind.
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: I can't tell
#
#
# *** Error ***
# Original tweet: Prayers going out to Joplin, Missouri and everyone affected by all this crazy weather!
# Groundtruth label: Negative
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: Sitting in deepsea world with a mixed slush puppy and a scone. :)
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: @mention it won't last too long...the storm that is.. :) nice & sunny in my neck of the woods..
# Groundtruth label: Positive
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: A storm with quarter-sized hail is making the situation in Joplin even tougher {link}
# Groundtruth label: Negative
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: Severe Thunderstorm Warning for Allen and Van Wert County in OH until 7:45pm EDT. #ohwx
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: RT @mention: Looks like t-storm with 60+ mph winds within 30 minutes of downtown #joplin
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: Thunderstorm Light Drizzle in Vicinity and 68 F at Jacksonville Municipal Airport, IL Winds are from the South at 13.8  {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: I can't tell
#
#
# *** Error ***
# Original tweet: Northern IN likely to go under a weather watch per SPC soon...details to come.
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: Good dreary, rainy, foggy, drizzly, misty, stormy morning everyone.
# Groundtruth label: Negative
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: Weather Alert: Flood Warning issued May 22 at 6:32PM MDT expiring May 23 at 9:32AM MDT by NWS Glasgow {link}... {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: @mention they got me goin out in this storm..riskin my life..just cause I can't afford to miss a day of class..smh!
# Groundtruth label: Negative
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: Severe Thunderstorm Warning for Kay and Noble County until 6:45pm. {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: I can't tell
#
#
# *** Error ***
# Original tweet: Severe Storm Damage In Southeast Wisconsin: At the height of Sunday's severe storms, thousands lost power in... {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: Militants storm Pakistani naval base in Karachi \n    (AP)\n: AP - Islamist militants stormed a naval base in t... {link}
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: #WEATHER:  2:55 pm : 86.0F. Feels F. 30.06% Humidity. 4.6MPH Southeast Wind.
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: #WEATHER:  4:53 pm : 89.0F. Feels F. 29.72% Humidity. 21.9MPH South Wind.
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: I can't tell
#
#
# *** Error ***
# Original tweet: just informed my sister that canucks fans stole 'the green man' from its always sunny in philly...she was surprised. THE MORE YOU KNOW ---*
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: #WEATHER:  1:53 pm : 59.0F. Feels 58F. 30.06% Humidity. 6.9MPH West Wind.
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: #WEATHER:  12:52 am: 74.0F. Feels F. 30.03% Humidity. 5.8MPH Southeast Wind.
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: Sundress weather is the best weather.
# Groundtruth label: Positive
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: So far today is pretty great weather wise for this 7lb hot dog BBQ.
# Groundtruth label: Positive
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: RT @mention: It'll be sunny again by time you land RT @mention: Every time I think about going back to Portland it starts ra ...
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: @mention A cheers to #ACBW with @mention Blue Dot Double IPA. Bottled sunshine.
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: #WEATHER:  7:52 am : 65.0F. Feels F. 29.53% Humidity. 16.1MPH Southwest Wind.
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: I can't tell
#
#
# *** Error ***
# Original tweet: Haters can make like bees wit no stingers n drop dead #Cold
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Neutral / author is just sharing information
#
#
# *** Error ***
# Original tweet: It's 82 degrees
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: SPC Severe Thunderstorm Watch 321 Status Reports: WW 0321 Status Reports         STATUS FOR WATCH 0321 HAS NO... {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: RT @mention: SEVERE STORM WARNING SE MN  13 MILES NORTH OF WINDOM...AND MOVING NORTH AT 40 MPH {link} for HD weather ...
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: Does it snow a lot in Idaho,Utah,Colorado and New Mexico in December? {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: This weather forecast is depressing
# Groundtruth label: Negative
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: Severe Thunderstorm Warning for Atchison and Leavenworth County in KS until 9:45pm. Updates as needed from Bryan Busby
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: Nothing like a lazy Sunday afternoon waiting for storm to roll in
# Groundtruth label: Positive
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: #WEATHER:  7:56 am : 67.0F. Feels F. 29.96% Humidity. 4.6MPH Southeast Wind.
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: RT @mention: Severe Thunderstorm Warning for Dakota, Goodhue, Rice and Steele County in MN until 2:30pm. More: {link} & o ...
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: On my way to celebrate the homie @mention's graduation. 2 degrees. 1 woman. #motivation
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Neutral / author is just sharing information
#
#
# *** Error ***
# Original tweet: RT @mention: I can't wait for the storm tonight :)
# Groundtruth label: Positive
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: Gunmen storm Afghan government building {link}
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: RT @mention: Life isn't about waiting for the storm to pass, it's about learning to dance in the rain.
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: "I can't wait until tomorrow night so that when I'm still alive, I'll tweet up a storm, ""world ends on Saturday"" my ass"
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: I can't tell
#
#
# *** Error ***
# Original tweet: @mention Hi Five! I love a bit of Snow Patrol! Have this band on now tho.  They are going to be HUGE.  {link}
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: It's fuckin hot out
# Groundtruth label: Negative
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: @mention check out dis video shit is hot song is crazy trust RT (@mention {link})
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: Sunshine linked to fatherhood | Parent Pages for parents, families ... {link}
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: Just got to my apt... It's 2 damn hot outside for me!
# Groundtruth label: Negative
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: #NMFire #NMwx Fire Weather Watch issued May 21 at 1:28PM MDT expiring May 23 at 9:00PM MDT by NWS Albuquerque... {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: Today's weather is simply *perfect*. Rowan's so happy to be outside. But oy, $18 on sunblock for him? My mother just used olive oil on us :/
# Groundtruth label: Positive
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: RT @mention: Learn about online masters psychology degrees {link}
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: @mention you around Detroit at all?  Got a weather page set up for it.
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: Footballer sparks Twitter storm: Twitter users have reacted to a footballer's bid to find out who is putting inf... {link}
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: #C4IforHumanity: Extreme Weather - North-America - USA {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: Sweden Climate, Temperatures &amp; Weather Info | It&#39;s a Stormy Life {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: I'll be at Shuckers - Wake Forest tonight, starting at 6:30! Fantastic weather for an evening on the patio!
# Groundtruth label: Positive
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: @mention good morning Viv how are you this beautiful sunny morning
# Groundtruth label: Positive
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: RT @mention: YO BRO #haveyouseenacouple -- Snow bunnies- iNTRuSHUNN FT East Coast E {link} via @mention
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Neutral / author is just sharing information
#
#
# *** Error ***
# Original tweet: @mention A warm sunny day deserves a delicious, gourmet and slightly pornographic hotdog from Wild Dawgs.....
# Groundtruth label: Positive
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: In Rhode Island and it's a beautiful sunny day!
# Groundtruth label: Positive
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: Valley Center area is under a several thunderstorm watch until 10 p.m.
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: #WEATHER:  4:53 pm : 67.0F. Feels F. 29.93% Humidity. 8.1MPH Southeast Wind.
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: @mention We can finally compete with your weather in FL! Sunny & 70 here in Chicago today!
# Groundtruth label: Positive
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: #WEATHER:  4:56 pm : 70.0F. Feels F. 29.96% Humidity. 6.9MPH East Wind.
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: {link} Montreal Weather Webcams st. Hubert street Plaza, Qc. Canada
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: Photo: weather forecast for the #Rapture {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: @mention hangin out on corners hangin wit da fellers lookim out 4 hot chicks lol
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Neutral / author is just sharing information
#
#
# *** Error ***
# Original tweet: Waiting patiently for the electric car. Glorious day in Caithness, huge skies and plenty of sunshine...
# Groundtruth label: Positive
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: Hope everyone is having better weather than we are here in New England.  Ugh, hope it stops raining sometime soon.
# Groundtruth label: Negative
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: I'm glad it's nice weather here for Bike to Work Day. Not that I did. Bike to work. I just like nice weather.
# Groundtruth label: Positive
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: #WEATHER:  9:56 pm : 67.0F. Feels F. 29.83% Humidity. 11.5MPH Northeast Wind.
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: eww its 81% humidity  today :I
# Groundtruth label: Negative
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: 78.1F (Feels: 78.1F) - Humidity: 87% - Wind: 9.2mph NE - Gust: 13.0mph - Pressure: 1008.7mb (+0.5)  #weather {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: RT @mention: This kind of weather makes me want to go swimming.
# Groundtruth label: Positive
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: Eat yourheart out too!i'm @ the vacation house.Nice weather&beautiful sight.Nothing like this in SG. ;p @mention  {link}
# Groundtruth label: Positive
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: #WEATHER:  7:53 pm : 79.0F. Feels F. 29.63% Humidity. 24.2MPH Southeast Wind.
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: I can't tell
#
#
# *** Error ***
# Original tweet: Sunshine parks and new hair scarves make life not so bad when @mention stays up all night.
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: misty, cloudy, rainy evening spoiled viewing of beautiful Niagara Falls...
# Groundtruth label: Negative
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: "The weather channel local on the 8s just said it was ""sunny"". LOL {link}"
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: I can't tell
#
#
# *** Error ***
# Original tweet: Out walking enjoying the sunshine...NOT!
# Groundtruth label: Negative
# Snorkel label: Neutral / author is just sharing information
#
#
# *** Error ***
# Original tweet: RT @mention Why does Lindsay Lohan hate Christmas? She's been in & out of rehab for dashing through the snow...LMMFAO
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: Mostly sunny this afternoon, high 84 (29 C).  Low  66 (19 C) tonight.
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: @mention yeah, i'm talking, you see these pics of the river up on the rocks, as opposed to storm conditions
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: Damn weather, just turn and stay sunny.
# Groundtruth label: Negative
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: "Severe Thunderstorm Warning until 05:45 PM CDT issued for Edwards & Kiowa Counties with 60mph gusts & 1.00"" hail possible"
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: Freezing, wet, and still looking at rocks @mention @mention
# Groundtruth label: Negative
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: it's a nice day in LA. sunny :)
# Groundtruth label: Positive
# Snorkel label: I can't tell
#
#
# *** Error ***
# Original tweet: New event. Severe Thunderstorm Warning from 5/19/2011 3:57 PM to 5:00 PM CDT for Woodward Count... Read more at {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: @mention Done with the rain and headed to the beach tomorrow.  Finally sunshine and sand!
# Groundtruth label: Positive
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: WZTV FOX17 :: Weather {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: Severe Thunderstorm Warning issued May 19 at 3:40PM MDT expiring May 19 at 4:30PM MDT by NWS Boulder {link}.... {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: I can't tell
#
#
# *** Error ***
# Original tweet: If a storm picks up, lean into the wind instead of turning away from it if you want to keep balance
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: @mention If this is what Seattle is like, I'm not surprised somebody killed Rosie Larsen. Everybody must be surly. #TheKilling #Rain
# Groundtruth label: Negative
# Snorkel label: I can't tell
#
#
# *** Error ***
# Original tweet: Amen RT @mention Bulls defense is too good to get blown out. They just have to weather this storm and take the lead in the 4th
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: Oh yeah forgot to say Today is my kinda weather #AllSmiles #Grateful
# Groundtruth label: Positive
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: @mention how's the weather there?
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: I don't remember the weather sucking this bad last May... Regardless, it feels good to just stay in and relax all day. #chillin
# Groundtruth label: Negative
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: Palm Beach County Commission cites Sunshine Law concerns for dumping committee of local leaders.{link}
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: "@mention REALLY HOT. turns out, he ALWAYS grunts during that dance move. it's louder in a diff. perf. really loud. like, ""ughhAHH~"""
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: RT @mention @mention Vote vote vote vote vote!!!!! 99jamz.com!!! Sunny Zoe!! RT!! Pls
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Neutral / author is just sharing information
#
#
# *** Error ***
# Original tweet: I love the weather in PHX right now!!
# Groundtruth label: Positive
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: RT @mention: Iso. t-storm this evening if anything, likely get the game in tonight. #Royals fcast: {link}  Sorry @mention ...
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: 60 degrees. And its almost the end of may. Wisconsin... I hate you.
# Groundtruth label: Negative
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: "The weather forecast for this evening looks fabulous! Stop by tonight's LPYP ""Rock the Boat"" Party at Columbia Yac {link}"
# Groundtruth label: Positive
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: Mostly sunny and 80 degrees saturday. Perfect weather for #preakness
# Groundtruth label: Positive
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: RT @mention: Tonight and tomorrow, partly cloudy. Lows around 56. Highs around 76. Chance of storms. #Richmond #weather
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: @mention Hey what's up stranger? not a whole lot over this way I'm back in MI and hating the weather lol What about u
# Groundtruth label: Negative
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: RT @mention: The 3rd world war hasn't even happened yet... and the crazy weather is from Earth changing and possibly from H.A.A.R. ...
# Groundtruth label: Negative
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: @mention correct! Weather is awful.. Headed out now to try and practice!
# Groundtruth label: Negative
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: The bad news about warm weather, there seem to be more assault crimes. {link}
# Groundtruth label: Negative
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: RT @mention: Its rockin at this maverick game. Dirk and durant are flat out cold on the basketball court.
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: @mention hows them weather in. hawaii
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: Fire Weather Watch issued May 18 at 5:52AM CDT expiring May 19 at 9:00PM CDT by NWS Midland-Odessa {link}... {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: Post Edited: La Crosse Technology Weather Direct WD-3308U-WAL 4 Day Internet Powered Wireless Forecaster {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: I kno everybody in AZ betta be outside enjoying this Good weather cuz I'm sure its gone be short lived smh
# Groundtruth label: Positive
# Snorkel label: I can't tell
#
#
# *** Error ***
# Original tweet: Um I would like a powerade slush. Thank you. RT @mention: finna be on this #HappyHour flow at Sonic #yesyes
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: I also need to know why it's 65 degrees out right now. Stooooopppp.
# Groundtruth label: Negative
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: "@mention They're cheeping up a storm, and he has that ""Where is your mother?!"" look.  LOL"
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: RT @mention: Just finished copy edit of A History of Ancient Britain. Emerged blinking into sunshine for first time in days. In boo ...
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: @mention stuck overnight?! That's awful! I've been delayed by blizzard but it was before my flight too off. I feel sorry for connecting.
# Groundtruth label: Negative
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: The Storm announce today that they have signed Tyler Thomas and Jeremy Bollinger to one-year deals.
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: @mention Happy Birthday....weather is so shitty yeeeesh! Well atleast smile bright :D
# Groundtruth label: Negative
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: Couldn't ask for a better forecast @mention @mention @mention @mention {link}
# Groundtruth label: Positive
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: RT @mention: Life is so much more manageable when the weather is nice.
# Groundtruth label: Positive
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: 50 degrees and rainy. Guess there's no cookout.
# Groundtruth label: Negative
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: Flash #flood warning in effect for parts of Long island due to tstorm. #SNE #weather #NYC  {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: A GATOR found on in jamestown, details at 7/10 plus sports and weather
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: RT @mention: Popcap is the Blizzard of casual games.  I could purchase *any* Popcap game sight unseen and know I was getting somethin ...
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Neutral / author is just sharing information
#
#
# *** Error ***
# Original tweet: US National Weather Service Lower Mississippi River Forecast Center The Vicksburg District of the US Army Corps of... {link}
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Tweet not related to weather condition
#
#
# *** Error ***
# Original tweet: @mention I know what you mean! :) the day is going well,  we are finally having nice weather
# Groundtruth label: Positive
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: Ew... bought a salad at the Sunshine store and the chicken has gone bad.  One bite won't make me get sick, right? Ick.
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Negative
#
#
# *** Error ***
# Original tweet: Scattered thunderstorms this afternoon, high 62 (17 C).  Low  51 (11 C) tonight.
# Groundtruth label: Neutral / author is just sharing information
# Snorkel label: Positive
#
#
# *** Error ***
# Original tweet: Chef Gelman of The Driskill joins us for a beer pairing duel against Chef Rob Snow of Judges' Hill Restaurant!!... {link}
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Neutral / author is just sharing information
#
#
# *** Error ***
# Original tweet: RT @mention: RT @mention RT @mention: @mention check out this hot shit ---&gt; (cont) {link}
# Groundtruth label: Tweet not related to weather condition
# Snorkel label: Negative
#
#
#
# *** Overall Performance Statistics ***
# Wrongly infered labels: 184 out of 246.0
# Accuracy of Snorkels model =  0.252032520325

# %% [markdown]
# **Take-away**: As shown above the performance of the trained discriminative model is the same as that of the generative model. The big difference between the two is that the discriminative model can be used to label new tweets without paying the additional cost of obtaining crowd labels.
