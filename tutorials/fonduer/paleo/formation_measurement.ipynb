# %% [markdown]
# # Tutorial: Extracting Formation Measurements from Paleontology Literature

# %% [markdown]
# # Introduction
#
# We will walk through the process of using `Fonduer` to extract relations from [**richly formatted** data](https://hazyresearch.github.io/snorkel/blog/fonduer.html), where information is conveyed via combinations of textual, structural, tabular, and visual expressions, as seen in webpages, business reports, product specifications, and scientific literature.
#
# In this tutorial, we use `Fonduer` to extract relations between paleontological formations and their corresponding physical measurements from paleontology journal articles on fossils and ancient organisms.
#
# The tutorial is broken into several parts, each covering a Phase of the `Fonduer` pipeline (as outlined in the [paper](https://arxiv.org/abs/1703.05028)):
#
# 1. KBC Initialization
# 2. Candidate Generation and Multimodal Featurization
# 3. Probabilistic Relation Classification
#
#
# # Phase 1: KBC Initialization
#
# In this first phase of `Fonduer`'s pipeline, `Fonduer` uses a user specified _schema_ to initialize a relational database where the output KB will be stored. Furthermore, `Fonduer` iterates over its input _corpus_ and transforms each document into a unified data model, which captures the variability and multimodality of richly formatted data. This unified data model then servers as an intermediate representation used in the rest of the phases.
#
# This preprocessed data is saved to a database. Connection strings can be specified by setting the `SNORKELDB` environment variable. If no database is specified, then SQLite at `./snorkel.db` is created by default. However, to enabled parallel execution, we use PostgreSQL throughout this tutorial.
#
# We initialize several variables for convenience that define what the database should be called and what level of parallelization the `Fonduer` pipeline will be run with. In the code below, we use PostgreSQL as our database backend.
#
# Before you continue, please make sure that you have PostgreSQL installed and have created a new database named `formation_measurement`.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import sys
import json

PARALLEL = 4 # assuming a quad-core machine
ATTRIBUTE = "formation_measurement"

os.environ['SNORKELDBNAME'] = ATTRIBUTE
os.environ['SNORKELDB'] = 'postgres://localhost:5432/' + os.environ['SNORKELDBNAME']
        
sys.path.append(os.environ['SNORKELHOME'] + '/tutorials/fonduer/paleo/')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1.1 Defining a Candidate Schema
#
# We first initialize a `SnorkelSession`, which manages the connection to the database automatically, and enables us to save intermediate results.

# %%
from snorkel.contrib.fonduer import SnorkelSession

session = SnorkelSession()

# %% [markdown]
# Next, we define the _schema_ of the relation we want to extract. This must be a subclass of Candidate, and we define it using a helper function. Here, we define a binary relation which connects two Span objects of text. This is what creates the relation's database table if it does not already exist.

# %%
from snorkel.contrib.fonduer.models import candidate_subclass

Formation_Measurement = candidate_subclass('Formation_Measurement', ['formation','measurement'])

# %% [markdown]
# Next, we define some measurements we want to extract.

# %%
measurements = ['delta13CTC', 'delta13CORG', 'delta13CIC', 'delta13C', 'delta18O', 'delta13CCARB', 'delta18OCARB']

# %% [markdown]
# ## 1.2 Parsing and Transforming the Input Documents into Unified Data Models
#
# Next, we load the corpus of datasheets and transform them into the unified data model. Each datasheet has a PDF and HTML representation. Both representations are used in conjunction to create a robust unified data model with textual, structural, tabular, and visual modality information. Note that since each document is independent of each other, we can parse the documents in parallel. Note that parallel execution will not work with SQLite, the default database engine. We depend on PostgreSQL for this functionality.
#
# ### Configuring an `HTMLPreprocessor`
# We start by setting the paths to where our documents are stored, and defining a `HTMLPreprocessor` to read in the documents found in the specified paths. `max_docs` specified the number of documents to parse. For the sake of this tutorial, we only look at 7 documents.
#
# **Note that you need to have run `download_data.sh` before executing these next steps or you won't have the documents needed for the tutorial.**

# %%
from snorkel.contrib.fonduer import HTMLPreprocessor, OmniParser

docs_path = os.environ['SNORKELHOME'] + '/tutorials/fonduer/paleo/data/html/'
pdf_path = os.environ['SNORKELHOME'] + '/tutorials/fonduer/paleo/data/pdf/'

max_docs = 7
doc_preprocessor = HTMLPreprocessor(docs_path, max_docs=max_docs)

# %% [markdown]
# ### Configuring an `OmniParser`
# Next, we configure an `OmniParser`, which serves as our `CorpusParser` for PDF documents. We use [CoreNLP](https://stanfordnlp.github.io/CoreNLP/) as a preprocessing tool to split our documents into phrases and tokens, and to provide annotations such as part-of-speech tags and dependency parse structures for these phrases. In addition, we can specify which modality information to include in the unified data model for each document. Below, we enable all modality information.

# %%
corpus_parser = OmniParser(structural=True, lingual=True, visual=True, pdf_path=pdf_path)
# %time corpus_parser.apply(doc_preprocessor, parallelism=PARALLEL)
# Out:
# Clearing existing...
# Running UDF...
# CPU times: user 2.11 s, sys: 68 ms, total: 2.18 s
# Wall time: 2min 12s

# %% [markdown]
# We can then use simple database queries (written in the syntax of [SQLAlchemy](http://www.sqlalchemy.org/), which `Fonduer` uses) to check how many documents and phrases (sentences) were parsed, or even check how many phrases and tables are contained in each document.

# %%
from snorkel.contrib.fonduer.models import Document, Phrase

print "Documents:", session.query(Document).count()
print "Phrases:", session.query(Phrase).count()
# Out:
# Documents: 7
# Phrases: 12942

# %% [markdown]
# ## 1.3 Dividing the Corpus into Test and Train
#
# We'll split the documents 5/1/1 into train/dev/test splits. Note that here we do this in a non-random order to preverse the consistency in the tutorial, and we reference the splits by 0/1/2 respectively.

# %%
docs = session.query(Document).order_by(Document.name).all()
ld   = len(docs)

train_docs = set()
dev_docs   = set()
test_docs  = set()
splits = (0.6, 0.8)
data = [(doc.name, doc) for doc in docs]
data.sort(key=lambda x: x[0])
for i, (doc_name, doc) in enumerate(data):
    if i < splits[0] * ld:
        train_docs.add(doc)
    elif i < splits[1] * ld:
        dev_docs.add(doc)
    else:
        test_docs.add(doc)
from pprint import pprint
pprint([x.name for x in train_docs])
# Out:
# [u'1-s2.0-S0301926806002701-main',
#  u'1-s2.0-S0031018215005167-main',
#  u'1-s2.0-S0037073898000566-main',
#  u'1-s2.0-S0016703714002981-main',
#  u'1-s2.0-S003101821500111X-main']

# %% [markdown]
# # Phase 2: Candidate Extraction & Multimodal Featurization
# Given the unified data model from Phase 1, `Fonduer` extracts relation candidates based on user-provided **matchers** and **throttlers**. Then, `Fonduer` leverages the multimodality information captured in the unified data model to provide multimodal features for each candidate.
#
# ## 2.1 Candidate Extraction
#
# The next step is to extract **candidates** from our corpus. A `candidate` is the object for which we want to make predictions. In this case, the candidates are pairs of paleontological formation names and their corresponding physical measurements as reported in journal articles. Our task is to predict which pairs are true in the associated document.
#
# To do so, we write **matchers** to define which spans of text in the corpus are instances of each entity. Matchers can leverage a variety of information from regular expressions, to dictionaries, to user-defined functions. Furthermore, different techniques can be combined to form higher quality matchers. In general, matchers should seek to be as precise as possible while maintaining complete recall.
#
# In our case, we need to write a matcher that defines a formation and a matcher to define a valid measurement value.
#
# ### Writing a simple measurement matcher
#
# Our measurement matcher can be a very simple regular expression since we know that we are looking for real values (sometimes written in scientific notation).

# %%
from snorkel.matchers import *

measurement_matcher = RegexMatchSpan(rgx = u'^[+-]?[ ]?((\d){1,2}[\.]\d*)([eE][+-]?\d+)?$', longest_match_only = True)

# %% [markdown]
# ### Writing a formation matcher
#
# For formations, we show that a matcher can leverage human knowledge as a dictionary of known formation names, and use user-defined names together. Here, we create a dictionary matcher for standard formation names.

# %%
### Dictionary of known transistor parts ###

with open(os.environ['SNORKELHOME'] + '/tutorials/fonduer/paleo/data/dict/dictionaries.json', 'r') as f:
    raw_dict_json = json.load(f)
formation_dict = raw_dict_json['success']['data'][0]['term_hits'].keys()

formation_dict += ['Angostura', 'Dolostone', 'Doushantuo', 'Dolostones', 'Heletz Formation', 
                   'Atar Group', 'Carboniferous sandstones']
            
formation_matcher = DictionaryMatch(d = formation_dict, ignore_case = True, longest_match_only = True)

# %% [markdown]
# Note, `Fonduer` can use *Union* to union all of different matchers together to form your final matcher.
#
# *matcher = Union(matcher_1, matcher_2)*

# %% [markdown]
# ### Define a relation's `ContextSpaces`
#
# Next, in order to define the "space" of all candidates that are even considered from the document, we need to define a `ContextSpace` for each component of the relation we wish to extract.
#
# In the case of formation names, the `ContextSpace` can be quite complex due to the need to handle the wide variety of formation names. To handle these, we consider all n-grams up to 6 words long.
#
# In contrast, the `ContextSpace` for measurement values is simpler: we don't need to look at more than two words at a time.

# %%
from snorkel.contrib.fonduer.fonduer.candidates import OmniNgrams

formation_ngrams = OmniNgrams(n_max=6, split_tokens=[])
measurement_ngrams = OmniNgrams(n_max=2, split_tokens=[])

# %% [markdown]
# ### Defining candidate `Throttlers`
#
# Next, we need to define **throttlers**, which allow us to further prune excess candidates and avoid unnecessarily materializing invalid candidates. Trottlers, like matchers, act as hard filters, and should be created to have high precision while maintaining complete recall, if possible.
#
# Here, we create a throttler that only keep candidates if they are all have visual features, and located within 2 pages, and measurement value are not start with `+`.

# %%
from snorkel.contrib.fonduer.lf_helpers import *

def formation_measurement_filter((formation, measurement)):
    return formation.sentence.is_visual() and measurement.sentence.is_visual() and \
        abs(bbox_from_span(formation).page - bbox_from_span(measurement).page) <= 1 and \
        measurement.get_span().startswith('+') == False
candidate_filter = formation_measurement_filter

# %% [markdown]
# ### Running the `CandidateExtractor`
#
# Now, we have all the component necessary to perform candidate extraction. We have defined the "space" of things to consider for each candidate, provided matchers that signal when a valid mention is seen, and a throttler to prunes away excess candidates. We now can define the `CandidateExtractor` with the contexts to extract from, the matchers, and the throttler to use.

# %%
from snorkel.contrib.fonduer.candidates import CandidateExtractor

candidate_extractor = CandidateExtractor(Formation_Measurement, 
                        [formation_ngrams, measurement_ngrams], 
                        [formation_matcher, measurement_matcher], 
                        candidate_filter=candidate_filter)

# %time candidate_extractor.apply(train_docs, split=0, parallelism=PARALLEL)
# Out:
# Clearing existing...
# Running UDF...
# [========================================] 100%
# CPU times: user 32.7 s, sys: 2.09 s, total: 34.8 s
# Wall time: 1min 46s

# %% [markdown]
# Here we specified that these `Candidates` belong to the training set by specifying `split=0`; recall that we're referring to train/dev/test as splits 0/1/2.

# %%
train_cands = session.query(Formation_Measurement).filter(Formation_Measurement.split == 0).all()
print "Number of candidates:", len(train_cands)
# Out:
# Number of candidates: 12289

# %% [markdown]
# ### Repeating for development and test splits
# Finally, we rerun the same operation for the other two document divisions: dev and test. For each, we simply load the `Corpus` object and run them through the `CandidateExtractor`.

# %%
# %%time
for i, docs in enumerate([dev_docs, test_docs]):
    candidate_extractor.apply(docs, split=i+1)
    print "Number of candidates:", session.query(Formation_Measurement).filter(Formation_Measurement.split == i+1).count()
# Out:
# Clearing existing...
# Running UDF...
# [========================================] 100%
# Number of candidates: 1731
# Clearing existing...
# Running UDF...
# [========================================] 100%
# Number of candidates: 5768
# CPU times: user 12.2 s, sys: 1.18 s, total: 13.3 s
# Wall time: 52.1 s

# %% [markdown]
# ## 2.2 Multimodal Featurization
# Unlike dealing with plain unstructured text, `Fonduer` deals with richly formatted data, and consequently featurizes each candidate with a baseline library of multimodal features.
#
# ### Featurize with `Fonduer`'s optimized Postgres Feature Annotator
# We now annotate the candidates in our training, dev, and test sets with features. The `BatchFeatureAnnotator` provided by `Fonduer` allows this to be done in parallel to improve performance.
#
# `featurizer.apply` takes three important arguments.
# * `split` defines which candidate set we are dealing with. For example, `split=0` is the training set.
# * `replace_key_set` determine whether or not replace, or reinitialize, the set of features to apply to candidates. That is, when `replace_key_set` is true, key set of features will be replaced with the key set of the features found in the split that is being processed.
# * `parallelism` determines how many processes to run in parallel.
#
# Notice that `replace_key_set=True` only for the first call to `featurizer.apply`, while the other calls have this parameter set to `False`. This is because we want to have the set of features we label candidates with defined by the features found in the set of training documents only. If a later call to `featurizer.apply` replaced the key set, then only the features of that particular split would be considered later in the pipeline.

# %%
from snorkel.contrib.fonduer import BatchFeatureAnnotator

featurizer = BatchFeatureAnnotator(Formation_Measurement)
# %time F_train = featurizer.apply(split=0, replace_key_set=True, parallelism=PARALLEL)
print F_train.shape
# %time F_dev = featurizer.apply(split=1, replace_key_set=False, parallelism=PARALLEL)
print F_dev.shape
# %time F_test = featurizer.apply(split=2, replace_key_set=False, parallelism=PARALLEL)
print F_test.shape
# Out:
# Clearing existing...
# Running UDF...
# Copying formation_measurement_feature to postgres
# COPY 12289
#
# CPU times: user 23.8 s, sys: 448 ms, total: 24.2 s
# Wall time: 9min 42s
# (12289, 35282)
# Clearing existing...
# Running UDF...
# Copying formation_measurement_feature_updates to postgres
# COPY 1731
#
# CPU times: user 1.27 s, sys: 208 ms, total: 1.48 s
# Wall time: 50.7 s
# (1731, 35282)
# Clearing existing...
# Running UDF...

# %% [markdown]
# At the end of this phase, `Fonduer` has generated the set of candidates and the feature matrix. Note that Phase 1 and 2 are relatively static and typically are only executed once during the KBC process.
#
# # Phase 3: Probabilistic Relation Classification
# In this phase, `Fonduer` applies user-defined **labeling functions**, which express various heuristics, patterns, and [weak supervision](http://hazyresearch.github.io/snorkel/blog/weak_supervision.html) strategies to label our data, to each of the candidates to create a label matrix that is used by our data programming engine.
#
# In the wild, hand-labeled training data is rare and expensive. A common scenario is to have access to tons of unlabeled training data, and have some idea of how to label them programmatically. For example:
# * We may be able to think of text patterns that would indicate a formation and measurement mention are related, for example a user can identify frequent keywords that appear to express the measurement relation.
# * We may have access to an external knowledge base that lists some pairs of formations and measurements, and can use these to noisily label some of our mention pairs.
# Our labeling functions will capture these types of strategies. We know that these labeling functions will not be perfect, and some may be quite low-quality, so we will model their accuracies with a generative model, which `Fonduer` will help us easily apply.
#
# Using data programming, we can then train machine learning models to learn which features are the most important in classifying candidates.
#
# ### Loading Gold Data
# For convenience in error analysis and evaluation, we have already annotated the dev and test set for this tutorial, and we'll now load it using an externally-defined helper function.
#
# Loading and saving external "gold" labels can be a bit messy, but is often a critical part of development, especially when gold labels are expensive and/or time-consuming to obtain. Snorkel stores all labels that are manually annotated in a **stable** format (called StableLabels), which is somewhat independent from the rest of Snorkel's data model, does not get deleted when you delete the candidates, corpus, or any other objects, and can be recovered even if the rest of the data changes or is deleted.
#
# Our general procedure with external labels is to load them into the `StableLabel` table, then use `Fonduer`'s helpers to load them into the main data model from there. If interested in example implementation details, please see the script we now load:

# %%
from paleo_utils import load_paleo_labels

gold_file = os.environ['SNORKELHOME'] + '/tutorials/fonduer/paleo/data/paleo_gold.csv'

load_paleo_labels(session, Formation_Measurement, gold_file, measurements ,annotator_name='gold')

# %% [markdown]
# ### Creating Labeling Functions
#
# In `Fonduer`, our primary interface through which we provide training signal to the end extraction model we are training is by writing labeling functions (**LFs**) (as opposed to hand-labeling massive training sets).
#
# A labeling function isn't anything special. It's just a Python function that accepts a `Candidate` as the input argument and returns TRUE (`1`) if it says the Candidate should be marked as true, FALSE (`-1`) if it says the `Candidate` should be marked as false, and ABSTAIN (`0`) if it doesn't know how to vote and abstains. In practice, many labeling functions are unipolar: they only label TRUEs and ABSTAINs, or only FALSEs and ABSTAINs.
#
# Recall that our goal is to ultimately train a high-performance classification model that predicts which of our Candidates are true mentions of formation measurement relations. It turns out that we can do this by writing potentially low-quality labeling functions!
#
# With `Fonduer`, labeling functions can be written using intuitive patterns discovered by inspecting the target corpus. A library of labeling function helpers can be found in `fonduer.lf_helpers`.
#
# For example, inspecting several document may reveal that measurement values are typically listed inside a table where the row header contains the measurement keywords. This intuitive pattern can be directly expressed as a labeling function. Similarly, the measurement keywords is an obvious positive signal.

# %%
# Helper functions
TRUE,FALSE,ABSTAIN = 1,-1,0

# %%
def isfloat(value):
  try:
    float(value)
    return True
  except ValueError:
    return False

# %% [markdown]
# We express several of these simple patterns below as a set of labeling functions:

# %%
from snorkel.contrib.fonduer.lf_helpers import *

def LF_page_distance(c):
    if abs(c[0].get_attrib_tokens('page')[0] - c[1].get_attrib_tokens('page')[0]) >= 2:
        return FALSE
    return ABSTAIN

def LF_page_order(c):
    if c[0].get_attrib_tokens('page')[0] < c[1].get_attrib_tokens('page')[0]:
        return FALSE
    return ABSTAIN

def LF_invalid_measuremnt(c):
    measurement = (''.join(c[1].get_span().split())).upper()
    return FALSE if (not isfloat(measurement)) or abs(float(measurement)) >= 100 else ABSTAIN

def LF_vert_ngrams(c):
    if c[1].sentence.table is None: return ABSTAIN
    ml = [_.upper() for _ in list(get_vert_ngrams(c[1], from_phrase=True))]
    me = ''.join(ml).upper()
    for m in measurements:
        if len(m) > 2:
            if m.upper() in me or m.upper().replace('DELTA', '8') in me or m.upper().replace('DELTA', 'D') in me:
                return ABSTAIN
        else:
            if m.upper() in ml or m.upper().replace('DELTA', '8') in ml or m.upper().replace('DELTA', 'D') in ml:
                return ABSTAIN
    return FALSE

def LF_LCA_and_Ngrams_and_colname(c):
    return TRUE if same_page(c) and c[1].sentence.table and LF_vert_ngrams(c)==0 and lowest_common_ancestor_depth(c)<=1 else ABSTAIN

# %% [markdown]
# Then, we collect all of the labeling function we would like to use into a single list, which is provided as input to the `LabelAnnotator`.

# %%
formation_measurement_lfs = [LF_page_distance, LF_invalid_measuremnt, LF_vert_ngrams, LF_LCA_and_Ngrams_and_colname]

# %% [markdown]
# ### Applying the Labeling Functions
#
# Next, we need to actually run the LFs over all of our training candidates, producing a set of `Labels` and `LabelKeys` (just the names of the LFs) in the database. We'll do this using the `LabelAnnotator` class, a `UDF` which we will again run with `UDFRunner`. Note that this will delete any existing `Labels` and `LabelKeys` for this candidate set. Also note that we are using `Fonduer`'s optimized batch label annotator, which runs in parallel and depends on having Postgres as the backend database.
#
# By default, `labeler.apply` will drop the existing table of labeling functions and the label values for each candidate. However, this behavior can be controlled by three parameters to the function to improve iteration performance and reduce redundant computation:
# - `split` defines which set to operate on (e.g. train, dev, or test)
# - `clear` can be `True` or `False`, and is `True` by default. When set to `False`, the labeling function table is not dropped, and the behavior of `labeler.apply` is defined by the following two parameters.
# - `update_keys` can be `True` or `False`. When `True`, the keys (which are each labeling function) are updated according to the set of labeling functions provided to the function. This should be set to `True` if new labeling functions are added. When `False`, no new LFs are evaluated and the keys of existing LFs remain the same.
# - `update_values` can be `True` or `False`. This defines how to resolve conflicts. When `True`, the values assigned to each candiate is updated to the new values when in conflict. This should be set to `True` if labeling function logic is edited, even though the name of the labeling function remains the same. When `False`, the existing labels assigned to each candidate are used, and newly computed labels are ignored.
# - `parallelism` is the amount of parallelism to use when labeling.
#
# With this in mind, we set `clear=True` when we first apply our labeling functions, and this ensures that the table is created and intialized with proper keys and values.
#
# In future iterations, we would typically set `clear=False, update_keys=True, update_values=True` so that we can simply update the set of LFs and their values without recreating the entire table.

# %%
from snorkel.contrib.fonduer import BatchLabelAnnotator

labeler = BatchLabelAnnotator(Formation_Measurement, lfs = formation_measurement_lfs)
# %time L_train = labeler.apply(split=0, clear=True, parallelism=PARALLEL)
print L_train.shape
# Out:
# Clearing existing...
# Running UDF...
# Copying formation_measurement_label_updates to postgres
# COPY 12289
#
# CPU times: user 502 ms, sys: 75.6 ms, total: 578 ms
# Wall time: 34.9 s
# (12289, 2)

# %% [markdown]
# Note that the returned matrix is a special subclass of the scipy.sparse.csr_matrix class, with some special features which we demonstrate below:

# %%
L_train.get_candidate(session, 0)
# Out:
# Formation_Measurement(Span("Carrara marble", sentence=26216, chars=[30,43], words=[5,6]), Span("5.", sentence=26185, chars=[5,6], words=[1,2]))

# %% [markdown]
# We can also view statistics about the resulting label matrix.
# * **Coverage** is the fraction of candidates that the labeling function emits a non-zero label for.
# * **Overlap** is the fraction candidates that the labeling function emits a non-zero label for and that another labeling function emits a non-zero label for.
# * **Conflict** is the fraction candidates that the labeling function emits a non-zero label for and that another labeling function emits a conflicting non-zero label for.
#
# In addition, because we have already loaded the gold labels, we can view the emperical accuracy of these labeling functions when compared to our gold labels:

# %%
from snorkel.annotations import load_gold_labels
L_gold_train = load_gold_labels(session, annotator_name='gold', split=0)
# %time L_train.lf_stats(L_gold_train)
# Out:
# CPU times: user 8.07 ms, sys: 559 µs, total: 8.63 ms
# Wall time: 8.63 ms
#                                j  Coverage  Overlaps  Conflicts  TP  FP    FN  \
# LF_LCA_and_Ngrams_and_colname  0  0.006917       0.0        0.0  85   0     0
# LF_vert_ngrams                 1  0.638864       0.0        0.0   0   0  2704
#
#                                  TN  Empirical Acc.
# LF_LCA_and_Ngrams_and_colname     0        1.000000
# LF_vert_ngrams                 5147        0.655585

# %% [markdown]
# ### Fitting the Generative Model
#
# Now, we'll train a model of the LFs to estimate their accuracies. Once the model is trained, we can combine the outputs of the LFs into a single, noise-aware training label set for our extractor. Intuitively, we'll model the LFs by observing how they overlap and conflict with each other.

# %%
from snorkel.learning import GenerativeModel

gen_model = GenerativeModel()
# %time gen_model.train(L_train, epochs=500, decay=0.9, step_size=0.001/L_train.shape[0], reg_param=0)
# Out:
# /Users/senwu/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:1401: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# CPU times: user 39.6 s, sys: 176 ms, total: 39.7 s
# Wall time: 39.9 s

# %% [markdown]
# We now apply the generative model to the training candidates to get the noise-aware training label set. We'll refer to these as the training marginals:

# %%
train_marginals = gen_model.marginals(L_train)

# %% [markdown]
# We'll look at the distribution of the training marginals:

# %%
import matplotlib.pyplot as plt
plt.hist(train_marginals, bins=20)
plt.show()

# %% [markdown]
# We can view the learned accuracy parameters as well.

# %%
gen_model.weights.lf_accuracy()
# Out:
# array([ 0.72881538,  0.73070967])

# %% [markdown]
# ### Training the Discriminative Model
#
# Now, we'll use the noisy training labels we generated in the last part to train our end extraction model. For this tutorial, we will be training a simple - but fairly effective - logistic regression model.
#
# We use the training marginals to train a discriminative model that classifies each Candidate as a true or false mention.

# %%
from snorkel.learning import SparseLogisticRegression

disc_model = SparseLogisticRegression()
# %time disc_model.train(F_train, train_marginals, n_epochs=200, lr=0.001)
# Out:
# [SparseLR] lr=0.001 l1=0.0 l2=0.0
# [SparseLR] Building model
# [SparseLR] Training model
# [SparseLR] #examples=7936  #epochs=200  batch size=100
# [SparseLR] Epoch 0 (2.71s)	Avg. loss=0.429473	NNZ=50977
# [SparseLR] Epoch 5 (15.69s)	Avg. loss=0.367919	NNZ=50977
# [SparseLR] Epoch 10 (28.76s)	Avg. loss=0.366825	NNZ=50977
# [SparseLR] Epoch 15 (43.41s)	Avg. loss=0.366513	NNZ=50977
# [SparseLR] Epoch 20 (57.00s)	Avg. loss=0.366350	NNZ=50977
# [SparseLR] Epoch 25 (68.53s)	Avg. loss=0.366261	NNZ=50977
# [SparseLR] Epoch 30 (81.35s)	Avg. loss=0.366203	NNZ=50977
# [SparseLR] Epoch 35 (94.93s)	Avg. loss=0.366165	NNZ=50977
# [SparseLR] Epoch 40 (108.15s)	Avg. loss=0.366158	NNZ=50977
# [SparseLR] Epoch 45 (120.92s)	Avg. loss=0.366162	NNZ=50977
# [SparseLR] Epoch 50 (133.52s)	Avg. loss=0.366184	NNZ=50977
# [SparseLR] Epoch 55 (147.59s)	Avg. loss=0.366263	NNZ=50977
# [SparseLR] Epoch 60 (161.01s)	Avg. loss=0.366133	NNZ=50977
# [SparseLR] Epoch 65 (173.89s)	Avg. loss=0.366450	NNZ=50977
# [SparseLR] Epoch 70 (186.67s)	Avg. loss=0.366209	NNZ=50977
# [SparseLR] Epoch 75 (200.32s)	Avg. loss=0.366261	NNZ=50977
# [SparseLR] Epoch 80 (216.24s)	Avg. loss=0.366590	NNZ=50977
# [SparseLR] Epoch 85 (229.36s)	Avg. loss=0.366137	NNZ=50977
# [SparseLR] Epoch 90 (242.48s)	Avg. loss=0.366126	NNZ=50977
# [SparseLR] Epoch 95 (257.52s)	Avg. loss=0.366239	NNZ=50977
# [SparseLR] Epoch 100 (270.74s)	Avg. loss=0.366253	NNZ=50977
# [SparseLR] Epoch 105 (284.46s)	Avg. loss=0.366286	NNZ=50977
# [SparseLR] Epoch 110 (297.35s)	Avg. loss=0.366627	NNZ=50977
# [SparseLR] Epoch 115 (310.16s)	Avg. loss=0.366259	NNZ=50977
# [SparseLR] Epoch 120 (323.50s)	Avg. loss=0.366180	NNZ=50977
# [SparseLR] Epoch 125 (336.40s)	Avg. loss=0.366181	NNZ=50977
# [SparseLR] Epoch 130 (348.44s)	Avg. loss=0.366242	NNZ=50977
# [SparseLR] Epoch 135 (363.03s)	Avg. loss=0.366168	NNZ=50977
# [SparseLR] Epoch 140 (377.03s)	Avg. loss=0.366233	NNZ=50977
# [SparseLR] Epoch 145 (390.62s)	Avg. loss=0.366565	NNZ=50977
# [SparseLR] Epoch 150 (405.23s)	Avg. loss=0.366354	NNZ=50977
# [SparseLR] Epoch 155 (419.10s)	Avg. loss=0.366250	NNZ=50977
# [SparseLR] Epoch 160 (433.19s)	Avg. loss=0.366228	NNZ=50977
# [SparseLR] Epoch 165 (447.45s)	Avg. loss=0.366456	NNZ=50977
# [SparseLR] Epoch 170 (461.40s)	Avg. loss=0.366469	NNZ=50977
# [SparseLR] Epoch 175 (475.03s)	Avg. loss=0.366195	NNZ=50977
# [SparseLR] Epoch 180 (489.12s)	Avg. loss=0.366226	NNZ=50977
# [SparseLR] Epoch 185 (502.76s)	Avg. loss=0.366253	NNZ=50977
# [SparseLR] Epoch 190 (516.19s)	Avg. loss=0.366374	NNZ=50977
# [SparseLR] Epoch 195 (529.54s)	Avg. loss=0.366261	NNZ=50977
# [SparseLR] Epoch 199 (540.30s)	Avg. loss=0.366183	NNZ=50977
# [SparseLR] Training done (540.30s)
# CPU times: user 10min 18s, sys: 57 s, total: 11min 15s
# Wall time: 9min

# %% [markdown]
# ### Evaluating on the Test Set
# In this final section, we'll get the score we've been after: the performance of the extraction model on the blind test set (split 2). First, we load the test set labels and gold candidates from earlier:

# %%
from snorkel.annotations import load_gold_labels
L_gold_test = load_gold_labels(session, annotator_name='gold', split=2)

# %% [markdown]
# Now, we score using the discriminitive model:

# %%
tp, fp, tn, fn = disc_model.score(session, F_test, L_gold_test, b=0.4)
# Out:
# ========================================
# Scores (Un-adjusted)
# ========================================
# Pos. class accuracy: 0.523
# Neg. class accuracy: 0.42
# Precision            0.324
# Recall               0.523
# F1                   0.4
# ----------------------------------------
# TP: 1047 | FP: 2185 | TN: 1583 | FN: 953
# ========================================

# %%
from paleo_utils import entity_level_f1

# %time (TP, FP, FN) = entity_level_f1(tp.union(fp), gold_file, test_docs, measurements)
# Out:
# ========================================
# Scoring on Entity-Level Gold Data
# ========================================
# Corpus Precision 0.176
# Corpus Recall    0.955
# Corpus F1        0.297
# ----------------------------------------
# TP: 105 | FP: 492 | FN: 5
# ========================================
#
# CPU times: user 4.79 s, sys: 199 ms, total: 4.99 s
# Wall time: 5.96 s

# %% [markdown]
# # Phase 4:  Error Analysis & Iterative KBC
#
# During the development process, we can iteratively improve the quality of our labeling functions through error analysis, without executing the full pipeline as in previous techniques.
#
# You may have noticed that our final score is about 26 F1 points. To remedy this and improve our quality, we can perform error analysis to understand what kinds of patterns we may have missed, or what issues exist with our labeling functions. Then, we can edit our set of labeling functions and rerun Phase 3, Probabilistic Relation Classification.

# %% [markdown]
# ## Error Analysis
# For example, notice that our `entity_level_f1` returns `TP`, `FP`, `FN` sets. We can also see that our recall is high, but we have low precision, so let's look at our false positivies, `FP`.

# %%
FP
# Out:
# {(u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-0.36'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-0.42'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-0.96'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-1.05'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-1.33'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-1.43'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-1.45'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-1.6'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-1.66'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-1.73'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-1.76'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-1.77'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-1.79'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-10.66'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-11.09'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-11.66'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-11.77'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-11.81'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-11.92'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-2.06'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-2.15'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-2.19'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-2.32'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-2.4'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-2.53'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-2.55'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-2.56'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-2.65'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-2.84'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-2.86'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-3.07'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-3.09'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-3.25'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-3.35'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-3.36'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-3.46'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-3.52'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-3.53'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-3.6'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-3.61'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-3.68'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-3.73'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-3.78'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-4.03'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-4.12'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-4.13'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-4.22'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-4.27'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-4.28'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-4.32'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-4.34'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-4.35'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-4.43'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-4.5'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-4.57'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-4.6'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-4.73'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-5.01'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-5.19'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-5.21'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-5.24'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-5.27'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-5.33'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-5.39'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-5.61'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-5.72'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-6.02'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-6.44'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-6.57'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-6.58'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-6.65'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-6.86'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-6.88'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-7.04'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-7.59'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-7.73'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-8.05'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-8.26'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-8.27'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-8.62'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-8.77'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-8.81'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-9.04'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-9.12'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-9.45'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'-9.86'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.01'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.02'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.09'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.1'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.12'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.14'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.15'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.16'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.17'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.18'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.19'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.21'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.25'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.28'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.3'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.31'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.32'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.33'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.34'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.35'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.36'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.37'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.38'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.39'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.47'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.51'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.52'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.53'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.54'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.56'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.58'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.59'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.6'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.61'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.62'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.63'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.64'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.65'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.66'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.67'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'0.76'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'1.01'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'1.03'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'1.04'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'1.05'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'1.06'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'1.07'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'1.08'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'1.09'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'1.11'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'1.12'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'1.13'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'1.14'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'1.15'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'1.16'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'1.17'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'1.4'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'1.5'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'1.66'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'1.7'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'10.4'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'10.43'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'13.5'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'13.78'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'13.9'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'15.39'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'15.79'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'18.67'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'2.'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'2.29'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'2.37'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'2.8'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'2.84'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'2.88'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'20.8'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'21.4'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'21.8'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'23.3'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'23.8'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'23.9'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'24.5'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'3.'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'3.18'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'3.5'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'3.53'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'4.'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'5.02'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'5.8'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'6.8'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'7.1'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'7.3'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'7.35'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'7.47'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'71.1'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'71.9'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'72.5'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'75.97'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'77.96'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'78.14'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'79.46'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'8.4'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'8.9'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'9.5'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'CARRARA MARBLE', u'9.6'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-0.36'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-1.33'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-1.43'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-1.6'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-1.60'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-1.66'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-1.77'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-1.79'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-10.66'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-11.09'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-11.66'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-11.81'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-11.92'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-12.94'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-2.06'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-2.32'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-2.53'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-2.65'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-2.84'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-3.09'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-3.25'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-3.35'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-3.46'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-3.53'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-3.61'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-3.68'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-3.73'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-4.03'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-4.12'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-4.13'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-4.22'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-4.27'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-4.28'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-4.34'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-5.19'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-5.21'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-5.24'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-5.27'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-5.33'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-5.61'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-6.44'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-6.57'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-6.58'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-6.65'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-6.86'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-6.88'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-7.04'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-7.59'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-7.73'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-8.05'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-8.26'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-8.27'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-8.62'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-8.77'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-8.81'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-9.12'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-9.45'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'-9.86'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'0.01'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'0.02'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'0.09'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'0.12'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'0.14'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'0.16'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'0.17'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'0.19'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'0.25'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'0.28'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'0.3'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'0.31'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'0.32'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'0.33'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'0.34'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'0.35'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'0.36'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'0.37'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'0.39'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'0.52'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'0.53'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'0.58'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'0.76'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'0.88'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'1.03'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'1.04'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'1.05'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'1.06'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'1.08'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'1.09'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'1.11'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'1.12'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'1.13'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'1.14'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'1.15'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'1.4'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'1.60'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'1.7'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'10.4'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'11.92'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'12.9'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'12.94'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'13.5'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'13.78'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'13.9'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'15.39'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'15.79'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'18.67'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'2.29'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'2.37'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'2.53'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'2.8'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'2.84'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'2.88'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'20.8'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'21.4'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'21.8'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'23.3'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'23.8'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'23.9'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'24.5'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'3.18'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'3.5'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'3.53'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'4.22'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'4.28'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'4.7'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'4.73'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'5.02'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'5.8'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'6.8'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'7.1'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'7.3'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'7.35'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'7.47'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'71.1'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'71.9'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'75.97'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'78.14'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'79.46'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'8.4'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'8.77'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'8.8'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'9.45'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'9.5'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'DOLOSTONE', u'9.6'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'-0.30'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'-0.5'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'-0.82'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'-1.4'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'-1.60'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'-2.19'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'-3.4'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'-3.50'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'-5.6'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.01'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.02'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.09'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.1'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.12'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.14'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.16'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.17'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.18'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.19'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.25'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.28'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.29'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.3'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.31'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.32'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.33'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.34'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.35'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.36'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.37'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.38'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.39'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.47'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.49'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.5'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.51'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.53'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.54'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.56'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.57'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.58'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.59'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.6'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.61'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.62'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.63'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.64'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.65'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.66'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.67'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.69'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.71'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.72'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.73'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.74'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.76'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.77'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.82'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'0.88'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'1.'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'1.01'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'1.03'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'1.04'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'1.05'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'1.06'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'1.07'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'1.08'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'1.09'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'1.1'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'1.11'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'1.12'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'1.13'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'1.14'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'1.16'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'1.17'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'1.4'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'1.5'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'1.60'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'1.66'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'1.7'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'10.'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'10.4'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'10.43'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'11.92'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'12.9'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'12.94'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'13.5'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'13.78'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'13.9'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'15.39'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'15.79'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'18.67'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'2.'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'2.29'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'2.37'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'2.53'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'2.65'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'2.78'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'2.8'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'2.84'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'2.88'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'2.89'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'20.8'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'21.4'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'21.8'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'23.3'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'23.8'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'23.9'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'24.5'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'28.'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'3.'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'3.13'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'3.18'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'3.46'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'3.5'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'3.53'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'4.'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'4.22'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'4.28'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'4.7'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'4.73'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'5.'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'5.02'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'5.2'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'5.8'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'6.'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'6.8'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'6.86'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'7.'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'7.1'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'7.3'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'7.35'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'7.47'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'71.1'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'71.9'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'72.5'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'75.97'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'77.96'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'78.14'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'79.46'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'8.'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'8.4'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'8.77'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'8.8'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'8.9'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'9.'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'9.45'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'9.5'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'HELETZ FORMATION', u'9.6'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'REWAN GROUP', u'-1.66'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'REWAN GROUP', u'-12.94'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'REWAN GROUP', u'-5.6'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'REWAN GROUP', u'-6.86'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'REWAN GROUP', u'0.3'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'REWAN GROUP', u'0.53'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'REWAN GROUP', u'0.69'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'REWAN GROUP', u'10.'),
#  (u'1-S2.0-S0375674210001536-MAIN', u'REWAN GROUP', u'9.')}

# %% [markdown]
# So, let's inspect one of those candidates using our visualization tools:

# %%
from snorkel.contrib.fonduer.visualizer import *
from paleo_utils import entity_to_candidates
vis = Visualizer(pdf_path)

# Get a list of candidates that match the FN[10] entity
test_cands = session.query(Formation_Measurement).filter(Formation_Measurement.split == 2).all()
fp_cands = entity_to_candidates(list(FP)[10], test_cands)
# Display a candidate
vis.display_candidates([fp_cands[0]])
# Out:
# <wand.image.Image: 440a101 'PDF' (595x793)>
# <wand.image.Image: 7dbe900 'PDF' (595x793)>

# %% [markdown]
# Here, the candidates are boxed in yellow. We see that the `-1.4` falls within the range of numbers that our matcher for measurement values allows. By inspecting candidates like this, or just by examining the problematic PDFs directly, we can notice some patterns that we can exploit as new labeling functions.

# %% [markdown]
# ## Iteratively Improving Labeling Functions
#
# From this error analysis, we may notice two important things. First, our original set of labeling functions had no labeling functions that labeled candidates a negative. This resulted in most skewing the models to accept most candidates, and hurt our precision. Second, we have now noticed that we need to focus on negatively labeling numbers that pass through our measurement value matchers, but are not related to particular formations.
#
# Below are a set of negative labeling functions that capture some of these patterns. For example, we label candidates an negative if the formation is found on a later page than the measurement (as formations are typically introduced before their measurements are shown). Other negative patterns include the fact that we notice that all the measurements we are looking for are typically less than the value `50`, and are usually not found on the first page.

# %%
def LF_mention_order(c):
    if c[0].get_attrib_tokens('page')[0] > c[1].get_attrib_tokens('page')[0]:
        return FALSE
    return ABSTAIN

def LF_invalid_measuremnt_1(c):
    measuremnt = (''.join(c[1].get_span().split())).upper()
    return FALSE if (not isfloat(measuremnt)) or abs(float(measuremnt)) >= 50 else ABSTAIN

def LF_invalid_measurement_location(c):
    if c[1].get_attrib_tokens('page')[0] == 0:
        return FALSE
    return ABSTAIN

# %% [markdown]
# Then, we can add these to our list of labeling functions

# %%
formation_measurement_lfs_1 = [
    LF_mention_order,
    LF_invalid_measuremnt_1,
    LF_invalid_measurement_location
]

# %% [markdown]
# And rerun labeling. Importantly, this time we set `clear=False`, `update_keys=True` and `update_values=True` to reflect the fact that we are adding new labeling functions, but do not want to throw away the computations already performed in the previous iteration.

# %%
labeler = BatchLabelAnnotator(Formation_Measurement, lfs = formation_measurement_lfs_1)
# %time L_train = labeler.apply(split=0, clear=False, update_keys=True, update_values=True, parallelism=PARALLEL)
print L_train.shape
# Out:
# Running UDF...
# Copying formation_measurement_label_updates to postgres
# COPY 12289
#
# CPU times: user 658 ms, sys: 119 ms, total: 778 ms
# Wall time: 23.9 s
# (12289, 4)

# %%
gen_model = GenerativeModel()
# %time gen_model.train(L_train, epochs=500, decay=0.9, step_size=0.001/L_train.shape[0], reg_param=0)
train_marginals = gen_model.marginals(L_train)
# Out:
# CPU times: user 1min 4s, sys: 242 ms, total: 1min 4s
# Wall time: 1min 4s

# %%
disc_model = SparseLogisticRegression()
# %time disc_model.train(F_train, train_marginals, n_epochs=200, lr=0.001)
tp, fp, tn, fn = disc_model.score(session, F_test, L_gold_test, b=0.4)
# Out:
# [SparseLR] lr=0.001 l1=0.0 l2=0.0
# [SparseLR] Building model
# [SparseLR] Training model
# [SparseLR] #examples=9513  #epochs=200  batch size=100
# [SparseLR] Epoch 0 (3.23s)	Avg. loss=0.345215	NNZ=50977
# [SparseLR] Epoch 5 (17.41s)	Avg. loss=0.273662	NNZ=50977
# [SparseLR] Epoch 10 (32.36s)	Avg. loss=0.271334	NNZ=50977
# [SparseLR] Epoch 15 (46.73s)	Avg. loss=0.270300	NNZ=50977
# [SparseLR] Epoch 20 (61.70s)	Avg. loss=0.269825	NNZ=50977
# [SparseLR] Epoch 25 (76.90s)	Avg. loss=0.269587	NNZ=50977
# [SparseLR] Epoch 30 (91.79s)	Avg. loss=0.269459	NNZ=50977
# [SparseLR] Epoch 35 (106.18s)	Avg. loss=0.269445	NNZ=50977
# [SparseLR] Epoch 40 (121.81s)	Avg. loss=0.269395	NNZ=50977
# [SparseLR] Epoch 45 (138.40s)	Avg. loss=0.269451	NNZ=50977
# [SparseLR] Epoch 50 (154.29s)	Avg. loss=0.269419	NNZ=50977
# [SparseLR] Epoch 55 (168.37s)	Avg. loss=0.269425	NNZ=50977
# [SparseLR] Epoch 60 (183.97s)	Avg. loss=0.269440	NNZ=50977
# [SparseLR] Epoch 65 (198.73s)	Avg. loss=0.269428	NNZ=50977
# [SparseLR] Epoch 70 (214.19s)	Avg. loss=0.269432	NNZ=50977
# [SparseLR] Epoch 75 (229.76s)	Avg. loss=0.269460	NNZ=50977
# [SparseLR] Epoch 80 (245.28s)	Avg. loss=0.269505	NNZ=50977
# [SparseLR] Epoch 85 (260.75s)	Avg. loss=0.269377	NNZ=50977
# [SparseLR] Epoch 90 (275.49s)	Avg. loss=0.269605	NNZ=50977
# [SparseLR] Epoch 95 (290.87s)	Avg. loss=0.269440	NNZ=50977
# [SparseLR] Epoch 100 (306.29s)	Avg. loss=0.269434	NNZ=50977
# [SparseLR] Epoch 105 (321.41s)	Avg. loss=0.269471	NNZ=50977
# [SparseLR] Epoch 110 (336.97s)	Avg. loss=0.269477	NNZ=50977
# [SparseLR] Epoch 115 (352.36s)	Avg. loss=0.269486	NNZ=50977
# [SparseLR] Epoch 120 (367.76s)	Avg. loss=0.269519	NNZ=50977
# [SparseLR] Epoch 125 (383.44s)	Avg. loss=0.269455	NNZ=50977
# [SparseLR] Epoch 130 (399.86s)	Avg. loss=0.269434	NNZ=50977
# [SparseLR] Epoch 135 (416.82s)	Avg. loss=0.269464	NNZ=50977
# [SparseLR] Epoch 140 (433.62s)	Avg. loss=0.269444	NNZ=50977
# [SparseLR] Epoch 145 (449.98s)	Avg. loss=0.269495	NNZ=50977
# [SparseLR] Epoch 150 (467.00s)	Avg. loss=0.269472	NNZ=50977
# [SparseLR] Epoch 155 (483.41s)	Avg. loss=0.269440	NNZ=50977
# [SparseLR] Epoch 160 (501.76s)	Avg. loss=0.269522	NNZ=50977
# [SparseLR] Epoch 165 (519.17s)	Avg. loss=0.269488	NNZ=50977
# [SparseLR] Epoch 170 (536.05s)	Avg. loss=0.269507	NNZ=50977
# [SparseLR] Epoch 175 (553.36s)	Avg. loss=0.269451	NNZ=50977
# [SparseLR] Epoch 180 (571.59s)	Avg. loss=0.269509	NNZ=50977
# [SparseLR] Epoch 185 (589.78s)	Avg. loss=0.269464	NNZ=50977
# [SparseLR] Epoch 190 (608.06s)	Avg. loss=0.269437	NNZ=50977
# [SparseLR] Epoch 195 (626.43s)	Avg. loss=0.269530	NNZ=50977
# [SparseLR] Epoch 199 (640.43s)	Avg. loss=0.269430	NNZ=50977
# [SparseLR] Training done (640.43s)
# CPU times: user 12min 14s, sys: 56.7 s, total: 13min 11s
# Wall time: 10min 40s
# ========================================
# Scores (Un-adjusted)
# ========================================
# Pos. class accuracy: 0.183
# Neg. class accuracy: 0.867
# Precision            0.422
# Recall               0.183
# F1                   0.255
# ----------------------------------------
# TP: 366 | FP: 501 | TN: 3267 | FN: 1634
# ========================================

# %%
# %time (TP, FP, FN) = entity_level_f1(tp.union(fp), gold_file, test_docs, measurements)
# Out:
# ========================================
# Scoring on Entity-Level Gold Data
# ========================================
# Corpus Precision 0.336
# Corpus Recall    0.682
# Corpus F1        0.45
# ----------------------------------------
# TP: 75 | FP: 148 | FN: 35
# ========================================
#
# CPU times: user 24.1 ms, sys: 1.72 ms, total: 25.8 ms
# Wall time: 26.8 ms

# %% [markdown]
# Using these new LFs, we've significantly improved precision and recall for an F1 score of about 45.
