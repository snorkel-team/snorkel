# %% [markdown]
# # HARDWARE

# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

"""
To change attributes:
1) Change ATTRIBUTE and you're good to go
"""
ATTRIBUTE = 'stg_temp_min'
COUNTER = 0
PARALLEL = 20
PARALLEL_EXTRACTION = 8
DEV_SIZE = 125

import os
import sys
sys.path.append(os.environ['SNORKELHOME'] + '/tutorials/tables/')
snorkel_postgres = os.environ['SNORKELDB'].startswith('postgres')
print snorkel_postgres
# Out:
# True

# %%
import os
if snorkel_postgres:
    os.environ['SNORKELDBNAME'] = ATTRIBUTE + str(COUNTER)
    print os.system("dropdb " + os.environ['SNORKELDBNAME'])
    print os.system("createdb " + os.environ['SNORKELDBNAME'])
    print "SNORKELDBNAME = %s" % os.environ['SNORKELDBNAME']
else:
    try:
        os.remove('snorkel.db')
    except:
        pass

from snorkel import SnorkelSession
session = SnorkelSession()
# Out:
# 0
# 0
# SNORKELDBNAME = stg_temp_min0

# %% [markdown]
# ## Parsing

# %%
import os
if snorkel_postgres:
    from snorkel.async_parser import parse_corpus, HTMLParser, AsyncOmniParser
    print "Starting async parse..."
    
    # PARSE DEV
    docs_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/dev/html/'
    pdf_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/dev/pdf/'
    doc_parser = HTMLParser()
    context_parser = AsyncOmniParser(blacklist=['style'], flatten=['span','br'], 
                                     tabular=True, lingual=True,
                                     visual=True, pdf_path=pdf_path)
    # %time corpus = parse_corpus(session, 'Hardware Dev', docs_path,\
                                doc_parser, context_parser,\
                                max_docs=DEV_SIZE, parallel=PARALLEL)
    print "%s contains %d documents" % (corpus, len(corpus))
else:
    from snorkel.parser import CorpusParser, HTMLParser, OmniParser
    from snorkel.utils import get_ORM_instance
    from snorkel.queries import split_corpus

    print "Starting sync parse..."
    
    # PARSE DEV
    docs_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/dev/html/'
    pdf_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/dev/pdf/'
    doc_parser = HTMLParser(path=docs_path)
    context_parser = AsyncOmniParser(blacklist=['style'], flatten=['span','br'], 
                                 tabular=True, lingual=True,
                                 visual=True, pdf_path=pdf_path)
    cp = CorpusParser(doc_parser, context_parser, max_docs=125)

    # %time corpus = cp.parse_corpus(name='Hardware Dev', session=session)
    print "%s contains %d documents" % (corpus, len(corpus))
    session.add(corpus)
    session.commit()
# Out:
# Starting async parse...
# [========================================] 100%
# CPU times: user 400 ms, sys: 276 ms, total: 676 ms
# Wall time: 1min 8s
# Corpus (Hardware Dev) contains 122 documents

# %% [markdown]
# ### Save Corpus

# %%
# If necessary
if not snorkel_postgres:
    import os
    os.system('cp snorkel.db snorkel.db\ corpus');

# %% [markdown]
# ## Extraction

# %%
from snorkel.models import candidate_subclass

Part_Attr = candidate_subclass('Part_Attr', ['part','attr'])

# %% [markdown]
# ### Define Matchers

# %%
from hardware_matchers import get_matcher

part_matcher = get_matcher('part_rgx')
attr_matcher = get_matcher(ATTRIBUTE)

# %% [markdown]
# ### Define ContextSpaces

# %%
from hardware_spaces import get_space
# TEMP
from hardware_spaces import OmniNgramsPart
    
part_ngrams = OmniNgramsPart(n_max=3, expand=False)
attr_ngrams = get_space(ATTRIBUTE)

# %% [markdown]
# ### Run CandidateExtractor

# %%
from snorkel.models import Corpus
from snorkel.candidates import CandidateExtractor
from snorkel.utils import get_ORM_instance
from snorkel.async_candidates import parallel_extract

ce = CandidateExtractor(Part_Attr, 
                        [part_ngrams, attr_ngrams], 
                        [part_matcher, attr_matcher], 
                        throttler=None)


for corpus_name in ['Hardware Dev']:
    corpus = get_ORM_instance(Corpus, session, corpus_name)
    print "Extracting Candidates from %s" % corpus
    # %time candidates = parallel_extract(session, ce, corpus, \
                                        corpus_name + ' Candidates', \
                                        parallel=PARALLEL_EXTRACTION)
    session.add(candidates)
    print "%s contains %d Candidates" % (candidates, len(candidates))
session.commit()
# Out:
# Extracting Candidates from Corpus (Hardware Dev)
# [========================================] 100%
# CPU times: user 52 ms, sys: 88 ms, total: 140 ms
# Wall time: 19.1 s
# Candidate Set (Hardware Dev Candidates) contains 15907 Candidates

# %% [markdown]
# ## Apply Rules

# %%
from snorkel.lf_helpers import is_horz_aligned, get_horz_ngrams

def baseline_rules(c):
    if ((not c.part.is_tabular() or is_horz_aligned(c)) and 
        'temperature' in get_horz_ngrams(c.attr)):
        return True
    else:
        return False

passing_candidates = set()
for c in candidates:
    if baseline_rules(c):
        passing_candidates.add(c)

print "%d/%d candidates accepted" % (len(passing_candidates), len(candidates))
# Out:
# 1883/15907 candidates accepted

# %%
from snorkel.models import Corpus
from hardware_utils import entity_level_f1_from_candidates
import os

gold_file = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/dev/hardware_dev_gold.csv'
corpus = session.query(Corpus).filter(Corpus.name == 'Hardware Dev').one()
(TP, FP, FN) = entity_level_f1_from_candidates(passing_candidates, gold_file, ATTRIBUTE, corpus)
# Out:
# Preparing candidates...
# [========================================] 100%
# ========================================
# Scoring on Entity-Level Gold Data
# ========================================
# Corpus Precision 0.727
# Corpus Recall    0.399
# Corpus F1        0.516
# ----------------------------------------
# TP: 355 | FP: 133 | FN: 534
# ========================================

# %%
from pprint import pprint
pprint(FP)
# Out:
# [(u'AUKCS04635-1', u'2N3904', u'-55'),
#  (u'BC337', u'BC327', u'-55'),
#  (u'BC337', u'BC328', u'-55'),
#  (u'BC337-D', u'BC337-XX', u'-55'),
#  (u'BC546', u'BC556', u'-65'),
#  (u'BC546', u'BC557', u'-65'),
#  (u'BC546', u'BC558', u'-65'),
#  (u'BC546', u'BC559', u'-65'),
#  (u'BC546', u'BC560', u'-65'),
#  (u'BC546_DIOTEC', u'BC556', u'-55'),
#  (u'BC546_DIOTEC', u'BC557', u'-55'),
#  (u'BC546_DIOTEC', u'BC558', u'-55'),
#  (u'BC546_DIOTEC', u'BC559', u'-55'),
#  (u'BC547', u'BC556', u'-65'),
#  (u'BC547', u'BC557', u'-65'),
#  (u'BC547', u'BC558', u'-65'),
#  (u'BC547', u'BC559', u'-65'),
#  (u'BC547', u'BC560', u'-65'),
#  (u'BC550', u'BC556', u'-65'),
#  (u'BC550', u'BC560', u'-65'),
#  (u'BC818', u'BC807', u'-65'),
#  (u'BC818', u'BC808', u'-65'),
#  (u'BC818-40LT1-D', u'BC818-40LT1', u'-55'),
#  (u'BOURNSINC_BD246BS', u'BD245', u'-65'),
#  (u'BOURNSINC_BD246BS', u'TIS633AA', u'-65'),
#  (u'BOURNSINC_TIP152S', u'BY205-600', u'-65'),
#  (u'CSEMS03485-1', u'2N3903', u'-65'),
#  (u'CSEMS03485-1', u'2N3904', u'-65'),
#  (u'CSEMS05382-1', u'BC546-48ABC', u'-65'),
#  (u'DIODESINCORPORATED_FCX491ATA', u'AP02001', u'-65'),
#  (u'DIODESINCORPORATED_FCX491ATA', u'AP02002', u'-65'),
#  (u'DIODESINCORPORATED_FZT651TC', u'AP02001', u'-55'),
#  (u'DIODESINCORPORATED_FZT651TC', u'AP02002', u'-55'),
#  (u'DIODESINCORPORATED_ZXT690BKTC', u'AP02001', u'-55'),
#  (u'DIODESINCORPORATED_ZXT690BKTC', u'AP02002', u'-55'),
#  (u'DIODESINCORPORATED_ZXT690BKTC', u'ZXT690B', u'-55'),
#  (u'DIODS13249-1', u'BC807', u'-55'),
#  (u'DIODS13249-1', u'BC808', u'-55'),
#  (u'DIODS13249-1', u'BC81840', u'-55'),
#  (u'DISES00023-1', u'2N3904', u'-55'),
#  (u'DISES00189-1', u'BC546XBK', u'-55'),
#  (u'DISES00189-1', u'BC547XBK', u'-55'),
#  (u'DISES00189-1', u'BC548XBK', u'-55'),
#  (u'DISES00189-1', u'BC549XBK', u'-55'),
#  (u'DISES00189-1', u'BC556', u'-55'),
#  (u'DISES00189-1', u'BC557', u'-55'),
#  (u'DISES00189-1', u'BC558', u'-55'),
#  (u'DISES00189-1', u'BC559', u'-55'),
#  (u'DISES00192-1', u'BC817', u'-55'),
#  (u'DISES00192-1', u'BC818', u'-55'),
#  (u'DISES00242-1', u'MMBT3906', u'-55'),
#  (u'DISES00490-1', u'BC856W', u'-55'),
#  (u'DISES00490-1', u'BC857W', u'-55'),
#  (u'DISES00490-1', u'BC858W', u'-55'),
#  (u'DISES00490-1', u'BC859W', u'-55'),
#  (u'DISES00616-1', u'BC846', u'-55'),
#  (u'DISES00616-1', u'BC847', u'-55'),
#  (u'DISES00616-1', u'BC848', u'-55'),
#  (u'DISES00616-1', u'BC849', u'-55'),
#  (u'DISES00616-1', u'BC850', u'-55'),
#  (u'DISES00645-1', u'BC807K', u'-55'),
#  (u'DISES00645-1', u'BC808K', u'-55'),
#  (u'FAIRS19194-1', u'BC846', u'-65'),
#  (u'FAIRS19194-1', u'BC847', u'-65'),
#  (u'FAIRS19194-1', u'BC848', u'-65'),
#  (u'FAIRS19194-1', u'BC849', u'-65'),
#  (u'FAIRS19194-1', u'BC850', u'-65'),
#  (u'INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', u'AN077', u'-65'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'AN077',
#   u'-65'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC856-BC860',
#   u'-65'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857W',
#   u'-65'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC857W-BC860W',
#   u'-65'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC858W',
#   u'-65'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC859W',
#   u'-65'),
#  (u'INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   u'BC860W',
#   u'-65'),
#  (u'INFNS19372-1', u'AN077', u'-65'),
#  (u'INFNS19372-1', u'MMBT3906', u'-65'),
#  (u'INFNS19372-1', u'SMBT3906', u'-65'),
#  (u'KECCS03676-1', u'BC846', u'-55'),
#  (u'KECCS03676-1', u'BC847', u'-55'),
#  (u'KECCS03676-1', u'BC848', u'-55'),
#  (u'KECCS05435-1', u'BC556', u'-55'),
#  (u'KECCS05435-1', u'BC557', u'-55'),
#  (u'KECCS05435-1', u'BC558', u'-55'),
#  (u'LITES00424-1', u'2N3904', u'-55'),
#  (u'LITES00424-1', u'MMBT3906', u'-55'),
#  (u'LITES00690-1', u'BC556', u'-65'),
#  (u'LITES00690-1', u'BC557', u'-65'),
#  (u'LITES00690-1', u'BC558', u'-65'),
#  (u'LTSCS02910-1', u'BC818-REV', u'-55'),
#  (u'LTSCS02912-1', u'BC846W-REV', u'-55'),
#  (u'LTSCS02920-1', u'BC857-REV', u'-65'),
#  (u'MICROSEMICORPORATION_2N2484UB', u'2N2484', u'-65'),
#  (u'ONSEMICONDUCTOR_MMBT6521LT1', u'AN569', u'-55'),
#  (u'ONSEMICONDUCTOR_MMBT6521LT1', u'MPS6521', u'-55'),
#  (u'ONSMS04099-1', u'2N4407', u'-55'),
#  (u'ONSMS04099-1', u'2N4931', u'-55'),
#  (u'ONSMS04099-1', u'2N5401', u'-55'),
#  (u'ONSMS04099-1', u'2N697', u'-55'),
#  (u'ONSMS04099-1', u'2N718A', u'-55'),
#  (u'ONSMS04099-1', u'BF720T1', u'-55'),
#  (u'ONSMS04099-1', u'MPS3640', u'-55'),
#  (u'ONSMS04099-1', u'MPS3904', u'-55'),
#  (u'ONSMS04099-1', u'MPS5771', u'-55'),
#  (u'ONSMS04099-1', u'MPS6520', u'-55'),
#  (u'ONSMS04099-1', u'MPS6521', u'-55'),
#  (u'ONSMS04099-1', u'MPS8599', u'-55'),
#  (u'PHGLS18216-1', u'BC847DG', u'-65'),
#  (u'PHGLS18216-1', u'BC857CW', u'-65'),
#  (u'PHGLS19500-1', u'MMBT3906', u'-65'),
#  (u'PHGLS20267-1', u'2N4126', u'-65'),
#  (u'PHGLS20267-1', u'BP317', u'-65'),
#  (u'RECTS01214-1', u'DTC114ECA-1', u'-55'),
#  (u'RECTS01325-1', u'DTC114YCA-1', u'-55'),
#  (u'SGSTS13702-1', u'BC557B', u'-65'),
#  (u'SGSTS13734-1', u'BC327-25', u'-65'),
#  (u'SGSTS13734-1', u'BC327-40', u'-65'),
#  (u'TWSCS04757-1', u'BC807', u'-55'),
#  (u'TWSCS04757-1', u'BC817', u'-55'),
#  (u'UTCLS01324-1', u'MMBT3904-E', u'-55'),
#  (u'UTCLS01324-1', u'MMBT3906', u'-55'),
#  (u'UTCLS02155-1', u'BC817', u'-65'),
#  (u'UTCLS02155-1', u'BC818', u'-65'),
#  (u'UTCLS03593-1', u'DTC114E-I', u'-55'),
#  (u'VISHS23888-1', u'BC556', u'-65'),
#  (u'VISHS23888-1', u'BC557', u'-65'),
#  (u'VISHS23888-1', u'BC558', u'-65'),
#  (u'VISHS23888-1', u'BC559', u'-65'),
#  (u'VSMIS03793-1', u'BC807', u'-65'),
#  (u'VSMIS03793-1', u'BC808', u'-65'),
#  (u'WEITS00252-1', u'BC807-1', u'-55'),
#  (u'WEITS00252-1', u'BC807-17', u'-55'),
#  (u'ZETXS01948-1', u'BC860C', u'-55')]

# %%
from pprint import pprint
pprint(FN)
# Out:
# [('112823', 'BC546BG', '-55'),
#  ('112823', 'BC546BRL1', '-55'),
#  ('112823', 'BC546BRL1G', '-55'),
#  ('112823', 'BC546BZL1G', '-55'),
#  ('112823', 'BC547ARL', '-55'),
#  ('112823', 'BC547ARLG', '-55'),
#  ('112823', 'BC547AZL1G', '-55'),
#  ('112823', 'BC547BG', '-55'),
#  ('112823', 'BC547BRL1G', '-55'),
#  ('112823', 'BC547BZL1G', '-55'),
#  ('112823', 'BC547C', '-55'),
#  ('112823', 'BC547CG', '-55'),
#  ('112823', 'BC547CZL1G', '-55'),
#  ('112823', 'BC548BG', '-55'),
#  ('112823', 'BC548BRL1G', '-55'),
#  ('112823', 'BC548CG', '-55'),
#  ('112823', 'BC548CZL1G', '-55'),
#  ('2N3906', '2N3906BU', '-55'),
#  ('2N3906', '2N3906TA', '-55'),
#  ('2N3906', '2N3906TAR', '-55'),
#  ('2N3906', '2N3906TF', '-55'),
#  ('2N3906', '2N3906TFR', '-55'),
#  ('2N3906-D', '2N3906G', '-55'),
#  ('2N3906-D', '2N3906RL1', '-55'),
#  ('2N3906-D', '2N3906RL1G', '-55'),
#  ('2N3906-D', '2N3906RLRA', '-55'),
#  ('2N3906-D', '2N3906RLRAG', '-55'),
#  ('2N3906-D', '2N3906RLRM', '-55'),
#  ('2N3906-D', '2N3906RLRMG', '-55'),
#  ('2N3906-D', '2N3906RLRP', '-55'),
#  ('2N3906-D', '2N3906RLRPG', '-55'),
#  ('2N4123-D', '2N4123RLRM', '-55'),
#  ('2N4123-D', '2N4124G', '-55'),
#  ('2N6426-D', '2N6426G', '-55'),
#  ('2N6426-D', '2N6426RLRAG', '-55'),
#  ('2N6426-D', '2N6427G', '-55'),
#  ('2N6426-D', '2N6427RLRAG', '-55'),
#  ('BC182-D', 'BC182BG', '-55'),
#  ('BC182-D', 'BC182BRL1G', '-55'),
#  ('BC182-D', 'BC182G', '-55'),
#  ('BC337', 'BC337-16', '-55'),
#  ('BC337', 'BC337-25', '-55'),
#  ('BC337', 'BC337-40', '-55'),
#  ('BC337', 'BC33716BU', '-55'),
#  ('BC337', 'BC33716TA', '-55'),
#  ('BC337', 'BC33716TFR', '-55'),
#  ('BC337', 'BC33725BU', '-55'),
#  ('BC337', 'BC33725TA', '-55'),
#  ('BC337', 'BC33725TAR', '-55'),
#  ('BC337', 'BC33725TF', '-55'),
#  ('BC337', 'BC33725TFR', '-55'),
#  ('BC337', 'BC33740TA', '-55'),
#  ('BC337', 'BC338-25', '-55'),
#  ('BC337', 'BC33825TA', '-55'),
#  ('BC337-D', 'BC337-025G', '-55'),
#  ('BC337-D', 'BC337-040G', '-55'),
#  ('BC337-D', 'BC337-25RL1G', '-55'),
#  ('BC337-D', 'BC337-25RLRAG', '-55'),
#  ('BC337-D', 'BC337-25ZL1G', '-55'),
#  ('BC337-D', 'BC337-40RL1G', '-55'),
#  ('BC337-D', 'BC337-40ZL1G', '-55'),
#  ('BC337-D', 'BC337G', '-55'),
#  ('BC337-D', 'BC337RL1G', '-55'),
#  ('BC546', 'BC546A', '-65'),
#  ('BC546', 'BC546ABU', '-65'),
#  ('BC546', 'BC546ATA', '-65'),
#  ('BC546', 'BC546B', '-65'),
#  ('BC546', 'BC546BTA', '-65'),
#  ('BC546', 'BC546BTF', '-65'),
#  ('BC546', 'BC546C', '-65'),
#  ('BC546', 'BC546CTA', '-65'),
#  ('BC546', 'BC547A', '-65'),
#  ('BC546', 'BC547ATA', '-65'),
#  ('BC546', 'BC547B', '-65'),
#  ('BC546', 'BC547BBU', '-65'),
#  ('BC546', 'BC547BTA', '-65'),
#  ('BC546', 'BC547BTF', '-65'),
#  ('BC546', 'BC547C', '-65'),
#  ('BC546', 'BC547CBU', '-65'),
#  ('BC546', 'BC547CTA', '-65'),
#  ('BC546', 'BC547CTFR', '-65'),
#  ('BC546', 'BC548B', '-65'),
#  ('BC546', 'BC548BTA', '-65'),
#  ('BC546', 'BC548BU', '-65'),
#  ('BC546', 'BC548C', '-65'),
#  ('BC546', 'BC548CTA', '-65'),
#  ('BC546', 'BC549B', '-65'),
#  ('BC546', 'BC549BTA', '-65'),
#  ('BC546', 'BC549BTF', '-65'),
#  ('BC546', 'BC549C', '-65'),
#  ('BC546', 'BC549CTA', '-65'),
#  ('BC546', 'BC550C', '-65'),
#  ('BC546', 'BC550CBU', '-65'),
#  ('BC546', 'BC550CTA', '-65'),
#  ('BC546-BC548C(TO-92)', 'BC546', '-55'),
#  ('BC546-BC548C(TO-92)', 'BC546B', '-55'),
#  ('BC546-BC548C(TO-92)', 'BC547', '-55'),
#  ('BC546-BC548C(TO-92)', 'BC547A', '-55'),
#  ('BC546-BC548C(TO-92)', 'BC547B', '-55'),
#  ('BC546-BC548C(TO-92)', 'BC547C', '-55'),
#  ('BC546-BC548C(TO-92)', 'BC548', '-55'),
#  ('BC546-BC548C(TO-92)', 'BC548A', '-55'),
#  ('BC546-BC548C(TO-92)', 'BC548B', '-55'),
#  ('BC546-BC548C(TO-92)', 'BC548C', '-55'),
#  ('BC546-D', 'BC546BG', '-55'),
#  ('BC546-D', 'BC546BRL1', '-55'),
#  ('BC546-D', 'BC546BRL1G', '-55'),
#  ('BC546-D', 'BC546BZL1G', '-55'),
#  ('BC546-D', 'BC547ARL', '-55'),
#  ('BC546-D', 'BC547ARLG', '-55'),
#  ('BC546-D', 'BC547AZL1G', '-55'),
#  ('BC546-D', 'BC547BG', '-55'),
#  ('BC546-D', 'BC547BRL1G', '-55'),
#  ('BC546-D', 'BC547BZL1G', '-55'),
#  ('BC546-D', 'BC547C', '-55'),
#  ('BC546-D', 'BC547CG', '-55'),
#  ('BC546-D', 'BC547CZL1G', '-55'),
#  ('BC546-D', 'BC548BG', '-55'),
#  ('BC546-D', 'BC548BRL1G', '-55'),
#  ('BC546-D', 'BC548CG', '-55'),
#  ('BC546-D', 'BC548CZL1G', '-55'),
#  ('BC546A_SERIES_B14-521026', 'BC546', '-65'),
#  ('BC546A_SERIES_B14-521026', 'BC547', '-65'),
#  ('BC546A_SERIES_B14-521026', 'BC548', '-65'),
#  ('BC546A_SERIES_B14-521026', 'BC549', '-65'),
#  ('BC546A_SERIES_B14-521026', 'BC550', '-65'),
#  ('BC547', 'BC546A', '-65'),
#  ('BC547', 'BC546ABU', '-65'),
#  ('BC547', 'BC546ATA', '-65'),
#  ('BC547', 'BC546B', '-65'),
#  ('BC547', 'BC546BTA', '-65'),
#  ('BC547', 'BC546BTF', '-65'),
#  ('BC547', 'BC546C', '-65'),
#  ('BC547', 'BC546CTA', '-65'),
#  ('BC547', 'BC547A', '-65'),
#  ('BC547', 'BC547ATA', '-65'),
#  ('BC547', 'BC547B', '-65'),
#  ('BC547', 'BC547BBU', '-65'),
#  ('BC547', 'BC547BTA', '-65'),
#  ('BC547', 'BC547BTF', '-65'),
#  ('BC547', 'BC547C', '-65'),
#  ('BC547', 'BC547CBU', '-65'),
#  ('BC547', 'BC547CTA', '-65'),
#  ('BC547', 'BC547CTFR', '-65'),
#  ('BC547', 'BC548B', '-65'),
#  ('BC547', 'BC548BTA', '-65'),
#  ('BC547', 'BC548C', '-65'),
#  ('BC547', 'BC548CTA', '-65'),
#  ('BC547', 'BC549B', '-65'),
#  ('BC547', 'BC549BTA', '-65'),
#  ('BC547', 'BC549BTF', '-65'),
#  ('BC547', 'BC549C', '-65'),
#  ('BC547', 'BC549CTA', '-65'),
#  ('BC547', 'BC550C', '-65'),
#  ('BC547', 'BC550CBU', '-65'),
#  ('BC547', 'BC550CTA', '-65'),
#  ('BC550', 'BC546A', '-65'),
#  ('BC550', 'BC546B', '-65'),
#  ('BC550', 'BC546C', '-65'),
#  ('BC550', 'BC547A', '-65'),
#  ('BC550', 'BC547B', '-65'),
#  ('BC550', 'BC547C', '-65'),
#  ('BC550', 'BC548A', '-65'),
#  ('BC550', 'BC548B', '-65'),
#  ('BC550', 'BC548C', '-65'),
#  ('BC550', 'BC549A', '-65'),
#  ('BC550', 'BC549B', '-65'),
#  ('BC550', 'BC549C', '-65'),
#  ('BC550', 'BC550A', '-65'),
#  ('BC550', 'BC550B', '-65'),
#  ('BC550', 'BC550C', '-65'),
#  ('BC818', 'BC817-16', '-65'),
#  ('BC818', 'BC817-25', '-65'),
#  ('BC818', 'BC817-40', '-65'),
#  ('BC818', 'BC81716MTF', '-65'),
#  ('BC818', 'BC81725MTF', '-65'),
#  ('BC818', 'BC81740MTF', '-65'),
#  ('BC818', 'BC818-16', '-65'),
#  ('BC818', 'BC818-25', '-65'),
#  ('BC818', 'BC818-40', '-65'),
#  ('BC818', 'BC81816MTF', '-65'),
#  ('BC818', 'BC81825MTF', '-65'),
#  ('BC818', 'BC81840MTF', '-65'),
#  ('BC818-40LT1-D', 'BC818-40LT1G', '-55'),
#  ('BC818-40LT1-D', 'NSVBC818-40LT1G', '-55'),
#  ('CENTRALSEMICONDUCTORCORP_CENU45', 'CEN-U45', '-65'),
#  ('CENTRALSEMICONDUCTORCORP_CMPT5401ETR', 'CMPT5401E', '-65'),
#  ('CENTRALSEMICONDUCTORCORP_CXT4033TR', 'CXT4033', '-65'),
#  ('CSEMS02742-1', 'BC846A', '-65'),
#  ('CSEMS02742-1', 'BC846B', '-65'),
#  ('CSEMS02742-1', 'BC847A', '-65'),
#  ('CSEMS02742-1', 'BC847B', '-65'),
#  ('CSEMS02742-1', 'BC847C', '-65'),
#  ('CSEMS02742-1', 'BC848A', '-65'),
#  ('CSEMS02742-1', 'BC848B', '-65'),
#  ('CSEMS02742-1', 'BC848C', '-65'),
#  ('CSEMS05382-1', 'BC546A', '-65'),
#  ('CSEMS05382-1', 'BC546B', '-65'),
#  ('CSEMS05382-1', 'BC547A', '-65'),
#  ('CSEMS05382-1', 'BC547B', '-65'),
#  ('CSEMS05382-1', 'BC547C', '-65'),
#  ('CSEMS05382-1', 'BC548A', '-65'),
#  ('CSEMS05382-1', 'BC548B', '-65'),
#  ('CSEMS05382-1', 'BC548C', '-65'),
#  ('CSEMS05383-1', 'BC817-16', '-65'),
#  ('CSEMS05383-1', 'BC817-25', '-65'),
#  ('CSEMS05383-1', 'BC817-40', '-65'),
#  ('CSEMS05383-1', 'BC818-16', '-65'),
#  ('CSEMS05383-1', 'BC818-25', '-65'),
#  ('CSEMS05383-1', 'BC818-40', '-65'),
#  ('DIODESINCORPORATED_2DD26527', '2DD2652', '-55'),
#  ('DIODESINCORPORATED_2DD26527', '2DD2652-7', '-55'),
#  ('DIODESINCORPORATED_FCX491ATA', 'FCX491A', '-65'),
#  ('DIODESINCORPORATED_FZT651TC', 'FZT651TA', '-55'),
#  ('DIODESINCORPORATED_FZT651TC', 'FZT651TC', '-55'),
#  ('DIODESINCORPORATED_ZXT690BKTC', 'ZXT690BKQTC', '-55'),
#  ('DIODESINCORPORATED_ZXT690BKTC', 'ZXT690BKTC', '-55'),
#  ('DIODS00215-1', '2N4124', '-65'),
#  ('DTC114W', 'DTC114WE', '-55'),
#  ('DTC114W', 'DTC114WUA', '-55'),
#  ('FAIRCHILDSEMICONDUCTOR_KSC2310YTA', 'KSC2310', '-55'),
#  ('FAIRCHILDSEMICONDUCTOR_KSC2310YTA', 'KSC2310O', '-55'),
#  ('FAIRCHILDSEMICONDUCTOR_KSC2310YTA', 'KSC2310R', '-55'),
#  ('FAIRCHILDSEMICONDUCTOR_KSC2310YTA', 'KSC2310Y', '-55'),
#  ('FAIRS19194-1', 'BC856A', '-65'),
#  ('FAIRS19194-1', 'BC856B', '-65'),
#  ('FAIRS19194-1', 'BC856C', '-65'),
#  ('FAIRS19194-1', 'BC857A', '-65'),
#  ('FAIRS19194-1', 'BC857B', '-65'),
#  ('FAIRS19194-1', 'BC857C', '-65'),
#  ('FAIRS19194-1', 'BC858A', '-65'),
#  ('FAIRS19194-1', 'BC858B', '-65'),
#  ('FAIRS19194-1', 'BC858C', '-65'),
#  ('FAIRS19194-1', 'BC859A', '-65'),
#  ('FAIRS19194-1', 'BC859B', '-65'),
#  ('FAIRS19194-1', 'BC859C', '-65'),
#  ('FAIRS19194-1', 'BC860A', '-65'),
#  ('FAIRS19194-1', 'BC860B', '-65'),
#  ('FAIRS19194-1', 'BC860C', '-65'),
#  ('FAIRS25065-1', 'BC237A', '-55'),
#  ('FAIRS25065-1', 'BC237B', '-55'),
#  ('FAIRS25065-1', 'BC237C', '-55'),
#  ('FAIRS25065-1', 'BC238A', '-55'),
#  ('FAIRS25065-1', 'BC238B', '-55'),
#  ('FAIRS25065-1', 'BC238C', '-55'),
#  ('FAIRS25065-1', 'BC239A', '-55'),
#  ('FAIRS25065-1', 'BC239B', '-55'),
#  ('FAIRS25065-1', 'BC239C', '-55'),
#  ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-16', '-65'),
#  ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-16W', '-65'),
#  ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-25', '-65'),
#  ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-25W', '-65'),
#  ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-40', '-65'),
#  ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC818K-40', '-65'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC857BW',
#   '-65'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC857C',
#   '-65'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC857CW',
#   '-65'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC858A',
#   '-65'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC858B',
#   '-65'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC858BW',
#   '-65'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC858C',
#   '-65'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC858CW',
#   '-65'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC859C',
#   '-65'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC860B',
#   '-65'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC860BW',
#   '-65'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC860CW',
#   '-65'),
#  ('KECCS03676-1', 'BC856A', '-55'),
#  ('KECCS03676-1', 'BC856B', '-55'),
#  ('KECCS03676-1', 'BC857A', '-55'),
#  ('KECCS03676-1', 'BC857B', '-55'),
#  ('KECCS03676-1', 'BC857C', '-55'),
#  ('KECCS03676-1', 'BC858A', '-55'),
#  ('KECCS03676-1', 'BC858B', '-55'),
#  ('KECCS03676-1', 'BC858C', '-55'),
#  ('KECCS05435-1', 'BC546A', '-55'),
#  ('KECCS05435-1', 'BC546B', '-55'),
#  ('KECCS05435-1', 'BC547A', '-55'),
#  ('KECCS05435-1', 'BC547B', '-55'),
#  ('KECCS05435-1', 'BC547C', '-55'),
#  ('KECCS05435-1', 'BC548A', '-55'),
#  ('KECCS05435-1', 'BC548B', '-55'),
#  ('KECCS05435-1', 'BC548C', '-55'),
#  ('LITES00686-1', '2N4124', '-65'),
#  ('LITES00689-1', 'BC337-16', '-55'),
#  ('LITES00689-1', 'BC337-25', '-55'),
#  ('LITES00689-1', 'BC337-40', '-55'),
#  ('LITES00690-1', 'BC546A', '-65'),
#  ('LITES00690-1', 'BC546B', '-65'),
#  ('LITES00690-1', 'BC546C', '-65'),
#  ('LITES00690-1', 'BC547A', '-65'),
#  ('LITES00690-1', 'BC547B', '-65'),
#  ('LITES00690-1', 'BC547C', '-65'),
#  ('LITES00690-1', 'BC548A', '-65'),
#  ('LITES00690-1', 'BC548B', '-65'),
#  ('LITES00690-1', 'BC548C', '-65'),
#  ('LTSCS02910-1', 'BC818-16', '-55'),
#  ('LTSCS02910-1', 'BC818-25', '-55'),
#  ('LTSCS02910-1', 'BC818-40', '-55'),
#  ('LTSCS02912-1', 'BC846AW', '-55'),
#  ('LTSCS02912-1', 'BC846BW', '-55'),
#  ('LTSCS02920-1', 'BC857A', '-65'),
#  ('LTSCS02920-1', 'BC857B', '-65'),
#  ('LTSCS02920-1', 'BC857C', '-65'),
#  ('MCCCS08984-1', 'MMBT3904', '-55'),
#  ('MCCCS09540-1', 'BC846', '-55'),
#  ('MCCCS09540-1', 'BC846A', '-55'),
#  ('MCCCS09540-1', 'BC846B', '-55'),
#  ('MCCCS09540-1', 'BC847', '-55'),
#  ('MCCCS09540-1', 'BC847A', '-55'),
#  ('MCCCS09540-1', 'BC847B', '-55'),
#  ('MCCCS09540-1', 'BC847C', '-55'),
#  ('MCCCS09540-1', 'BC848', '-55'),
#  ('MCCCS09540-1', 'BC848A', '-55'),
#  ('MCCCS09540-1', 'BC848B', '-55'),
#  ('MCCCS09540-1', 'BC848C', '-55'),
#  ('MCCCS09540-1', 'BC849', '-55'),
#  ('MCCCS09540-1', 'BC849B', '-55'),
#  ('MCCCS09540-1', 'BC849C', '-55'),
#  ('MCCCS09741-1', 'BC337', '-55'),
#  ('MCCCS09741-1', 'BC337-16', '-55'),
#  ('MCCCS09741-1', 'BC337-25', '-55'),
#  ('MCCCS09741-1', 'BC337-40', '-55'),
#  ('MCCCS09741-1', 'BC338', '-55'),
#  ('MCCCS09741-1', 'BC338-16', '-55'),
#  ('MCCCS09741-1', 'BC338-25', '-55'),
#  ('MCCCS09741-1', 'BC338-40', '-55'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904', '-55'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904-AP', '-55'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904-AP-HF', '-55'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904-BP', '-55'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904-BP-HF', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29A-BP', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29A-BP-HF', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29B-BP', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29B-BP-HF', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29C-BP', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29C-BP-HF', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30A', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30A-BP', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30A-BP-HF', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30B', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30B-BP', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30B-BP-HF', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30C', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30C-BP', '-55'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30C-BP-HF', '-55'),
#  ('MMBT3904', '2N3904BU', '-55'),
#  ('MMBT3904', '2N3904TA', '-55'),
#  ('MMBT3904', '2N3904TAR', '-55'),
#  ('MMBT3904', '2N3904TF', '-55'),
#  ('MMBT3904', '2N3904TFR', '-55'),
#  ('MMMCS17742-1', 'BC807-16W', '-55'),
#  ('MMMCS17742-1', 'BC807-25W', '-55'),
#  ('MMMCS17742-1', 'BC807-40W', '-55'),
#  ('MOTOS03160-1', 'BC182A', '-55'),
#  ('MOTOS03160-1', 'BC182B', '-55'),
#  ('MOTOS03189-1', 'BC337-16', '-55'),
#  ('MOTOS03189-1', 'BC337-25', '-55'),
#  ('MOTOS03189-1', 'BC337-40', '-55'),
#  ('MOTOS03189-1', 'BC338', '-55'),
#  ('MOTOS03189-1', 'BC338-16', '-55'),
#  ('MOTOS03189-1', 'BC338-25', '-55'),
#  ('MOTOS03189-1', 'BC338-40', '-55'),
#  ('NXPUSAINC_PBSS5360PASX', 'PBSS5360PAS', '-65'),
#  ('ONSEMICONDUCTOR_MMBT6521LT1', 'MMBT6521LT1G', '-55'),
#  ('ONSEMICONDUCTOR_MMBT6521LT1', 'SMMBT6521LT1G', '-55'),
#  ('ONSMS04099-1', 'BC237A', '-55'),
#  ('ONSMS04099-1', 'BC237B', '-55'),
#  ('ONSMS04099-1', 'BC237C', '-55'),
#  ('ONSMS04099-1', 'BC238', '-55'),
#  ('ONSMS04099-1', 'BC239C', '-55'),
#  ('PHGLS18216-1', 'BC847A', '-65'),
#  ('PHGLS18216-1', 'BC847AW', '-65'),
#  ('PHGLS18216-1', 'BC847B', '-65'),
#  ('PHGLS18216-1', 'BC847B/DG', '-65'),
#  ('PHGLS18216-1', 'BC847BW', '-65'),
#  ('PHGLS18216-1', 'BC847BW/DG', '-65'),
#  ('PHGLS18216-1', 'BC847C', '-65'),
#  ('PHGLS18216-1', 'BC847W', '-65'),
#  ('PHGLS20125-1', 'BC327-16', '-65'),
#  ('PHGLS20125-1', 'BC327-25', '-65'),
#  ('PHGLS20125-1', 'BC807-16W', '-65'),
#  ('PHGLS20125-1', 'BC807-25W', '-65'),
#  ('PHGLS20125-1', 'BC807-40', '-65'),
#  ('PHGLS20125-1', 'BC807-40W', '-65'),
#  ('PHGLS20126-1', 'BC337-16', '-65'),
#  ('PHGLS20126-1', 'BC337-25', '-65'),
#  ('PHGLS20126-1', 'BC817-16W', '-65'),
#  ('PHGLS20126-1', 'BC817-25W', '-65'),
#  ('PHGLS20126-1', 'BC817-40', '-65'),
#  ('PHGLS20126-1', 'BC817-40W', '-65'),
#  ('PJECS00521-1', 'MMBT3904', '-55'),
#  ('PNJIS00254-1', 'BC807-16W', '-55'),
#  ('PNJIS00254-1', 'BC807-25W', '-55'),
#  ('PNJIS00254-1', 'BC807-40W', '-55'),
#  ('PNJIS01186-1', 'BC807-16', '-55'),
#  ('PNJIS01186-1', 'BC807-25', '-55'),
#  ('PNJIS01186-1', 'BC807-40', '-55'),
#  ('PNJIS01593-1', 'BC856', '-50'),
#  ('PNJIS01593-1', 'BC856A', '-50'),
#  ('PNJIS01593-1', 'BC856B', '-50'),
#  ('PNJIS01593-1', 'BC857', '-50'),
#  ('PNJIS01593-1', 'BC857A', '-50'),
#  ('PNJIS01593-1', 'BC857B', '-50'),
#  ('PNJIS01593-1', 'BC857C', '-50'),
#  ('PNJIS01593-1', 'BC858', '-50'),
#  ('PNJIS01593-1', 'BC858A', '-50'),
#  ('PNJIS01593-1', 'BC858B', '-50'),
#  ('PNJIS01593-1', 'BC858C', '-50'),
#  ('PNJIS01593-1', 'BC859', '-50'),
#  ('PNJIS01593-1', 'BC859B', '-50'),
#  ('PNJIS01593-1', 'BC859C', '-50'),
#  ('RECTS00705-1', 'BC546B', '-55'),
#  ('RECTS00705-1', 'BC546C', '-55'),
#  ('RECTS00705-1', 'BC547A', '-55'),
#  ('RECTS00705-1', 'BC547B', '-55'),
#  ('RECTS00705-1', 'BC547C', '-55'),
#  ('RECTS00705-1', 'BC548A', '-55'),
#  ('RECTS00705-1', 'BC548B', '-55'),
#  ('RECTS00705-1', 'BC548C', '-55'),
#  ('RECTS01002-1', 'MMBT3904', '-55'),
#  ('RECTS01158-1', 'BC807-25', '-55'),
#  ('RECTS01242-1', 'BC857B', '-55'),
#  ('SANKEN_2SC4886', '2SC4886', '-55'),
#  ('SANKEN_2SD2643', '2SD2643', '-55'),
#  ('SANKEN_STD01N', 'STD01N', '-55'),
#  ('SANKEN_STD01N', 'STD01P', '-55'),
#  ('SCSCS02175-1', 'BC546', '-55'),
#  ('SCSCS02175-1', 'BC546A', '-55'),
#  ('SCSCS02175-1', 'BC546B', '-55'),
#  ('SCSCS02175-1', 'BC546C', '-55'),
#  ('SCSCS02175-1', 'BC547', '-55'),
#  ('SCSCS02175-1', 'BC547A', '-55'),
#  ('SCSCS02175-1', 'BC547B', '-55'),
#  ('SCSCS02175-1', 'BC547C', '-55'),
#  ('SCSCS02175-1', 'BC548', '-55'),
#  ('SCSCS02175-1', 'BC548A', '-55'),
#  ('SCSCS02175-1', 'BC548B', '-55'),
#  ('SCSCS02175-1', 'BC548C', '-55'),
#  ('SCSCS02324-1', 'MMBT3904', '-55'),
#  ('SGSTS13702-1', 'BC547B-AP', '-65'),
#  ('SGSTS13702-1', 'BC547C-AP', '-65'),
#  ('SGSTS13734-1', 'BC337-25-AP', '-65'),
#  ('SGSTS13734-1', 'BC337-40-AP', '-65'),
#  ('SIEMS01215-1', 'BC856', '-65'),
#  ('SIEMS01215-1', 'BC856A', '-65'),
#  ('SIEMS01215-1', 'BC856B', '-65'),
#  ('SIEMS01215-1', 'BC857', '-65'),
#  ('SIEMS01215-1', 'BC857A', '-65'),
#  ('SIEMS01215-1', 'BC857B', '-65'),
#  ('SIEMS01215-1', 'BC857C', '-65'),
#  ('SIEMS01215-1', 'BC858', '-65'),
#  ('SIEMS01215-1', 'BC858A', '-65'),
#  ('SIEMS01215-1', 'BC858B', '-65'),
#  ('SIEMS01215-1', 'BC858C', '-65'),
#  ('SIEMS01215-1', 'BC859', '-65'),
#  ('SIEMS01215-1', 'BC859A', '-65'),
#  ('SIEMS01215-1', 'BC859B', '-65'),
#  ('SIEMS01215-1', 'BC859C', '-65'),
#  ('SIEMS01215-1', 'BC860', '-65'),
#  ('SIEMS01215-1', 'BC860B', '-65'),
#  ('SIEMS01215-1', 'BC860C', '-65'),
#  ('STMICROELECTRONICS_BUV48A', 'BUV48A', '-65'),
#  ('STMICROELECTRONICS_STI130051', 'STI13005-1', '-65'),
#  ('TKCGS00622-1', 'DTC114TE', '-55'),
#  ('TKCGS00622-1', 'DTC114YE', '-55'),
#  ('TKCGS00622-1', 'DTC123EE', '-55'),
#  ('TKCGS00622-1', 'DTC124EE', '-55'),
#  ('TKCGS00622-1', 'DTC124XE', '-55'),
#  ('TKCGS00622-1', 'DTC143EE', '-55'),
#  ('TKCGS00622-1', 'DTC143TE', '-55'),
#  ('TKCGS00622-1', 'DTC143ZE', '-55'),
#  ('TTELECTRONICSOPTEKTECHNOLOGY_2N2222AUATXV', '2N2222AUATX', '-65'),
#  ('TTELECTRONICSOPTEKTECHNOLOGY_2N2222AUATXV', '2N2222AUATXV', '-65'),
#  ('TWSCS04757-1', 'BC807-40', '-55'),
#  ('UTCLS01324-1', 'MMBT3904G-AE3-R', '-55'),
#  ('UTCLS01324-1', 'MMBT3904G-AL3-R', '-55'),
#  ('UTCLS01324-1', 'MMBT3904L-AE3-R', '-55'),
#  ('UTCLS01324-1', 'MMBT3904L-AL3-R', '-55'),
#  ('UTCLS02155-1', 'BC807', '-65'),
#  ('UTCLS02155-1', 'BC807-16', '-65'),
#  ('UTCLS02155-1', 'BC807-25', '-65'),
#  ('UTCLS02155-1', 'BC807-40', '-65'),
#  ('UTCLS02155-1', 'BC808', '-65'),
#  ('UTCLS02155-1', 'BC808-16', '-65'),
#  ('UTCLS02155-1', 'BC808-25', '-65'),
#  ('UTCLS02155-1', 'BC808-40', '-65'),
#  ('UTCLS03593-1', 'DTC114EG-AE3-R', '-55'),
#  ('UTCLS03593-1', 'DTC114EG-AL3-R', '-55'),
#  ('UTCLS03593-1', 'DTC114EG-AN3-R', '-55'),
#  ('UTCLS03593-1', 'DTC114EG-T92-B', '-55'),
#  ('UTCLS03593-1', 'DTC114EG-T92-K', '-55'),
#  ('UTCLS03593-1', 'DTC114EG-T92-R', '-55'),
#  ('UTCLS03593-1', 'DTC114EG-T9S-K', '-55'),
#  ('UTCLS03593-1', 'DTC114EL-AE3-R', '-55'),
#  ('UTCLS03593-1', 'DTC114EL-AL3-R', '-55'),
#  ('UTCLS03593-1', 'DTC114EL-AN3-R', '-55'),
#  ('UTCLS03593-1', 'DTC114EL-T92-B', '-55'),
#  ('UTCLS03593-1', 'DTC114EL-T92-K', '-55'),
#  ('UTCLS03593-1', 'DTC114EL-T92-R', '-55'),
#  ('UTCLS03593-1', 'DTC114EL-T9S-K', '-55'),
#  ('VISHS23888-1', 'BC546A', '-65'),
#  ('VISHS23888-1', 'BC546B', '-65'),
#  ('VISHS23888-1', 'BC547A', '-65'),
#  ('VISHS23888-1', 'BC547B', '-65'),
#  ('VISHS23888-1', 'BC547C', '-65'),
#  ('VISHS23888-1', 'BC548A', '-65'),
#  ('VISHS23888-1', 'BC548B', '-65'),
#  ('VISHS23888-1', 'BC548C', '-65'),
#  ('VISHS23888-1', 'BC549B', '-65'),
#  ('VISHS23888-1', 'BC549C', '-65'),
#  ('VSMIS00373-1', 'BC337', '-65'),
#  ('VSMIS00373-1', 'BC337-16', '-65'),
#  ('VSMIS00373-1', 'BC337-25', '-65'),
#  ('VSMIS00373-1', 'BC337-40', '-65'),
#  ('VSMIS00373-1', 'BC338', '-65'),
#  ('VSMIS00373-1', 'BC338-16', '-65'),
#  ('VSMIS00373-1', 'BC338-25', '-65'),
#  ('VSMIS00373-1', 'BC338-40', '-65'),
#  ('WEILS00082-1', 'BC859', '-55'),
#  ('ZETXS01948-1', 'BC856A-3A', '-55'),
#  ('ZETXS01948-1', 'BC856B-Z3B', '-55'),
#  ('ZETXS01948-1', 'BC857A-Z3E', '-55'),
#  ('ZETXS01948-1', 'BC857B-3F', '-55'),
#  ('ZETXS01948-1', 'BC857C-3G', '-55'),
#  ('ZETXS01948-1', 'BC858A-3J', '-55'),
#  ('ZETXS01948-1', 'BC858B-3K', '-55'),
#  ('ZETXS01948-1', 'BC858C-3L', '-55'),
#  ('ZETXS01948-1', 'BC859A-Z4A', '-55'),
#  ('ZETXS01948-1', 'BC859B-4B', '-55'),
#  ('ZETXS01948-1', 'BC859C-Z4C', '-55'),
#  ('ZETXS01948-1', 'BC860A-Z4E', '-55'),
#  ('ZETXS01948-1', 'BC860B-4F', '-55'),
#  ('ZETXS01948-1', 'BC860C-4GZ', '-55')]
