# %% [markdown]
# # polarity

# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import sys
sys.path.append(os.environ['SNORKELHOME'] + '/tutorials/tables/')

# %% [markdown]
# ## Clearing db

# %%
from snorkel.models.meta import clear_database
clear_database()

# %% [markdown]
# ## Parsing

# %%
from snorkel import SnorkelSession
session = SnorkelSession()

# %% [markdown]
# ### Define Parser

# %%
import os
from snorkel.parser import CorpusParser, HTMLParser, OmniParser
from snorkel.utils import get_ORM_instance
from snorkel.queries import split_corpus

docs_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/hardware100_html/'
pdf_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/hardware100_pdf/'
doc_parser = HTMLParser(path=docs_path)
context_parser = OmniParser(pdf_path=pdf_path, visual=True, session=session)
cp = CorpusParser(doc_parser, context_parser, max_docs=10)

# %% [markdown]
# ### Run Parser

# %%
# %time corpus = cp.parse_corpus(name='Hardware', session=session)

session.add(corpus)
session.commit()
# Out:
# [========================================] 100%
# CPU times: user 4.3 s, sys: 312 ms, total: 4.62 s
# Wall time: 7.87 s

# %% [markdown]
# ### Split Corpus

# %%
from snorkel.models import Corpus

corpus = get_ORM_instance(Corpus, session, 'Hardware')
split_corpus(session, corpus, train=0.6, development=0.4, test=0, seed=3)
# Out:
# 6 Documents added to corpus Hardware Training
# 4 Documents added to corpus Hardware Development

# %% [markdown]
# ## Extraction

# %%
from snorkel.models import candidate_subclass

Part_Polarity = candidate_subclass('Part_Polarity', ['part','polarity'])

# %% [markdown]
# ### Define Matchers

# %%
from snorkel.matchers import RegexMatchSpan, Union

eeca_matcher = RegexMatchSpan(rgx='([b]{1}[abcdefklnpqruyz]{1}[\swxyz]?[0-9]{3,5}[\s]?[A-Z\/]{0,5}[0-9]?[A-Z]?([-][A-Z0-9]{1,7})?([-][A-Z0-9]{1,2})?)')
jedec_matcher = RegexMatchSpan(rgx='([123]N\d{3,4}[A-Z]{0,5}[0-9]?[A-Z]?)')
jis_matcher = RegexMatchSpan(rgx='(2S[abcdefghjkmqrstvz]{1}[\d]{2,4})')
others_matcher = RegexMatchSpan(rgx='((NSVBC|SMBT|MJ|MJE|MPS|MRF|RCA|TIP|ZTX|ZT|TIS|TIPL|DTC|MMBT|PZT){1}[\d]{2,4}[A-Z]{0,3}([-][A-Z0-9]{0,6})?([-][A-Z0-9]{0,1})?)')
parts_matcher = Union(eeca_matcher, jedec_matcher, jis_matcher, others_matcher)

polarity_matcher = RegexMatchSpan(rgx=r'(pnp|npn)', ignore_case=True)

# %% [markdown]
# ### Define ContextSpaces

# %%
from snorkel.candidates import OmniNgrams
from hardware_utils import OmniNgramsPart, get_gold_dict
from collections import defaultdict
import os

# Make parts list
gold_file = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/hardware_gold.csv'
gold_parts = get_gold_dict(gold_file, doc_on=True, part_on=True, val_on=False)
parts_by_doc = defaultdict(set)
for part in gold_parts:
    parts_by_doc[part[0]].add(part[1])

part_ngrams = OmniNgramsPart(n_max=3, parts_by_doc=None) # NOTE: linking is turned off
polarity_ngrams = OmniNgrams(n_max=1)

# %% [markdown]
# ### Run CandidateExtractor

# %%
from snorkel.models import Corpus
from snorkel.candidates import CandidateExtractor
from snorkel.utils import get_ORM_instance
ce = CandidateExtractor(Part_Polarity, 
                        [part_ngrams, polarity_ngrams], 
                        [parts_matcher, polarity_matcher], 
                        throttler=None)

for corpus_name in ['Hardware Training', 'Hardware Development']:
    corpus = get_ORM_instance(Corpus, session, corpus_name)
    print "Extracting Candidates from %s" % corpus
    # %time candidates = ce.extract(\
        corpus.documents, corpus_name + ' Candidates', session)
    session.add(candidates)
    print "%s contains %d Candidates" % (candidates, len(candidates))
session.commit()
# Out:
# Extracting Candidates from Corpus (Hardware Training)
# [========================================] 100%
# CPU times: user 860 ms, sys: 40 ms, total: 900 ms
# Wall time: 1.09 s
# Candidate Set (Hardware Training Candidates) contains 399 Candidates
# Extracting Candidates from Corpus (Hardware Development)
# [========================================] 100%
# CPU times: user 404 ms, sys: 4 ms, total: 408 ms
# Wall time: 489 ms
# Candidate Set (Hardware Development Candidates) contains 130 Candidates

# %% [markdown]
# ### Assess Recall

# %%
from snorkel.models import Candidate
from hardware_utils import entity_level_total_recall

all_candidates = session.query(Candidate).all()
gold_file = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/hardware_gold.csv'
(tp, fp, fn) = entity_level_total_recall(
    all_candidates, gold_file, 'polarity', relation=True)
# Out:
# Preparing candidates...
# [========================================] 100%
# ========================================
# Scoring on Entity-Level Total Recall
# ========================================
# Entity-level Candidates extracted: 93
# Entity-level Gold: 829
# Intersection Candidates: 52
# ----------------------------------------
# Overlap with Gold:  0.0627
# ========================================

# %%
from pprint import pprint
pprint(fn)
print len(fn)
# Out:
# set([('112823', 'BC546', 'NPN'),
#      ('112823', 'BC546B', 'NPN'),
#      ('112823', 'BC546BG', 'NPN'),
#      ('112823', 'BC546BRL1', 'NPN'),
#      ('112823', 'BC546BRL1G', 'NPN'),
#      ('112823', 'BC546BZL1G', 'NPN'),
#      ('112823', 'BC547', 'NPN'),
#      ('112823', 'BC547A', 'NPN'),
#      ('112823', 'BC547ARL', 'NPN'),
#      ('112823', 'BC547ARLG', 'NPN'),
#      ('112823', 'BC547AZL1G', 'NPN'),
#      ('112823', 'BC547B', 'NPN'),
#      ('112823', 'BC547BG', 'NPN'),
#      ('112823', 'BC547BRL1G', 'NPN'),
#      ('112823', 'BC547BZL1G', 'NPN'),
#      ('112823', 'BC547C', 'NPN'),
#      ('112823', 'BC547CG', 'NPN'),
#      ('112823', 'BC547CZL1G', 'NPN'),
#      ('112823', 'BC548', 'NPN'),
#      ('112823', 'BC548B', 'NPN'),
#      ('112823', 'BC548BG', 'NPN'),
#      ('112823', 'BC548BRL1G', 'NPN'),
#      ('112823', 'BC548BZL1G', 'NPN'),
#      ('112823', 'BC548C', 'NPN'),
#      ('112823', 'BC548CG', 'NPN'),
#      ('112823', 'BC548CZL1G', 'NPN'),
#      ('2N3906', '2N3906', 'PNP'),
#      ('2N3906', '2N3906BU', 'PNP'),
#      ('2N3906', '2N3906TA', 'PNP'),
#      ('2N3906', '2N3906TAR', 'PNP'),
#      ('2N3906', '2N3906TF', 'PNP'),
#      ('2N3906', '2N3906TFR', 'PNP'),
#      ('2N3906', 'MMBT3906', 'PNP'),
#      ('2N3906', 'PZT3906', 'PNP'),
#      ('2N3906-D', '2N3906', 'PNP'),
#      ('2N3906-D', '2N3906G', 'PNP'),
#      ('2N3906-D', '2N3906RL1', 'PNP'),
#      ('2N3906-D', '2N3906RL1G', 'PNP'),
#      ('2N3906-D', '2N3906RLRA', 'PNP'),
#      ('2N3906-D', '2N3906RLRAG', 'PNP'),
#      ('2N3906-D', '2N3906RLRM', 'PNP'),
#      ('2N3906-D', '2N3906RLRMG', 'PNP'),
#      ('2N3906-D', '2N3906RLRP', 'PNP'),
#      ('2N3906-D', '2N3906RLRPG', 'PNP'),
#      ('2N4123-D', '2N4123', 'NPN'),
#      ('2N4123-D', '2N4123RLRM', 'NPN'),
#      ('2N4123-D', '2N4124', 'NPN'),
#      ('2N4123-D', '2N4124G', 'NPN'),
#      ('2N4124', '2N4124', 'NPN'),
#      ('2N4124', 'MMBT4124', 'NPN'),
#      ('2N6426-D', '2N6426', 'NPN'),
#      ('2N6426-D', '2N6426G', 'NPN'),
#      ('2N6426-D', '2N6426RLRAG', 'NPN'),
#      ('2N6426-D', '2N6427', 'NPN'),
#      ('2N6426-D', '2N6427G', 'NPN'),
#      ('2N6426-D', '2N6427RLRAG', 'NPN'),
#      ('2N6427', '2N6427', 'NPN'),
#      ('2N6427', 'MMBT6427', 'NPN'),
#      ('AUKCS04635-1', '2N3906', 'PNP'),
#      ('BC182', 'BC182', 'NPN'),
#      ('BC337', 'BC337', 'NPN'),
#      ('BC337', 'BC337-16', 'NPN'),
#      ('BC337', 'BC337-25', 'NPN'),
#      ('BC337', 'BC337-40', 'NPN'),
#      ('BC337', 'BC33716BU', 'NPN'),
#      ('BC337', 'BC33716TA', 'NPN'),
#      ('BC337', 'BC33716TFR', 'NPN'),
#      ('BC337', 'BC33725BU', 'NPN'),
#      ('BC337', 'BC33725TA', 'NPN'),
#      ('BC337', 'BC33725TAR', 'NPN'),
#      ('BC337', 'BC33725TF', 'NPN'),
#      ('BC337', 'BC33725TFR', 'NPN'),
#      ('BC337', 'BC33740TA', 'NPN'),
#      ('BC337', 'BC338', 'NPN'),
#      ('BC337', 'BC338-25', 'NPN'),
#      ('BC337', 'BC33825TA', 'NPN'),
#      ('BC337-D', 'BC337', 'NPN'),
#      ('BC337-D', 'BC337-025G', 'NPN'),
#      ('BC337-D', 'BC337-040G', 'NPN'),
#      ('BC337-D', 'BC337-25', 'NPN'),
#      ('BC337-D', 'BC337-25RL1G', 'NPN'),
#      ('BC337-D', 'BC337-25RLRAG', 'NPN'),
#      ('BC337-D', 'BC337-25ZL1G', 'NPN'),
#      ('BC337-D', 'BC337-40', 'NPN'),
#      ('BC337-D', 'BC337-40RL1G', 'NPN'),
#      ('BC337-D', 'BC337-40ZL1G', 'NPN'),
#      ('BC337-D', 'BC337G', 'NPN'),
#      ('BC337-D', 'BC337RL1G', 'NPN'),
#      ('BC546', 'BC546', 'NPN'),
#      ('BC546', 'BC546A', 'NPN'),
#      ('BC546', 'BC546ABU', 'NPN'),
#      ('BC546', 'BC546ATA', 'NPN'),
#      ('BC546', 'BC546B', 'NPN'),
#      ('BC546', 'BC546BTA', 'NPN'),
#      ('BC546', 'BC546BTF', 'NPN'),
#      ('BC546', 'BC546C', 'NPN'),
#      ('BC546', 'BC546CTA', 'NPN'),
#      ('BC546', 'BC547', 'NPN'),
#      ('BC546', 'BC547A', 'NPN'),
#      ('BC546', 'BC547ATA', 'NPN'),
#      ('BC546', 'BC547B', 'NPN'),
#      ('BC546', 'BC547BBU', 'NPN'),
#      ('BC546', 'BC547BTA', 'NPN'),
#      ('BC546', 'BC547BTF', 'NPN'),
#      ('BC546', 'BC547C', 'NPN'),
#      ('BC546', 'BC547CBU', 'NPN'),
#      ('BC546', 'BC547CTA', 'NPN'),
#      ('BC546', 'BC547CTFR', 'NPN'),
#      ('BC546', 'BC548', 'NPN'),
#      ('BC546', 'BC548B', 'NPN'),
#      ('BC546', 'BC548BTA', 'NPN'),
#      ('BC546', 'BC548BU', 'NPN'),
#      ('BC546', 'BC548C', 'NPN'),
#      ('BC546', 'BC548CTA', 'NPN'),
#      ('BC546', 'BC549', 'NPN'),
#      ('BC546', 'BC549B', 'NPN'),
#      ('BC546', 'BC549BTA', 'NPN'),
#      ('BC546', 'BC549BTF', 'NPN'),
#      ('BC546', 'BC549C', 'NPN'),
#      ('BC546', 'BC549CTA', 'NPN'),
#      ('BC546', 'BC550', 'NPN'),
#      ('BC546', 'BC550C', 'NPN'),
#      ('BC546', 'BC550CBU', 'NPN'),
#      ('BC546', 'BC550CTA', 'NPN'),
#      ('BC546-BC548C(TO-92)', 'BC546', 'NPN'),
#      ('BC546-BC548C(TO-92)', 'BC546B', 'NPN'),
#      ('BC546-BC548C(TO-92)', 'BC547', 'NPN'),
#      ('BC546-BC548C(TO-92)', 'BC547A', 'NPN'),
#      ('BC546-BC548C(TO-92)', 'BC547B', 'NPN'),
#      ('BC546-BC548C(TO-92)', 'BC547C', 'NPN'),
#      ('BC546-BC548C(TO-92)', 'BC548', 'NPN'),
#      ('BC546-BC548C(TO-92)', 'BC548A', 'NPN'),
#      ('BC546-BC548C(TO-92)', 'BC548B', 'NPN'),
#      ('BC546-BC548C(TO-92)', 'BC548C', 'NPN'),
#      ('BC546-D', 'BC546', 'NPN'),
#      ('BC546-D', 'BC546B', 'NPN'),
#      ('BC546-D', 'BC546BG', 'NPN'),
#      ('BC546-D', 'BC546BRL1', 'NPN'),
#      ('BC546-D', 'BC546BRL1G', 'NPN'),
#      ('BC546-D', 'BC546BZL1G', 'NPN'),
#      ('BC546-D', 'BC547', 'NPN'),
#      ('BC546-D', 'BC547A', 'NPN'),
#      ('BC546-D', 'BC547ARL', 'NPN'),
#      ('BC546-D', 'BC547ARLG', 'NPN'),
#      ('BC546-D', 'BC547AZL1G', 'NPN'),
#      ('BC546-D', 'BC547B', 'NPN'),
#      ('BC546-D', 'BC547BG', 'NPN'),
#      ('BC546-D', 'BC547BRL1G', 'NPN'),
#      ('BC546-D', 'BC547BZL1G', 'NPN'),
#      ('BC546-D', 'BC547C', 'NPN'),
#      ('BC546-D', 'BC547CG', 'NPN'),
#      ('BC546-D', 'BC547CZL1G', 'NPN'),
#      ('BC546-D', 'BC548', 'NPN'),
#      ('BC546-D', 'BC548B', 'NPN'),
#      ('BC546-D', 'BC548BG', 'NPN'),
#      ('BC546-D', 'BC548BRL1G', 'NPN'),
#      ('BC546-D', 'BC548BZL1G', 'NPN'),
#      ('BC546-D', 'BC548C', 'NPN'),
#      ('BC546-D', 'BC548CG', 'NPN'),
#      ('BC546-D', 'BC548CZL1G', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC546', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC546A', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC546B', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC546C', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC547', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC547A', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC547B', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC547C', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC548', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC548A', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC548B', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC548C', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC549', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC549A', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC549B', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC549C', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC550', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC550A', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC550B', 'NPN'),
#      ('BC546A_SERIES_B14-521026', 'BC550C', 'NPN'),
#      ('BC546_DIOTEC', 'BC546', 'NPN'),
#      ('BC546_DIOTEC', 'BC546A', 'NPN'),
#      ('BC546_DIOTEC', 'BC546B', 'NPN'),
#      ('BC546_DIOTEC', 'BC547', 'NPN'),
#      ('BC546_DIOTEC', 'BC547A', 'NPN'),
#      ('BC546_DIOTEC', 'BC547B', 'NPN'),
#      ('BC546_DIOTEC', 'BC547C', 'NPN'),
#      ('BC546_DIOTEC', 'BC548', 'NPN'),
#      ('BC546_DIOTEC', 'BC548A', 'NPN'),
#      ('BC546_DIOTEC', 'BC548B', 'NPN'),
#      ('BC546_DIOTEC', 'BC548C', 'NPN'),
#      ('BC546_DIOTEC', 'BC549', 'NPN'),
#      ('BC546_DIOTEC', 'BC549B', 'NPN'),
#      ('BC546_DIOTEC', 'BC549C', 'NPN'),
#      ('BC547', 'BC546', 'NPN'),
#      ('BC547', 'BC546A', 'NPN'),
#      ('BC547', 'BC546ABU', 'NPN'),
#      ('BC547', 'BC546ATA', 'NPN'),
#      ('BC547', 'BC546B', 'NPN'),
#      ('BC547', 'BC546BTA', 'NPN'),
#      ('BC547', 'BC546BTF', 'NPN'),
#      ('BC547', 'BC546C', 'NPN'),
#      ('BC547', 'BC546CTA', 'NPN'),
#      ('BC547', 'BC547', 'NPN'),
#      ('BC547', 'BC547A', 'NPN'),
#      ('BC547', 'BC547ATA', 'NPN'),
#      ('BC547', 'BC547B', 'NPN'),
#      ('BC547', 'BC547BBU', 'NPN'),
#      ('BC547', 'BC547BTA', 'NPN'),
#      ('BC547', 'BC547BTF', 'NPN'),
#      ('BC547', 'BC547C', 'NPN'),
#      ('BC547', 'BC547CBU', 'NPN'),
#      ('BC547', 'BC547CTA', 'NPN'),
#      ('BC547', 'BC547CTFR', 'NPN'),
#      ('BC547', 'BC548', 'NPN'),
#      ('BC547', 'BC548B', 'NPN'),
#      ('BC547', 'BC548BTA', 'NPN'),
#      ('BC547', 'BC548C', 'NPN'),
#      ('BC547', 'BC548CTA', 'NPN'),
#      ('BC547', 'BC549', 'NPN'),
#      ('BC547', 'BC549B', 'NPN'),
#      ('BC547', 'BC549BTA', 'NPN'),
#      ('BC547', 'BC549BTF', 'NPN'),
#      ('BC547', 'BC549C', 'NPN'),
#      ('BC547', 'BC549CTA', 'NPN'),
#      ('BC547', 'BC550', 'NPN'),
#      ('BC547', 'BC550C', 'NPN'),
#      ('BC547', 'BC550CBU', 'NPN'),
#      ('BC547', 'BC550CTA', 'NPN'),
#      ('BC550', 'BC546', 'NPN'),
#      ('BC550', 'BC546A', 'NPN'),
#      ('BC550', 'BC546B', 'NPN'),
#      ('BC550', 'BC546C', 'NPN'),
#      ('BC550', 'BC547', 'NPN'),
#      ('BC550', 'BC547A', 'NPN'),
#      ('BC550', 'BC547B', 'NPN'),
#      ('BC550', 'BC547C', 'NPN'),
#      ('BC550', 'BC548', 'NPN'),
#      ('BC550', 'BC548A', 'NPN'),
#      ('BC550', 'BC548B', 'NPN'),
#      ('BC550', 'BC548C', 'NPN'),
#      ('BC550', 'BC549', 'NPN'),
#      ('BC550', 'BC549A', 'NPN'),
#      ('BC550', 'BC549B', 'NPN'),
#      ('BC550', 'BC549C', 'NPN'),
#      ('BC550', 'BC550', 'NPN'),
#      ('BC550', 'BC550A', 'NPN'),
#      ('BC550', 'BC550B', 'NPN'),
#      ('BC550', 'BC550C', 'NPN'),
#      ('BC818', 'BC817', 'NPN'),
#      ('BC818', 'BC817-16', 'NPN'),
#      ('BC818', 'BC817-25', 'NPN'),
#      ('BC818', 'BC817-40', 'NPN'),
#      ('BC818', 'BC81716MTF', 'NPN'),
#      ('BC818', 'BC81725MTF', 'NPN'),
#      ('BC818', 'BC81740MTF', 'NPN'),
#      ('BC818', 'BC818', 'NPN'),
#      ('BC818', 'BC818-16', 'NPN'),
#      ('BC818', 'BC818-25', 'NPN'),
#      ('BC818', 'BC818-40', 'NPN'),
#      ('BC818', 'BC81816MTF', 'NPN'),
#      ('BC818', 'BC81825MTF', 'NPN'),
#      ('BC818', 'BC81840MTF', 'NPN'),
#      ('BC818-40LT1-D', 'BC818-40L', 'NPN'),
#      ('BC818-40LT1-D', 'BC818-40LT1G', 'NPN'),
#      ('BC818-40LT1-D', 'NSVBC818-40L', 'NPN'),
#      ('BC818-40LT1-D', 'NSVBC818-40LT1G', 'NPN'),
#      ('CSEMS02742-1', 'BC846', 'NPN'),
#      ('CSEMS02742-1', 'BC846A', 'NPN'),
#      ('CSEMS02742-1', 'BC846B', 'NPN'),
#      ('CSEMS02742-1', 'BC847', 'NPN'),
#      ('CSEMS02742-1', 'BC847A', 'NPN'),
#      ('CSEMS02742-1', 'BC847B', 'NPN'),
#      ('CSEMS02742-1', 'BC847C', 'NPN'),
#      ('CSEMS02742-1', 'BC848', 'NPN'),
#      ('CSEMS02742-1', 'BC848A', 'NPN'),
#      ('CSEMS02742-1', 'BC848B', 'NPN'),
#      ('CSEMS02742-1', 'BC848C', 'NPN'),
#      ('CSEMS03485-1', '2N3905', 'PNP'),
#      ('CSEMS03485-1', '2N3906', 'PNP'),
#      ('CSEMS05382-1', 'BC546', 'NPN'),
#      ('CSEMS05382-1', 'BC546A', 'NPN'),
#      ('CSEMS05382-1', 'BC546B', 'NPN'),
#      ('CSEMS05382-1', 'BC547', 'NPN'),
#      ('CSEMS05382-1', 'BC547A', 'NPN'),
#      ('CSEMS05382-1', 'BC547B', 'NPN'),
#      ('CSEMS05382-1', 'BC547C', 'NPN'),
#      ('CSEMS05382-1', 'BC548', 'NPN'),
#      ('CSEMS05382-1', 'BC548A', 'NPN'),
#      ('CSEMS05382-1', 'BC548B', 'NPN'),
#      ('CSEMS05382-1', 'BC548C', 'NPN'),
#      ('CSEMS05383-1', 'BC817', 'NPN'),
#      ('CSEMS05383-1', 'BC817-16', 'NPN'),
#      ('CSEMS05383-1', 'BC817-25', 'NPN'),
#      ('CSEMS05383-1', 'BC817-40', 'NPN'),
#      ('CSEMS05383-1', 'BC818', 'NPN'),
#      ('CSEMS05383-1', 'BC818-16', 'NPN'),
#      ('CSEMS05383-1', 'BC818-25', 'NPN'),
#      ('CSEMS05383-1', 'BC818-40', 'NPN'),
#      ('DIODS00215-1', '2N4124', 'NPN'),
#      ('DISES00023-1', '2N3906', 'PNP'),
#      ('DISES00189-1', 'BC546', 'NPN'),
#      ('DISES00189-1', 'BC546A', 'NPN'),
#      ('DISES00189-1', 'BC546B', 'NPN'),
#      ('DISES00189-1', 'BC547', 'NPN'),
#      ('DISES00189-1', 'BC547A', 'NPN'),
#      ('DISES00189-1', 'BC547B', 'NPN'),
#      ('DISES00189-1', 'BC547C', 'NPN'),
#      ('DISES00189-1', 'BC548', 'NPN'),
#      ('DISES00189-1', 'BC548A', 'NPN'),
#      ('DISES00189-1', 'BC548B', 'NPN'),
#      ('DISES00189-1', 'BC548C', 'NPN'),
#      ('DISES00189-1', 'BC549', 'NPN'),
#      ('DISES00189-1', 'BC549B', 'NPN'),
#      ('DISES00189-1', 'BC549C', 'NPN'),
#      ('DISES00192-1', 'BC807', 'PNP'),
#      ('DISES00192-1', 'BC807-16', 'PNP'),
#      ('DISES00192-1', 'BC807-25', 'PNP'),
#      ('DISES00192-1', 'BC807-40', 'PNP'),
#      ('DISES00192-1', 'BC808', 'PNP'),
#      ('DISES00192-1', 'BC808-16', 'PNP'),
#      ('DISES00192-1', 'BC808-25', 'PNP'),
#      ('DISES00192-1', 'BC808-40', 'PNP'),
#      ('DISES00242-1', 'MMBT3904', 'NPN'),
#      ('DISES00490-1', 'BC846AW', 'NPN'),
#      ('DISES00490-1', 'BC846BW', 'NPN'),
#      ('DISES00490-1', 'BC846W', 'NPN'),
#      ('DISES00490-1', 'BC847AW', 'NPN'),
#      ('DISES00490-1', 'BC847BW', 'NPN'),
#      ('DISES00490-1', 'BC847CW', 'NPN'),
#      ('DISES00490-1', 'BC847W', 'NPN'),
#      ('DISES00490-1', 'BC848AW', 'NPN'),
#      ('DISES00490-1', 'BC848BW', 'NPN'),
#      ('DISES00490-1', 'BC848CW', 'NPN'),
#      ('DISES00490-1', 'BC848W', 'NPN'),
#      ('DISES00490-1', 'BC849BW', 'NPN'),
#      ('DISES00490-1', 'BC849CW', 'NPN'),
#      ('DISES00490-1', 'BC849W', 'NPN'),
#      ('DISES00616-1', 'BC856', 'PNP'),
#      ('DISES00616-1', 'BC856A', 'PNP'),
#      ('DISES00616-1', 'BC856B', 'PNP'),
#      ('DISES00616-1', 'BC856C', 'PNP'),
#      ('DISES00616-1', 'BC857', 'PNP'),
#      ('DISES00616-1', 'BC857A', 'PNP'),
#      ('DISES00616-1', 'BC857B', 'PNP'),
#      ('DISES00616-1', 'BC857C', 'PNP'),
#      ('DISES00616-1', 'BC858', 'PNP'),
#      ('DISES00616-1', 'BC858A', 'PNP'),
#      ('DISES00616-1', 'BC858B', 'PNP'),
#      ('DISES00616-1', 'BC858C', 'PNP'),
#      ('DISES00616-1', 'BC859', 'PNP'),
#      ('DISES00616-1', 'BC859B', 'PNP'),
#      ('DISES00616-1', 'BC859C', 'PNP'),
#      ('DISES00616-1', 'BC860', 'PNP'),
#      ('DISES00616-1', 'BC860B', 'PNP'),
#      ('DISES00616-1', 'BC860C', 'PNP'),
#      ('DTC114W', 'DTC114W', 'NPN'),
#      ('DTC114W', 'DTC114WE', 'NPN'),
#      ('DTC114W', 'DTC114WKA', 'NPN'),
#      ('DTC114W', 'DTC114WUA', 'NPN'),
#      ('FAIRS19194-1', 'BC856A', 'PNP'),
#      ('FAIRS19194-1', 'BC856B', 'PNP'),
#      ('FAIRS19194-1', 'BC856C', 'PNP'),
#      ('FAIRS19194-1', 'BC857A', 'PNP'),
#      ('FAIRS19194-1', 'BC857B', 'PNP'),
#      ('FAIRS19194-1', 'BC857C', 'PNP'),
#      ('FAIRS19194-1', 'BC858A', 'PNP'),
#      ('FAIRS19194-1', 'BC858B', 'PNP'),
#      ('FAIRS19194-1', 'BC858C', 'PNP'),
#      ('FAIRS19194-1', 'BC859A', 'PNP'),
#      ('FAIRS19194-1', 'BC859B', 'PNP'),
#      ('FAIRS19194-1', 'BC859C', 'PNP'),
#      ('FAIRS19194-1', 'BC860A', 'PNP'),
#      ('FAIRS19194-1', 'BC860B', 'PNP'),
#      ('FAIRS19194-1', 'BC860C', 'PNP'),
#      ('FAIRS25065-1', 'BC237', 'NPN'),
#      ('FAIRS25065-1', 'BC237A', 'NPN'),
#      ('FAIRS25065-1', 'BC237B', 'NPN'),
#      ('FAIRS25065-1', 'BC237C', 'NPN'),
#      ('FAIRS25065-1', 'BC238', 'NPN'),
#      ('FAIRS25065-1', 'BC238A', 'NPN'),
#      ('FAIRS25065-1', 'BC238B', 'NPN'),
#      ('FAIRS25065-1', 'BC238C', 'NPN'),
#      ('FAIRS25065-1', 'BC239', 'NPN'),
#      ('FAIRS25065-1', 'BC239A', 'NPN'),
#      ('FAIRS25065-1', 'BC239B', 'NPN'),
#      ('FAIRS25065-1', 'BC239C', 'NPN'),
#      ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K', 'NPN'),
#      ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-16', 'NPN'),
#      ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-16W', 'NPN'),
#      ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-25', 'NPN'),
#      ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-25W', 'NPN'),
#      ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-40', 'NPN'),
#      ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-40W', 'NPN'),
#      ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817KW', 'NPN'),
#      ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC818K', 'NPN'),
#      ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC818K-16W', 'NPN'),
#      ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC818K-40', 'NPN'),
#      ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC818KW', 'NPN'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC857',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC857A',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC857B',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC857BL3',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC857BW',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC857C',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC857CW',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC858',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC858A',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC858B',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC858BW',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC858C',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC858CW',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC859',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC859C',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC860',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC860B',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC860BW',
#       'PNP'),
#      ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#       'BC860CW',
#       'PNP'),
#      ('INFNS19372-1', 'MMBT3904', 'NPN'),
#      ('INFNS19372-1', 'SMBT3904', 'NPN'),
#      ('INFNS19372-1', 'SMBT3904S', 'NPN'),
#      ('JCSTS01155-1', '2N4124', 'NPN'),
#      ('KECCS03676-1', 'BC856', 'PNP'),
#      ('KECCS03676-1', 'BC856A', 'PNP'),
#      ('KECCS03676-1', 'BC856B', 'PNP'),
#      ('KECCS03676-1', 'BC857', 'PNP'),
#      ('KECCS03676-1', 'BC857A', 'PNP'),
#      ('KECCS03676-1', 'BC857B', 'PNP'),
#      ('KECCS03676-1', 'BC857C', 'PNP'),
#      ('KECCS03676-1', 'BC858', 'PNP'),
#      ('KECCS03676-1', 'BC858A', 'PNP'),
#      ('KECCS03676-1', 'BC858B', 'PNP'),
#      ('KECCS03676-1', 'BC858C', 'PNP'),
#      ('KECCS05435-1', 'BC546A', 'NPN'),
#      ('KECCS05435-1', 'BC546B', 'NPN'),
#      ('KECCS05435-1', 'BC547A', 'NPN'),
#      ('KECCS05435-1', 'BC547B', 'NPN'),
#      ('KECCS05435-1', 'BC547C', 'NPN'),
#      ('KECCS05435-1', 'BC548A', 'NPN'),
#      ('KECCS05435-1', 'BC548B', 'NPN'),
#      ('KECCS05435-1', 'BC548C', 'NPN'),
#      ('LITES00424-1', '2N3906', 'PNP'),
#      ('LITES00686-1', '2N4124', 'NPN'),
#      ('LITES00689-1', 'BC337', 'NPN'),
#      ('LITES00689-1', 'BC337-16', 'NPN'),
#      ('LITES00689-1', 'BC337-25', 'NPN'),
#      ('LITES00689-1', 'BC337-40', 'NPN'),
#      ('LITES00690-1', 'BC546', 'NPN'),
#      ('LITES00690-1', 'BC546A', 'NPN'),
#      ('LITES00690-1', 'BC546B', 'NPN'),
#      ('LITES00690-1', 'BC546C', 'NPN'),
#      ('LITES00690-1', 'BC547', 'NPN'),
#      ('LITES00690-1', 'BC547A', 'NPN'),
#      ('LITES00690-1', 'BC547B', 'NPN'),
#      ('LITES00690-1', 'BC547C', 'NPN'),
#      ('LITES00690-1', 'BC548', 'NPN'),
#      ('LITES00690-1', 'BC548A', 'NPN'),
#      ('LITES00690-1', 'BC548B', 'NPN'),
#      ('LITES00690-1', 'BC548C', 'NPN'),
#      ('LTSCS02910-1', 'BC818', 'NPN'),
#      ('LTSCS02910-1', 'BC818-16', 'NPN'),
#      ('LTSCS02910-1', 'BC818-25', 'NPN'),
#      ('LTSCS02910-1', 'BC818-40', 'NPN'),
#      ('LTSCS02912-1', 'BC846AW', 'NPN'),
#      ('LTSCS02912-1', 'BC846BW', 'NPN'),
#      ('LTSCS02912-1', 'BC846W', 'NPN'),
#      ('LTSCS02920-1', 'BC857', 'PNP'),
#      ('LTSCS02920-1', 'BC857A', 'PNP'),
#      ('LTSCS02920-1', 'BC857B', 'PNP'),
#      ('LTSCS02920-1', 'BC857C', 'PNP'),
#      ('MCCCS08610-1', '2N4123', 'NPN'),
#      ('MCCCS08610-1', '2N4124', 'NPN'),
#      ('MCCCS08984-1', 'MMBT3904', 'NPN'),
#      ('MCCCS09540-1', 'BC846', 'NPN'),
#      ('MCCCS09540-1', 'BC846A', 'NPN'),
#      ('MCCCS09540-1', 'BC846B', 'NPN'),
#      ('MCCCS09540-1', 'BC847', 'NPN'),
#      ('MCCCS09540-1', 'BC847A', 'NPN'),
#      ('MCCCS09540-1', 'BC847B', 'NPN'),
#      ('MCCCS09540-1', 'BC847C', 'NPN'),
#      ('MCCCS09540-1', 'BC848', 'NPN'),
#      ('MCCCS09540-1', 'BC848A', 'NPN'),
#      ('MCCCS09540-1', 'BC848B', 'NPN'),
#      ('MCCCS09540-1', 'BC848C', 'NPN'),
#      ('MCCCS09540-1', 'BC849', 'NPN'),
#      ('MCCCS09540-1', 'BC849B', 'NPN'),
#      ('MCCCS09540-1', 'BC849C', 'NPN'),
#      ('MINDS00015-1', '2N3904', 'NPN'),
#      ('MINDS00015-1', 'MMBT3904', 'NPN'),
#      ('MMMCS17742-1', 'BC807-16W', 'PNP'),
#      ('MMMCS17742-1', 'BC807-25W', 'PNP'),
#      ('MMMCS17742-1', 'BC807-40W', 'PNP'),
#      ('MOTOS03160-1', 'BC182', 'NPN'),
#      ('MOTOS03160-1', 'BC182A', 'NPN'),
#      ('MOTOS03160-1', 'BC182B', 'NPN'),
#      ('MOTOS03160-1', 'BC183', 'NPN'),
#      ('MOTOS03160-1', 'BC184', 'NPN'),
#      ('MOTOS03189-1', 'BC337', 'NPN'),
#      ('MOTOS03189-1', 'BC337-16', 'NPN'),
#      ('MOTOS03189-1', 'BC337-25', 'NPN'),
#      ('MOTOS03189-1', 'BC337-40', 'NPN'),
#      ('MOTOS03189-1', 'BC338', 'NPN'),
#      ('MOTOS03189-1', 'BC338-16', 'NPN'),
#      ('MOTOS03189-1', 'BC338-25', 'NPN'),
#      ('MOTOS03189-1', 'BC338-40', 'NPN'),
#      ('MOTOS04676-1', '2N4123', 'NPN'),
#      ('MOTOS04676-1', '2N4124', 'NPN'),
#      ('MOTOS04796-1', '2N6426', 'NPN'),
#      ('MOTOS04796-1', '2N6427', 'NPN'),
#      ('ONSMS04099-1', 'BC237', 'NPN'),
#      ('ONSMS04099-1', 'BC237A', 'NPN'),
#      ('ONSMS04099-1', 'BC237B', 'NPN'),
#      ('ONSMS04099-1', 'BC237C', 'NPN'),
#      ('ONSMS04099-1', 'BC238', 'NPN'),
#      ('ONSMS04099-1', 'BC238B', 'NPN'),
#      ('ONSMS04099-1', 'BC238C', 'NPN'),
#      ('ONSMS04099-1', 'BC239', 'NPN'),
#      ('ONSMS04099-1', 'BC239C', 'NPN'),
#      ('PHGLS18216-1', 'BC547', 'NPN'),
#      ('PHGLS18216-1', 'BC547B', 'NPN'),
#      ('PHGLS18216-1', 'BC547C', 'NPN'),
#      ('PHGLS18216-1', 'BC847', 'NPN'),
#      ('PHGLS18216-1', 'BC847A', 'NPN'),
#      ('PHGLS18216-1', 'BC847AM', 'NPN'),
#      ('PHGLS18216-1', 'BC847AT', 'NPN'),
#      ('PHGLS18216-1', 'BC847AT/DG', 'NPN'),
#      ('PHGLS18216-1', 'BC847AW', 'NPN'),
#      ('PHGLS18216-1', 'BC847B', 'NPN'),
#      ('PHGLS18216-1', 'BC847B/DG', 'NPN'),
#      ('PHGLS18216-1', 'BC847BM', 'NPN'),
#      ('PHGLS18216-1', 'BC847BT', 'NPN'),
#      ('PHGLS18216-1', 'BC847BW', 'NPN'),
#      ('PHGLS18216-1', 'BC847BW/DG', 'NPN'),
#      ('PHGLS18216-1', 'BC847C', 'NPN'),
#      ('PHGLS18216-1', 'BC847CM', 'NPN'),
#      ('PHGLS18216-1', 'BC847CT', 'NPN'),
#      ('PHGLS18216-1', 'BC847CW', 'NPN'),
#      ('PHGLS18216-1', 'BC847T', 'NPN'),
#      ('PHGLS18216-1', 'BC847W', 'NPN'),
#      ('PHGLS19500-1', 'MMBT3904', 'NPN'),
#      ('PHGLS20125-1', 'BC327', 'PNP'),
#      ('PHGLS20125-1', 'BC327-16', 'PNP'),
#      ('PHGLS20125-1', 'BC327-25', 'PNP'),
#      ('PHGLS20125-1', 'BC327-40', 'PNP'),
#      ('PHGLS20125-1', 'BC807', 'PNP'),
#      ('PHGLS20125-1', 'BC807-16', 'PNP'),
#      ('PHGLS20125-1', 'BC807-16W', 'PNP'),
#      ('PHGLS20125-1', 'BC807-25', 'PNP'),
#      ('PHGLS20125-1', 'BC807-25W', 'PNP'),
#      ('PHGLS20125-1', 'BC807-40', 'PNP'),
#      ('PHGLS20125-1', 'BC807-40W', 'PNP'),
#      ('PHGLS20125-1', 'BC807W', 'PNP'),
#      ('PHGLS20126-1', 'BC337', 'NPN'),
#      ('PHGLS20126-1', 'BC337-16', 'NPN'),
#      ('PHGLS20126-1', 'BC337-25', 'NPN'),
#      ('PHGLS20126-1', 'BC337-40', 'NPN'),
#      ('PHGLS20126-1', 'BC817', 'NPN'),
#      ('PHGLS20126-1', 'BC817-16', 'NPN'),
#      ('PHGLS20126-1', 'BC817-16W', 'NPN'),
#      ('PHGLS20126-1', 'BC817-25', 'NPN'),
#      ('PHGLS20126-1', 'BC817-25W', 'NPN'),
#      ('PHGLS20126-1', 'BC817-40', 'NPN'),
#      ('PHGLS20126-1', 'BC817-40W', 'NPN'),
#      ('PHGLS20126-1', 'BC817W', 'NPN'),
#      ('PHGLS20267-1', '2N4124', 'NPN'),
#      ('PHGLS25601-1', 'BC846', 'NPN'),
#      ('PHGLS25601-1', 'BC846A', 'NPN'),
#      ('PHGLS25601-1', 'BC846AT', 'NPN'),
#      ('PHGLS25601-1', 'BC846AW', 'NPN'),
#      ('PHGLS25601-1', 'BC846B', 'NPN'),
#      ('PHGLS25601-1', 'BC846BT', 'NPN'),
#      ('PHGLS25601-1', 'BC846BW', 'NPN'),
#      ('PHGLS25601-1', 'BC846T', 'NPN'),
#      ('PHGLS25601-1', 'BC846W', 'NPN'),
#      ('PJECS00521-1', 'MMBT3904', 'NPN'),
#      ('PNJIS00254-1', 'BC807-16W', 'PNP'),
#      ('PNJIS00254-1', 'BC807-25W', 'PNP'),
#      ('PNJIS00254-1', 'BC807-40W', 'PNP'),
#      ('PNJIS01186-1', 'BC807-16', 'PNP'),
#      ('PNJIS01186-1', 'BC807-25', 'PNP'),
#      ('PNJIS01186-1', 'BC807-40', 'PNP'),
#      ('PNJIS01305-1', 'MMBT3904', 'NPN'),
#      ('PNJIS01453-1', 'BC846', 'NPN'),
#      ('PNJIS01453-1', 'BC846A', 'NPN'),
#      ('PNJIS01453-1', 'BC846B', 'NPN'),
#      ('PNJIS01453-1', 'BC847', 'NPN'),
#      ('PNJIS01453-1', 'BC847A', 'NPN'),
#      ('PNJIS01453-1', 'BC847B', 'NPN'),
#      ('PNJIS01453-1', 'BC847C', 'NPN'),
#      ('PNJIS01453-1', 'BC848', 'NPN'),
#      ('PNJIS01453-1', 'BC848A', 'NPN'),
#      ('PNJIS01453-1', 'BC848B', 'NPN'),
#      ('PNJIS01453-1', 'BC848C', 'NPN'),
#      ('PNJIS01453-1', 'BC849', 'NPN'),
#      ('PNJIS01453-1', 'BC849B', 'NPN'),
#      ('PNJIS01453-1', 'BC849C', 'NPN'),
#      ('PNJIS01453-1', 'BC850', 'NPN'),
#      ('PNJIS01453-1', 'BC850B', 'NPN'),
#      ('PNJIS01453-1', 'BC850C', 'NPN'),
#      ('PNJIS01593-1', 'BC856', 'PNP'),
#      ('PNJIS01593-1', 'BC856A', 'PNP'),
#      ('PNJIS01593-1', 'BC856B', 'PNP'),
#      ('PNJIS01593-1', 'BC857', 'PNP'),
#      ('PNJIS01593-1', 'BC857A', 'PNP'),
#      ('PNJIS01593-1', 'BC857B', 'PNP'),
#      ('PNJIS01593-1', 'BC857C', 'PNP'),
#      ('PNJIS01593-1', 'BC858', 'PNP'),
#      ('PNJIS01593-1', 'BC858A', 'PNP'),
#      ('PNJIS01593-1', 'BC858B', 'PNP'),
#      ('PNJIS01593-1', 'BC858C', 'PNP'),
#      ('PNJIS01593-1', 'BC859', 'PNP'),
#      ('PNJIS01593-1', 'BC859B', 'PNP'),
#      ('PNJIS01593-1', 'BC859C', 'PNP'),
#      ('RECTS00705-1', 'BC546', 'NPN'),
#      ('RECTS00705-1', 'BC546A', 'NPN'),
#      ('RECTS00705-1', 'BC546B', 'NPN'),
#      ('RECTS00705-1', 'BC546C', 'NPN'),
#      ('RECTS00705-1', 'BC547', 'NPN'),
#      ('RECTS00705-1', 'BC547A', 'NPN'),
#      ('RECTS00705-1', 'BC547B', 'NPN'),
#      ('RECTS00705-1', 'BC547C', 'NPN'),
#      ('RECTS00705-1', 'BC548', 'NPN'),
#      ('RECTS00705-1', 'BC548A', 'NPN'),
#      ('RECTS00705-1', 'BC548B', 'NPN'),
#      ('RECTS00705-1', 'BC548C', 'NPN'),
#      ('RECTS01002-1', 'MMBT3904', 'NPN'),
#      ('RECTS01158-1', 'BC807-25', 'PNP'),
#      ('RECTS01242-1', 'BC857B', 'PNP'),
#      ('RECTS01325-1', 'DTC114YUA', 'NPN'),
#      ('SAMSD00049-518', 'BC546', 'NPN'),
#      ('SAMSD00049-518', 'BC546A', 'NPN'),
#      ('SAMSD00049-518', 'BC546B', 'NPN'),
#      ('SAMSD00049-518', 'BC546C', 'NPN'),
#      ('SAMSD00049-518', 'BC547', 'NPN'),
#      ('SAMSD00049-518', 'BC547A', 'NPN'),
#      ('SAMSD00049-518', 'BC547B', 'NPN'),
#      ('SAMSD00049-518', 'BC547C', 'NPN'),
#      ('SAMSD00049-518', 'BC548', 'NPN'),
#      ('SAMSD00049-518', 'BC548A', 'NPN'),
#      ('SAMSD00049-518', 'BC548B', 'NPN'),
#      ('SAMSD00049-518', 'BC548C', 'NPN'),
#      ('SAMSD00049-518', 'BC549', 'NPN'),
#      ('SAMSD00049-518', 'BC549A', 'NPN'),
#      ('SAMSD00049-518', 'BC549B', 'NPN'),
#      ('SAMSD00049-518', 'BC549C', 'NPN'),
#      ('SAMSD00049-518', 'BC550', 'NPN'),
#      ('SAMSD00049-518', 'BC550A', 'NPN'),
#      ('SAMSD00049-518', 'BC550B', 'NPN'),
#      ('SAMSD00049-518', 'BC550C', 'NPN'),
#      ('SCSCS02175-1', 'BC546', 'NPN'),
#      ('SCSCS02175-1', 'BC546A', 'NPN'),
#      ('SCSCS02175-1', 'BC546B', 'NPN'),
#      ('SCSCS02175-1', 'BC546C', 'NPN'),
#      ('SCSCS02175-1', 'BC547', 'NPN'),
#      ('SCSCS02175-1', 'BC547A', 'NPN'),
#      ('SCSCS02175-1', 'BC547B', 'NPN'),
#      ('SCSCS02175-1', 'BC547C', 'NPN'),
#      ('SCSCS02175-1', 'BC548', 'NPN'),
#      ('SCSCS02175-1', 'BC548A', 'NPN'),
#      ('SCSCS02175-1', 'BC548B', 'NPN'),
#      ('SCSCS02175-1', 'BC548C', 'NPN'),
#      ('SCSCS02324-1', 'MMBT3904', 'NPN'),
#      ('SGSTS13702-1', 'BC547B', 'NPN'),
#      ('SGSTS13702-1', 'BC547B-AP', 'NPN'),
#      ('SGSTS13702-1', 'BC547C', 'NPN'),
#      ('SGSTS13702-1', 'BC547C-AP', 'NPN'),
#      ('SGSTS13734-1', 'BC337-25', 'NPN'),
#      ('SGSTS13734-1', 'BC337-25-AP', 'NPN'),
#      ('SGSTS13734-1', 'BC337-40', 'NPN'),
#      ('SGSTS13734-1', 'BC337-40-AP', 'NPN'),
#      ('SIEMS01215-1', 'BC856', 'PNP'),
#      ('SIEMS01215-1', 'BC856A', 'PNP'),
#      ('SIEMS01215-1', 'BC856B', 'PNP'),
#      ('SIEMS01215-1', 'BC857', 'PNP'),
#      ('SIEMS01215-1', 'BC857A', 'PNP'),
#      ('SIEMS01215-1', 'BC857B', 'PNP'),
#      ('SIEMS01215-1', 'BC857C', 'PNP'),
#      ('SIEMS01215-1', 'BC858', 'PNP'),
#      ('SIEMS01215-1', 'BC858A', 'PNP'),
#      ('SIEMS01215-1', 'BC858B', 'PNP'),
#      ('SIEMS01215-1', 'BC858C', 'PNP'),
#      ('SIEMS01215-1', 'BC859', 'PNP'),
#      ('SIEMS01215-1', 'BC859A', 'PNP'),
#      ('SIEMS01215-1', 'BC859B', 'PNP'),
#      ('SIEMS01215-1', 'BC859C', 'PNP'),
#      ('SIEMS01215-1', 'BC860', 'PNP'),
#      ('SIEMS01215-1', 'BC860B', 'PNP'),
#      ('SIEMS01215-1', 'BC860C', 'PNP'),
#      ('TKCGS00622-1', 'DTC114EE', 'NPN'),
#      ('TKCGS00622-1', 'DTC114TE', 'NPN'),
#      ('TKCGS00622-1', 'DTC114YE', 'NPN'),
#      ('TKCGS00622-1', 'DTC123EE', 'NPN'),
#      ('TKCGS00622-1', 'DTC123JE', 'NPN'),
#      ('TKCGS00622-1', 'DTC124EE', 'NPN'),
#      ('TKCGS00622-1', 'DTC124XE', 'NPN'),
#      ('TKCGS00622-1', 'DTC143EE', 'NPN'),
#      ('TKCGS00622-1', 'DTC143TE', 'NPN'),
#      ('TKCGS00622-1', 'DTC143ZE', 'NPN'),
#      ('TKCGS00622-1', 'DTC144EE', 'NPN'),
#      ('TWSCS04757-1', 'BC807-16', 'PNP'),
#      ('TWSCS04757-1', 'BC807-25', 'PNP'),
#      ('TWSCS04757-1', 'BC807-40', 'PNP'),
#      ('UTCLS02155-1', 'BC807', 'PNP'),
#      ('UTCLS02155-1', 'BC807-16', 'PNP'),
#      ('UTCLS02155-1', 'BC807-25', 'PNP'),
#      ('UTCLS02155-1', 'BC807-40', 'PNP'),
#      ('UTCLS02155-1', 'BC808', 'PNP'),
#      ('UTCLS02155-1', 'BC808-16', 'PNP'),
#      ('UTCLS02155-1', 'BC808-25', 'PNP'),
#      ('UTCLS02155-1', 'BC808-40', 'PNP'),
#      ('UTCLS03593-1', 'DTC114E', 'NPN'),
#      ('VISHS23888-1', 'BC546', 'NPN'),
#      ('VISHS23888-1', 'BC546A', 'NPN'),
#      ('VISHS23888-1', 'BC546B', 'NPN'),
#      ('VISHS23888-1', 'BC547', 'NPN'),
#      ('VISHS23888-1', 'BC547A', 'NPN'),
#      ('VISHS23888-1', 'BC547B', 'NPN'),
#      ('VISHS23888-1', 'BC547C', 'NPN'),
#      ('VISHS23888-1', 'BC548', 'NPN'),
#      ('VISHS23888-1', 'BC548A', 'NPN'),
#      ('VISHS23888-1', 'BC548B', 'NPN'),
#      ('VISHS23888-1', 'BC548C', 'NPN'),
#      ('VISHS23888-1', 'BC549', 'NPN'),
#      ('VISHS23888-1', 'BC549B', 'NPN'),
#      ('VISHS23888-1', 'BC549C', 'NPN'),
#      ('VSMIS00373-1', 'BC337', 'NPN'),
#      ('VSMIS00373-1', 'BC337-16', 'NPN'),
#      ('VSMIS00373-1', 'BC337-25', 'NPN'),
#      ('VSMIS00373-1', 'BC337-40', 'NPN'),
#      ('VSMIS00373-1', 'BC338', 'NPN'),
#      ('VSMIS00373-1', 'BC338-16', 'NPN'),
#      ('VSMIS00373-1', 'BC338-25', 'NPN'),
#      ('VSMIS00373-1', 'BC338-40', 'NPN'),
#      ('VSMIS03793-1', 'BC817', 'NPN'),
#      ('VSMIS03793-1', 'BC817-16', 'NPN'),
#      ('VSMIS03793-1', 'BC817-25', 'NPN'),
#      ('VSMIS03793-1', 'BC817-40', 'NPN'),
#      ('VSMIS03793-1', 'BC818', 'NPN'),
#      ('VSMIS03793-1', 'BC818-16', 'NPN'),
#      ('VSMIS03793-1', 'BC818-25', 'NPN'),
#      ('VSMIS03793-1', 'BC818-40', 'NPN'),
#      ('WEILS00082-1', 'BC856', 'PNP'),
#      ('WEILS00082-1', 'BC856A', 'PNP'),
#      ('WEILS00082-1', 'BC856B', 'PNP'),
#      ('WEILS00082-1', 'BC857', 'PNP'),
#      ('WEILS00082-1', 'BC857A', 'PNP'),
#      ('WEILS00082-1', 'BC857B', 'PNP'),
#      ('WEILS00082-1', 'BC857C', 'PNP'),
#      ('WEILS00082-1', 'BC858', 'PNP'),
#      ('WEILS00082-1', 'BC858A', 'PNP'),
#      ('WEILS00082-1', 'BC858B', 'PNP'),
#      ('WEILS00082-1', 'BC858C', 'PNP'),
#      ('WEILS00082-1', 'BC859', 'PNP'),
#      ('WEILS00082-1', 'BC859B', 'PNP'),
#      ('WEILS00082-1', 'BC859C', 'PNP'),
#      ('WEITS00252-1', 'BC807-16', 'PNP'),
#      ('WEITS00252-1', 'BC807-25', 'PNP'),
#      ('WEITS00252-1', 'BC807-40', 'PNP'),
#      ('ZETXS01948-1', 'BC856', 'PNP'),
#      ('ZETXS01948-1', 'BC856A-3A', 'PNP'),
#      ('ZETXS01948-1', 'BC856B-Z3B', 'PNP'),
#      ('ZETXS01948-1', 'BC857', 'PNP'),
#      ('ZETXS01948-1', 'BC857A-Z3E', 'PNP'),
#      ('ZETXS01948-1', 'BC857B-3F', 'PNP'),
#      ('ZETXS01948-1', 'BC857C-3G', 'PNP'),
#      ('ZETXS01948-1', 'BC858', 'PNP'),
#      ('ZETXS01948-1', 'BC858A-3J', 'PNP'),
#      ('ZETXS01948-1', 'BC858B-3K', 'PNP'),
#      ('ZETXS01948-1', 'BC858C-3L', 'PNP'),
#      ('ZETXS01948-1', 'BC859', 'PNP'),
#      ('ZETXS01948-1', 'BC859A-Z4A', 'PNP'),
#      ('ZETXS01948-1', 'BC859B-4B', 'PNP'),
#      ('ZETXS01948-1', 'BC859C-Z4C', 'PNP'),
#      ('ZETXS01948-1', 'BC860', 'PNP'),
#      ('ZETXS01948-1', 'BC860A-Z4E', 'PNP'),
#      ('ZETXS01948-1', 'BC860B-4F', 'PNP'),
#      ('ZETXS01948-1', 'BC860C-4GZ', 'PNP')])
# 777

# %% [markdown]
# ## Gold Labels

# %%
import os
from snorkel.models import CandidateSet
from hardware_utils import load_hardware_labels

gold_file = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/hardware_gold.csv'
for set_name in ['Training', 'Development']:
    candidate_set_name = 'Hardware %s Candidates' % set_name
    candidates = session.query(CandidateSet).filter(
        CandidateSet.name == candidate_set_name).one()
    label_set_name = 'Hardware %s Candidates -- Gold' % set_name
    annotation_key_name = 'Hardware %s Labels -- Gold' % set_name
    # %time gold_candidates, annotation_key = load_hardware_labels(session,\
                           label_set_name, \
                           annotation_key_name, \
                           candidates, \
                           gold_file, \
                           'polarity')
    candidates_gold = session.query(CandidateSet).filter(
        CandidateSet.name == candidate_set_name + ' -- Gold').one()
    print "%d/%d Candidates in %s have positive Labels" % (
        len(candidates_gold), len(candidates), candidates)
# Out:
# Loading 399 candidate labels
# [========================================] 100%
# CPU times: user 1.09 s, sys: 40 ms, total: 1.13 s
# Wall time: 1.33 s
# 327/399 Candidates in Candidate Set (Hardware Training Candidates) have positive Labels
# Loading 130 candidate labels
# [========================================] 100%
# CPU times: user 544 ms, sys: 16 ms, total: 560 ms
# Wall time: 632 ms
# 67/130 Candidates in Candidate Set (Hardware Development Candidates) have positive Labels

# %% [markdown]
# ### Assess Baseline Performance

# %%
# from snorkel.models import Corpus, Candidate
# from snorkel.utils import get_ORM_instance
# from snorkel.lf_helpers import *
# from hardware_utils import entity_level_f1
# from itertools import chain

# def LF_all_true(c):
#     return True

# def LF_complement_nearby(c):
#     return 1 if set(['complement','complementary']).isdisjoint(
#         chain.from_iterable(
#             [get_phrase_ngrams(c.part), 
#              get_phrase_ngrams(c.polarity),
#              get_neighbor_phrase_ngrams(c.polarity)])) else 0

# candidates = session.query(Candidate).all()
# (tp, fp, tn, fn) = baseline(candidates, LF_complement_nearby)

# corpus = get_ORM_instance(Corpus, session, 'Hardware')
# gold_file = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/hardware_gold.csv'
# (TP, FP, FN) = entity_level_f1(tp, fp, tn, fn, gold_file, corpus, 'polarity')

# %%
# from pprint import pprint
# pprint(FP)

# %%
# pprint(FN)

# %%
# from hardware_utils import entity_to_candidates

# print len(candidates)
# matches = entity_to_candidates((u'SIEMS01215-1', u'BC856', u'NPN'), candidates)
# c = matches[0]
# print c

# %%
# from snorkel.models import ImplicitSpan
# from snorkel.lf_helpers import *
# phrases = []
# print list(get_neighbor_phrase_ngrams(c.polarity))
# print c.polarity.parent
# print phrases
# print "SPAN_TYPE_[%s]" % ('IMPLICIT' if isinstance(c.polarity, ImplicitSpan) else 'EXPLICIT')
# # list(get_phrase_ngrams(c.polarity))

# %% [markdown]
# ## Features

# %% [markdown]
# ### Extract Features

# %%
from snorkel.models import CandidateSet
from snorkel.async_annotations import annotate
from snorkel.utils import get_ORM_instance

# Run batch extraction jobs
train = get_ORM_instance(CandidateSet, session, 'Hardware Training Candidates')
dev   = get_ORM_instance(CandidateSet, session, 'Hardware Development Candidates')

# %time F_train = annotate(train, parallel=4)
# %time F_dev = annotate(dev, parallel=4, keyset = 'Hardware Training Candidates')

print 'Training features hash:', hash(frozenset(F_train.keys)),'of length', len(F_train.keys)
# Out:
# Using 4 workers
# CPU times: user 224 ms, sys: 20 ms, total: 244 ms
# Wall time: 3.58 s
# Using 4 workers
# CPU times: user 40 ms, sys: 16 ms, total: 56 ms
# Wall time: 1.12 s
# Training features hash: 863853794477141919 of length 1735

# %%
# from snorkel.models import CandidateSet
# from snorkel.fast_annotations import FeatureManager
# from snorkel.utils import get_ORM_instance

# train = get_ORM_instance(CandidateSet, session, 'Hardware Training Candidates')
# dev   = get_ORM_instance(CandidateSet, session, 'Hardware Development Candidates')

# feature_manager = FeatureManager()
# %time F_train_sync = feature_manager.create(session, train, 'Train Features')
# %time F_dev_sync = feature_manager.update(session, dev, 'Train Features', expand_key_set=False)
# print F_train_sync.shape
# # Integrity check for async against original feature extractor
# from snorkel.models.annotation import AnnotationKeySet
# sync_keyset = session.query(AnnotationKeySet).filter(AnnotationKeySet.name=='Train Features').one()
# print 'Async extractor extracted the same set of features as the original impl:',set(key.name for key in sync_keyset) == set(F_train.keys)
# Out:
# [========================================] 100%
# Bulk upserting 39431 annotations...
# Done.
# Loading sparse Feature matrix...
# CPU times: user 8.52 s, sys: 296 ms, total: 8.82 s
# Wall time: 11.1 s
# [========================================] 100%
# Bulk upserting 4750 annotations...
# Done.
# Loading sparse Feature matrix...
# CPU times: user 2.87 s, sys: 56 ms, total: 2.93 s
# Wall time: 3.23 s
# (399, 1735)

# %%
# Out:
# True

# %% [markdown]
# ## LFs

# %%
# If necessary
# import os
# os.remove('snorkel.db');
# os.system('cp snorkel.db\ featurized snorkel.db');

# from snorkel import SnorkelSession
# session = SnorkelSession()

# import sys
# sys.path.append(os.environ['SNORKELHOME'] + '/tutorials/tables/')

# from snorkel.models import candidate_subclass
# Part_Polarity = candidate_subclass('Part_Polarity', ['part','polarity'])

# from snorkel.models import CandidateSet
# train = session.query(CandidateSet).filter(
#     CandidateSet.name == 'Hardware Training Candidates').one()

# %% [markdown]
# ### Define LFs

# %%
from snorkel.fast_annotations import LabelManager
from snorkel.lf_helpers import *
import re
label_manager = LabelManager()

LFs = []

def LF_complement_phrase_part(c):
    return -1 if overlap(['complement','complementary'], 
                         get_phrase_ngrams(c.part)) else 0
LFs.append(LF_complement_phrase_part)

def LF_complement_phrase_polarity(c):
    return -1 if overlap(['complement','complementary'], 
                         get_phrase_ngrams(c.polarity)) else 0
LFs.append(LF_complement_phrase_polarity)

def LF_complement_neighbor_polarity(c):
    return -1 if overlap(['complement','complementary'], 
                         get_neighbor_phrase_ngrams(c.polarity)) else 0
LFs.append(LF_complement_neighbor_polarity)

def LF_top_mark_col_part(c):
    return -1 if overlap(['top','mark'],
                         get_col_ngrams(c.part)) else 0
LFs.append(LF_top_mark_col_part)

def LF_endswith_D_part(c):
    return -1 if c.part.get_span().endswith('D') else 0
LFs.append(LF_endswith_D_part)

def LF_default_positive(c):
    return 1 if not overlap(['complement','complementary'],
                            chain.from_iterable([
                            get_phrase_ngrams(c.part),
                            get_phrase_ngrams(c.polarity),
                            get_neighbor_phrase_ngrams(c.polarity)])) else 0
LFs.append(LF_default_positive)

# %%
from snorkel.models import Candidate
from hardware_utils import entity_to_candidates

candidates = session.query(Candidate).all()
print len(candidates)
# matches = entity_to_candidates((u'SIEMS01215-1', u'BC856', u'NPN'), candidates)
# c = matches[0]
c = candidates[0]
print candidates[0]

print LF_complement_phrase_part(c)
print LF_complement_phrase_polarity(c)
print LF_complement_neighbor_polarity(c)
print LF_top_mark_col_part(c)
print LF_endswith_D_part(c)
print LF_default_positive(c)
# Out:
# 529
# Part_Polarity(Span("DTC114YE", parent=12, chars=[0,7], words=[0,0]), Span("NPN", parent=17, chars=[0,2], words=[0,0]))
# 0
# 0
# 0
# 0
# 0
# 1

# %% [markdown]
# ### Apply LFs

# %%
from snorkel.async_annotations import annotate
# %time L_train = annotate(train, lfs=LFs)
L_train
# Out:
# Using 2 workers
# CPU times: user 28 ms, sys: 4 ms, total: 32 ms
# Wall time: 911 ms
# <399x6 sparse matrix of type '<type 'numpy.float32'>'
# 	with 414 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Assess LF accuracy

# %%
train_gold = session.query(CandidateSet).filter(
    CandidateSet.name == 'Hardware Training Candidates -- Gold').one()
# %time L_train.lf_stats(train_gold)
# Out:
# [========================================] 100%
# CPU times: user 40 ms, sys: 0 ns, total: 40 ms
# Wall time: 37.5 ms
#                                  accuracy  conflicts  coverage  j  overlaps
# LF_endswith_D_part               1.000000   0.002506  0.002506  0  0.002506
# LF_complement_neighbor_polarity  0.104348   0.000000  0.576441  1  0.035088
# LF_complement_phrase_polarity    1.000000   0.000000  0.062657  2  0.000000
# LF_complement_phrase_part        1.000000   0.000000  0.035088  3  0.035088
# LF_default_positive              0.840278   0.002506  0.360902  4  0.002506
# LF_top_mark_col_part                  NaN   0.000000  0.000000  5  0.000000

# %% [markdown]
# ## Learn and Evaluate

# %%
# If necessary:
# import os
# os.remove('snorkel.db');
# os.system('cp snorkel.db\ features snorkel.db');

# from snorkel import SnorkelSession
# session = SnorkelSession()

# import sys
# sys.path.append(os.environ['SNORKELHOME'] + '/tutorials/tables/')

# from snorkel.models import candidate_subclass
# Part_Polarity = candidate_subclass('Part_Polarity', ['part','polarity'])

# from snorkel.models import CandidateSet
# train = session.query(CandidateSet).filter(
#     CandidateSet.name == 'Hardware Training Candidates').one()
# dev = session.query(CandidateSet).filter(
#     CandidateSet.name == 'Hardware Development Candidates').one()

# from snorkel.annotations import FeatureManager, LabelManager
# feature_manager = FeatureManager()
# %time F_train = feature_manager.load(session, train, 'Train Features')
# %time F_dev = feature_manager.load(session, dev, 'Train Features')

# label_manager = LabelManager()
# %time L_train = label_manager.load(session, train, 'LF Labels')

# %%
from snorkel.learning import NaiveBayes

gen_model = NaiveBayes()
gen_model.train(L_train, n_iter=15000, rate=1e-2)

#%time gen_model.save(session, 'Generative Params')
train_marginals = gen_model.marginals(L_train)
# Out:
# ================================================================================
# Training marginals (!= 0.5):	399
# Features:			6
# ================================================================================
# Begin training for rate=0.01, mu=1e-06
# 	Learning epoch = 0	Gradient mag. = 0.040699
# /home/xiao/software/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:1318: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# 	Learning epoch = 250	Gradient mag. = 0.045391
# 	Learning epoch = 500	Gradient mag. = 0.047990
# 	Learning epoch = 750	Gradient mag. = 0.050629
# 	Learning epoch = 1000	Gradient mag. = 0.053299
# 	Learning epoch = 1250	Gradient mag. = 0.055994
# 	Learning epoch = 1500	Gradient mag. = 0.058708
# 	Learning epoch = 1750	Gradient mag. = 0.061438
# 	Learning epoch = 2000	Gradient mag. = 0.064179
# 	Learning epoch = 2250	Gradient mag. = 0.066930
# 	Learning epoch = 2500	Gradient mag. = 0.069690
# 	Learning epoch = 2750	Gradient mag. = 0.072457
# 	Learning epoch = 3000	Gradient mag. = 0.075231
# 	Learning epoch = 3250	Gradient mag. = 0.078012
# 	Learning epoch = 3500	Gradient mag. = 0.080799
# 	Learning epoch = 3750	Gradient mag. = 0.083593
# 	Learning epoch = 4000	Gradient mag. = 0.086393
# 	Learning epoch = 4250	Gradient mag. = 0.089200
# 	Learning epoch = 4500	Gradient mag. = 0.092012
# 	Learning epoch = 4750	Gradient mag. = 0.094830
# 	Learning epoch = 5000	Gradient mag. = 0.097654
# 	Learning epoch = 5250	Gradient mag. = 0.100482
# 	Learning epoch = 5500	Gradient mag. = 0.103315
# 	Learning epoch = 5750	Gradient mag. = 0.106152
# 	Learning epoch = 6000	Gradient mag. = 0.108993
# 	Learning epoch = 6250	Gradient mag. = 0.111837
# 	Learning epoch = 6500	Gradient mag. = 0.114684
# 	Learning epoch = 6750	Gradient mag. = 0.117534
# 	Learning epoch = 7000	Gradient mag. = 0.120387
# 	Learning epoch = 7250	Gradient mag. = 0.123241
# 	Learning epoch = 7500	Gradient mag. = 0.118609
# 	Learning epoch = 7750	Gradient mag. = 0.109920
# 	Learning epoch = 8000	Gradient mag. = 0.102003
# 	Learning epoch = 8250	Gradient mag. = 0.094800
# 	Learning epoch = 8500	Gradient mag. = 0.088256
# 	Learning epoch = 8750	Gradient mag. = 0.082322
# 	Learning epoch = 9000	Gradient mag. = 0.076952
# 	Learning epoch = 9250	Gradient mag. = 0.072102
# 	Learning epoch = 9500	Gradient mag. = 0.067732
# 	Learning epoch = 9750	Gradient mag. = 0.063806
# 	Learning epoch = 10000	Gradient mag. = 0.060287
# 	Learning epoch = 10250	Gradient mag. = 0.057142
# 	Learning epoch = 10500	Gradient mag. = 0.054342
# 	Learning epoch = 10750	Gradient mag. = 0.051855
# 	Learning epoch = 11000	Gradient mag. = 0.049655
# 	Learning epoch = 11250	Gradient mag. = 0.047714
# 	Learning epoch = 11500	Gradient mag. = 0.046007
# 	Learning epoch = 11750	Gradient mag. = 0.044512
# 	Learning epoch = 12000	Gradient mag. = 0.043206
# 	Learning epoch = 12250	Gradient mag. = 0.042068
# 	Learning epoch = 12500	Gradient mag. = 0.041079
# 	Learning epoch = 12750	Gradient mag. = 0.040223
# 	Learning epoch = 13000	Gradient mag. = 0.039482
# 	Learning epoch = 13250	Gradient mag. = 0.038843
# 	Learning epoch = 13500	Gradient mag. = 0.038293
# 	Learning epoch = 13750	Gradient mag. = 0.037820
# 	Learning epoch = 14000	Gradient mag. = 0.037414
# 	Learning epoch = 14250	Gradient mag. = 0.037065
# 	Learning epoch = 14500	Gradient mag. = 0.036767
# 	Learning epoch = 14750	Gradient mag. = 0.036511
# Final gradient magnitude for rate=0.01, mu=1e-06: 0.036

# %%
from snorkel.learning import LogReg

disc_model = LogReg()
disc_model.train(F_train, train_marginals, n_iter=2000, rate=1e-5)
#%time disc_model.save(session, "Discriminative Params")
# Out:
# ================================================================================
# Training marginals (!= 0.5):	399
# Features:			1735
# ================================================================================
# Using gradient descent...
# 	Learning epoch = 0	Step size = 1e-05
# 	Loss = 276.565725	Gradient magnitude = 654.950444
# 	Learning epoch = 100	Step size = 9.04792147114e-06
# 	Loss = 167.040507	Gradient magnitude = 183.343963
# 	Learning epoch = 200	Step size = 8.18648829479e-06
# 	Loss = 148.391009	Gradient magnitude = 120.166380
# 	Learning epoch = 300	Step size = 7.40707032156e-06
# 	Loss = 140.063756	Gradient magnitude = 91.402797
# 	Learning epoch = 400	Step size = 6.70185906007e-06
# 	Loss = 135.401007	Gradient magnitude = 75.304996
# 	Learning epoch = 500	Step size = 6.06378944861e-06
# 	Loss = 132.426304	Gradient magnitude = 65.241920
# 	Learning epoch = 600	Step size = 5.48646907485e-06
# 	Loss = 130.366598	Gradient magnitude = 58.441075
# 	Learning epoch = 700	Step size = 4.96411413431e-06
# 	Loss = 128.857922	Gradient magnitude = 53.575855
# 	Learning epoch = 800	Step size = 4.4914914861e-06
# 	Loss = 127.715598	Gradient magnitude = 49.934675
# 	Learning epoch = 900	Step size = 4.06386622545e-06
# 	Loss = 126.827189	Gradient magnitude = 47.134292
# 	Learning epoch = 1000	Step size = 3.67695424771e-06
# 	Loss = 126.119392	Gradient magnitude = 44.936396
# 	Learning epoch = 1100	Step size = 3.32687932862e-06
# 	Loss = 125.546749	Gradient magnitude = 43.180837
# 	Learning epoch = 1200	Step size = 3.01013429093e-06
# 	Loss = 125.078244	Gradient magnitude = 41.760300
# 	Learning epoch = 1300	Step size = 2.72354586819e-06
# 	Loss = 124.691763	Gradient magnitude = 40.600282
# 	Learning epoch = 1400	Step size = 2.46424291385e-06
# 	Loss = 124.371149	Gradient magnitude = 39.647287
# 	Learning epoch = 1500	Step size = 2.22962763703e-06
# 	Loss = 124.104323	Gradient magnitude = 38.862024
# 	Learning epoch = 1600	Step size = 2.01734957697e-06
# 	Loss = 123.881803	Gradient magnitude = 38.213997
# 	Learning epoch = 1700	Step size = 1.82528205523e-06
# 	Loss = 123.696568	Gradient magnitude = 37.680685
# 	Learning epoch = 1800	Step size = 1.65150086984e-06
# 	Loss = 123.542860	Gradient magnitude = 37.244458
# 	Learning epoch = 1900	Step size = 1.49426501798e-06
# 	Loss = 123.416098	Gradient magnitude = 36.891168

# %%
train_gold = session.query(CandidateSet).filter(
    CandidateSet.name == 'Hardware Training Candidates -- Gold').one()

# %%
dev_gold = session.query(CandidateSet).filter(
    CandidateSet.name == 'Hardware Development Candidates -- Gold').one()

# %%
from snorkel.models import CandidateSet
from snorkel.annotations import LabelManager
label_manager = LabelManager()
L_dev = label_manager.load(session, dev, 'Hardware Development Labels -- Gold')

# %%
tp, fp, tn, fn = disc_model.score(F_dev, L_dev, dev_gold)
# Out:
# Calibration plot:
# /home/xiao/software/anaconda/lib/python2.7/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# ========================================
# Recall-corrected Noise-aware Model
# ========================================
# Pos. class accuracy: 0.0
# Neg. class accuracy: 1.0
# Corpus Precision nan
# Corpus Recall    0.0
# Corpus F1        nan
# ----------------------------------------
# TP: 0 | FP: 0 | TN: 63 | FN: 67
# ========================================
#
# ========================================
# Recall-corrected Noise-aware Model
# ========================================
# Pos. class accuracy: 0.0
# Neg. class accuracy: 1.0
# Corpus Precision nan
# Corpus Recall    0.0
# Corpus F1        nan
# ----------------------------------------
# TP: 0 | FP: 0 | TN: 63 | FN: 134
# ========================================

# %%
from snorkel.models import Corpus
from hardware_utils import entity_level_f1
import os

gold_file = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/hardware_gold.csv'
corpus = session.query(Corpus).filter(Corpus.name == 'Hardware Development').one()
(TP, FP, FN) = entity_level_f1(tp, fp, tn, fn, gold_file, corpus, 'polarity')
# Out:
# ========================================
# Scoring on Entity-Level Gold Data
# ========================================
# Corpus Precision nan
# Corpus Recall    0.0
# Corpus F1        nan
# ----------------------------------------
# TP: 0 | FP: 0 | FN: 32
# ========================================

# %%
from pprint import pprint
FP_list = sorted(list(FP))
pprint(FP_list[:10])
# Out:
# []

# %%
print '\n'.join(unicode(x[0]) for x in disc_model.get_feature_weights(F_dev))
# Out:
# DDL_e2_LEMMA_SEQ_[NPN]
# DDL_e2_W_RIGHT_3_[Epitaxial Silicon Transistor]
# DDL_e2_W_RIGHT_POS_3_[NNP NNP NNP]
# DDL_e2_LEMMA_SEQ_[PNP]
# DDL_e2_W_RIGHT_1_[Epitaxial]
# DDL_e2_W_RIGHT_2_[Epitaxial Silicon]
# DDL_e2_WORD_SEQ_[PNP]
# CORE_e1_STARTS_WITH_CAPITAL
# CORE_e1_SPAN_TYPE_[IMPLICIT]
# DDL_e2_W_RIGHT_2_[General-Purpose Amplifier]
# DDL_e2_W_RIGHT_1_[General-Purpose]
# STR_e2_HTML_ATTR_style=text-indent: 0pt;line-height: 12pt;text-align: left;
# DDL_e2_DEP_SEQ_[ROOT]
# DDL_e2_LEMMA_SEQ_[npn]
# DDL_e2_W_LEFT_POS_1_[NN]
# DDL_e2_W_LEFT_1_[npn]
# DDL_e2_POS_SEQ_[NN]
# VIZ_e2_PAGE_[1]
# STR_e2_ANCESTOR_ID_[None None None]
# STR_e2_ANCESTOR_CLASS_[None None None]
# DDL_e1_W_LEFT_POS_1_[CD]
# DDL_e1_W_LEFT_POS_2_[: CD]
# STR_e1_TAG_p
# CORE_e2_SPAN_TYPE_[EXPLICIT]
# CORE_e2_LENGTH_1
# CORE_e2_STARTS_WITH_CAPITAL
# DDL_e2_W_LEMMA_L_3_R_2_[bc856/857/858 / 859/860]_[Epitaxial Silicon]
# DDL_e2_W_LEFT_1_[859/860]
# DDL_e2_W_LEFT_POS_2_[: CD]
# DDL_e2_W_POS_L_3_R_2_[NN : CD]_[NNP NNP]
# DDL_e2_W_POS_L_2_R_1_[: CD]_[NNP]
# DDL_e2_W_LEMMA_L_3_R_1_[bc856/857/858 / 859/860]_[Epitaxial]
# DDL_e2_W_POS_L_1_R_2_[CD]_[NNP NNP]
# DDL_e2_W_LEMMA_L_3_R_3_[bc856/857/858 / 859/860]_[Epitaxial Silicon Transistor]
# DDL_e2_W_LEMMA_L_2_R_2_[/ 859/860]_[Epitaxial Silicon]
# DDL_e2_W_LEMMA_L_2_R_3_[/ 859/860]_[Epitaxial Silicon Transistor]
# DDL_e2_W_LEFT_2_[/ 859/860]
# DDL_e2_W_LEFT_POS_3_[NN : CD]
# DDL_e2_W_POS_L_1_R_3_[CD]_[NNP NNP NNP]
# DDL_e2_W_POS_L_3_R_1_[NN : CD]_[NNP]
# DDL_e2_W_POS_L_1_R_1_[CD]_[NNP]
# DDL_e2_W_POS_L_2_R_3_[: CD]_[NNP NNP NNP]
# DDL_e2_W_LEMMA_L_2_R_1_[/ 859/860]_[Epitaxial]
# DDL_e2_W_POS_L_3_R_3_[NN : CD]_[NNP NNP NNP]
# DDL_e2_W_LEMMA_L_1_R_2_[859/860]_[Epitaxial Silicon]
# DDL_e2_W_POS_L_2_R_2_[: CD]_[NNP NNP]
# DDL_e2_W_LEFT_3_[bc856/857/858 / 859/860]
# DDL_e2_W_LEMMA_L_1_R_1_[859/860]_[Epitaxial]
# DDL_e2_W_LEMMA_L_1_R_3_[859/860]_[Epitaxial Silicon Transistor]
# DDL_e2_W_LEFT_POS_1_[CD]
# STR_e2_NEXT_SIB_TAG_style
# STR_e2_NEXT_SIB_TAG_p
# VIZ_SAME_PAGE
# DDL_e2_W_LEMMA_L_1_R_2_[-]_[General-Purpose Amplifier]
# DDL_e2_W_POS_L_1_R_1_[:]_[NNP]
# DDL_e2_W_LEFT_2_[pzt3904 -]
# DDL_e2_W_LEFT_POS_1_[:]
# DDL_e2_W_POS_L_2_R_1_[NN :]_[NNP]
# DDL_e2_W_POS_L_1_R_2_[:]_[NNP NNP]
# DDL_e2_W_POS_L_2_R_2_[NN :]_[NNP NNP]
# DDL_e2_W_LEMMA_L_2_R_1_[pzt3904 -]_[General-Purpose]
# DDL_e2_W_LEMMA_L_1_R_1_[-]_[General-Purpose]
# DDL_e2_W_LEMMA_L_2_R_2_[pzt3904 -]_[General-Purpose Amplifier]
# DDL_e2_W_LEFT_1_[-]
# DDL_e2_W_LEFT_POS_2_[NN :]
# STR_e1_PREV_SIB_TAG_p
# DDL_e2_W_POS_L_1_R_3_[NNP]_[NNP NNP NNP]
# VIZ_e2_ALIGNED_CENTER_and
# DDL_e2_W_LEFT_1_[Transistor]
# DDL_e2_W_LEMMA_L_1_R_3_[Transistor]_[Epitaxial Silicon Transistor]
# VIZ_e2_ALIGNED_application
# VIZ_e2_ALIGNED_RIGHT_and
# VIZ_e2_ALIGNED_CENTER_amplifier
# STR_e2_HTML_ATTR_style=padding-left: 24pt;text-indent: 0pt;text-align: left;
# VIZ_e2_ALIGNED_LEFT_switching
# DDL_e2_W_POS_L_2_R_3_[NNP NNP]_[NNP NNP NNP]
# DDL_e2_W_LEMMA_L_1_R_2_[Transistor]_[Epitaxial Silicon]
# VIZ_e2_ALIGNED_RIGHT_amplifier
# VIZ_e2_ALIGNED_RIGHT_switching
# VIZ_e2_ALIGNED_switching
# DDL_e2_W_POS_L_3_R_3_[NNP NNP NNP]_[NNP NNP NNP]
# DDL_e2_W_LEMMA_L_2_R_1_[Silicon Transistor]_[Epitaxial]
# VIZ_e2_ALIGNED_LEFT_application
# DDL_e2_W_LEMMA_L_3_R_3_[Epitaxial Silicon Transistor]_[Epitaxial Silicon Transistor]
# DDL_e2_W_LEFT_3_[Epitaxial Silicon Transistor]
# DDL_e2_W_LEMMA_L_2_R_3_[Silicon Transistor]_[Epitaxial Silicon Transistor]
# STR_e2_NEXT_SIB_TAG_table
# VIZ_e2_ALIGNED_RIGHT_application
# STR_e2_NODE_POS_13
# VIZ_e2_ALIGNED_CENTER_switching
# DDL_e2_W_LEMMA_L_3_R_2_[Epitaxial Silicon Transistor]_[Epitaxial Silicon]
# VIZ_e2_ALIGNED_and
# VIZ_e2_ALIGNED_LEFT_and
# DDL_e2_W_LEMMA_L_1_R_1_[Transistor]_[Epitaxial]
# VIZ_e2_ALIGNED_CENTER_application
# DDL_e2_W_LEMMA_L_3_R_1_[Epitaxial Silicon Transistor]_[Epitaxial]
# DDL_e2_W_LEFT_2_[Silicon Transistor]
# DDL_e2_W_LEMMA_L_2_R_2_[Silicon Transistor]_[Epitaxial Silicon]
# STR_COMMON_ANCESTOR_[ html body]
# STR_LOWEST_ANCESTOR_DEPTH_[1]
# VIZ_e2_ALIGNED_npn
# STR_e2_PREV_SIB_TAG_h2
# STR_e2_NODE_POS_10
# VIZ_e2_ALIGNED_Y_npn
# STR_e2_NODE_POS_6
# STR_e2_NEXT_SIB_TAG_h1
# STR_e2_PARENT_TAG_body
# CORE_e1_LENGTH_3
# STR_e1_LAST_NODE
# STR_e2_NODE_POS_9
# DDL_e2_W_LEMMA_L_3_R_1_[NPN General-Purpose Amplifier]_[General-Purpose]
# DDL_e2_W_LEFT_2_[General-Purpose Amplifier]
# STR_e2_HTML_ATTR_style=padding-top: 1pt;padding-left: 23pt;text-indent: 0pt;text-align: left;
# DDL_e2_W_LEFT_1_[Amplifier]
# DDL_e2_W_LEMMA_L_2_R_1_[General-Purpose Amplifier]_[General-Purpose]
# DDL_e2_W_LEMMA_L_2_R_2_[General-Purpose Amplifier]_[General-Purpose Amplifier]
# DDL_e2_W_LEMMA_L_1_R_2_[Amplifier]_[General-Purpose Amplifier]
# DDL_e2_W_LEFT_3_[NPN General-Purpose Amplifier]
# STR_e2_PREV_SIB_TAG_h1
# DDL_e2_W_LEMMA_L_1_R_1_[Amplifier]_[General-Purpose]
# DDL_e2_W_LEMMA_L_3_R_2_[NPN General-Purpose Amplifier]_[General-Purpose Amplifier]
# STR_e1_ANCESTOR_TAG_[html body p]
# DDL_e1_W_LEFT_POS_3_[NN : CD]
# DDL_e1_W_LEFT_2_[/ 859/860]
# DDL_e1_W_LEFT_1_[859/860]
# DDL_e1_W_LEFT_3_[bc856/857/858 / 859/860]
# VIZ_e1_PAGE_[1]
# DDL_e1_W_LEFT_1_[bc818k]
# STR_e1_NEXT_SIB_TAG_p
# VIZ_e1_PAGE_[2]
# DDL_e2_WORD_SEQ_[NPN]
# DDL_e1_W_LEFT_2_[/ bc818k]
# DDL_e1_W_LEFT_3_[bc817k / bc818k]
# DDL_e1_W_LEFT_POS_3_[CD : CD]
# STR_e2_PREV_SIB_TAG_p
# STR_e2_NODE_POS_2
# STR_e2_ANCESTOR_TAG_[html head title]
# STR_e2_TAG_title
# STR_e2_PREV_SIB_TAG_meta
# STR_e2_PARENT_TAG_head
# STR_e1_ANCESTOR_CLASS_[None None None]
# STR_e1_NODE_POS_3
# TAB_e1_COL_HEAD_WORDS_[parameter]
# TAB_e1_COL_WORDS_[voltage]
# TAB_e1_COL_WORDS_[:]
# TAB_e1_COL_WORDS_[collector-emitter]
# TAB_e1_COL_WORDS_[collector]
# STR_e1_HTML_ATTR_class=s7
# TAB_e1_COL_WORDS_[dc]
# TAB_e1_COL_WORDS_[current]
# STR_e1_ANCESTOR_CLASS_[None None None None None s7]
# TAB_e1_COL_WORDS_[parameter]
# STR_e1_HTML_ATTR_style=padding-left: 1pt;text-indent: 0pt;line-height: 13pt;text-align: left;
# DDL_e1_W_LEFT_POS_1_[NN]
# STR_e1_HTML_ATTR_style=padding-left: 1pt;text-indent: 0pt;line-height: 15pt;text-align: left;
# TAB_e1_ROW_WORDS_[to-92]
# DDL_e1_POS_SEQ_[NN : CD]
# DDL_e1_WORD_SEQ_[BC856/857/858 / 859/860]
# DDL_e1_LEMMA_SEQ_[bc856/857/858 / 859/860]
# STR_e1_FIRST_NODE
# DDL_e2_W_POS_L_3_R_2_[: NN :]_[NNP NNP]
# DDL_e2_W_LEMMA_L_3_R_1_[/ pzt3904 -]_[General-Purpose]
# DDL_e2_W_LEFT_3_[/ pzt3904 -]
# STR_e2_HTML_ATTR_style=padding-left: 1pt;text-indent: 0pt;line-height: 13pt;text-align: left;
# DDL_e2_W_POS_L_3_R_1_[: NN :]_[NNP]
# DDL_e2_W_LEMMA_L_3_R_2_[/ pzt3904 -]_[General-Purpose Amplifier]
# DDL_e2_W_LEFT_POS_3_[: NN :]
# DDL_e1_LEMMA_SEQ_[2n3904]
# DDL_e1_WORD_SEQ_[2N3904]
# STR_e1_PARENT_TAG_body
# STR_e1_HTML_ATTR_class=s10
# STR_e1_ANCESTOR_CLASS_[None None None None None s10]
# VIZ_e2_ALIGNED_LEFT_amplifier
# VIZ_e2_ALIGNED_amplifier
# TAB_e1_ROW_WORDS_[v]
# DDL_e1_W_RIGHT_POS_2_[: CD]
# CORE_e1_SPAN_TYPE_[EXPLICIT]
# CORE_e1_LENGTH_2
# DDL_e2_W_LEFT_2_[NPN Silicon]
# STR_e2_NODE_POS_5
# VIZ_e2_ALIGNED_LEFT_transistor
# DDL_e2_W_LEFT_1_[Silicon]
# DDL_e2_W_LEMMA_L_2_R_1_[NPN Silicon]_[Silicon]
# DDL_e2_W_RIGHT_1_[Silicon]
# STR_e2_HTML_ATTR_style=padding-top: 7pt;padding-left: 6pt;text-indent: 0pt;text-align: left;
# DDL_e2_W_LEMMA_L_1_R_1_[Silicon]_[Silicon]
# VIZ_e2_ALIGNED_transistor
# DDL_e1_W_RIGHT_POS_1_[CD]
# DDL_e2_W_LEMMA_L_3_R_2_[mmbt3904 pzt3904 -]_[General-Purpose Amplifier]
# DDL_e2_W_POS_L_3_R_1_[NN NN :]_[NNP]
# DDL_e2_W_LEFT_POS_3_[NN NN :]
# STR_e2_NEXT_SIB_TAG_meta
# DDL_e2_W_LEMMA_L_3_R_1_[mmbt3904 pzt3904 -]_[General-Purpose]
# DDL_e2_W_LEFT_3_[mmbt3904 pzt3904 -]
# DDL_e2_W_POS_L_3_R_2_[NN NN :]_[NNP NNP]
# VIZ_HORZ_ALIGNED
# DDL_e1_W_LEFT_2_[mmbt3904 /]
# DDL_e1_W_LEFT_3_[/ mmbt3904 /]
# STR_e2_ANCESTOR_TAG_[html body h2]
# STR_e2_TAG_h2
# TDL_INV_BETWEEN-MENTION-and-MENTION[LEN:0-2]
# TDL_INV_LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[None]
# TAB_e1_ROW_WORDS_[3l]
# STR_e2_TAG_h1
# STR_e2_ANCESTOR_TAG_[html body h1]
# TDL_INV_DEP_LABEL:BETWEEN-MENTION-and-MENTION[ROOT]
# DDL_e1_W_LEFT_1_[:]
# DDL_e1_DEP_SEQ_[ROOT punct dep]
# DDL_e1_POS_SEQ_[CD]
# DDL_e1_POS_SEQ_[NN]
# STR_e1_ANCESTOR_ID_[None None None]
# TAB_e1_ROW_WORDS_[to-92 3l]
# TDL_LEMMA:LEFT-OF-MENTION[/]
# DDL_e1_W_POS_L_1_R_2_[CD]_[: CD]
# DDL_e1_W_POS_L_2_R_1_[: CD]_[:]
# DDL_e1_W_POS_L_2_R_2_[: CD]_[: CD]
# DDL_e1_W_POS_L_1_R_1_[CD]_[:]
# TAB_e1_ROW_WORDS_[:]
# TAB_e1_CELL_WORDS_[:]
# DDL_e1_W_POS_L_1_R_1_[CD]_[CD]
# DDL_e1_W_POS_L_2_R_1_[: CD]_[CD]
# TAB_e1_COL_NUM_[0]
# DDL_e1_W_POS_L_1_R_1_[NN]_[JJ]
# DDL_e1_W_POS_L_2_R_1_[CC NN]_[JJ]
# DDL_e1_W_POS_L_3_R_1_[NN CC NN]_[JJ]
# DDL_e1_W_RIGHT_POS_2_[JJ NN]
# DDL_e1_W_POS_L_3_R_2_[NN CC NN]_[JJ NN]
# DDL_e1_W_POS_L_3_R_3_[NN CC NN]_[JJ NN CC]
# DDL_e1_W_POS_L_1_R_3_[NN]_[JJ NN CC]
# DDL_e1_W_LEFT_POS_2_[CC NN]
# DDL_e1_W_RIGHT_1_[=]
# DDL_e1_W_RIGHT_POS_1_[JJ]
# DDL_e1_W_LEFT_POS_3_[NN CC NN]
# DDL_e1_W_RIGHT_POS_3_[JJ NN CC]
# DDL_e1_W_POS_L_2_R_2_[CC NN]_[JJ NN]
# DDL_e1_W_POS_L_2_R_3_[CC NN]_[JJ NN CC]
# STR_e1_HTML_ATTR_style=padding-top: 5pt;padding-left: 8pt;text-indent: 0pt;text-align: justify;
# DDL_e1_W_POS_L_1_R_2_[NN]_[JJ NN]
# DDL_e1_W_LEFT_1_[2n3904]
# STR_e1_ANCESTOR_ID_[None None None None]
# STR_e1_HTML_ATTR_style=display: inline;
# STR_e1_PARENT_TAG_li
# STR_e1_ANCESTOR_ID_[None None l1 None None]
# VIZ_e1_ALIGNED_LEFT_for
# VIZ_e1_ALIGNED_suitable
# STR_e1_ANCESTOR_CLASS_[None None None None None]
# VIZ_e1_ALIGNED_for
# VIZ_e1_ALIGNED_LEFT_suitable
# STR_e1_ANCESTOR_TAG_[html body ul li p]
# STR_e1_NEXT_SIB_TAG_meta
# TAB_e1_COL_NUM_[1]
# DDL_e1_LEMMA_SEQ_[mmbt3904]
# DDL_e1_WORD_SEQ_[MMBT3904]
# DDL_e1_LEMMA_SEQ_[pzt3904]
# DDL_e1_WORD_SEQ_[PZT3904]
# DDL_e2_W_LEFT_POS_2_[NNP NNP]
# DDL_e2_W_POS_L_1_R_1_[NNP]_[NNP]
# DDL_e2_W_LEFT_POS_1_[NNP]
# DDL_e2_W_POS_L_2_R_1_[NNP NNP]_[NNP]
# TAB_e1_ROW_WORDS_[2000]
# DDL_e1_LEMMA_SEQ_[bc817k / bc818k]
# DDL_e1_WORD_SEQ_[BC817K / BC818K]
# DDL_e1_POS_SEQ_[CD : CD]
# DDL_e1_DEP_SEQ_[ROOT punct nummod]
# DDL_e1_WORD_SEQ_[BC856/857/858]
# DDL_e1_LEMMA_SEQ_[bc856/857/858]
# STR_e1_TAG_a
# STR_e1_ANCESTOR_TAG_[html body h1 a]
# STR_e1_ANCESTOR_CLASS_[None None None None]
# STR_e1_PARENT_TAG_h1
# STR_e1_HTML_ATTR_name=bookmark0
# TAB_e1_COL_WORDS_[emitter-base]
# TAB_e1_COL_WORDS_[dissipation]
# TAB_e1_COL_WORDS_[bc858/859]
# TAB_e1_COL_WORDS_[power]
# TAB_e1_COL_WORDS_[collector-emitter voltage]
# TAB_e1_COL_WORDS_[temperature]
# TAB_e1_COL_WORDS_[power dissipation]
# TAB_e1_COL_WORDS_[)]
# TAB_e1_COL_WORDS_[collector current]
# TAB_e1_COL_WORDS_[storage temperature]
# TAB_e1_COL_WORDS_[emitter-base voltage]
# TAB_e1_COL_WORDS_[junction]
# TAB_e1_COL_WORDS_[(]
# TAB_e1_COL_WORDS_[current (]
# TAB_e1_COL_WORDS_[: bc858/859]
# TAB_e1_COL_WORDS_[: bc856]
# TAB_e1_COL_WORDS_[: bc857/860]
# TAB_e1_COL_WORDS_[bc856]
# TAB_e1_COL_WORDS_[( dc]
# TAB_e1_COL_WORDS_[bc857/860]
# TAB_e1_COL_WORDS_[junction temperature]
# TAB_e1_COL_WORDS_[collector-base]
# TAB_e1_COL_WORDS_[storage]
# TAB_e1_COL_WORDS_[collector power]
# TAB_e1_COL_WORDS_[collector-base voltage]
# TAB_e1_COL_WORDS_[dc )]
# STR_LOWEST_ANCESTOR_DEPTH_[2]
# STR_COMMON_ANCESTOR_[ html]
# DDL_e1_LEMMA_SEQ_[bc818k]
# DDL_e1_WORD_SEQ_[BC818K]
# TAB_e1_ROW_HEAD_WORDS_[v]
# TDL_LEMMA:SEQ-BETWEEN[859/860]
# TDL_LEMMA:RIGHT-OF-MENTION[/]
# DDL_e1_W_LEFT_2_[Silicon Transistor]
# DDL_e1_W_LEFT_1_[Transistor]
# DDL_e1_W_LEFT_3_[Epitaxial Silicon Transistor]
# STR_e2_NODE_POS_4
# DDL_e1_W_LEFT_1_[/]
# DDL_e1_LEMMA_SEQ_[bc856/857/858 /]
# DDL_e1_WORD_SEQ_[BC856/857/858 /]
# DDL_e1_W_RIGHT_1_[859/860]
# DDL_e1_W_RIGHT_POS_2_[: NN]
# DDL_e1_W_RIGHT_2_[/ 859/860]
# VIZ_e1_ALIGNED_parameter
# VIZ_e1_ALIGNED_CENTER_parameter
# STR_e1_HTML_ATTR_style=padding-top: 3pt;text-indent: 0pt;text-align: right;
# STR_e1_NODE_POS_55
# DDL_e1_DEP_SEQ_[compound]
# STR_e1_NODE_POS_33
# DDL_e2_W_RIGHT_POS_2_[NNP NNP]
# STR_e1_HTML_ATTR_style=padding-top: 3pt;padding-left: 5pt;text-indent: 0pt;text-align: left;
# TDL_INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|2n3904]
# TDL_INV_LEMMA:BETWEEN-MENTION-and-MENTION[2n3904]
# DDL_e1_W_POS_L_1_R_1_[:]_[:]
# DDL_e1_W_POS_L_2_R_1_[NN :]_[:]
# DDL_e1_DEP_SEQ_[dep]
# TDL_INV_LEMMA:SEQ-BETWEEN[mmbt3904]
# DDL_e1_W_LEFT_1_[mmbt3904]
# STR_e1_NEXT_SIB_TAG_style
# VIZ_e1_ALIGNED_number
# DDL_e2_POS_SEQ_[NNP]
# TDL_LEMMA:BETWEEN-MENTION-and-MENTION[pzt3904]
# DDL_e1_LEMMA_SEQ_[bc817k]
# DDL_e1_WORD_SEQ_[BC817K]
# DDL_e1_W_POS_L_1_R_1_[:]_[NNP]
# DDL_e1_W_POS_L_3_R_1_[: NN :]_[NNP]
# DDL_e1_W_POS_L_2_R_2_[NN :]_[NNP NNP]
# DDL_e1_W_POS_L_3_R_2_[: NN :]_[NNP NNP]
# DDL_e1_W_POS_L_1_R_2_[:]_[NNP NNP]
# DDL_e1_W_POS_L_2_R_1_[NN :]_[NNP]
# TAB_e1_ROW_WORDS_[reel]
# TAB_e1_ROW_WORDS_[tape]
# VIZ_e1_ALIGNED_CENTER_mhz
# VIZ_e1_ALIGNED_mhz
# TDL_DEP_LABEL:BETWEEN-MENTION-and-MENTION[dep]
# STR_e1_NODE_POS_5
# STR_e1_HTML_ATTR_style=padding-top: 8pt;padding-left: 153pt;text-indent: 0pt;text-align: left;
# VIZ_e1_ALIGNED_LEFT_t
# VIZ_e1_ALIGNED_t
# STR_e1_NODE_POS_24
# TAB_e1_COL_WORDS_[collector cut-off]
# TAB_e1_COL_WORDS_[on]
# TAB_e1_COL_WORDS_[noise]
# TAB_e1_COL_WORDS_[output capacitance]
# TAB_e1_COL_WORDS_[on voltage]
# TAB_e1_COL_WORDS_[base-emitter]
# TAB_e1_COL_WORDS_[collector-emitter saturation]
# TAB_e1_COL_WORDS_[current gain]
# TAB_e1_COL_WORDS_[product]
# TAB_e1_COL_WORDS_[bandwidth]
# TAB_e1_ROW_WORDS_[db]
# TAB_e1_COL_WORDS_[dc current]
# TAB_e1_COL_WORDS_[gain]
# TAB_e1_COL_WORDS_[output]
# TAB_e1_COL_WORDS_[bandwidth product]
# TAB_e1_COL_WORDS_[capacitance]
# TAB_e1_ROW_WORDS_[=]
# TAB_e1_COL_WORDS_[saturation]
# TAB_e1_COL_WORDS_[base-emitter saturation]
# TAB_e1_COL_WORDS_[base-emitter on]
# TAB_e1_COL_WORDS_[cut-off]
# TAB_e1_ROW_WORDS_[,]
# TAB_e1_COL_WORDS_[saturation voltage]
# TAB_e1_ROW_HEAD_WORDS_[=]
# TAB_e1_COL_WORDS_[gain bandwidth]
# TAB_e1_ROW_HEAD_WORDS_[,]
# TAB_e1_COL_WORDS_[cut-off current]
# DDL_e1_W_RIGHT_POS_3_[: NN :]
# DDL_e1_DEP_SEQ_[ROOT punct]
# DDL_e1_W_RIGHT_POS_1_[NNP]
# DDL_e1_W_RIGHT_POS_2_[NNP NNP]
# TAB_e1_COL_HEAD_WORDS_[part number]
# TAB_e1_COL_WORDS_[part number]
# TAB_e1_COL_WORDS_[number]
# TAB_e1_COL_HEAD_WORDS_[number]
# TAB_e1_COL_WORDS_[part]
# TAB_e1_COL_HEAD_WORDS_[part]
# DDL_e2_DEP_SEQ_[compound]
# STR_e1_ANCESTOR_CLASS_[None None s1]
# STR_e1_HTML_ATTR_style=padding-left: 6pt;text-indent: 0pt;line-height: 22pt;text-align: left;
# STR_e1_HTML_ATTR_class=s1
# TDL_INV_LEMMA:SEQ-BETWEEN[=]
# DDL_e1_DEP_SEQ_[ROOT]
# DDL_e1_W_LEFT_2_[2n3904 mmbt3904]
# STR_e1_NODE_POS_8
# TAB_e1_COL_WORDS_[: bc859]
# TAB_e1_COL_WORDS_[bc859]
# TAB_e1_COL_WORDS_[bc860]
# TAB_e1_COL_WORDS_[: bc860]
# VIZ_e2_PAGE_[2]
# TDL_INV_LEMMA:SEQ-BETWEEN[or]
# TDL_INV_LEMMA:SEQ-BETWEEN[or 6cr]
# TDL_INV_LEMMA:RIGHT-OF-MENTION[=]
# TDL_INV_LEMMA:LEFT-OF-MENTION[=]
# TDL_INV_LEMMA:SEQ-BETWEEN[6cr]
# TAB_e1_ROW_WORDS_[-30]
# DDL_e1_POS_SEQ_[: NN]
# DDL_e1_DEP_SEQ_[nummod]
# DDL_e1_W_LEFT_POS_3_[CD CD :]
# DDL_e1_W_LEFT_2_[bc817k /]
# DDL_e1_W_LEFT_3_[bc818k bc817k /]
# DDL_e1_W_LEFT_POS_2_[CD :]
# DDL_e1_W_LEFT_POS_2_[NN NN]
# TDL_INV_LEMMA:BETWEEN-MENTION-and-MENTION[mmbt3904]
# TAB_e1_COL_HEAD_WORDS_[marking]
# TAB_e1_COL_WORDS_[1a]
# TAB_e1_COL_WORDS_[2n3904]
# TAB_e1_COL_WORDS_[3904]
# TAB_e1_COL_WORDS_[marking]
# STR_e1_HTML_ATTR_style=padding-top: 1pt;padding-left: 30pt;text-indent: 0pt;text-align: left;
# TAB_e1_ROW_WORDS_[tape and]
# TAB_e1_ROW_WORDS_[and]
# TAB_e1_ROW_WORDS_[and reel]
# TAB_e1_COL_WORDS_[2n3904tf]
# VIZ_VERT_ALIGNED
# TAB_e1_COL_WORDS_[2n3904tfr]
# TDL_INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|bc817k]
# TDL_INV_LEMMA:BETWEEN-MENTION-and-MENTION[bc817k]
# TAB_e1_COL_WORDS_[2n3904ta]
# TAB_e1_COL_WORDS_[2n3904tar]
# TAB_e1_COL_WORDS_[2n3904bu]
# STR_e1_TAG_h2
# STR_e1_ANCESTOR_TAG_[html body h2]
# STR_e1_NODE_POS_4
# VIZ_e1_PAGE_[3]
# TAB_e1_COL_WORDS_[mmbt3904]
# VIZ_e1_ALIGNED_part
# VIZ_e1_ALIGNED_CENTER_number
# VIZ_e1_ALIGNED_CENTER_part
# DDL_e1_W_LEMMA_L_3_R_1_[bc856/857/858 / 859/860]_[859/860]
# DDL_e1_W_LEMMA_L_1_R_1_[859/860]_[859/860]
# DDL_e1_W_POS_L_3_R_1_[NN : CD]_[CD]
# DDL_e1_W_LEMMA_L_2_R_1_[/ 859/860]_[859/860]
# TAB_e1_COL_WORDS_[figure]
# TAB_e1_COL_WORDS_[noise figure]
# DDL_e1_W_LEMMA_L_3_R_2_[bc856/857/858 / 859/860]_[/ 859/860]
# DDL_e1_W_LEMMA_L_3_R_1_[bc856/857/858 / 859/860]_[/]
# DDL_e1_W_LEMMA_L_1_R_1_[859/860]_[/]
# DDL_e1_W_LEMMA_L_2_R_1_[/ 859/860]_[/]
# DDL_e1_W_POS_L_3_R_1_[NN : CD]_[:]
# DDL_e1_W_LEMMA_L_2_R_2_[/ 859/860]_[/ 859/860]
# DDL_e1_W_LEMMA_L_1_R_2_[859/860]_[/ 859/860]
# DDL_e1_W_POS_L_3_R_2_[NN : CD]_[: CD]
# DDL_e1_W_RIGHT_2_[NPN General-Purpose]
# DDL_e1_WORD_SEQ_[PZT3904 -]
# DDL_e1_W_RIGHT_3_[NPN General-Purpose Amplifier]
# DDL_e1_LEMMA_SEQ_[pzt3904 -]
# DDL_e1_W_RIGHT_1_[NPN]
# TAB_e1_COL_WORDS_[pzt3904]
# STR_e1_HTML_ATTR_style=padding-top: 2pt;padding-left: 23pt;text-indent: 0pt;text-align: left;
# STR_e1_NEXT_SIB_TAG_h1
# TDL_INV_LEMMA:SEQ-BETWEEN[/ mmbt3904 /]
# TDL_INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|2n3904 dep|mmbt3904]
# TDL_INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[dep|mmbt3904]
# TDL_INV_LEMMA:SEQ-BETWEEN[/ mmbt3904]
# TDL_INV_LEMMA:BETWEEN-MENTION-and-MENTION[2n3904 mmbt3904]
# TDL_INV_LEMMA:SEQ-BETWEEN[mmbt3904 /]
# DDL_e1_W_LEFT_2_[, bc182b]
# DDL_e1_W_LEFT_3_[bc182 , bc182b]
# DDL_e1_W_LEFT_POS_3_[NN , NN]
# DDL_e1_W_LEFT_POS_2_[, NN]
# DDL_e1_W_LEFT_1_[bc182b]
# DDL_e2_W_RIGHT_POS_1_[NNP]
# VIZ_e1_ALIGNED_low
# VIZ_e1_ALIGNED_noise
# VIZ_e1_ALIGNED_LEFT_low
# VIZ_e1_ALIGNED_LEFT_noise
# STR_e1_NODE_POS_72
# DDL_e1_DEP_SEQ_[punct ROOT]
# DDL_e1_W_RIGHT_2_[General-Purpose Amplifier]
# DDL_e1_LEMMA_SEQ_[pzt3904 - NPN]
# DDL_e1_WORD_SEQ_[PZT3904 - NPN]
# DDL_e1_POS_SEQ_[NN : NNP]
# DDL_e1_W_RIGHT_1_[General-Purpose]
# TDL_INV_DEP_LABEL:BETWEEN-MENTION-and-MENTION[ROOT dep]
# STR_e2_NODE_POS_33
# STR_e1_NODE_POS_73
# DDL_e1_POS_SEQ_[NN : NN]
# TAB_e1_ROW_NUM_[0]
# TAB_e1_COL_WORDS_[v]
# STR_e1_HTML_ATTR_class=s8
# STR_e1_ANCESTOR_CLASS_[None None None None None s8]
# TAB_e1_COL_WORDS_[bc859/860]
# VIZ_e1_ALIGNED_collector
# TAB_e1_COL_WORDS_[: bc859/860]
# VIZ_e1_ALIGNED_current
# VIZ_VERT_ALIGNED_LEFT
# TDL_LEMMA:BETWEEN-MENTION-and-MENTION[pzt3904 Amplifier]
# TDL_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[dep|Amplifier]
# TDL_LEMMA:RIGHT-OF-MENTION[General-Purpose]
# TDL_LEMMA:BETWEEN-MENTION-and-MENTION[Amplifier]
# DDL_e1_W_LEMMA_L_2_R_1_[2n3904 /]_[/]
# DDL_e1_W_LEMMA_L_2_R_2_[2n3904 /]_[/ pzt3904]
# DDL_e1_W_POS_L_2_R_2_[NN :]_[: NN]
# DDL_e1_W_LEFT_2_[2n3904 /]
# DDL_e1_W_LEMMA_L_1_R_1_[/]_[/]
# DDL_e1_W_RIGHT_2_[/ pzt3904]
# DDL_e1_W_LEMMA_L_1_R_2_[/]_[/ pzt3904]
# DDL_e1_W_POS_L_1_R_2_[:]_[: NN]
# DDL_e1_W_LEFT_1_[pzt3904]
# DDL_e1_W_LEMMA_L_2_R_1_[/ bc818k]_[/]
# DDL_e1_W_POS_L_3_R_2_[CD : CD]_[: CD]
# DDL_e1_W_LEMMA_L_2_R_2_[/ bc818k]_[/ bc818k]
# DDL_e1_W_RIGHT_2_[/ bc818k]
# DDL_e1_W_LEMMA_L_1_R_1_[bc818k]_[/]
# DDL_e1_W_LEMMA_L_3_R_2_[bc817k / bc818k]_[/ bc818k]
# DDL_e1_W_POS_L_3_R_1_[CD : CD]_[:]
# DDL_e1_W_LEMMA_L_1_R_2_[bc818k]_[/ bc818k]
# DDL_e1_W_LEMMA_L_3_R_1_[bc817k / bc818k]_[/]
# DDL_e1_W_LEFT_3_[Amplifier 2n3904 mmbt3904]
# DDL_e1_W_LEFT_POS_3_[NNP NN NN]
# DDL_e1_W_LEFT_POS_2_[NNP NNP]
# DDL_e1_W_LEFT_POS_3_[NNP NNP NNP]
# DDL_e1_W_LEFT_POS_1_[NNP]
# STR_e1_ANCESTOR_ID_[None None None None None None]
# TAB_e1_COL_SPAN_[1]
# TAB_e1_ROW_SPAN_[1]
# STR_e1_ANCESTOR_TAG_[html body table tr td p]
# STR_e1_PARENT_TAG_td
# STR_e2_TAG_p
# TDL_INV_DEP_LABEL:BETWEEN-MENTION-and-MENTION[dep]
# TAB_e1_ROW_WORDS_[ammo]
# TAB_e1_ROW_WORDS_[2n3904]
# TDL_LEMMA:LEFT-OF-MENTION[859/860]
# TDL_LEMMA:RIGHT-OF-MENTION[Epitaxial]
# TDL_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|Transistor]
# TDL_LEMMA:BETWEEN-MENTION-and-MENTION[Transistor]
# TAB_e1_ROW_WORDS_[bulk]
# DDL_e1_W_LEFT_POS_1_[TO]
# DDL_e1_W_LEFT_POS_3_[NN NN TO]
# DDL_e1_W_LEFT_POS_2_[NN TO]
# DDL_e1_W_LEFT_2_[complement to]
# DDL_e1_W_LEFT_3_[bc850 complement to]
# DDL_e1_W_LEFT_1_[to]
# DDL_e1_W_LEMMA_L_3_R_1_[bc817k / bc818k]_[bc818k]
# DDL_e1_POS_SEQ_[CD :]
# DDL_e1_LEMMA_SEQ_[bc817k /]
# DDL_e1_WORD_SEQ_[BC817K /]
# DDL_e1_W_POS_L_3_R_1_[CD : CD]_[CD]
# DDL_e1_W_LEMMA_L_1_R_1_[bc818k]_[bc818k]
# DDL_e1_W_RIGHT_1_[bc818k]
# DDL_e1_W_LEMMA_L_2_R_1_[/ bc818k]_[bc818k]
# DDL_e1_W_RIGHT_POS_1_[NN]
# TAB_e1_ROW_WORDS_[2]
# TAB_e1_COL_WORDS_[figure :]
# TAB_e1_ROW_WORDS_[v ,]
# TAB_e1_ROW_WORDS_[a]
# TAB_e1_ROW_HEAD_WORDS_[a]
# TAB_e1_ROW_WORDS_[c]
# TAB_e1_ROW_WORDS_[, i]
# TAB_e1_ROW_HEAD_WORDS_[, i]
# TAB_e1_ROW_WORDS_[= -200]
# TAB_e1_ROW_HEAD_WORDS_[c]
# TAB_e1_ROW_WORDS_[-200]
# TAB_e1_ROW_HEAD_WORDS_[-5 v]
# TAB_e1_ROW_WORDS_[-5]
# TAB_e1_ROW_WORDS_[i]
# TAB_e1_ROW_HEAD_WORDS_[v ,]
# TAB_e1_ROW_WORDS_[ce]
# TAB_e1_ROW_HEAD_WORDS_[= -5]
# TAB_e1_ROW_HEAD_WORDS_[= -200]
# TAB_e1_ROW_WORDS_[-5 v]
# TAB_e1_ROW_HEAD_WORDS_[i]
# TAB_e1_ROW_HEAD_WORDS_[-200]
# TAB_e1_ROW_WORDS_[= -5]
# TAB_e1_ROW_HEAD_WORDS_[ce]
# TAB_e1_ROW_HEAD_WORDS_[-5]
# TAB_e1_ROW_WORDS_[collector-emitter]
# TAB_e1_ROW_HEAD_WORDS_[ceo]
# TAB_e1_ROW_WORDS_[-45]
# TAB_e1_ROW_WORDS_[voltage]
# TAB_e1_CELL_WORDS_[collector-emitter voltage]
# TAB_e1_CELL_WORDS_[collector-emitter]
# TAB_e1_ROW_WORDS_[-65]
# TAB_e1_ROW_WORDS_[collector-emitter voltage]
# TAB_e1_ROW_WORDS_[ceo]
# TAB_e1_CELL_WORDS_[voltage]
# TAB_e1_ROW_WORDS_[v v]
# TDL_LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[2n3904]
# TDL_LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[None 2n3904]
# TDL_LEMMA:SEQ-BETWEEN[/ 859/860]
# DDL_e1_W_RIGHT_1_[-]
# DDL_e1_W_RIGHT_POS_2_[: NNP]
# DDL_e1_W_RIGHT_POS_3_[: NNP NNP]
# DDL_e1_W_RIGHT_2_[- NPN]
# DDL_e1_W_RIGHT_3_[- NPN General-Purpose]
# STR_e1_HTML_ATTR_style=text-indent: 0pt;line-height: 9pt;text-align: center;
# TDL_LEMMA:LEFT-OF-MENTION[:]
# STR_e1_HTML_ATTR_style=padding-top: 3pt;padding-left: 98pt;text-indent: 0pt;text-align: left;
# STR_e1_NODE_POS_15
# DDL_e1_W_RIGHT_2_[/ mmbt3904]
# DDL_e1_W_RIGHT_3_[/ mmbt3904 /]
# TDL_INV_SEQ-BETWEEN[LEN:0-4]
# DDL_e1_W_POS_L_1_R_1_[NN]_[NN]
# DDL_e1_W_RIGHT_1_[/]
# TDL_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|pzt3904]
# VIZ_e1_ALIGNED_gain
# VIZ_e1_ALIGNED_CENTER_voltage
# VIZ_e1_ALIGNED_dc
# VIZ_e1_ALIGNED_capacitance
# VIZ_e1_ALIGNED_bandwidth
# VIZ_e1_ALIGNED_LEFT_product
# VIZ_e1_ALIGNED_Y_nf
# VIZ_e1_ALIGNED_LEFT_dc
# VIZ_e1_ALIGNED_product
# VIZ_e1_ALIGNED_LEFT_voltage
# TAB_e1_ROW_WORDS_[10]
# VIZ_e1_ALIGNED_LEFT_saturation
# STR_e1_HTML_ATTR_style=padding-left: 4pt;text-indent: 0pt;text-align: left;
# VIZ_e1_ALIGNED_LEFT_capacitance
# VIZ_e1_ALIGNED_output
# TAB_e1_ROW_WORDS_[noise]
# VIZ_e1_ALIGNED_voltage
# VIZ_e1_ALIGNED_LEFT_current
# VIZ_e1_ALIGNED_LEFT_collector
# VIZ_e1_ALIGNED_LEFT_output
# VIZ_e1_ALIGNED_LEFT_bandwidth
# VIZ_e1_ALIGNED_saturation
# VIZ_e1_ALIGNED_nf
# TAB_e1_CELL_WORDS_[noise]
# VIZ_e1_ALIGNED_on
# VIZ_e1_ALIGNED_LEFT_on
# VIZ_e1_ALIGNED_LEFT_gain
# TAB_e1_ROW_NUM_[9]
# DDL_e1_W_LEFT_POS_1_[:]
# TDL_INV_LEMMA:RIGHT-OF-MENTION[:]
# TDL_LEMMA:SEQ-BETWEEN[-]
# DDL_e1_W_LEFT_3_[NPN General-Purpose Amplifier]
# DDL_e1_W_LEFT_2_[General-Purpose Amplifier]
# DDL_e1_W_LEFT_1_[Amplifier]
# DDL_e1_W_LEMMA_L_3_R_2_[Epitaxial Silicon Transistor]_[PNP Epitaxial]
# DDL_e1_W_POS_L_1_R_3_[NNP]_[NNP NNP NNP]
# DDL_e1_W_LEMMA_L_2_R_2_[Silicon Transistor]_[PNP Epitaxial]
# DDL_e1_W_LEMMA_L_1_R_2_[Transistor]_[PNP Epitaxial]
# DDL_e1_W_POS_L_3_R_2_[NNP NNP NNP]_[NNP NNP]
# DDL_e1_W_LEMMA_L_1_R_3_[Transistor]_[PNP Epitaxial Silicon]
# DDL_e1_W_POS_L_2_R_3_[NNP NNP]_[NNP NNP NNP]
# DDL_e1_W_LEMMA_L_2_R_3_[Silicon Transistor]_[PNP Epitaxial Silicon]
# DDL_e1_W_POS_L_1_R_1_[NNP]_[NNP]
# DDL_e1_W_RIGHT_3_[PNP Epitaxial Silicon]
# DDL_e1_DEP_SEQ_[compound punct nummod]
# DDL_e1_W_LEMMA_L_3_R_1_[Epitaxial Silicon Transistor]_[PNP]
# DDL_e1_W_POS_L_3_R_1_[NNP NNP NNP]_[NNP]
# DDL_e1_W_POS_L_2_R_1_[NNP NNP]_[NNP]
# DDL_e1_W_POS_L_2_R_2_[NNP NNP]_[NNP NNP]
# DDL_e1_W_POS_L_3_R_3_[NNP NNP NNP]_[NNP NNP NNP]
# DDL_e1_W_POS_L_1_R_2_[NNP]_[NNP NNP]
# DDL_e1_W_RIGHT_2_[PNP Epitaxial]
# DDL_e1_W_LEMMA_L_3_R_3_[Epitaxial Silicon Transistor]_[PNP Epitaxial Silicon]
# DDL_e1_W_LEMMA_L_2_R_1_[Silicon Transistor]_[PNP]
# DDL_e1_W_LEMMA_L_1_R_1_[Transistor]_[PNP]
# DDL_e1_W_RIGHT_1_[PNP]
# TAB_e1_ROW_WORDS_[bc856]
# TAB_e1_ROW_WORDS_[: bc856]
# TAB_e1_CELL_WORDS_[bc856]
# TAB_e1_CELL_WORDS_[: bc856]
# STR_e1_HTML_ATTR_style=text-indent: 0pt;text-align: center;
# TDL_LEMMA:SEQ-BETWEEN[mmbt3904]
# DDL_e1_W_LEMMA_L_1_R_1_[/]_[NPN]
# DDL_e1_W_POS_L_1_R_3_[:]_[NNP NNP NNP]
# DDL_e1_W_LEMMA_L_2_R_3_[mmbt3904 /]_[NPN General-Purpose Amplifier]
# DDL_e1_W_LEMMA_L_1_R_2_[/]_[NPN General-Purpose]
# DDL_e1_W_POS_L_2_R_3_[NN :]_[NNP NNP NNP]
# DDL_e1_W_LEMMA_L_2_R_2_[mmbt3904 /]_[NPN General-Purpose]
# DDL_e1_W_LEMMA_L_3_R_2_[/ mmbt3904 /]_[NPN General-Purpose]
# DDL_e1_W_LEMMA_L_3_R_3_[/ mmbt3904 /]_[NPN General-Purpose Amplifier]
# DDL_e1_W_LEMMA_L_1_R_3_[/]_[NPN General-Purpose Amplifier]
# DDL_e1_W_LEMMA_L_3_R_1_[/ mmbt3904 /]_[NPN]
# DDL_e1_W_LEMMA_L_2_R_1_[mmbt3904 /]_[NPN]
# DDL_e1_W_POS_L_3_R_3_[: NN :]_[NNP NNP NNP]
# DDL_e1_WORD_SEQ_[BC846 ... BC850]
# DDL_e1_DEP_SEQ_[nmod punct ROOT]
# DDL_e1_LEMMA_SEQ_[bc846 ... bc850]
# TDL_LEMMA:RIGHT-OF-MENTION[=]
# DDL_e1_W_LEMMA_L_2_R_1_[or 6ct]_[=]
# DDL_e1_W_LEMMA_L_1_R_1_[6ct]_[=]
# DDL_e1_W_LEFT_1_[6ct]
# DDL_e1_W_LEFT_2_[or 6ct]
# TDL_LEMMA:SEQ-BETWEEN[pzt3904]
# DDL_e1_W_LEFT_POS_2_[: NN]
# VIZ_e1_ALIGNED_mark
# VIZ_e1_ALIGNED_CENTER_mark
# DDL_e2_W_POS_L_3_R_2_[NNP NNP NNP]_[NNP NNP]
# DDL_e2_W_POS_L_1_R_2_[NNP]_[NNP NNP]
# DDL_e2_W_POS_L_2_R_2_[NNP NNP]_[NNP NNP]
# DDL_e2_W_LEFT_POS_3_[NNP NNP NNP]
# DDL_e2_W_POS_L_3_R_1_[NNP NNP NNP]_[NNP]
# DDL_e1_W_LEMMA_L_2_R_2_[mmbt3904 /]_[General-Purpose Amplifier]
# DDL_e1_W_LEMMA_L_1_R_1_[/]_[General-Purpose]
# DDL_e1_W_LEMMA_L_1_R_2_[/]_[General-Purpose Amplifier]
# DDL_e1_DEP_SEQ_[dep punct compound]
# DDL_e1_W_LEMMA_L_3_R_1_[/ mmbt3904 /]_[General-Purpose]
# DDL_e1_W_LEMMA_L_2_R_1_[mmbt3904 /]_[General-Purpose]
# DDL_e1_W_LEMMA_L_3_R_2_[/ mmbt3904 /]_[General-Purpose Amplifier]
# TDL_INV_LEMMA:SEQ-BETWEEN[= 6a or]
# TDL_INV_LEMMA:SEQ-BETWEEN[6a]
# TDL_INV_LEMMA:SEQ-BETWEEN[= 6a]
# TDL_INV_LEMMA:SEQ-BETWEEN[6a or 6cr]
# TDL_INV_LEMMA:SEQ-BETWEEN[6a or]
# TDL_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[dep|pzt3904 dep|Amplifier]
# TDL_DEP_LABEL:BETWEEN-MENTION-and-MENTION[dep dep]
# TDL_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[dep|pzt3904]
# TDL_INV_LEMMA:SEQ-BETWEEN[6e or 6cr]
# TDL_INV_LEMMA:SEQ-BETWEEN[6e]
# TDL_INV_LEMMA:SEQ-BETWEEN[= 6e]
# TDL_INV_LEMMA:SEQ-BETWEEN[6e or]
# TDL_INV_LEMMA:SEQ-BETWEEN[= 6e or]
# TDL_INV_SEQ-BETWEEN[LEN:8-13]
# TDL_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[dep|mmbt3904]
# TDL_LEMMA:BETWEEN-MENTION-and-MENTION[mmbt3904]
# TAB_e1_ROW_NUM_[1]
# DDL_e1_W_POS_L_3_R_1_[NNP NN NN]_[NNP]
# DDL_e1_W_POS_L_1_R_2_[NN]_[NNP NNP]
# DDL_e1_W_POS_L_2_R_1_[NN NN]_[NNP]
# DDL_e1_W_POS_L_1_R_1_[NN]_[NNP]
# DDL_e1_W_POS_L_2_R_2_[NN NN]_[NNP NNP]
# DDL_e1_W_POS_L_3_R_2_[NNP NN NN]_[NNP NNP]
# TDL_INV_LEMMA:BETWEEN-MENTION-and-MENTION[6c]
# TDL_INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|6c]
# TDL_INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|6g]
# TDL_INV_LEMMA:BETWEEN-MENTION-and-MENTION[6g]
# TDL_DEP_LABEL:BETWEEN-MENTION-and-MENTION[ROOT]
# DDL_e1_W_LEMMA_L_2_R_1_[or 6cr]_[=]
# DDL_e1_W_LEFT_2_[or 6cr]
# DDL_e1_W_LEFT_1_[6cr]
# DDL_e1_W_LEMMA_L_1_R_1_[6cr]_[=]
# TAB_e1_ROW_WORDS_[)]
# TAB_e1_ROW_WORDS_[pb-free )]
# TAB_e1_ROW_WORDS_[(]
# TAB_e1_COL_HEAD_WORDS_[device]
# TAB_e1_ROW_WORDS_[/]
# TAB_e1_ROW_WORDS_[pb-free]
# TAB_e1_COL_WORDS_[device]
# TAB_e1_ROW_WORDS_[( pb-free]
# STR_e1_HTML_ATTR_class=s6
# STR_e1_ANCESTOR_CLASS_[None None None None None s6]
# DDL_e1_W_LEMMA_L_2_R_1_[or 6cs]_[=]
# TDL_INV_LEMMA:SEQ-BETWEEN[or 6cs]
# DDL_e1_W_LEFT_2_[or 6cs]
# TDL_INV_LEMMA:SEQ-BETWEEN[6cs]
# DDL_e1_W_LEMMA_L_1_R_1_[6cs]_[=]
# DDL_e1_W_LEFT_1_[6cs]
# TAB_e1_COL_WORDS_[bc856/857/858]
# TAB_e1_COL_WORDS_[: bc856/857/858]
# DDL_e1_W_RIGHT_1_[mmbt3904]
# DDL_e1_W_LEFT_2_[noise :]
# DDL_e1_W_LEFT_POS_3_[JJ NN :]
# DDL_e1_W_LEFT_3_[low noise :]
# STR_e1_ANCESTOR_TAG_[html body h4]
# STR_e1_TAG_h4
# DDL_e1_W_LEFT_POS_3_[: NN :]
# DDL_e1_DEP_SEQ_[dep punct]
# TDL_INV_LEMMA:RIGHT-OF-MENTION[mmbt3904]
# TDL_INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|pzt3904]
# TDL_INV_LEMMA:BETWEEN-MENTION-and-MENTION[pzt3904]
# DDL_e1_W_POS_L_3_R_2_[NNP NN :]_[: NN]
# DDL_e1_W_LEMMA_L_1_R_3_[/]_[/ pzt3904 -]
# DDL_e1_W_RIGHT_3_[/ pzt3904 -]
# DDL_e1_W_LEMMA_L_3_R_1_[Amplifier 2n3904 /]_[/]
# DDL_e1_W_POS_L_3_R_3_[NNP NN :]_[: NN :]
# DDL_e1_W_LEMMA_L_3_R_2_[Amplifier 2n3904 /]_[/ pzt3904]
# DDL_e1_W_LEFT_POS_3_[NNP NN :]
# DDL_e1_W_LEMMA_L_3_R_3_[Amplifier 2n3904 /]_[/ pzt3904 -]
# DDL_e1_W_POS_L_3_R_1_[NNP NN :]_[:]
# DDL_e1_W_POS_L_2_R_3_[NN :]_[: NN :]
# DDL_e1_W_LEFT_3_[Amplifier 2n3904 /]
# DDL_e1_W_POS_L_1_R_3_[:]_[: NN :]
# DDL_e1_W_LEMMA_L_2_R_3_[2n3904 /]_[/ pzt3904 -]
# TDL_DEP_LABEL:BETWEEN-MENTION-and-MENTION[ROOT dep]
# DDL_e1_W_POS_L_3_R_1_[: NN :]_[:]
# DDL_e1_W_POS_L_1_R_2_[:]_[: NNP]
# DDL_e1_W_LEMMA_L_2_R_2_[mmbt3904 /]_[- NPN]
# DDL_e1_W_LEMMA_L_3_R_1_[/ mmbt3904 /]_[-]
# DDL_e1_W_POS_L_1_R_3_[:]_[: NNP NNP]
# DDL_e1_W_LEMMA_L_1_R_1_[/]_[-]
# DDL_e1_W_LEMMA_L_1_R_3_[/]_[- NPN General-Purpose]
# DDL_e1_W_LEMMA_L_3_R_2_[/ mmbt3904 /]_[- NPN]
# DDL_e1_W_POS_L_2_R_2_[NN :]_[: NNP]
# DDL_e1_W_LEMMA_L_1_R_2_[/]_[- NPN]
# DDL_e1_W_LEMMA_L_2_R_3_[mmbt3904 /]_[- NPN General-Purpose]
# DDL_e1_W_LEMMA_L_2_R_1_[mmbt3904 /]_[-]
# DDL_e1_W_POS_L_2_R_3_[NN :]_[: NNP NNP]
# DDL_e1_W_POS_L_3_R_3_[: NN :]_[: NNP NNP]
# DDL_e1_W_LEMMA_L_3_R_3_[/ mmbt3904 /]_[- NPN General-Purpose]
# DDL_e1_W_POS_L_3_R_2_[: NN :]_[: NNP]
# DDL_e1_W_POS_L_1_R_1_[NN]_[:]
# DDL_e1_WORD_SEQ_[BC807K]
# STR_e1_ANCESTOR_TAG_[html body p span]
# DDL_e1_LEMMA_SEQ_[bc807k]
# STR_e1_ANCESTOR_CLASS_[None None None s20]
# STR_e1_PARENT_TAG_p
# DDL_e1_W_LEFT_1_[bc807k]
# STR_e1_HTML_ATTR_class=s20
# DDL_e1_W_LEFT_POS_2_[NN :]
# TAB_e1_ROW_NUM_[2]
# DDL_e1_WORD_SEQ_[BC182 , BC182B]
# DDL_e1_DEP_SEQ_[ROOT punct appos]
# DDL_e1_LEMMA_SEQ_[bc182 , bc182b]
# STR_e2_NODE_POS_3
# STR_e2_HTML_ATTR_class=s5
# STR_e2_ANCESTOR_ID_[None None l1 None None]
# STR_e2_ANCESTOR_CLASS_[None None None None s5]
# STR_e2_HTML_ATTR_style=text-indent: 0pt;line-height: 20pt;text-align: center;
# STR_e2_ANCESTOR_TAG_[html body ul li p]
# STR_e2_PARENT_TAG_li
# DDL_e1_LEMMA_SEQ_[dtc114ye]
# DDL_e1_WORD_SEQ_[DTC114YE]
# STR_e1_HTML_ATTR_style=padding-top: 1pt;padding-left: 24pt;text-indent: 0pt;text-align: left;
# TAB_e1_ROW_WORDS_[f]
# TAB_e1_ROW_HEAD_WORDS_[= 2k]
# TAB_e1_ROW_HEAD_WORDS_[2k]
# TAB_e1_ROW_HEAD_WORDS_[r]
# TAB_e1_ROW_WORDS_[r]
# TAB_e1_ROW_HEAD_WORDS_[g]
# TAB_e1_ROW_WORDS_[f =]
# TAB_e1_ROW_WORDS_[2k]
# TAB_e1_ROW_WORDS_[= 2k]
# TAB_e1_ROW_HEAD_WORDS_[f]
# TAB_e1_ROW_HEAD_WORDS_[f =]
# TAB_e1_ROW_WORDS_[g]
# TAB_e1_ROW_WORDS_[4]
# DDL_e1_W_POS_L_1_R_2_[NNP]_[: NN]
# DDL_e1_W_LEMMA_L_3_R_2_[NPN General-Purpose Amplifier]_[/ mmbt3904]
# DDL_e1_W_LEMMA_L_3_R_3_[NPN General-Purpose Amplifier]_[/ mmbt3904 /]
# DDL_e1_W_POS_L_1_R_3_[NNP]_[: NN :]
# DDL_e1_W_POS_L_2_R_3_[NNP NNP]_[: NN :]
# DDL_e1_W_LEMMA_L_1_R_3_[Amplifier]_[/ mmbt3904 /]
# DDL_e1_W_LEMMA_L_2_R_2_[General-Purpose Amplifier]_[/ mmbt3904]
# DDL_e1_W_LEMMA_L_2_R_1_[General-Purpose Amplifier]_[/]
# DDL_e1_W_POS_L_3_R_2_[NNP NNP NNP]_[: NN]
# DDL_e1_W_POS_L_3_R_3_[NNP NNP NNP]_[: NN :]
# DDL_e1_W_LEMMA_L_1_R_2_[Amplifier]_[/ mmbt3904]
# DDL_e1_W_LEMMA_L_1_R_1_[Amplifier]_[/]
# DDL_e1_W_LEMMA_L_2_R_3_[General-Purpose Amplifier]_[/ mmbt3904 /]
# DDL_e1_W_POS_L_2_R_2_[NNP NNP]_[: NN]
# DDL_e1_W_LEMMA_L_3_R_1_[NPN General-Purpose Amplifier]_[/]
# STR_e1_ANCESTOR_TAG_[html head title]
# STR_e1_TAG_title
# STR_e1_PARENT_TAG_head
# STR_e1_PREV_SIB_TAG_meta
# TAB_e1_ROW_WORDS_[figure]
# TAB_e1_ROW_WORDS_[noise figure]
# TAB_e1_CELL_WORDS_[noise figure]
# TAB_e1_CELL_WORDS_[figure]
# TAB_e1_COL_WORDS_[50 v]
# STR_e1_HTML_ATTR_style=padding-top: 2pt;padding-left: 13pt;text-indent: 0pt;text-align: left;
# TAB_e1_ROW_WORDS_[bc818k]
# TAB_e1_COL_WORDS_[45 v]
# DDL_e1_W_LEFT_1_[bc817k]
# TAB_e1_COL_WORDS_[50]
# TAB_e1_COL_NUM_[2]
# TAB_e1_COL_WORDS_[45]
# TDL_LEMMA:LEFT-OF-MENTION[-]
# TDL_LEMMA:SEQ-BETWEEN[General-Purpose]
# TDL_INV_LEMMA:BETWEEN-MENTION-and-MENTION[bc850]
# TDL_INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|bc850]
# TDL_LEMMA:SEQ-BETWEEN[pzt3904 -]
# DDL_e1_POS_SEQ_[NN :]
# TAB_e1_COL_WORDS_[25]
# VIZ_e1_ALIGNED_diotec
# TAB_e1_COL_WORDS_[30 v]
# TAB_e1_COL_WORDS_[25 v]
# VIZ_e1_ALIGNED_semiconductor
# STR_e1_HTML_ATTR_style=padding-top: 2pt;padding-left: 10pt;text-indent: 0pt;text-align: left;
# VIZ_e1_ALIGNED_ag
# TAB_e1_ROW_WORDS_[bc817k]
# TAB_e1_COL_NUM_[3]
# VIZ_e1_ALIGNED_RIGHT_ag
# TAB_e1_COL_WORDS_[30]
# VIZ_e1_ALIGNED_RIGHT_semiconductor
# VIZ_e1_ALIGNED_RIGHT_diotec
# TDL_LEMMA:LEFT-OF-MENTION[bc846]
# TDL_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[compound|complement]
# TDL_LEMMA:BETWEEN-MENTION-and-MENTION[complement]
# TAB_e1_CELL_WORDS_[: bc857/860]
# TAB_e1_ROW_WORDS_[: bc857/860]
# TAB_e1_ROW_WORDS_[bc857/860]
# TAB_e1_CELL_WORDS_[bc857/860]
# TDL_LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[mmbt3904]
# TDL_LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[2n3904 mmbt3904]
# TDL_LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[None 2n3904 mmbt3904]
# TDL_INV_LEMMA:SEQ-BETWEEN[to]
# TAB_e1_CELL_WORDS_[bc858/859]
# TAB_e1_ROW_WORDS_[bc858/859]
# TAB_e1_CELL_WORDS_[: bc858/859]
# TAB_e1_ROW_WORDS_[: bc858/859]
# DDL_e1_W_POS_L_1_R_2_[NNP]_[: CD]
# DDL_e1_W_LEMMA_L_2_R_3_[Silicon Transistor]_[/ 859/860 PNP]
# DDL_e1_W_LEMMA_L_1_R_1_[Transistor]_[/]
# DDL_e1_W_POS_L_2_R_2_[NNP NNP]_[: CD]
# DDL_e1_W_POS_L_3_R_3_[NNP NNP NNP]_[: CD NNP]
# DDL_e1_W_LEMMA_L_1_R_3_[Transistor]_[/ 859/860 PNP]
# DDL_e1_W_LEMMA_L_2_R_2_[Silicon Transistor]_[/ 859/860]
# DDL_e1_W_POS_L_2_R_3_[NNP NNP]_[: CD NNP]
# DDL_e1_W_LEMMA_L_1_R_2_[Transistor]_[/ 859/860]
# DDL_e1_W_RIGHT_POS_3_[: CD NNP]
# DDL_e1_W_LEMMA_L_3_R_1_[Epitaxial Silicon Transistor]_[/]
# DDL_e1_W_LEMMA_L_3_R_3_[Epitaxial Silicon Transistor]_[/ 859/860 PNP]
# DDL_e1_W_LEMMA_L_2_R_1_[Silicon Transistor]_[/]
# DDL_e1_W_RIGHT_3_[/ 859/860 PNP]
# DDL_e1_W_POS_L_3_R_2_[NNP NNP NNP]_[: CD]
# DDL_e1_W_POS_L_1_R_3_[NNP]_[: CD NNP]
# DDL_e1_W_LEMMA_L_3_R_2_[Epitaxial Silicon Transistor]_[/ 859/860]
# TDL_INV_LEMMA:LEFT-OF-MENTION[:]
# TAB_e1_ROW_NUM_[5]
# DDL_e1_W_RIGHT_2_[859/860 PNP]
# DDL_e1_W_POS_L_3_R_1_[NNP NNP NNP]_[CD]
# DDL_e1_W_RIGHT_POS_2_[CD NNP]
# DDL_e1_W_LEMMA_L_2_R_1_[Silicon Transistor]_[859/860]
# DDL_e1_W_LEMMA_L_2_R_2_[Silicon Transistor]_[859/860 PNP]
# DDL_e1_W_POS_L_3_R_2_[NNP NNP NNP]_[CD NNP]
# DDL_e1_W_POS_L_2_R_2_[NNP NNP]_[CD NNP]
# DDL_e1_W_LEMMA_L_2_R_3_[Silicon Transistor]_[859/860 PNP Epitaxial]
# DDL_e1_W_LEMMA_L_1_R_2_[Transistor]_[859/860 PNP]
# DDL_e1_W_POS_L_1_R_1_[NNP]_[CD]
# DDL_e1_W_POS_L_1_R_2_[NNP]_[CD NNP]
# DDL_e1_W_LEMMA_L_1_R_3_[Transistor]_[859/860 PNP Epitaxial]
# DDL_e1_DEP_SEQ_[compound punct]
# DDL_e1_W_LEMMA_L_3_R_1_[Epitaxial Silicon Transistor]_[859/860]
# DDL_e1_W_LEMMA_L_3_R_2_[Epitaxial Silicon Transistor]_[859/860 PNP]
# DDL_e1_W_LEMMA_L_1_R_1_[Transistor]_[859/860]
# DDL_e1_W_LEMMA_L_3_R_3_[Epitaxial Silicon Transistor]_[859/860 PNP Epitaxial]
# DDL_e1_W_POS_L_2_R_1_[NNP NNP]_[CD]
# DDL_e1_W_RIGHT_POS_3_[CD NNP NNP]
# DDL_e1_W_POS_L_3_R_3_[NNP NNP NNP]_[CD NNP NNP]
# DDL_e1_W_RIGHT_3_[859/860 PNP Epitaxial]
# DDL_e1_W_POS_L_2_R_3_[NNP NNP]_[CD NNP NNP]
# DDL_e1_W_POS_L_1_R_3_[NNP]_[CD NNP NNP]
# DDL_e1_WORD_SEQ_[BC182]
# DDL_e1_LEMMA_SEQ_[bc182]
# TAB_e1_ROW_WORDS_[10000]
# DDL_e1_W_LEFT_1_[.]
# DDL_e1_W_LEFT_POS_1_[.]
# TDL_INV_LEMMA:SEQ-BETWEEN[:]
# DDL_e1_W_LEFT_2_[mmbt3904 2n3904]
# DDL_e1_W_LEFT_3_[2n3904 mmbt3904 2n3904]
# DDL_e1_W_LEFT_3_[/ bc808k /]
# STR_e1_HTML_ATTR_style=padding-left: 8pt;text-indent: 0pt;line-height: 15pt;text-align: left;
# DDL_e1_W_LEFT_2_[bc808k /]
# DDL_e1_WORD_SEQ_[BC808K]
# DDL_e1_LEMMA_SEQ_[bc808k]
# TDL_DEP_LABEL:BETWEEN-MENTION-and-MENTION[compound]
# TDL_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|bc817k]
# TDL_LEMMA:BETWEEN-MENTION-and-MENTION[bc817k]
# TDL_LEMMA:SEQ-BETWEEN[/ pzt3904]
# VIZ_e2_ALIGNED_characteristic
# DDL_e2_W_LEFT_1_[complementary]
# DDL_e2_W_LEFT_POS_2_[VBN JJ]
# VIZ_e2_ALIGNED_LEFT_sperrschicht
# VIZ_e2_ALIGNED_LEFT_lötpunkt
# VIZ_e2_ALIGNED_LEFT_min
# VIZ_e2_ALIGNED_sperrschicht
# DDL_e2_W_LEMMA_L_3_R_1_[transistor recommend complementary]_[transistor]
# STR_e2_NODE_POS_69
# VIZ_e2_ALIGNED_LEFT_resistance
# VIZ_e2_ALIGNED_point
# VIZ_e2_ALIGNED_LEFT_frequency
# DDL_e2_W_LEMMA_L_1_R_1_[complementary]_[transistor]
# VIZ_e2_ALIGNED_LEFT_wärmewiderstand
# VIZ_e2_ALIGNED_LEFT_to
# VIZ_e2_ALIGNED_LEFT_cutoff
# VIZ_e2_ALIGNED_LEFT_capacitance
# DDL_e2_W_POS_L_1_R_1_[JJ]_[NNS]
# VIZ_e2_ALIGNED_LEFT_transition
# VIZ_e2_ALIGNED_cutoff
# VIZ_e2_ALIGNED_frequency
# VIZ_e2_ALIGNED_wärmewiderstand
# DDL_e2_W_LEFT_POS_3_[NNS VBN JJ]
# VIZ_e2_ALIGNED_current
# VIZ_e2_ALIGNED_min
# DDL_e2_W_POS_L_3_R_1_[NNS VBN JJ]_[NNS]
# DDL_e2_W_LEMMA_L_2_R_1_[recommend complementary]_[transistor]
# VIZ_e2_ALIGNED_soldering
# DDL_e2_W_POS_L_2_R_1_[VBN JJ]_[NNS]
# VIZ_e2_ALIGNED_LEFT_junction
# DDL_e2_W_LEFT_3_[transistor recommend complementary]
# VIZ_e2_ALIGNED_thermal
# DDL_e2_W_LEFT_POS_1_[JJ]
# DDL_e2_W_LEFT_2_[recommend complementary]
# VIZ_e2_ALIGNED_LEFT_soldering
# VIZ_e2_ALIGNED_resistance
# VIZ_e2_ALIGNED_capacitance
# STR_e2_HTML_ATTR_style=padding-top: 5pt;padding-left: 8pt;text-indent: 0pt;line-height: 9pt;text-align: left;
# VIZ_e2_ALIGNED_LEFT_transitfrequenz
# VIZ_e2_ALIGNED_LEFT_point
# DDL_e2_W_RIGHT_POS_1_[NNS]
# DDL_e2_LEMMA_SEQ_[pnp]
# VIZ_e2_ALIGNED_transitfrequenz
# DDL_e2_W_RIGHT_1_[transistor]
# VIZ_e2_ALIGNED_lötpunkt
# VIZ_e2_ALIGNED_c
# VIZ_e2_ALIGNED_LEFT_characteristic
# VIZ_e2_ALIGNED_LEFT_c
# VIZ_e2_ALIGNED_junction
# VIZ_e2_ALIGNED_LEFT_thermal
# VIZ_e2_ALIGNED_transition
# VIZ_e2_ALIGNED_to
# STR_e2_ANCESTOR_TAG_[html body p]
# VIZ_e2_ALIGNED_LEFT_current
# TAB_e1_ROW_WORDS_[/ bulk]
# TAB_e1_ROW_WORDS_[units]
# TAB_e1_ROW_WORDS_[5000 units]
# TAB_e1_COL_WORDS_[bc182brl1g]
# TAB_e1_ROW_WORDS_[5000]
# TAB_e1_ROW_WORDS_[units /]
# TDL_INV_LEMMA:BETWEEN-MENTION-and-MENTION[bc808k]
# TDL_INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|bc808k]
# TAB_e1_COL_WORDS_[bc182bg]
# TAB_e1_COL_WORDS_[bc182g]
# STR_e1_NODE_POS_2
# DDL_e2_W_LEFT_POS_2_[NNP -LRB-]
# DDL_e2_W_LEFT_1_[(]
# DDL_e2_W_POS_L_2_R_1_[NNP -LRB-]_[-RRB-]
# STR_e2_ANCESTOR_ID_[None None None None]
# DDL_e2_W_LEFT_POS_3_[NNP NNP -LRB-]
# DDL_e2_W_LEMMA_L_1_R_1_[(]_[)]
# DDL_e2_DEP_SEQ_[appos]
# STR_e2_PARENT_TAG_h3
# STR_e2_LAST_NODE
# STR_e2_TAG_a
# STR_e2_ANCESTOR_CLASS_[None None None None]
# DDL_e2_W_POS_L_3_R_1_[NNP NNP -LRB-]_[-RRB-]
# DDL_e2_W_LEFT_3_[TRANSISTOR TRANSISTORS (]
# DDL_e2_W_LEMMA_L_3_R_1_[TRANSISTOR TRANSISTORS (]_[)]
# DDL_e2_W_LEFT_POS_1_[-LRB-]
# DDL_e2_W_POS_L_1_R_1_[-LRB-]_[-RRB-]
# DDL_e2_W_RIGHT_1_[)]
# STR_e2_FIRST_NODE
# DDL_e2_W_RIGHT_POS_1_[-RRB-]
# DDL_e2_W_LEMMA_L_2_R_1_[TRANSISTORS (]_[)]
# STR_e2_HTML_ATTR_name=bookmark0
# DDL_e2_W_LEFT_2_[TRANSISTORS (]
# STR_e2_ANCESTOR_TAG_[html body h3 a]
# TAB_e1_ROW_HEAD_WORDS_[-50]
# TAB_e1_ROW_WORDS_[-50]
# TAB_e1_ROW_HEAD_WORDS_[-30]
# TDL_INV_LEMMA:SEQ-BETWEEN[noise]
# TDL_INV_LEMMA:BETWEEN-MENTION-and-MENTION[noise]
# TDL_INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|noise]
# STR_e1_HTML_ATTR_style=padding-left: 62pt;text-indent: 0pt;line-height: 8pt;text-align: left;
# VIZ_e1_ALIGNED_RIGHT_a
# TAB_e1_ROW_HEAD_WORDS_[1khz ,]
# TAB_e1_ROW_WORDS_[1khz ,]
# TAB_e1_ROW_HEAD_WORDS_[= 1khz]
# TAB_e1_ROW_NUM_[10]
# TAB_e1_ROW_WORDS_[1]
# TAB_e1_ROW_WORDS_[, r]
# TAB_e1_ROW_WORDS_[= 1khz]
# VIZ_e1_ALIGNED_a
# TAB_e1_ROW_HEAD_WORDS_[, r]
# TAB_e1_ROW_HEAD_WORDS_[1khz]
# TAB_e1_ROW_WORDS_[1khz]
# VIZ_VERT_ALIGNED_CENTER
# DDL_e1_W_LEFT_1_[noise]
# TDL_LEMMA:SEQ-BETWEEN[mmbt3904 /]
# TDL_LEMMA:SEQ-BETWEEN[/ mmbt3904]
# TDL_LEMMA:SEQ-BETWEEN[/ mmbt3904 /]
# STR_LOWEST_ANCESTOR_DEPTH_[4]
# STR_COMMON_ANCESTOR_[]
# TDL_SEQ-BETWEEN[LEN:0-4]
# STR_e1_ANCESTOR_CLASS_[None None None s2]
# STR_e1_PARENT_TAG_h2
# STR_e1_ANCESTOR_TAG_[html body h2 span]
# STR_e1_HTML_ATTR_class=s2
# DDL_e1_LEMMA_SEQ_[: bc858/859]
# DDL_e1_WORD_SEQ_[: BC858/859]
# DDL_e1_W_LEFT_1_[bc858/859]
# DDL_e1_W_LEFT_2_[: bc858/859]
# DDL_e1_LEMMA_SEQ_[: bc857/860]
# DDL_e1_W_LEFT_2_[: bc857/860]
# DDL_e1_WORD_SEQ_[: BC857/860]
# DDL_e1_W_LEFT_1_[bc857/860]
# DDL_e1_LEMMA_SEQ_[bc858/859]
# DDL_e1_W_LEFT_3_[: bc858/859 :]
# DDL_e1_W_LEFT_2_[bc858/859 :]
# DDL_e1_WORD_SEQ_[BC858/859]
# TDL_LEMMA:BETWEEN-MENTION-and-MENTION[bc850]
# TDL_LEMMA:BETWEEN-MENTION-and-MENTION[bc850 complement]
# TDL_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|bc850]
# TDL_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|bc850 compound|complement]
# DDL_e1_W_LEFT_2_[bc857/860 :]
# DDL_e1_WORD_SEQ_[BC857/860]
# DDL_e1_LEMMA_SEQ_[bc857/860]
# DDL_e1_W_LEFT_3_[: bc857/860 :]
# DDL_e1_W_RIGHT_POS_3_[NNP NNP NNP]
# DDL_e1_W_LEFT_3_[pzt3904 2n3904 /]
# DDL_e1_W_LEMMA_L_3_R_2_[pzt3904 2n3904 /]_[/ pzt3904]
# DDL_e1_W_POS_L_3_R_2_[NN NN :]_[: NN]
# DDL_e1_W_LEMMA_L_3_R_1_[pzt3904 2n3904 /]_[/]
# DDL_e1_W_POS_L_3_R_1_[NN NN :]_[:]
# DDL_e1_W_LEMMA_L_3_R_1_[Amplifier 2n3904 mmbt3904]_[NPN]
# DDL_e1_W_LEMMA_L_1_R_1_[mmbt3904]_[NPN]
# DDL_e1_W_LEMMA_L_2_R_1_[2n3904 mmbt3904]_[NPN]
# DDL_e1_W_POS_L_1_R_3_[NN]_[NNP NNP NNP]
# DDL_e1_W_LEMMA_L_3_R_3_[Amplifier 2n3904 mmbt3904]_[NPN General-Purpose Amplifier]
# DDL_e1_W_POS_L_2_R_3_[NN NN]_[NNP NNP NNP]
# DDL_e1_W_LEMMA_L_3_R_2_[Amplifier 2n3904 mmbt3904]_[NPN General-Purpose]
# DDL_e1_W_LEMMA_L_2_R_3_[2n3904 mmbt3904]_[NPN General-Purpose Amplifier]
# DDL_e1_W_LEMMA_L_1_R_3_[mmbt3904]_[NPN General-Purpose Amplifier]
# DDL_e1_W_LEMMA_L_2_R_2_[2n3904 mmbt3904]_[NPN General-Purpose]
# DDL_e1_W_LEMMA_L_1_R_2_[mmbt3904]_[NPN General-Purpose]
# DDL_e1_W_POS_L_3_R_3_[NNP NN NN]_[NNP NNP NNP]
# DDL_e1_W_LEMMA_L_3_R_1_[6c or 6ct]_[=]
# DDL_e1_W_LEMMA_L_1_R_2_[6ct]_[= 6a]
# DDL_e1_W_LEMMA_L_2_R_3_[or 6ct]_[= 6a or]
# DDL_e1_LEMMA_SEQ_[bc817k-16]
# DDL_e1_W_LEMMA_L_2_R_2_[or 6ct]_[= 6a]
# DDL_e1_W_LEMMA_L_3_R_2_[6c or 6ct]_[= 6a]
# DDL_e1_W_RIGHT_2_[= 6a]
# DDL_e1_W_LEFT_3_[6c or 6ct]
# DDL_e1_W_LEMMA_L_1_R_3_[6ct]_[= 6a or]
# DDL_e1_WORD_SEQ_[BC817K-16]
# DDL_e1_W_LEMMA_L_3_R_3_[6c or 6ct]_[= 6a or]
# DDL_e1_W_RIGHT_3_[= 6a or]
# DDL_e1_W_POS_L_2_R_1_[NN NN]_[NN]
# DDL_e1_W_LEMMA_L_2_R_1_[2n3904 mmbt3904]_[mmbt3904]
# DDL_e1_W_LEMMA_L_1_R_1_[mmbt3904]_[mmbt3904]
# TDL_LEMMA:SEQ-BETWEEN[NPN]
# TDL_LEMMA:SEQ-BETWEEN[NPN General-Purpose]
# TDL_DEP_LABEL:BETWEEN-MENTION-and-MENTION[ROOT compound]
# DDL_e1_W_LEMMA_L_1_R_2_[6ct]_[= 6e]
# DDL_e1_W_RIGHT_2_[= 6e]
# DDL_e1_W_LEMMA_L_3_R_3_[6g or 6ct]_[= 6e or]
# DDL_e1_W_LEFT_3_[6g or 6ct]
# DDL_e1_W_LEMMA_L_2_R_3_[or 6ct]_[= 6e or]
# DDL_e1_W_LEMMA_L_1_R_3_[6ct]_[= 6e or]
# DDL_e1_W_LEMMA_L_3_R_1_[6g or 6ct]_[=]
# DDL_e1_LEMMA_SEQ_[bc818k-16]
# DDL_e1_W_LEMMA_L_3_R_2_[6g or 6ct]_[= 6e]
# DDL_e1_W_LEMMA_L_2_R_2_[or 6ct]_[= 6e]
# DDL_e1_WORD_SEQ_[BC818K-16]
# DDL_e1_W_RIGHT_3_[= 6e or]
# STR_e1_HTML_ATTR_style=padding-top: 1pt;padding-left: 21pt;text-indent: 0pt;text-align: left;
# TDL_INV_LEMMA:SEQ-BETWEEN[/]
# TDL_INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|figure]
# TDL_INV_LEMMA:BETWEEN-MENTION-and-MENTION[figure]
# TDL_INV_LEMMA:SEQ-BETWEEN[noise :]
# DDL_e1_LEMMA_SEQ_[bc817k-25]
# DDL_e1_W_LEMMA_L_1_R_2_[6cr]_[= 6b]
# DDL_e1_W_RIGHT_3_[= 6b or]
# DDL_e1_W_LEMMA_L_2_R_3_[or 6cr]_[= 6b or]
# DDL_e1_W_LEFT_3_[6a or 6cr]
# DDL_e1_W_LEMMA_L_3_R_2_[6a or 6cr]_[= 6b]
# DDL_e1_WORD_SEQ_[BC817K-25]
# DDL_e1_W_LEMMA_L_3_R_1_[6a or 6cr]_[=]
# DDL_e1_W_RIGHT_2_[= 6b]
# DDL_e1_W_LEMMA_L_1_R_3_[6cr]_[= 6b or]
# DDL_e1_W_LEMMA_L_3_R_3_[6a or 6cr]_[= 6b or]
# DDL_e1_W_LEMMA_L_2_R_2_[or 6cr]_[= 6b]
# DDL_e1_LEMMA_SEQ_[bc818k-25]
# DDL_e1_W_LEMMA_L_3_R_2_[6e or 6cr]_[= 6f]
# DDL_e1_W_RIGHT_2_[= 6f]
# DDL_e1_W_LEMMA_L_2_R_3_[or 6cr]_[= 6f or]
# DDL_e1_W_RIGHT_3_[= 6f or]
# DDL_e1_W_LEMMA_L_2_R_2_[or 6cr]_[= 6f]
# DDL_e1_W_LEMMA_L_3_R_3_[6e or 6cr]_[= 6f or]
# DDL_e1_W_LEMMA_L_1_R_3_[6cr]_[= 6f or]
# DDL_e1_W_LEMMA_L_3_R_1_[6e or 6cr]_[=]
# DDL_e1_W_LEFT_3_[6e or 6cr]
# DDL_e1_WORD_SEQ_[BC818K-25]
# DDL_e1_W_LEMMA_L_1_R_2_[6cr]_[= 6f]
# DDL_e1_W_LEMMA_L_2_R_2_[or 6cs]_[= 6c]
# DDL_e1_W_LEMMA_L_1_R_2_[6cs]_[= 6c]
# TDL_INV_LEMMA:SEQ-BETWEEN[6cr bc817k-25 =]
# DDL_e1_W_LEMMA_L_3_R_2_[6b or 6cs]_[= 6c]
# TDL_INV_LEMMA:SEQ-BETWEEN[6b or 6cs]
# TDL_INV_LEMMA:SEQ-BETWEEN[bc817k-25]
# DDL_e1_W_LEMMA_L_2_R_3_[or 6cs]_[= 6c or]
# TDL_INV_LEMMA:SEQ-BETWEEN[or 6cr bc817k-25]
# TDL_INV_LEMMA:SEQ-BETWEEN[6b or]
# TDL_INV_LEMMA:SEQ-BETWEEN[= 6b]
# TDL_INV_LEMMA:SEQ-BETWEEN[6cr bc817k-25]
# TDL_INV_LEMMA:SEQ-BETWEEN[= 6b or]
# DDL_e1_LEMMA_SEQ_[bc817k-40]
# DDL_e1_WORD_SEQ_[BC817K-40]
# DDL_e1_W_LEFT_3_[6b or 6cs]
# DDL_e1_W_LEMMA_L_1_R_3_[6cs]_[= 6c or]
# DDL_e1_W_RIGHT_3_[= 6c or]
# TDL_INV_LEMMA:SEQ-BETWEEN[6b]
# TDL_INV_LEMMA:SEQ-BETWEEN[bc817k-25 = 6b]
# DDL_e1_W_LEMMA_L_3_R_1_[6b or 6cs]_[=]
# DDL_e1_W_RIGHT_2_[= 6c]
# TDL_INV_LEMMA:SEQ-BETWEEN[bc817k-25 =]
# DDL_e1_W_LEMMA_L_3_R_3_[6b or 6cs]_[= 6c or]
# DDL_e1_POS_SEQ_[NN , NN]
# TDL_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|2n3904 dep|mmbt3904]
# TDL_LEMMA:BETWEEN-MENTION-and-MENTION[2n3904]
# TDL_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|2n3904]
# TDL_LEMMA:BETWEEN-MENTION-and-MENTION[2n3904 mmbt3904]
# DDL_e1_W_LEMMA_L_3_R_3_[6f or 6cs]_[= 6g or]
# DDL_e1_LEMMA_SEQ_[bc818k-40]
# TDL_INV_LEMMA:SEQ-BETWEEN[bc818k-25]
# DDL_e1_W_LEMMA_L_3_R_2_[6f or 6cs]_[= 6g]
# TDL_INV_LEMMA:SEQ-BETWEEN[6f]
# DDL_e1_W_LEMMA_L_3_R_1_[6f or 6cs]_[=]
# DDL_e1_W_RIGHT_2_[= 6g]
# TDL_INV_LEMMA:SEQ-BETWEEN[6cr bc818k-25 =]
# DDL_e1_W_LEFT_3_[6f or 6cs]
# DDL_e1_W_LEMMA_L_2_R_2_[or 6cs]_[= 6g]
# DDL_e1_W_RIGHT_3_[= 6g or]
# TDL_INV_LEMMA:SEQ-BETWEEN[6f or]
# DDL_e1_W_LEMMA_L_2_R_3_[or 6cs]_[= 6g or]
# TDL_INV_LEMMA:SEQ-BETWEEN[bc818k-25 =]
# DDL_e1_W_LEMMA_L_1_R_3_[6cs]_[= 6g or]
# TDL_INV_LEMMA:SEQ-BETWEEN[= 6f or]
# TDL_INV_LEMMA:SEQ-BETWEEN[= 6f]
# DDL_e1_WORD_SEQ_[BC818K-40]
# TDL_INV_LEMMA:SEQ-BETWEEN[6cr bc818k-25]
# TDL_INV_LEMMA:SEQ-BETWEEN[6f or 6cs]
# TDL_INV_LEMMA:SEQ-BETWEEN[or 6cr bc818k-25]
# DDL_e1_W_LEMMA_L_1_R_2_[6cs]_[= 6g]
# TDL_INV_LEMMA:SEQ-BETWEEN[bc818k-25 = 6f]
# VIZ_e1_ALIGNED_information
# VIZ_e1_ALIGNED_RIGHT_y
# VIZ_e1_ALIGNED_RIGHT_w
# STR_e1_PREV_SIB_TAG_h4
# VIZ_e1_ALIGNED_week
# VIZ_e1_ALIGNED_RIGHT_year
# VIZ_e1_ALIGNED_RIGHT_publication
# VIZ_e1_ALIGNED_RIGHT_number
# DDL_e1_LEMMA_SEQ_[bc182/d]
# STR_e1_HTML_ATTR_style=text-indent: 0pt;text-align: right;
# VIZ_e1_ALIGNED_order
# VIZ_e1_ALIGNED_RIGHT_work
# VIZ_e1_ALIGNED_y
# VIZ_e1_ALIGNED_w
# VIZ_e1_ALIGNED_RIGHT_order
# DDL_e1_W_LEFT_1_[bc182/d]
# VIZ_e1_ALIGNED_year
# VIZ_e1_ALIGNED_publication
# VIZ_e1_ALIGNED_RIGHT_information
# VIZ_e1_ALIGNED_work
# DDL_e1_WORD_SEQ_[BC182/D]
# VIZ_e1_ALIGNED_RIGHT_package
# VIZ_e1_ALIGNED_RIGHT_week
# VIZ_e1_ALIGNED_package
# DDL_e1_W_RIGHT_1_[bc860]
# DDL_e1_W_LEMMA_L_1_R_2_[mmbt3904]_[General-Purpose Amplifier]
# DDL_e1_W_LEMMA_L_3_R_1_[Amplifier 2n3904 mmbt3904]_[General-Purpose]
# DDL_e1_W_LEMMA_L_2_R_2_[2n3904 mmbt3904]_[General-Purpose Amplifier]
# DDL_e1_W_LEMMA_L_1_R_1_[mmbt3904]_[General-Purpose]
# DDL_e1_W_LEMMA_L_3_R_2_[Amplifier 2n3904 mmbt3904]_[General-Purpose Amplifier]
# DDL_e1_DEP_SEQ_[ROOT punct compound]
# DDL_e1_W_LEMMA_L_2_R_1_[2n3904 mmbt3904]_[General-Purpose]
# DDL_e1_W_POS_L_1_R_3_[NN]_[NN : NNP]
# DDL_e1_W_LEMMA_L_3_R_1_[General-Purpose Amplifier 2n3904]_[pzt3904]
# DDL_e1_W_RIGHT_2_[pzt3904 -]
# DDL_e1_W_POS_L_2_R_2_[NNP NN]_[NN :]
# DDL_e1_W_POS_L_1_R_2_[NN]_[NN :]
# DDL_e1_W_RIGHT_POS_2_[NN :]
# DDL_e1_W_POS_L_3_R_1_[NNP NNP NN]_[NN]
# DDL_e1_W_LEMMA_L_1_R_1_[2n3904]_[pzt3904]
# DDL_e1_W_LEMMA_L_1_R_3_[2n3904]_[pzt3904 - NPN]
# DDL_e1_W_LEMMA_L_2_R_3_[Amplifier 2n3904]_[pzt3904 - NPN]
# DDL_e1_W_LEMMA_L_2_R_2_[Amplifier 2n3904]_[pzt3904 -]
# DDL_e1_W_POS_L_3_R_3_[NNP NNP NN]_[NN : NNP]
# DDL_e1_W_LEMMA_L_2_R_1_[Amplifier 2n3904]_[pzt3904]
# DDL_e1_W_POS_L_2_R_1_[NNP NN]_[NN]
# DDL_e1_W_POS_L_3_R_2_[NNP NNP NN]_[NN :]
# DDL_e1_W_LEMMA_L_3_R_2_[General-Purpose Amplifier 2n3904]_[pzt3904 -]
# DDL_e1_W_LEMMA_L_3_R_3_[General-Purpose Amplifier 2n3904]_[pzt3904 - NPN]
# DDL_e1_W_RIGHT_1_[pzt3904]
# DDL_e1_W_LEFT_POS_3_[NNP NNP NN]
# DDL_e1_W_LEMMA_L_1_R_2_[2n3904]_[pzt3904 -]
# DDL_e1_W_POS_L_2_R_3_[NNP NN]_[NN : NNP]
# DDL_e1_W_LEFT_3_[General-Purpose Amplifier 2n3904]
# DDL_e1_W_LEFT_POS_2_[NNP NN]
# DDL_e1_W_LEFT_2_[Amplifier 2n3904]
# DDL_e1_W_RIGHT_3_[pzt3904 - NPN]
# DDL_e1_W_RIGHT_POS_3_[NN : NNP]
# DDL_e1_W_LEFT_POS_3_[NN : NN]
# DDL_e1_W_LEMMA_L_2_R_1_[/ pzt3904]_[/]
# DDL_e1_W_LEMMA_L_2_R_2_[/ pzt3904]_[/ mmbt3904]
# DDL_e1_W_LEMMA_L_1_R_2_[pzt3904]_[/ mmbt3904]
# DDL_e1_W_LEFT_3_[mmbt3904 / pzt3904]
# DDL_e1_W_POS_L_2_R_1_[: NN]_[:]
# DDL_e1_W_POS_L_3_R_2_[NN : NN]_[: NN]
# DDL_e1_W_LEMMA_L_3_R_2_[mmbt3904 / pzt3904]_[/ mmbt3904]
# DDL_e1_W_LEMMA_L_1_R_3_[pzt3904]_[/ mmbt3904 /]
# DDL_e1_W_LEMMA_L_1_R_1_[pzt3904]_[/]
# DDL_e1_W_POS_L_3_R_1_[NN : NN]_[:]
# DDL_e1_W_POS_L_1_R_3_[NN]_[: NN :]
# DDL_e1_W_POS_L_3_R_3_[NN : NN]_[: NN :]
# DDL_e1_W_LEMMA_L_2_R_3_[/ pzt3904]_[/ mmbt3904 /]
# DDL_e1_W_POS_L_1_R_2_[NN]_[: NN]
# DDL_e1_W_LEFT_2_[/ pzt3904]
# DDL_e1_W_LEMMA_L_3_R_3_[mmbt3904 / pzt3904]_[/ mmbt3904 /]
# DDL_e1_W_POS_L_2_R_3_[: NN]_[: NN :]
# DDL_e1_W_POS_L_2_R_2_[: NN]_[: NN]
# DDL_e1_W_LEMMA_L_3_R_1_[mmbt3904 / pzt3904]_[/]
# DDL_e1_WORD_SEQ_[BC859 , BC860]
# DDL_e1_LEMMA_SEQ_[bc859 , bc860]
# DDL_e1_DEP_SEQ_[dep punct appos]
# DDL_e1_W_LEFT_1_[dtc114ye]
# STR_e1_HTML_ATTR_style=padding-top: 15pt;padding-left: 42pt;text-indent: 0pt;text-align: left;
# STR_e1_NODE_POS_18
# TDL_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|figure]
# TDL_LEMMA:BETWEEN-MENTION-and-MENTION[figure]
# DDL_e1_W_LEMMA_L_3_R_1_[bc182 , bc182b]_[bc182b]
# DDL_e1_W_POS_L_3_R_1_[NN , NN]_[NN]
# DDL_e1_W_LEMMA_L_2_R_1_[, bc182b]_[bc182b]
# DDL_e1_W_LEMMA_L_1_R_1_[bc182b]_[bc182b]
# DDL_e1_W_POS_L_2_R_1_[, NN]_[NN]
# DDL_e1_W_RIGHT_1_[bc182b]
# DDL_e1_WORD_SEQ_[BC182 ,]
# DDL_e1_LEMMA_SEQ_[bc182 ,]
# DDL_e1_WORD_SEQ_[BC860]
# DDL_e1_LEMMA_SEQ_[bc860]
# DDL_e1_LEMMA_SEQ_[bc182b]
# TDL_INV_LEMMA:BETWEEN-MENTION-and-MENTION[bc182]
# DDL_e1_W_LEFT_POS_3_[NN NN ,]
# TDL_INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|bc182]
# DDL_e1_W_LEFT_3_[bc182b bc182 ,]
# DDL_e1_W_LEFT_2_[bc182 ,]
# DDL_e1_WORD_SEQ_[BC182B]
# TDL_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|pzt3904 dep|Amplifier]
# TAB_e1_ROW_NUM_[3]
# DDL_e1_W_POS_L_2_R_1_[NN NN]_[:]
# DDL_e1_W_POS_L_2_R_3_[NN NN]_[: NNP NNP]
# DDL_e1_W_LEMMA_L_3_R_2_[Amplifier 2n3904 mmbt3904]_[- NPN]
# DDL_e1_W_POS_L_1_R_3_[NN]_[: NNP NNP]
# DDL_e1_W_LEMMA_L_3_R_3_[Amplifier 2n3904 mmbt3904]_[- NPN General-Purpose]
# DDL_e1_W_LEMMA_L_3_R_1_[Amplifier 2n3904 mmbt3904]_[-]
# DDL_e1_W_LEMMA_L_2_R_3_[2n3904 mmbt3904]_[- NPN General-Purpose]
# DDL_e1_W_LEMMA_L_2_R_2_[2n3904 mmbt3904]_[- NPN]
# DDL_e1_W_LEMMA_L_1_R_1_[mmbt3904]_[-]
# DDL_e1_W_LEMMA_L_1_R_2_[mmbt3904]_[- NPN]
# DDL_e1_W_POS_L_3_R_3_[NNP NN NN]_[: NNP NNP]
# DDL_e1_W_POS_L_2_R_2_[NN NN]_[: NNP]
# DDL_e1_W_LEMMA_L_2_R_1_[2n3904 mmbt3904]_[-]
# DDL_e1_W_POS_L_3_R_2_[NNP NN NN]_[: NNP]
# DDL_e1_W_POS_L_3_R_1_[NNP NN NN]_[:]
# DDL_e1_W_LEMMA_L_1_R_3_[mmbt3904]_[- NPN General-Purpose]
# DDL_e1_W_POS_L_1_R_2_[NN]_[: NNP]
# TAB_e1_ROW_HEAD_WORDS_[2n3904tar]
# TAB_e1_ROW_WORDS_[2n3904tar]
# TAB_e1_ROW_HEAD_WORDS_[2n3904bu]
# TAB_e1_ROW_WORDS_[2n3904bu]
# DDL_e1_W_RIGHT_POS_1_[-LRB-]
# DDL_e1_W_LEFT_POS_3_[NN -RRB- .]
# DDL_e1_W_RIGHT_1_[(]
# DDL_e1_W_POS_L_2_R_3_[-RRB- .]_[-LRB- NN -RRB-]
# DDL_e1_W_LEFT_3_[sot-523 ) .]
# DDL_e1_W_POS_L_3_R_3_[NN -RRB- .]_[-LRB- NN -RRB-]
# DDL_e1_W_RIGHT_POS_2_[-LRB- NN]
# DDL_e1_W_POS_L_1_R_3_[.]_[-LRB- NN -RRB-]
# DDL_e1_W_POS_L_1_R_2_[.]_[-LRB- NN]
# DDL_e1_W_LEMMA_L_1_R_3_[.]_[( sot-523 )]
# DDL_e1_W_POS_L_2_R_2_[-RRB- .]_[-LRB- NN]
# DDL_e1_W_LEMMA_L_2_R_1_[) .]_[(]
# DDL_e1_W_POS_L_1_R_1_[.]_[-LRB-]
# DDL_e1_W_RIGHT_2_[( sot-523]
# DDL_e1_W_LEMMA_L_2_R_3_[) .]_[( sot-523 )]
# DDL_e1_W_LEMMA_L_3_R_1_[sot-523 ) .]_[(]
# DDL_e1_W_LEMMA_L_1_R_1_[.]_[(]
# DDL_e1_W_RIGHT_3_[( sot-523 )]
# DDL_e1_W_POS_L_3_R_1_[NN -RRB- .]_[-LRB-]
# DDL_e1_W_RIGHT_POS_3_[-LRB- NN -RRB-]
# DDL_e1_W_LEMMA_L_2_R_2_[) .]_[( sot-523]
# DDL_e1_W_LEMMA_L_1_R_2_[.]_[( sot-523]
# DDL_e1_W_POS_L_3_R_2_[NN -RRB- .]_[-LRB- NN]
# DDL_e1_W_LEMMA_L_3_R_3_[sot-523 ) .]_[( sot-523 )]
# DDL_e1_W_POS_L_2_R_1_[-RRB- .]_[-LRB-]
# DDL_e1_W_LEMMA_L_3_R_2_[sot-523 ) .]_[( sot-523]
# DDL_e1_W_LEFT_POS_2_[-RRB- .]
# DDL_e1_W_LEFT_2_[) .]
# TAB_e1_ROW_HEAD_WORDS_[2n3904ta]
# TAB_e1_ROW_WORDS_[2n3904ta]
# DDL_e1_LEMMA_SEQ_[bc859]
# DDL_e1_WORD_SEQ_[BC859]
# DDL_e1_LEMMA_SEQ_[figure : bc856/857/858]
# DDL_e1_W_LEFT_2_[bc856/857/858 noise]
# DDL_e1_WORD_SEQ_[Figure : BC856/857/858]
# DDL_e1_W_LEFT_3_[: bc856/857/858 noise]
# DDL_e1_W_LEFT_POS_3_[: NN NN]
# DDL_e1_W_LEFT_2_[noise figure]
# DDL_e1_LEMMA_SEQ_[: bc856/857/858]
# DDL_e1_DEP_SEQ_[punct dep]
# DDL_e1_W_LEFT_1_[figure]
# DDL_e1_W_LEFT_3_[bc856/857/858 noise figure]
# DDL_e1_WORD_SEQ_[: BC856/857/858]
# STR_e1_HTML_ATTR_style=padding-top: 1pt;padding-left: 27pt;text-indent: 0pt;text-align: left;
# TAB_e1_ROW_WORDS_[3904]
# VIZ_e1_ALIGNED_RIGHT_description
# TAB_e1_ROW_WORDS_[4l]
# TAB_e1_ROW_WORDS_[sot-223]
# VIZ_e1_ALIGNED_description
# TAB_e1_ROW_WORDS_[2500]
# TAB_e1_ROW_NUM_[7]
# TAB_e1_ROW_WORDS_[sot-223 4l]
# TAB_e1_ROW_WORDS_[figure :]
# DDL_e1_W_LEFT_2_[figure :]
# DDL_e1_W_LEFT_3_[noise figure :]
# TAB_e1_CELL_WORDS_[figure :]
# DDL_e1_W_POS_L_1_R_1_[NN]_[,]
# DDL_e1_W_RIGHT_2_[, bc182b]
# DDL_e1_W_POS_L_3_R_1_[NN , NN]_[,]
# DDL_e1_W_POS_L_2_R_2_[, NN]_[, NN]
# DDL_e1_W_LEMMA_L_1_R_1_[bc182b]_[,]
# DDL_e1_W_LEMMA_L_2_R_1_[, bc182b]_[,]
# DDL_e1_W_POS_L_3_R_2_[NN , NN]_[, NN]
# DDL_e1_W_LEMMA_L_3_R_1_[bc182 , bc182b]_[,]
# DDL_e1_W_LEMMA_L_2_R_2_[, bc182b]_[, bc182b]
# DDL_e1_W_POS_L_1_R_2_[NN]_[, NN]
# DDL_e1_W_LEMMA_L_3_R_2_[bc182 , bc182b]_[, bc182b]
# DDL_e1_W_LEMMA_L_1_R_2_[bc182b]_[, bc182b]
# DDL_e1_W_POS_L_2_R_1_[, NN]_[,]
# DDL_e1_W_LEMMA_L_2_R_3_[General-Purpose Amplifier]_[mmbt3904 pzt3904 -]
# DDL_e1_W_RIGHT_2_[mmbt3904 pzt3904]
# DDL_e1_W_POS_L_3_R_3_[NNP NNP NNP]_[NN NN :]
# DDL_e1_W_POS_L_1_R_2_[NNP]_[NN NN]
# DDL_e1_W_LEMMA_L_2_R_1_[General-Purpose Amplifier]_[mmbt3904]
# DDL_e1_W_LEMMA_L_2_R_2_[General-Purpose Amplifier]_[mmbt3904 pzt3904]
# DDL_e1_W_POS_L_1_R_3_[NNP]_[NN NN :]
# DDL_e1_W_POS_L_2_R_3_[NNP NNP]_[NN NN :]
# DDL_e1_W_POS_L_3_R_1_[NNP NNP NNP]_[NN]
# DDL_e1_W_LEMMA_L_1_R_2_[Amplifier]_[mmbt3904 pzt3904]
# DDL_e1_W_LEMMA_L_3_R_1_[NPN General-Purpose Amplifier]_[mmbt3904]
# DDL_e1_W_RIGHT_3_[mmbt3904 pzt3904 -]
# DDL_e1_W_LEMMA_L_3_R_3_[NPN General-Purpose Amplifier]_[mmbt3904 pzt3904 -]
# DDL_e1_W_RIGHT_POS_2_[NN NN]
# TDL_LEMMA:RIGHT-OF-MENTION[mmbt3904]
# DDL_e1_W_LEMMA_L_3_R_2_[NPN General-Purpose Amplifier]_[mmbt3904 pzt3904]
# DDL_e1_W_RIGHT_POS_3_[NN NN :]
# DDL_e1_W_POS_L_3_R_2_[NNP NNP NNP]_[NN NN]
# DDL_e1_W_POS_L_2_R_1_[NNP NNP]_[NN]
# DDL_e1_W_POS_L_2_R_2_[NNP NNP]_[NN NN]
# DDL_e1_W_LEMMA_L_1_R_1_[Amplifier]_[mmbt3904]
# DDL_e1_W_POS_L_1_R_1_[NNP]_[NN]
# DDL_e1_W_LEMMA_L_1_R_3_[Amplifier]_[mmbt3904 pzt3904 -]
# DDL_e1_W_LEFT_POS_3_[NN NN NN]
# TDL_LEMMA:SEQ-BETWEEN[- NPN]
# TDL_LEMMA:SEQ-BETWEEN[- NPN General-Purpose]
# TDL_INV_LEMMA:SEQ-BETWEEN[figure]
# TAB_e1_ROW_HEAD_WORDS_[2n3904tfr]
# TAB_e1_ROW_WORDS_[2n3904tfr]
# VIZ_VERT_ALIGNED_RIGHT
# TAB_e1_ROW_HEAD_WORDS_[2n3904tf]
# TAB_e1_ROW_WORDS_[2n3904tf]
# DDL_e1_LEMMA_SEQ_[dtc114eua]
# DDL_e1_WORD_SEQ_[DTC114EUA]
# STR_e1_HTML_ATTR_style=padding-left: 5pt;text-indent: 0pt;text-align: left;
# DDL_e1_W_LEFT_1_[dtc114eua]
# DDL_e1_W_LEFT_1_[bc182]
# DDL_e1_LEMMA_SEQ_[bc856]
# DDL_e1_WORD_SEQ_[BC856]
# DDL_e1_W_LEFT_2_[bc856 :]
# DDL_e1_W_LEFT_3_[: bc856 :]
# STR_e1_HTML_ATTR_style=padding-top: 1pt;padding-left: 3pt;text-indent: 0pt;text-align: left;
# DDL_e1_W_LEFT_1_[bc182g]
# DDL_e1_WORD_SEQ_[BC182G]
# DDL_e1_LEMMA_SEQ_[bc182g]
# VIZ_e1_ALIGNED_unit
# STR_e1_HTML_ATTR_style=padding-top: 3pt;padding-left: 4pt;text-indent: 0pt;text-align: left;
# DDL_e1_W_LEFT_1_[bc182bg]
# DDL_e1_LEMMA_SEQ_[bc182bg]
# VIZ_e1_ALIGNED_Y_bulk
# VIZ_e1_ALIGNED_Y_unit
# VIZ_e1_ALIGNED_bulk
# DDL_e1_WORD_SEQ_[BC182BG]
# TDL_LEMMA:SEQ-BETWEEN[/ pzt3904 -]
# TDL_DEP_LABEL:BETWEEN-MENTION-and-MENTION[dep dep dep]
# TDL_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[dep|mmbt3904 dep|pzt3904]
# TDL_LEMMA:BETWEEN-MENTION-and-MENTION[mmbt3904 pzt3904 Amplifier]
# TDL_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[dep|mmbt3904 dep|pzt3904 dep|Amplifier]
# TDL_LEMMA:BETWEEN-MENTION-and-MENTION[mmbt3904 pzt3904]
# DDL_e1_W_LEFT_1_[bc182brl1g]
# TAB_e1_ROW_WORDS_[2000 /]
# TAB_e1_ROW_WORDS_[tape &]
# DDL_e1_WORD_SEQ_[BC182BRL1G]
# TAB_e1_ROW_WORDS_[&]
# TAB_e1_ROW_WORDS_[& reel]
# TAB_e1_ROW_WORDS_[/ tape]
# STR_e1_HTML_ATTR_style=padding-top: 2pt;padding-left: 3pt;text-indent: 0pt;text-align: left;
# DDL_e1_LEMMA_SEQ_[bc182brl1g]
# TAB_e1_ROW_WORDS_[1.2]
# VIZ_e1_ALIGNED_RIGHT_current
# STR_e1_HTML_ATTR_style=padding-left: 9pt;text-indent: 0pt;line-height: 8pt;text-align: center;
# VIZ_e1_ALIGNED_RIGHT_collector
# TAB_e1_ROW_WORDS_[1a]
# STR_e1_HTML_ATTR_style=padding-top: 1pt;padding-left: 22pt;text-indent: 0pt;text-align: left;
# TAB_e1_ROW_NUM_[6]
# TAB_e1_ROW_WORDS_[sot-23]
# TAB_e1_ROW_WORDS_[sot-23 3l]
# TAB_e1_ROW_WORDS_[3000]
# DDL_e1_WORD_SEQ_[: BC859/860]
# DDL_e1_LEMMA_SEQ_[: bc859/860]
# DDL_e1_W_LEFT_2_[: bc859/860]
# DDL_e1_W_LEFT_1_[bc859/860]
# TDL_INV_LEMMA:BETWEEN-MENTION-and-MENTION[bc859]

# %%
from hardware_utils import entity_to_candidates

entity = FP_list[0]
matches = entity_to_candidates(entity, fp)
print "Entity: (%d matches)" % len(matches)
print entity

candidate = matches[0]
print "\nCandidate:"
print candidate

print "\nScore:"
print disc_model.get_candidate_score(candidate, F_dev)

print "\nFeatures:"
pprint(disc_model.get_candidate_feature_weights(candidate, F_dev))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-fa7e04ce4e08> in <module>()
#       1 from hardware_utils import entity_to_candidates
#       2
# ----> 3 entity = FP_list[0]
#       4 matches = entity_to_candidates(entity, fp)
#       5 print "Entity: (%d matches)" % len(matches)
#
# IndexError: list index out of range

# %%
from hardware_utils import part_error_analysis
part_error_analysis(candidate)
