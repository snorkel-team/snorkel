# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import sys
sys.path.append(os.environ['SNORKELHOME'] + '/tutorials/tables/')
snorkel_postgres = os.environ.get('SNORKELDB','').startswith('postgres')
print snorkel_postgres

PARALLEL = 3
PARALLEL_EXTRACTION = 3
# Out:
# False

# %% [markdown]
# ### Parse

# %%
# If necessary:
import os
if snorkel_postgres:
    os.environ['SNORKELDBNAME'] = 'parts_regex_dev'
    os.system("dropdb " + os.environ['SNORKELDBNAME'])
    os.system("createdb " + os.environ['SNORKELDBNAME'])
else:
    try:
        os.remove('snorkel.db')
    except:
        pass

from snorkel import SnorkelSession
session = SnorkelSession()

# %%
import os

docs_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/dev/html/DISES00490-1.html'
pdf_path = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/dev/pdf/'

if snorkel_postgres:
    from snorkel.async_parser import parse_corpus, HTMLParser, AsyncOmniParser
   
    # PARSE DEV
    print "Starting async parse..."
    doc_parser = HTMLParser()
    context_parser = AsyncOmniParser(blacklist=['style'], flatten=['span','br'], 
                                     tabular=True, lingual=True,
                                     visual=True, pdf_path=pdf_path)
    # %time corpus = parse_corpus(session, 'Hardware Dev', docs_path,\
                                doc_parser, context_parser,\
                                max_docs=125, parallel=PARALLEL)
    
else:
    from snorkel.parser import CorpusParser, HTMLParser, OmniParser
    from snorkel.utils import get_ORM_instance

    # PARSE DEV
    print "Starting sync parse..."
    doc_parser = HTMLParser(path=docs_path)
    context_parser = OmniParser(blacklist=['style'], flatten=['span','br'], 
                                tabular=True, lingual=True,
                                visual=True, pdf_path=pdf_path)
    cp = CorpusParser(doc_parser, context_parser, max_docs=125)
    # %time corpus = cp.parse_corpus(name='Hardware Dev', session=session)

    session.add(corpus)
    session.commit()

print "%s contains %d documents" % (corpus, len(corpus))
# Out:
# Starting sync parse...
# [========================================] 100%
# CPU times: user 556 ms, sys: 40 ms, total: 596 ms
# Wall time: 1.87 s
# Corpus (Hardware Dev) contains 1 documents

# %%
# If necessary:
if not snorkel_postgres:
    import os
    os.system('cp snorkel.db snorkel.db\ corpus');

# %% [markdown]
# ### Load

# %%
from snorkel.models import Corpus
import os, sys

os.system('cp snorkel.db\ corpus snorkel.db');
from snorkel import SnorkelSession
session = SnorkelSession()

sys.path.append(os.environ['SNORKELHOME'] + '/tutorials/tables/')
snorkel_postgres = False
print snorkel_postgres

corpus = session.query(Corpus).filter(Corpus.name == 'Hardware Dev').one()
print "%s contains %d Documents" % (corpus, len(corpus))
# Out:
# False
# Corpus (Hardware Dev) contains 1 Documents

# %% [markdown]
# ### Extraction

# %%
from snorkel.models import candidate_subclass
from hardware_spaces import get_space
from hardware_matchers import get_matcher

Part = candidate_subclass('Part', ['part'])
part_ngrams = get_space('part')
dict_path = os.environ['SNORKELHOME'] +\
    '/tutorials/tables/data/hardware/gold_raw/digikey_part_dictionary.csv'
part_matcher = get_matcher('part', dict_path=dict_path)
# Out:
# Using combined matcher.

# %%
# Attempt at alternative regex:
# from snorkel.matchers import RegexMatchSpan, Inverse, Intersect
# long_enough = RegexMatchSpan(rgx='[A-Z2][A-Z0-9\-]{4,}(?:\/(?:DG|HF))?', ignore_case=False)
# at_least_one_number = RegexMatchSpan(rgx='[A-Z0-9\-\/]*[0-9][A-Z0-9\-\/]*', ignore_case=False)
# at_least_one_letter = RegexMatchSpan(rgx='[A-Z0-9\-\/]*[A-Z][A-Z0-9\-\/]*', ignore_case=False) 
# bad_form = Inverse(RegexMatchSpan(rgx='(?:[A-Z]+\d)|(?:[A-Z0-9\-\/]{0,2}\-[A-Z0-9\-\/]*)'))
# bad_start = Inverse(RegexMatchSpan(rgx='(?:T[O0]|SOT|BRD|FIGURE|EHP)[A-Z0-9\-\/]*'))
# bad_end = Inverse(RegexMatchSpan(rgx='[A-Z0-9\-\/]*(TYP|MAX|MIN|BASE|HZ|MM|VDC|VDF)'))
# part_matcher = Intersect(long_enough, at_least_one_number, at_least_one_letter, 
#                          bad_form, bad_start, bad_end)

# %% [markdown]
# ### Throttlers

# %%
# from hardware_throttlers import get_part_throttler_wrapper
from hardware_lfs import get_lfs
from collections import namedtuple
from pdb import set_trace as t

# Option A: No throttler
part_throttler = None

# Option B: Standard throttler
# part_throttler = get_part_throttler_wrapper()

# Option C: LF-based throttler
# FakeCandidate = namedtuple('FakeCandidate',['part','attr'])
# parts_LFs = get_lfs('part')[:-1]
# def part_throttler(Part):
#     c = FakeCandidate(Part[0], None)
#     for lf in parts_LFs:
#         if lf(c) == -1:
#             return False
#     return True

# Option D: Testing throttler
# def part_throttler(Part):
#     part = Part[0]
#     if part.get_span() == '2N1613':
#         t()
#     return True

# %%
from snorkel.candidates import CandidateExtractor

ce = CandidateExtractor(Part, 
                        [part_ngrams], 
                        [part_matcher],
                        throttler=part_throttler)

# %%
from snorkel.lf_helpers import *
corpus_name = 'Hardware Dev'

if snorkel_postgres:
    from snorkel.async_candidates import parallel_extract
    # %time candidates = parallel_extract(session, ce, corpus, \
                                    corpus_name + ' Candidates', \
                                    parallel=PARALLEL_EXTRACTION)
else:   
    from snorkel.candidates import CandidateExtractor
    # %time candidates = ce.extract(corpus.documents.all(), corpus_name + ' Candidates', session)

print "%s contains %d Candidates" % (candidates, len(candidates))
# Out:
# [========================================] 100%
# CPU times: user 574 ms, sys: 17.5 ms, total: 591 ms
# Wall time: 933 ms
# Candidate Set (Hardware Dev Candidates) contains 38 Candidates

# %%
# If necessary:
if not snorkel_postgres:
    import os
    os.system('cp snorkel.db snorkel.db\ candidates');

# %% [markdown]
# ### Second Pass

# %%
# If necessary:
if not snorkel_postgres:
    import os
    os.system('cp snorkel.db\ candidates snorkel.db');

# %%
from hardware_utils import get_gold_parts_by_doc, get_manual_parts_by_doc
from snorkel.utils import get_ORM_instance
from snorkel.models import Corpus

corpus = get_ORM_instance(Corpus, session, 'Hardware Dev')

# parts_by_doc = get_gold_parts_by_doc()
parts_by_doc = get_manual_parts_by_doc(corpus)
# parts_by_doc = None
# Out:
# Finding part numbers...
# [========================================] 100%
# [set([u'A', u'C', u'B'])]
# > /Users/bradenhancock/snorkel/tutorials/tables/hardware_utils.py(377)generate_parts_by_doc()
# -> if any(s in part[5:] for part in parts):
# (Pdb) c
# > /Users/bradenhancock/snorkel/tutorials/tables/hardware_utils.py(376)generate_parts_by_doc()
# -> import pdb; pdb.set_trace()
# (Pdb) c
# > /Users/bradenhancock/snorkel/tutorials/tables/hardware_utils.py(377)generate_parts_by_doc()
# -> if any(s in part[5:] for part in parts):
# (Pdb) c
# [set([])]
# Appending suffixes...
# [========================================] 100%

# %%
# import cPickle as pickle
# pickle_file = os.environ['SNORKELHOME'] + '/tutorials/tables/sandbox/parts_by_doc_dev.pkl'

# with open(pickle_file, 'w') as f:
#     pickle.dump(parts_by_doc, f)

# %%
# import cPickle as pickle
# pickle_file = os.environ['SNORKELHOME'] + '/tutorials/tables/sandbox/parts_by_doc_dev.pkl'
# with open(pickle_file, 'r') as f:
#     parts_by_doc = pickle.load(f)

# %% [markdown]
# ### Evaluation

# %%
from hardware_utils import get_gold_dict

gold_file = os.environ['SNORKELHOME'] + '/tutorials/tables/data/hardware/dev/hardware_dev_gold.csv'
gold_parts = get_gold_dict(gold_file, doc_on=True, part_on=True, val_on=False)
print "%d gold parts loaded" % len(gold_parts)
# Out:
# 927 gold parts loaded

# %%
from hardware_utils import parts_f1

# %time TP, FP, FN = parts_f1(candidates, gold_parts, parts_by_doc)
# Out:
# ========================================
# Scoring on Entity-Level Gold Data
# ========================================
# Corpus Precision 1.0
# Corpus Recall    0.0151
# Corpus F1        0.0298
# ----------------------------------------
# TP: 14 | FP: 0 | FN: 913
# ========================================
#
# CPU times: user 103 ms, sys: 3.9 ms, total: 107 ms
# Wall time: 106 ms

# %%
from pprint import pprint
pprint(TP)
# Out:
# [(u'DISES00490-1', u'BC846AW'),
#  (u'DISES00490-1', u'BC846BW'),
#  (u'DISES00490-1', u'BC846W'),
#  (u'DISES00490-1', u'BC847AW'),
#  (u'DISES00490-1', u'BC847BW'),
#  (u'DISES00490-1', u'BC847CW'),
#  (u'DISES00490-1', u'BC847W'),
#  (u'DISES00490-1', u'BC848AW'),
#  (u'DISES00490-1', u'BC848BW'),
#  (u'DISES00490-1', u'BC848CW'),
#  (u'DISES00490-1', u'BC848W'),
#  (u'DISES00490-1', u'BC849BW'),
#  (u'DISES00490-1', u'BC849CW'),
#  (u'DISES00490-1', u'BC849W')]

# %%
pprint(FP)
# Out:
# []

# %%
pprint(FN)
# Out:
# [('112823', 'BC546'),
#  ('112823', 'BC546B'),
#  ('112823', 'BC546BG'),
#  ('112823', 'BC546BRL1'),
#  ('112823', 'BC546BRL1G'),
#  ('112823', 'BC546BZL1G'),
#  ('112823', 'BC547'),
#  ('112823', 'BC547A'),
#  ('112823', 'BC547ARL'),
#  ('112823', 'BC547ARLG'),
#  ('112823', 'BC547AZL1G'),
#  ('112823', 'BC547B'),
#  ('112823', 'BC547BG'),
#  ('112823', 'BC547BRL1G'),
#  ('112823', 'BC547BZL1G'),
#  ('112823', 'BC547C'),
#  ('112823', 'BC547CG'),
#  ('112823', 'BC547CZL1G'),
#  ('112823', 'BC548'),
#  ('112823', 'BC548B'),
#  ('112823', 'BC548BG'),
#  ('112823', 'BC548BRL1G'),
#  ('112823', 'BC548BZL1G'),
#  ('112823', 'BC548C'),
#  ('112823', 'BC548CG'),
#  ('112823', 'BC548CZL1G'),
#  ('2N3906', '2N3906'),
#  ('2N3906', '2N3906BU'),
#  ('2N3906', '2N3906TA'),
#  ('2N3906', '2N3906TAR'),
#  ('2N3906', '2N3906TF'),
#  ('2N3906', '2N3906TFR'),
#  ('2N3906', 'MMBT3906'),
#  ('2N3906', 'PZT3906'),
#  ('2N3906-D', '2N3906'),
#  ('2N3906-D', '2N3906G'),
#  ('2N3906-D', '2N3906RL1'),
#  ('2N3906-D', '2N3906RL1G'),
#  ('2N3906-D', '2N3906RLRA'),
#  ('2N3906-D', '2N3906RLRAG'),
#  ('2N3906-D', '2N3906RLRM'),
#  ('2N3906-D', '2N3906RLRMG'),
#  ('2N3906-D', '2N3906RLRP'),
#  ('2N3906-D', '2N3906RLRPG'),
#  ('2N4123-D', '2N4123'),
#  ('2N4123-D', '2N4123RLRM'),
#  ('2N4123-D', '2N4124'),
#  ('2N4123-D', '2N4124G'),
#  ('2N4124', '2N4124'),
#  ('2N4124', 'MMBT4124'),
#  ('2N6426-D', '2N6426'),
#  ('2N6426-D', '2N6426G'),
#  ('2N6426-D', '2N6426RLRAG'),
#  ('2N6426-D', '2N6427'),
#  ('2N6426-D', '2N6427G'),
#  ('2N6426-D', '2N6427RLRAG'),
#  ('2N6427', '2N6427'),
#  ('2N6427', 'MMBT6427'),
#  ('AUKCS04635-1', '2N3906'),
#  ('BC182', 'BC182'),
#  ('BC182-D', 'BC182'),
#  ('BC182-D', 'BC182B'),
#  ('BC182-D', 'BC182BG'),
#  ('BC182-D', 'BC182BRL1G'),
#  ('BC182-D', 'BC182G'),
#  ('BC337', 'BC337'),
#  ('BC337', 'BC337-16'),
#  ('BC337', 'BC337-25'),
#  ('BC337', 'BC337-40'),
#  ('BC337', 'BC33716BU'),
#  ('BC337', 'BC33716TA'),
#  ('BC337', 'BC33716TFR'),
#  ('BC337', 'BC33725BU'),
#  ('BC337', 'BC33725TA'),
#  ('BC337', 'BC33725TAR'),
#  ('BC337', 'BC33725TF'),
#  ('BC337', 'BC33725TFR'),
#  ('BC337', 'BC33740TA'),
#  ('BC337', 'BC338'),
#  ('BC337', 'BC338-25'),
#  ('BC337', 'BC33825TA'),
#  ('BC337-D', 'BC337'),
#  ('BC337-D', 'BC337-025G'),
#  ('BC337-D', 'BC337-040G'),
#  ('BC337-D', 'BC337-25'),
#  ('BC337-D', 'BC337-25RL1G'),
#  ('BC337-D', 'BC337-25RLRAG'),
#  ('BC337-D', 'BC337-25ZL1G'),
#  ('BC337-D', 'BC337-40'),
#  ('BC337-D', 'BC337-40RL1G'),
#  ('BC337-D', 'BC337-40ZL1G'),
#  ('BC337-D', 'BC337G'),
#  ('BC337-D', 'BC337RL1G'),
#  ('BC546', 'BC546'),
#  ('BC546', 'BC546A'),
#  ('BC546', 'BC546ABU'),
#  ('BC546', 'BC546ATA'),
#  ('BC546', 'BC546B'),
#  ('BC546', 'BC546BTA'),
#  ('BC546', 'BC546BTF'),
#  ('BC546', 'BC546C'),
#  ('BC546', 'BC546CTA'),
#  ('BC546', 'BC547'),
#  ('BC546', 'BC547A'),
#  ('BC546', 'BC547ATA'),
#  ('BC546', 'BC547B'),
#  ('BC546', 'BC547BBU'),
#  ('BC546', 'BC547BTA'),
#  ('BC546', 'BC547BTF'),
#  ('BC546', 'BC547C'),
#  ('BC546', 'BC547CBU'),
#  ('BC546', 'BC547CTA'),
#  ('BC546', 'BC547CTFR'),
#  ('BC546', 'BC548'),
#  ('BC546', 'BC548B'),
#  ('BC546', 'BC548BTA'),
#  ('BC546', 'BC548BU'),
#  ('BC546', 'BC548C'),
#  ('BC546', 'BC548CTA'),
#  ('BC546', 'BC549'),
#  ('BC546', 'BC549B'),
#  ('BC546', 'BC549BTA'),
#  ('BC546', 'BC549BTF'),
#  ('BC546', 'BC549C'),
#  ('BC546', 'BC549CTA'),
#  ('BC546', 'BC550'),
#  ('BC546', 'BC550C'),
#  ('BC546', 'BC550CBU'),
#  ('BC546', 'BC550CTA'),
#  ('BC546-BC548C(TO-92)', 'BC546'),
#  ('BC546-BC548C(TO-92)', 'BC546B'),
#  ('BC546-BC548C(TO-92)', 'BC547'),
#  ('BC546-BC548C(TO-92)', 'BC547A'),
#  ('BC546-BC548C(TO-92)', 'BC547B'),
#  ('BC546-BC548C(TO-92)', 'BC547C'),
#  ('BC546-BC548C(TO-92)', 'BC548'),
#  ('BC546-BC548C(TO-92)', 'BC548A'),
#  ('BC546-BC548C(TO-92)', 'BC548B'),
#  ('BC546-BC548C(TO-92)', 'BC548C'),
#  ('BC546-D', 'BC546'),
#  ('BC546-D', 'BC546B'),
#  ('BC546-D', 'BC546BG'),
#  ('BC546-D', 'BC546BRL1'),
#  ('BC546-D', 'BC546BRL1G'),
#  ('BC546-D', 'BC546BZL1G'),
#  ('BC546-D', 'BC547'),
#  ('BC546-D', 'BC547A'),
#  ('BC546-D', 'BC547ARL'),
#  ('BC546-D', 'BC547ARLG'),
#  ('BC546-D', 'BC547AZL1G'),
#  ('BC546-D', 'BC547B'),
#  ('BC546-D', 'BC547BG'),
#  ('BC546-D', 'BC547BRL1G'),
#  ('BC546-D', 'BC547BZL1G'),
#  ('BC546-D', 'BC547C'),
#  ('BC546-D', 'BC547CG'),
#  ('BC546-D', 'BC547CZL1G'),
#  ('BC546-D', 'BC548'),
#  ('BC546-D', 'BC548B'),
#  ('BC546-D', 'BC548BG'),
#  ('BC546-D', 'BC548BRL1G'),
#  ('BC546-D', 'BC548BZL1G'),
#  ('BC546-D', 'BC548C'),
#  ('BC546-D', 'BC548CG'),
#  ('BC546-D', 'BC548CZL1G'),
#  ('BC546A_SERIES_B14-521026', 'BC546'),
#  ('BC546A_SERIES_B14-521026', 'BC546A'),
#  ('BC546A_SERIES_B14-521026', 'BC546B'),
#  ('BC546A_SERIES_B14-521026', 'BC546C'),
#  ('BC546A_SERIES_B14-521026', 'BC547'),
#  ('BC546A_SERIES_B14-521026', 'BC547A'),
#  ('BC546A_SERIES_B14-521026', 'BC547B'),
#  ('BC546A_SERIES_B14-521026', 'BC547C'),
#  ('BC546A_SERIES_B14-521026', 'BC548'),
#  ('BC546A_SERIES_B14-521026', 'BC548A'),
#  ('BC546A_SERIES_B14-521026', 'BC548B'),
#  ('BC546A_SERIES_B14-521026', 'BC548C'),
#  ('BC546A_SERIES_B14-521026', 'BC549'),
#  ('BC546A_SERIES_B14-521026', 'BC549A'),
#  ('BC546A_SERIES_B14-521026', 'BC549B'),
#  ('BC546A_SERIES_B14-521026', 'BC549C'),
#  ('BC546A_SERIES_B14-521026', 'BC550'),
#  ('BC546A_SERIES_B14-521026', 'BC550A'),
#  ('BC546A_SERIES_B14-521026', 'BC550B'),
#  ('BC546A_SERIES_B14-521026', 'BC550C'),
#  ('BC546_DIOTEC', 'BC546'),
#  ('BC546_DIOTEC', 'BC546A'),
#  ('BC546_DIOTEC', 'BC546B'),
#  ('BC546_DIOTEC', 'BC547'),
#  ('BC546_DIOTEC', 'BC547A'),
#  ('BC546_DIOTEC', 'BC547B'),
#  ('BC546_DIOTEC', 'BC547C'),
#  ('BC546_DIOTEC', 'BC548'),
#  ('BC546_DIOTEC', 'BC548A'),
#  ('BC546_DIOTEC', 'BC548B'),
#  ('BC546_DIOTEC', 'BC548C'),
#  ('BC546_DIOTEC', 'BC549'),
#  ('BC546_DIOTEC', 'BC549B'),
#  ('BC546_DIOTEC', 'BC549C'),
#  ('BC547', 'BC546'),
#  ('BC547', 'BC546A'),
#  ('BC547', 'BC546ABU'),
#  ('BC547', 'BC546ATA'),
#  ('BC547', 'BC546B'),
#  ('BC547', 'BC546BTA'),
#  ('BC547', 'BC546BTF'),
#  ('BC547', 'BC546C'),
#  ('BC547', 'BC546CTA'),
#  ('BC547', 'BC547'),
#  ('BC547', 'BC547A'),
#  ('BC547', 'BC547ATA'),
#  ('BC547', 'BC547B'),
#  ('BC547', 'BC547BBU'),
#  ('BC547', 'BC547BTA'),
#  ('BC547', 'BC547BTF'),
#  ('BC547', 'BC547C'),
#  ('BC547', 'BC547CBU'),
#  ('BC547', 'BC547CTA'),
#  ('BC547', 'BC547CTFR'),
#  ('BC547', 'BC548'),
#  ('BC547', 'BC548B'),
#  ('BC547', 'BC548BTA'),
#  ('BC547', 'BC548C'),
#  ('BC547', 'BC548CTA'),
#  ('BC547', 'BC549'),
#  ('BC547', 'BC549B'),
#  ('BC547', 'BC549BTA'),
#  ('BC547', 'BC549BTF'),
#  ('BC547', 'BC549C'),
#  ('BC547', 'BC549CTA'),
#  ('BC547', 'BC550'),
#  ('BC547', 'BC550C'),
#  ('BC547', 'BC550CBU'),
#  ('BC547', 'BC550CTA'),
#  ('BC550', 'BC546'),
#  ('BC550', 'BC546A'),
#  ('BC550', 'BC546B'),
#  ('BC550', 'BC546C'),
#  ('BC550', 'BC547'),
#  ('BC550', 'BC547A'),
#  ('BC550', 'BC547B'),
#  ('BC550', 'BC547C'),
#  ('BC550', 'BC548'),
#  ('BC550', 'BC548A'),
#  ('BC550', 'BC548B'),
#  ('BC550', 'BC548C'),
#  ('BC550', 'BC549'),
#  ('BC550', 'BC549A'),
#  ('BC550', 'BC549B'),
#  ('BC550', 'BC549C'),
#  ('BC550', 'BC550'),
#  ('BC550', 'BC550A'),
#  ('BC550', 'BC550B'),
#  ('BC550', 'BC550C'),
#  ('BC818', 'BC817'),
#  ('BC818', 'BC817-16'),
#  ('BC818', 'BC817-25'),
#  ('BC818', 'BC817-40'),
#  ('BC818', 'BC81716MTF'),
#  ('BC818', 'BC81725MTF'),
#  ('BC818', 'BC81740MTF'),
#  ('BC818', 'BC818'),
#  ('BC818', 'BC818-16'),
#  ('BC818', 'BC818-25'),
#  ('BC818', 'BC818-40'),
#  ('BC818', 'BC81816MTF'),
#  ('BC818', 'BC81825MTF'),
#  ('BC818', 'BC81840MTF'),
#  ('BC818-40LT1-D', 'BC818-40L'),
#  ('BC818-40LT1-D', 'BC818-40LT1G'),
#  ('BC818-40LT1-D', 'NSVBC818-40L'),
#  ('BC818-40LT1-D', 'NSVBC818-40LT1G'),
#  ('BOURNSINC_BD246BS', 'BD246'),
#  ('BOURNSINC_BD246BS', 'BD246A'),
#  ('BOURNSINC_BD246BS', 'BD246B'),
#  ('BOURNSINC_BD246BS', 'BD246C'),
#  ('BOURNSINC_TIP152S', 'TIP150'),
#  ('BOURNSINC_TIP152S', 'TIP151'),
#  ('BOURNSINC_TIP152S', 'TIP152'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N3576'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N3672'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N3700'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N3701'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N3798A'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N3799A'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N3829'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N3946'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N3947'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N3962'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N3963'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N3964'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N3965'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N4013'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N4014'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N4026'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N4027'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N4028'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N4029'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N4034'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N4035'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N4068'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N4137'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N4207'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N4208'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N4209'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N4269'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N4359'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N4384'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N4386'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N4390'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N4413A'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N4415A'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N4962'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N4963'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N5056'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', '2N5057'),
#  ('CENTRALSEMICONDUCTORCORP_2N4013', 'CM4209'),
#  ('CENTRALSEMICONDUCTORCORP_CENU45', 'CEN-U45'),
#  ('CENTRALSEMICONDUCTORCORP_CMPT5401ETR', 'CMPT5401E'),
#  ('CENTRALSEMICONDUCTORCORP_CXT4033TR', 'CXT4033'),
#  ('CSEMS02742-1', 'BC846'),
#  ('CSEMS02742-1', 'BC846A'),
#  ('CSEMS02742-1', 'BC846B'),
#  ('CSEMS02742-1', 'BC847'),
#  ('CSEMS02742-1', 'BC847A'),
#  ('CSEMS02742-1', 'BC847B'),
#  ('CSEMS02742-1', 'BC847C'),
#  ('CSEMS02742-1', 'BC848'),
#  ('CSEMS02742-1', 'BC848A'),
#  ('CSEMS02742-1', 'BC848B'),
#  ('CSEMS02742-1', 'BC848C'),
#  ('CSEMS03485-1', '2N3905'),
#  ('CSEMS03485-1', '2N3906'),
#  ('CSEMS05382-1', 'BC546'),
#  ('CSEMS05382-1', 'BC546A'),
#  ('CSEMS05382-1', 'BC546B'),
#  ('CSEMS05382-1', 'BC547'),
#  ('CSEMS05382-1', 'BC547A'),
#  ('CSEMS05382-1', 'BC547B'),
#  ('CSEMS05382-1', 'BC547C'),
#  ('CSEMS05382-1', 'BC548'),
#  ('CSEMS05382-1', 'BC548A'),
#  ('CSEMS05382-1', 'BC548B'),
#  ('CSEMS05382-1', 'BC548C'),
#  ('CSEMS05383-1', 'BC817'),
#  ('CSEMS05383-1', 'BC817-16'),
#  ('CSEMS05383-1', 'BC817-25'),
#  ('CSEMS05383-1', 'BC817-40'),
#  ('CSEMS05383-1', 'BC818'),
#  ('CSEMS05383-1', 'BC818-16'),
#  ('CSEMS05383-1', 'BC818-25'),
#  ('CSEMS05383-1', 'BC818-40'),
#  ('DIODESINCORPORATED_2DD26527', '2DD2652'),
#  ('DIODESINCORPORATED_2DD26527', '2DD2652-7'),
#  ('DIODESINCORPORATED_FCX491ATA', 'FCX491A'),
#  ('DIODESINCORPORATED_FZT651TC', 'FZT651'),
#  ('DIODESINCORPORATED_FZT651TC', 'FZT651TA'),
#  ('DIODESINCORPORATED_FZT651TC', 'FZT651TC'),
#  ('DIODESINCORPORATED_ZTX688BSTZ', 'ZTX688B'),
#  ('DIODESINCORPORATED_ZTX789ASTZ', 'ZTX789A'),
#  ('DIODESINCORPORATED_ZTX953STZ', 'ZTX953'),
#  ('DIODESINCORPORATED_ZXT690BKTC', 'ZXT690BK'),
#  ('DIODESINCORPORATED_ZXT690BKTC', 'ZXT690BKQTC'),
#  ('DIODESINCORPORATED_ZXT690BKTC', 'ZXT690BKTC'),
#  ('DIODS00215-1', '2N4124'),
#  ('DIODS13249-1', 'BC817'),
#  ('DIODS13249-1', 'BC817-16'),
#  ('DIODS13249-1', 'BC817-25'),
#  ('DIODS13249-1', 'BC817-40'),
#  ('DIODS13249-1', 'BC818'),
#  ('DIODS13249-1', 'BC818-16'),
#  ('DIODS13249-1', 'BC818-25'),
#  ('DIODS13249-1', 'BC818-40'),
#  ('DISES00023-1', '2N3906'),
#  ('DISES00189-1', 'BC546'),
#  ('DISES00189-1', 'BC546A'),
#  ('DISES00189-1', 'BC546B'),
#  ('DISES00189-1', 'BC547'),
#  ('DISES00189-1', 'BC547A'),
#  ('DISES00189-1', 'BC547B'),
#  ('DISES00189-1', 'BC547C'),
#  ('DISES00189-1', 'BC548'),
#  ('DISES00189-1', 'BC548A'),
#  ('DISES00189-1', 'BC548B'),
#  ('DISES00189-1', 'BC548C'),
#  ('DISES00189-1', 'BC549'),
#  ('DISES00189-1', 'BC549B'),
#  ('DISES00189-1', 'BC549C'),
#  ('DISES00192-1', 'BC807'),
#  ('DISES00192-1', 'BC807-16'),
#  ('DISES00192-1', 'BC807-25'),
#  ('DISES00192-1', 'BC807-40'),
#  ('DISES00192-1', 'BC808'),
#  ('DISES00192-1', 'BC808-16'),
#  ('DISES00192-1', 'BC808-25'),
#  ('DISES00192-1', 'BC808-40'),
#  ('DISES00242-1', 'MMBT3904'),
#  ('DISES00616-1', 'BC856'),
#  ('DISES00616-1', 'BC856A'),
#  ('DISES00616-1', 'BC856B'),
#  ('DISES00616-1', 'BC856C'),
#  ('DISES00616-1', 'BC857'),
#  ('DISES00616-1', 'BC857A'),
#  ('DISES00616-1', 'BC857B'),
#  ('DISES00616-1', 'BC857C'),
#  ('DISES00616-1', 'BC858'),
#  ('DISES00616-1', 'BC858A'),
#  ('DISES00616-1', 'BC858B'),
#  ('DISES00616-1', 'BC858C'),
#  ('DISES00616-1', 'BC859'),
#  ('DISES00616-1', 'BC859B'),
#  ('DISES00616-1', 'BC859C'),
#  ('DISES00616-1', 'BC860'),
#  ('DISES00616-1', 'BC860B'),
#  ('DISES00616-1', 'BC860C'),
#  ('DISES00645-1', 'BC817K'),
#  ('DISES00645-1', 'BC817K-16'),
#  ('DISES00645-1', 'BC817K-25'),
#  ('DISES00645-1', 'BC817K-40'),
#  ('DISES00645-1', 'BC818K'),
#  ('DISES00645-1', 'BC818K-16'),
#  ('DISES00645-1', 'BC818K-25'),
#  ('DISES00645-1', 'BC818K-40'),
#  ('DTC114W', 'DTC114W'),
#  ('DTC114W', 'DTC114WE'),
#  ('DTC114W', 'DTC114WKA'),
#  ('DTC114W', 'DTC114WUA'),
#  ('FAIRCHILDSEMICONDUCTOR_KSC2310YTA', 'KSC2310'),
#  ('FAIRCHILDSEMICONDUCTOR_KSC2310YTA', 'KSC2310O'),
#  ('FAIRCHILDSEMICONDUCTOR_KSC2310YTA', 'KSC2310R'),
#  ('FAIRCHILDSEMICONDUCTOR_KSC2310YTA', 'KSC2310Y'),
#  ('FAIRS19194-1', 'BC856'),
#  ('FAIRS19194-1', 'BC856A'),
#  ('FAIRS19194-1', 'BC856B'),
#  ('FAIRS19194-1', 'BC856C'),
#  ('FAIRS19194-1', 'BC857'),
#  ('FAIRS19194-1', 'BC857A'),
#  ('FAIRS19194-1', 'BC857B'),
#  ('FAIRS19194-1', 'BC857C'),
#  ('FAIRS19194-1', 'BC858'),
#  ('FAIRS19194-1', 'BC858A'),
#  ('FAIRS19194-1', 'BC858B'),
#  ('FAIRS19194-1', 'BC858C'),
#  ('FAIRS19194-1', 'BC859'),
#  ('FAIRS19194-1', 'BC859A'),
#  ('FAIRS19194-1', 'BC859B'),
#  ('FAIRS19194-1', 'BC859C'),
#  ('FAIRS19194-1', 'BC860'),
#  ('FAIRS19194-1', 'BC860A'),
#  ('FAIRS19194-1', 'BC860B'),
#  ('FAIRS19194-1', 'BC860C'),
#  ('FAIRS25065-1', 'BC237'),
#  ('FAIRS25065-1', 'BC237A'),
#  ('FAIRS25065-1', 'BC237B'),
#  ('FAIRS25065-1', 'BC237C'),
#  ('FAIRS25065-1', 'BC238'),
#  ('FAIRS25065-1', 'BC238A'),
#  ('FAIRS25065-1', 'BC238B'),
#  ('FAIRS25065-1', 'BC238C'),
#  ('FAIRS25065-1', 'BC239'),
#  ('FAIRS25065-1', 'BC239A'),
#  ('FAIRS25065-1', 'BC239B'),
#  ('FAIRS25065-1', 'BC239C'),
#  ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K'),
#  ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-16'),
#  ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-16W'),
#  ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-25'),
#  ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-25W'),
#  ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-40'),
#  ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817K-40W'),
#  ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC817KW'),
#  ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC818K'),
#  ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC818K-16W'),
#  ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC818K-40'),
#  ('INFINEON-BC817KSERIES_BC818KSERIES-DS-V01_01-EN', 'BC818KW'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC857'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC857A'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC857B'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC857BL3'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC857BW'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC857C'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC857CW'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC858'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC858A'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC858B'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC858BW'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC858C'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC858CW'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC859'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC859C'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC860'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC860B'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC860BW'),
#  ('INFINEON-BC857SERIES_BC858SERIES_BC859SERIES_BC860SERIES-DS-V01_01-EN',
#   'BC860CW'),
#  ('INFNS19372-1', 'MMBT3904'),
#  ('INFNS19372-1', 'SMBT3904'),
#  ('INFNS19372-1', 'SMBT3904S'),
#  ('JCSTS01155-1', '2N4124'),
#  ('KECCS03676-1', 'BC856'),
#  ('KECCS03676-1', 'BC856A'),
#  ('KECCS03676-1', 'BC856B'),
#  ('KECCS03676-1', 'BC857'),
#  ('KECCS03676-1', 'BC857A'),
#  ('KECCS03676-1', 'BC857B'),
#  ('KECCS03676-1', 'BC857C'),
#  ('KECCS03676-1', 'BC858'),
#  ('KECCS03676-1', 'BC858A'),
#  ('KECCS03676-1', 'BC858B'),
#  ('KECCS03676-1', 'BC858C'),
#  ('KECCS05435-1', 'BC546'),
#  ('KECCS05435-1', 'BC546A'),
#  ('KECCS05435-1', 'BC546B'),
#  ('KECCS05435-1', 'BC547'),
#  ('KECCS05435-1', 'BC547A'),
#  ('KECCS05435-1', 'BC547B'),
#  ('KECCS05435-1', 'BC547C'),
#  ('KECCS05435-1', 'BC548'),
#  ('KECCS05435-1', 'BC548A'),
#  ('KECCS05435-1', 'BC548B'),
#  ('KECCS05435-1', 'BC548C'),
#  ('LITES00424-1', '2N3906'),
#  ('LITES00686-1', '2N4124'),
#  ('LITES00689-1', 'BC337'),
#  ('LITES00689-1', 'BC337-16'),
#  ('LITES00689-1', 'BC337-25'),
#  ('LITES00689-1', 'BC337-40'),
#  ('LITES00690-1', 'BC546'),
#  ('LITES00690-1', 'BC546A'),
#  ('LITES00690-1', 'BC546B'),
#  ('LITES00690-1', 'BC546C'),
#  ('LITES00690-1', 'BC547'),
#  ('LITES00690-1', 'BC547A'),
#  ('LITES00690-1', 'BC547B'),
#  ('LITES00690-1', 'BC547C'),
#  ('LITES00690-1', 'BC548'),
#  ('LITES00690-1', 'BC548A'),
#  ('LITES00690-1', 'BC548B'),
#  ('LITES00690-1', 'BC548C'),
#  ('LTSCS02910-1', 'BC818'),
#  ('LTSCS02910-1', 'BC818-16'),
#  ('LTSCS02910-1', 'BC818-25'),
#  ('LTSCS02910-1', 'BC818-40'),
#  ('LTSCS02912-1', 'BC846AW'),
#  ('LTSCS02912-1', 'BC846BW'),
#  ('LTSCS02912-1', 'BC846W'),
#  ('LTSCS02920-1', 'BC857'),
#  ('LTSCS02920-1', 'BC857A'),
#  ('LTSCS02920-1', 'BC857B'),
#  ('LTSCS02920-1', 'BC857C'),
#  ('MCCCS08610-1', '2N4123'),
#  ('MCCCS08610-1', '2N4124'),
#  ('MCCCS08818-1', 'DTC114YE'),
#  ('MCCCS08984-1', 'MMBT3904'),
#  ('MCCCS09540-1', 'BC846'),
#  ('MCCCS09540-1', 'BC846A'),
#  ('MCCCS09540-1', 'BC846B'),
#  ('MCCCS09540-1', 'BC847'),
#  ('MCCCS09540-1', 'BC847A'),
#  ('MCCCS09540-1', 'BC847B'),
#  ('MCCCS09540-1', 'BC847C'),
#  ('MCCCS09540-1', 'BC848'),
#  ('MCCCS09540-1', 'BC848A'),
#  ('MCCCS09540-1', 'BC848B'),
#  ('MCCCS09540-1', 'BC848C'),
#  ('MCCCS09540-1', 'BC849'),
#  ('MCCCS09540-1', 'BC849B'),
#  ('MCCCS09540-1', 'BC849C'),
#  ('MCCCS09741-1', 'BC337'),
#  ('MCCCS09741-1', 'BC337-16'),
#  ('MCCCS09741-1', 'BC337-25'),
#  ('MCCCS09741-1', 'BC337-40'),
#  ('MCCCS09741-1', 'BC338'),
#  ('MCCCS09741-1', 'BC338-16'),
#  ('MCCCS09741-1', 'BC338-25'),
#  ('MCCCS09741-1', 'BC338-40'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904-AP'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904-AP-HF'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904-BP'),
#  ('MICROCOMMERCIALCO_2N3904AP', '2N3904-BP-HF'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29A'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29A-BP'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29A-BP-HF'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29B'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29B-BP'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29B-BP-HF'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29C'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29C-BP'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP29C-BP-HF'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30A'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30A-BP'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30A-BP-HF'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30B'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30B-BP'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30B-BP-HF'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30C'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30C-BP'),
#  ('MICROCOMMERCIALCO_TIP29ABP', 'TIP30C-BP-HF'),
#  ('MICROSEMICORPORATION_2N2484UB', '2N2484UA'),
#  ('MICROSEMICORPORATION_2N2484UB', '2N2484UB'),
#  ('MICROSEMICORPORATION_2N2484UB', '2N2484UBC'),
#  ('MINDS00015-1', '2N3904'),
#  ('MINDS00015-1', 'MMBT3904'),
#  ('MMBT3904', '2N3904'),
#  ('MMBT3904', '2N3904BU'),
#  ('MMBT3904', '2N3904TA'),
#  ('MMBT3904', '2N3904TAR'),
#  ('MMBT3904', '2N3904TF'),
#  ('MMBT3904', '2N3904TFR'),
#  ('MMBT3904', 'MMBT3904'),
#  ('MMBT3904', 'PZT3904'),
#  ('MMMCS17742-1', 'BC807-16W'),
#  ('MMMCS17742-1', 'BC807-25W'),
#  ('MMMCS17742-1', 'BC807-40W'),
#  ('MOTOS03160-1', 'BC182'),
#  ('MOTOS03160-1', 'BC182A'),
#  ('MOTOS03160-1', 'BC182B'),
#  ('MOTOS03160-1', 'BC183'),
#  ('MOTOS03160-1', 'BC184'),
#  ('MOTOS03189-1', 'BC337'),
#  ('MOTOS03189-1', 'BC337-16'),
#  ('MOTOS03189-1', 'BC337-25'),
#  ('MOTOS03189-1', 'BC337-40'),
#  ('MOTOS03189-1', 'BC338'),
#  ('MOTOS03189-1', 'BC338-16'),
#  ('MOTOS03189-1', 'BC338-25'),
#  ('MOTOS03189-1', 'BC338-40'),
#  ('MOTOS04676-1', '2N4123'),
#  ('MOTOS04676-1', '2N4124'),
#  ('MOTOS04796-1', '2N6426'),
#  ('MOTOS04796-1', '2N6427'),
#  ('NXPUSAINC_PBSS5360PASX', 'PBSS5360PAS'),
#  ('ONSEMICONDUCTOR_MMBT6521LT1', 'MMBT6521LT1G'),
#  ('ONSEMICONDUCTOR_MMBT6521LT1', 'SMMBT6521LT1G'),
#  ('ONSMS04099-1', 'BC237'),
#  ('ONSMS04099-1', 'BC237A'),
#  ('ONSMS04099-1', 'BC237B'),
#  ('ONSMS04099-1', 'BC237C'),
#  ('ONSMS04099-1', 'BC238'),
#  ('ONSMS04099-1', 'BC238B'),
#  ('ONSMS04099-1', 'BC238C'),
#  ('ONSMS04099-1', 'BC239'),
#  ('ONSMS04099-1', 'BC239C'),
#  ('PHGLS18216-1', 'BC547'),
#  ('PHGLS18216-1', 'BC547B'),
#  ('PHGLS18216-1', 'BC547C'),
#  ('PHGLS18216-1', 'BC847'),
#  ('PHGLS18216-1', 'BC847A'),
#  ('PHGLS18216-1', 'BC847AM'),
#  ('PHGLS18216-1', 'BC847AT'),
#  ('PHGLS18216-1', 'BC847AT/DG'),
#  ('PHGLS18216-1', 'BC847AW'),
#  ('PHGLS18216-1', 'BC847B'),
#  ('PHGLS18216-1', 'BC847B/DG'),
#  ('PHGLS18216-1', 'BC847BM'),
#  ('PHGLS18216-1', 'BC847BT'),
#  ('PHGLS18216-1', 'BC847BW'),
#  ('PHGLS18216-1', 'BC847BW/DG'),
#  ('PHGLS18216-1', 'BC847C'),
#  ('PHGLS18216-1', 'BC847CM'),
#  ('PHGLS18216-1', 'BC847CT'),
#  ('PHGLS18216-1', 'BC847CW'),
#  ('PHGLS18216-1', 'BC847T'),
#  ('PHGLS18216-1', 'BC847W'),
#  ('PHGLS19500-1', 'MMBT3904'),
#  ('PHGLS20125-1', 'BC327'),
#  ('PHGLS20125-1', 'BC327-16'),
#  ('PHGLS20125-1', 'BC327-25'),
#  ('PHGLS20125-1', 'BC327-40'),
#  ('PHGLS20125-1', 'BC807'),
#  ('PHGLS20125-1', 'BC807-16'),
#  ('PHGLS20125-1', 'BC807-16W'),
#  ('PHGLS20125-1', 'BC807-25'),
#  ('PHGLS20125-1', 'BC807-25W'),
#  ('PHGLS20125-1', 'BC807-40'),
#  ('PHGLS20125-1', 'BC807-40W'),
#  ('PHGLS20125-1', 'BC807W'),
#  ('PHGLS20126-1', 'BC337'),
#  ('PHGLS20126-1', 'BC337-16'),
#  ('PHGLS20126-1', 'BC337-25'),
#  ('PHGLS20126-1', 'BC337-40'),
#  ('PHGLS20126-1', 'BC817'),
#  ('PHGLS20126-1', 'BC817-16'),
#  ('PHGLS20126-1', 'BC817-16W'),
#  ('PHGLS20126-1', 'BC817-25'),
#  ('PHGLS20126-1', 'BC817-25W'),
#  ('PHGLS20126-1', 'BC817-40'),
#  ('PHGLS20126-1', 'BC817-40W'),
#  ('PHGLS20126-1', 'BC817W'),
#  ('PHGLS20267-1', '2N4124'),
#  ('PHGLS25601-1', 'BC846'),
#  ('PHGLS25601-1', 'BC846A'),
#  ('PHGLS25601-1', 'BC846AT'),
#  ('PHGLS25601-1', 'BC846AW'),
#  ('PHGLS25601-1', 'BC846B'),
#  ('PHGLS25601-1', 'BC846BT'),
#  ('PHGLS25601-1', 'BC846BW'),
#  ('PHGLS25601-1', 'BC846T'),
#  ('PHGLS25601-1', 'BC846W'),
#  ('PJECS00521-1', 'MMBT3904'),
#  ('PNJIS00254-1', 'BC807-16W'),
#  ('PNJIS00254-1', 'BC807-25W'),
#  ('PNJIS00254-1', 'BC807-40W'),
#  ('PNJIS01186-1', 'BC807-16'),
#  ('PNJIS01186-1', 'BC807-25'),
#  ('PNJIS01186-1', 'BC807-40'),
#  ('PNJIS01305-1', 'MMBT3904'),
#  ('PNJIS01453-1', 'BC846'),
#  ('PNJIS01453-1', 'BC846A'),
#  ('PNJIS01453-1', 'BC846B'),
#  ('PNJIS01453-1', 'BC847'),
#  ('PNJIS01453-1', 'BC847A'),
#  ('PNJIS01453-1', 'BC847B'),
#  ('PNJIS01453-1', 'BC847C'),
#  ('PNJIS01453-1', 'BC848'),
#  ('PNJIS01453-1', 'BC848A'),
#  ('PNJIS01453-1', 'BC848B'),
#  ('PNJIS01453-1', 'BC848C'),
#  ('PNJIS01453-1', 'BC849'),
#  ('PNJIS01453-1', 'BC849B'),
#  ('PNJIS01453-1', 'BC849C'),
#  ('PNJIS01453-1', 'BC850'),
#  ('PNJIS01453-1', 'BC850B'),
#  ('PNJIS01453-1', 'BC850C'),
#  ('PNJIS01593-1', 'BC856'),
#  ('PNJIS01593-1', 'BC856A'),
#  ('PNJIS01593-1', 'BC856B'),
#  ('PNJIS01593-1', 'BC857'),
#  ('PNJIS01593-1', 'BC857A'),
#  ('PNJIS01593-1', 'BC857B'),
#  ('PNJIS01593-1', 'BC857C'),
#  ('PNJIS01593-1', 'BC858'),
#  ('PNJIS01593-1', 'BC858A'),
#  ('PNJIS01593-1', 'BC858B'),
#  ('PNJIS01593-1', 'BC858C'),
#  ('PNJIS01593-1', 'BC859'),
#  ('PNJIS01593-1', 'BC859B'),
#  ('PNJIS01593-1', 'BC859C'),
#  ('RECTS00705-1', 'BC546'),
#  ('RECTS00705-1', 'BC546A'),
#  ('RECTS00705-1', 'BC546B'),
#  ('RECTS00705-1', 'BC546C'),
#  ('RECTS00705-1', 'BC547'),
#  ('RECTS00705-1', 'BC547A'),
#  ('RECTS00705-1', 'BC547B'),
#  ('RECTS00705-1', 'BC547C'),
#  ('RECTS00705-1', 'BC548'),
#  ('RECTS00705-1', 'BC548A'),
#  ('RECTS00705-1', 'BC548B'),
#  ('RECTS00705-1', 'BC548C'),
#  ('RECTS01002-1', 'MMBT3904'),
#  ('RECTS01158-1', 'BC807-25'),
#  ('RECTS01214-1', 'DTC114EUA'),
#  ('RECTS01242-1', 'BC857B'),
#  ('RECTS01325-1', 'DTC114YUA'),
#  ('SANKEN_2SC4886', '2SC4886'),
#  ('SANKEN_2SD2643', '2SD2643'),
#  ('SANKEN_STD01N', 'STD01N'),
#  ('SANKEN_STD01N', 'STD01P'),
#  ('SCSCS02175-1', 'BC546'),
#  ('SCSCS02175-1', 'BC546A'),
#  ('SCSCS02175-1', 'BC546B'),
#  ('SCSCS02175-1', 'BC546C'),
#  ('SCSCS02175-1', 'BC547'),
#  ('SCSCS02175-1', 'BC547A'),
#  ('SCSCS02175-1', 'BC547B'),
#  ('SCSCS02175-1', 'BC547C'),
#  ('SCSCS02175-1', 'BC548'),
#  ('SCSCS02175-1', 'BC548A'),
#  ('SCSCS02175-1', 'BC548B'),
#  ('SCSCS02175-1', 'BC548C'),
#  ('SCSCS02324-1', 'MMBT3904'),
#  ('SGSTS13702-1', 'BC547B'),
#  ('SGSTS13702-1', 'BC547B-AP'),
#  ('SGSTS13702-1', 'BC547C'),
#  ('SGSTS13702-1', 'BC547C-AP'),
#  ('SGSTS13734-1', 'BC337-25'),
#  ('SGSTS13734-1', 'BC337-25-AP'),
#  ('SGSTS13734-1', 'BC337-40'),
#  ('SGSTS13734-1', 'BC337-40-AP'),
#  ('SIEMS01215-1', 'BC856'),
#  ('SIEMS01215-1', 'BC856A'),
#  ('SIEMS01215-1', 'BC856B'),
#  ('SIEMS01215-1', 'BC857'),
#  ('SIEMS01215-1', 'BC857A'),
#  ('SIEMS01215-1', 'BC857B'),
#  ('SIEMS01215-1', 'BC857C'),
#  ('SIEMS01215-1', 'BC858'),
#  ('SIEMS01215-1', 'BC858A'),
#  ('SIEMS01215-1', 'BC858B'),
#  ('SIEMS01215-1', 'BC858C'),
#  ('SIEMS01215-1', 'BC859'),
#  ('SIEMS01215-1', 'BC859A'),
#  ('SIEMS01215-1', 'BC859B'),
#  ('SIEMS01215-1', 'BC859C'),
#  ('SIEMS01215-1', 'BC860'),
#  ('SIEMS01215-1', 'BC860B'),
#  ('SIEMS01215-1', 'BC860C'),
#  ('STMICROELECTRONICS_BUV48A', 'BUV48A'),
#  ('STMICROELECTRONICS_STI130051', 'STI13005-1'),
#  ('TKCGS00622-1', 'DTC114EE'),
#  ('TKCGS00622-1', 'DTC114TE'),
#  ('TKCGS00622-1', 'DTC114YE'),
#  ('TKCGS00622-1', 'DTC123EE'),
#  ('TKCGS00622-1', 'DTC123JE'),
#  ('TKCGS00622-1', 'DTC124EE'),
#  ('TKCGS00622-1', 'DTC124XE'),
#  ('TKCGS00622-1', 'DTC143EE'),
#  ('TKCGS00622-1', 'DTC143TE'),
#  ('TKCGS00622-1', 'DTC143ZE'),
#  ('TKCGS00622-1', 'DTC144EE'),
#  ('TTELECTRONICSOPTEKTECHNOLOGY_2N2222AUATXV', '2N2222AUA'),
#  ('TTELECTRONICSOPTEKTECHNOLOGY_2N2222AUATXV', '2N2222AUATX'),
#  ('TTELECTRONICSOPTEKTECHNOLOGY_2N2222AUATXV', '2N2222AUATXV'),
#  ('TWSCS04757-1', 'BC807-16'),
#  ('TWSCS04757-1', 'BC807-25'),
#  ('TWSCS04757-1', 'BC807-40'),
#  ('UTCLS01324-1', 'MMBT3904'),
#  ('UTCLS01324-1', 'MMBT3904G-AE3-R'),
#  ('UTCLS01324-1', 'MMBT3904G-AL3-R'),
#  ('UTCLS01324-1', 'MMBT3904L-AE3-R'),
#  ('UTCLS01324-1', 'MMBT3904L-AL3-R'),
#  ('UTCLS02155-1', 'BC807'),
#  ('UTCLS02155-1', 'BC807-16'),
#  ('UTCLS02155-1', 'BC807-25'),
#  ('UTCLS02155-1', 'BC807-40'),
#  ('UTCLS02155-1', 'BC808'),
#  ('UTCLS02155-1', 'BC808-16'),
#  ('UTCLS02155-1', 'BC808-25'),
#  ('UTCLS02155-1', 'BC808-40'),
#  ('UTCLS03593-1', 'DTC114E'),
#  ('UTCLS03593-1', 'DTC114EG-AE3-R'),
#  ('UTCLS03593-1', 'DTC114EG-AL3-R'),
#  ('UTCLS03593-1', 'DTC114EG-AN3-R'),
#  ('UTCLS03593-1', 'DTC114EG-T92-B'),
#  ('UTCLS03593-1', 'DTC114EG-T92-K'),
#  ('UTCLS03593-1', 'DTC114EG-T92-R'),
#  ('UTCLS03593-1', 'DTC114EG-T9S-K'),
#  ('UTCLS03593-1', 'DTC114EL-AE3-R'),
#  ('UTCLS03593-1', 'DTC114EL-AL3-R'),
#  ('UTCLS03593-1', 'DTC114EL-AN3-R'),
#  ('UTCLS03593-1', 'DTC114EL-T92-B'),
#  ('UTCLS03593-1', 'DTC114EL-T92-K'),
#  ('UTCLS03593-1', 'DTC114EL-T92-R'),
#  ('UTCLS03593-1', 'DTC114EL-T9S-K'),
#  ('VISHS23888-1', 'BC546'),
#  ('VISHS23888-1', 'BC546A'),
#  ('VISHS23888-1', 'BC546B'),
#  ('VISHS23888-1', 'BC547'),
#  ('VISHS23888-1', 'BC547A'),
#  ('VISHS23888-1', 'BC547B'),
#  ('VISHS23888-1', 'BC547C'),
#  ('VISHS23888-1', 'BC548'),
#  ('VISHS23888-1', 'BC548A'),
#  ('VISHS23888-1', 'BC548B'),
#  ('VISHS23888-1', 'BC548C'),
#  ('VISHS23888-1', 'BC549'),
#  ('VISHS23888-1', 'BC549B'),
#  ('VISHS23888-1', 'BC549C'),
#  ('VSMIS00373-1', 'BC337'),
#  ('VSMIS00373-1', 'BC337-16'),
#  ('VSMIS00373-1', 'BC337-25'),
#  ('VSMIS00373-1', 'BC337-40'),
#  ('VSMIS00373-1', 'BC338'),
#  ('VSMIS00373-1', 'BC338-16'),
#  ('VSMIS00373-1', 'BC338-25'),
#  ('VSMIS00373-1', 'BC338-40'),
#  ('VSMIS03793-1', 'BC817'),
#  ('VSMIS03793-1', 'BC817-16'),
#  ('VSMIS03793-1', 'BC817-25'),
#  ('VSMIS03793-1', 'BC817-40'),
#  ('VSMIS03793-1', 'BC818'),
#  ('VSMIS03793-1', 'BC818-16'),
#  ('VSMIS03793-1', 'BC818-25'),
#  ('VSMIS03793-1', 'BC818-40'),
#  ('WEILS00082-1', 'BC856'),
#  ('WEILS00082-1', 'BC856A'),
#  ('WEILS00082-1', 'BC856B'),
#  ('WEILS00082-1', 'BC857'),
#  ('WEILS00082-1', 'BC857A'),
#  ('WEILS00082-1', 'BC857B'),
#  ('WEILS00082-1', 'BC857C'),
#  ('WEILS00082-1', 'BC858'),
#  ('WEILS00082-1', 'BC858A'),
#  ('WEILS00082-1', 'BC858B'),
#  ('WEILS00082-1', 'BC858C'),
#  ('WEILS00082-1', 'BC859'),
#  ('WEILS00082-1', 'BC859B'),
#  ('WEILS00082-1', 'BC859C'),
#  ('WEITS00252-1', 'BC807-16'),
#  ('WEITS00252-1', 'BC807-25'),
#  ('WEITS00252-1', 'BC807-40'),
#  ('ZETXS01948-1', 'BC856'),
#  ('ZETXS01948-1', 'BC856A-3A'),
#  ('ZETXS01948-1', 'BC856B-Z3B'),
#  ('ZETXS01948-1', 'BC857'),
#  ('ZETXS01948-1', 'BC857A-Z3E'),
#  ('ZETXS01948-1', 'BC857B-3F'),
#  ('ZETXS01948-1', 'BC857C-3G'),
#  ('ZETXS01948-1', 'BC858'),
#  ('ZETXS01948-1', 'BC858A-3J'),
#  ('ZETXS01948-1', 'BC858B-3K'),
#  ('ZETXS01948-1', 'BC858C-3L'),
#  ('ZETXS01948-1', 'BC859'),
#  ('ZETXS01948-1', 'BC859A-Z4A'),
#  ('ZETXS01948-1', 'BC859B-4B'),
#  ('ZETXS01948-1', 'BC859C-Z4C'),
#  ('ZETXS01948-1', 'BC860'),
#  ('ZETXS01948-1', 'BC860A-Z4E'),
#  ('ZETXS01948-1', 'BC860B-4F'),
#  ('ZETXS01948-1', 'BC860C-4GZ')]

# %%
from hardware_utils import entity_to_candidates
from snorkel.lf_helpers import *

entity = FP[0]
print entity
print

matches = entity_to_candidates(entity, candidates)
print "# Matches: %d" % len(matches)
print
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-9d26bf75ac3c> in <module>()
#       2 from snorkel.lf_helpers import *
#       3
# ----> 4 entity = FP[0]
#       5 print entity
#       6 print
#
# IndexError: list index out of range

# %%
from hardware_utils import print_table_info

candidate = matches[1]
# print candidate
# print
print_table_info(candidate.part)
# throttler = get_part_throttler()
# print throttler(candidate)

# %%
c = candidates[100]
print c
print c.part.get_attrib_tokens('top'), c.part.get_attrib_tokens('bottom')
from snorkel.lf_helpers import *
print get_min_col_num(c)
print get_max_col_num(c)
print list(get_row_ngrams(c))
print_table_info(c.part)
# print list(get_vert_ngrams(c.part))

# %%
# from snorkel.lf_helpers import *
# c = candidates[110]
# print c
# get_prev_sibling_tags(c.part).count('p')

# %% [markdown]
# The End.
